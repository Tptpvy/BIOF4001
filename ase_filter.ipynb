# %%
# import libraries
import os
import pandas as pd
import glob
import warnings

# define file paths
year = 2024
DATA_PATH = f"./presumed_infection/{year}/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + "demographic/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*_presumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, creatinine, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"{data_type}/csv/"
        pattern = "*_presumedInfection_" + data_type.title() + "_"
    elif data_type == "creatinine": # alternative filename handling for creatinine
        OUTPUT_PATH = DATA_PATH + f"{data_type}/csv/"
        pattern = "*_presumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + "Lact/csv/"
        pattern = "*_presumedInfection_lactate_"
    else: # alternative filename handling for bili/plt
        OUTPUT_PATH = DATA_PATH + f"Bili_Plt/csv_file/{data_type}/"
        pattern = "*_presumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
    df = date_df[date_df['Reference Key'] == Ref_Key].copy()
    if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
        admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
        deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
        return deadline_date.strftime('%Y-%m-%d')
    return None

# %%
def check_vasopressor(Ref_Key, df, deadline): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin missing
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'Drug Name' in df.columns and 'Prescription Start Date' in df.columns and not df.empty:
        if deadline:
            deadline_date = pd.to_datetime(deadline)
            df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce')
            for drug in vasopressor_list:
                if df['Drug Name'].str.contains(drug, case=True, na=False, regex=False).any():
                    mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False) & (df['Prescription Start Date'] <= deadline_date)
                    if mask.any():
                        return True
    # check: cannot be administered >2 days before blood culture date
    return False

# %%
def check_ventilation(Ref_Key, df, deadline): # check if mechanical ventilation is initiated
    procedure_list = ["Invasive mechanical ventilation (96.70:0)", "Non-invasive mechan ventilation (93.99:2)"] # matches, have other names? Intermitt +ve pressure ventilation (93.91:2) counts?
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'Procedure Name' in df.columns and not df.empty:
        # deadline = patient_date_deadline(Ref_Key, year) # not used
        for procedure in procedure_list:
            for i in range(1, 16):
                if df[f'Procedure HAMDCT Description (rank {i})'] == procedure:
                    return True
    # check: >1 day between ventilation episodes
    return False

# %%
def check_creatinine(Ref_Key, df, deadline): # check if creatinine level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if deadline:
            baseline = df['LIS Result: Numeric Result'].min() # baseline calculated with all data
            deadline_date = pd.to_datetime(deadline).date()
            df = df[df['LIS Reference Date'] <= deadline_date] # filter data before deadline
            if not df.empty:
                for value in df['LIS Result: Numeric Result']:
                    if value >= baseline * 2:
                        return True
    # check: exclude patients with end-stage renal disease
    return False

# %%
def check_bili(Ref_Key, df, deadline): # check if bilirubin level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if deadline:
            baseline = df['LIS Result: Numeric Result'].min() # baseline calculated with all data
            deadline_date = pd.to_datetime(deadline).date()
            df = df[df['LIS Reference Date'] <= deadline_date] # filter data before deadline
            if not df.empty:
                for value in df['LIS Result: Numeric Result']:
                    value_mgdl = value * 0.058467  # Convert umol/L to mg/dL
                    baseline_mgdl = baseline * 0.058467
                    if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                        return True
    return False

# %%
def check_plt(Ref_Key, df, deadline): # check if platelet count is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if deadline:
            deadline_date = pd.to_datetime(deadline).date()
            baseline = df['LIS Result: Numeric Result'].max() # baseline calculated with all data
            df = df[df['LIS Reference Date'] <= deadline_date] # filter data before deadline
            if not df.empty:
                if baseline >= 100:  # baseline must be ≥100 cells/µL
                    for value in df['LIS Result: Numeric Result']:
                        if value < 100 and value <= baseline * 0.5:
                            return True
    return False

# %%
def check_lact(Ref_Key, df, deadline): # check if lactate level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if deadline:
            deadline_date = pd.to_datetime(deadline).date()
            df = df[df['LIS Reference Date'] <= deadline_date] # filter data before deadline
            if not df.empty:
                for value in df['LIS Result: Numeric Result']:
                    if value >= 2.0:
                        return True
    return False

# %%
def check_ase(year):
    KEY_PATH = DATA_PATH + f"demographic/demographic_{year}.csv" # assuming demographic file contains all Reference Keys
    df = pd.read_csv(KEY_PATH )
    keys = df['Reference Key'].unique()
    DATE_PATH = DATA_PATH + f"demographic/demographic_{year}.csv" # admission date placeholder for blood culture date
    date_df = pd.read_csv(DATE_PATH) # deadline date
    INOTROPE_PATH = DATA_PATH + f"inotrope/csv/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    PROCEDURE_PATH = DATA_PATH + f"procedure/csv/procedure_{year}.csv" # no date?
    procedure_df = pd.read_csv(PROCEDURE_PATH)
    CREATININE_PATH = DATA_PATH + f"creatinine/csv/creatinine_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    BILI_PATH = DATA_PATH + f"Bili_Plt/csv_file/bili/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    PLT_PATH = DATA_PATH + f"Bili_Plt/csv_file/plt/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    LACT_PATH = DATA_PATH + f"Lact/csv/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    
    results = []
    for key in keys: 
        deadline = patient_date_deadline(key, date_df) # calculate deadline
        if check_vasopressor(key, inotrope_df, deadline): # check vasopressor
            results.append({'Reference Key': key, 'vasopressor': True})
        else:
            results.append({'Reference Key': key, 'vasopressor': False})

        if check_ventilation(key, procedure_df, deadline): # check ventilation
            results[-1]['ventilation'] = True
        else:
            results[-1]['ventilation'] = False

        if check_creatinine(key, creatinine_df, deadline): # check creatinine
            results[-1]['creatinine'] = True
        else:
            results[-1]['creatinine'] = False

        if check_bili(key, bili_df, deadline): # check bilirubin
            results[-1]['bili'] = True
        else:
            results[-1]['bili'] = False

        if check_plt(key, plt_df, deadline): # check platelet
            results[-1]['plt'] = True
        else: 
            results[-1]['plt'] = False

        if check_lact(key, lact_df, deadline): # check lactate
            results[-1]['lact'] = True
        else: 
            results[-1]['lact'] = False
        
        print(f"Checked Reference Key: {key}")

    results_df = pd.DataFrame(results)
    output_file = os.path.join(DATA_PATH, f'ase_{year}.csv')
    results_df.to_csv(output_file, index=False)
    print(f"ASE vasopressor results saved to {output_file}")

# %%
merge_demographic(year)
data_types = ["inotrope", "procedure", "creatinine", "bili", "plt", "lact"]
for data_type in data_types:
    merge_data(data_type, year)
# Out:
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/demographic/demographic_2024.csv, 714449 total rows
# Processing year: 2024
# Found 34 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/inotrope/csv/inotrope_2024.csv, 147188 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/procedure/csv/procedure_2024.csv, 214215 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/creatinine/csv/creatinine_2024.csv, 1210378 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/Bili_Plt/csv_file/bili/bili_2024.csv, 857258 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/Bili_Plt/csv_file/plt/plt_2024.csv, 1059032 total rows
# Processing year: 2024
# Found 34 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2024/Lact/csv/lact_2024.csv, 90564 total rows

# %%
warnings.filterwarnings('ignore')
check_ase(2024)
# Out:
# Checked Reference Key: 13666
# Checked Reference Key: 14191
# Checked Reference Key: 15199
# Checked Reference Key: 16095
# Checked Reference Key: 18626
# Checked Reference Key: 18903
# Checked Reference Key: 20209
# Checked Reference Key: 25981
# Checked Reference Key: 26473
# Checked Reference Key: 27600
# Checked Reference Key: 28117
# Checked Reference Key: 31709
# Checked Reference Key: 33364
# Checked Reference Key: 35369
# Checked Reference Key: 35830
# Checked Reference Key: 38276
# Checked Reference Key: 38752
# Checked Reference Key: 39561
# Checked Reference Key: 40617
# Checked Reference Key: 41122
# Checked Reference Key: 42540
# Checked Reference Key: 48714
# Checked Reference Key: 51655
# Checked Reference Key: 51682
# Checked Reference Key: 51994
# Checked Reference Key: 53101
# Checked Reference Key: 54297
# Checked Reference Key: 56368
# Checked Reference Key: 57364
# Checked Reference Key: 57407
# Checked Reference Key: 58065
# Checked Reference Key: 59761
# Checked Reference Key: 61749
# Checked Reference Key: 64332
# Checked Reference Key: 64838
# Checked Reference Key: 68129
# Checked Reference Key: 69219
# Checked Reference Key: 69648
# Checked Reference Key: 69898
# Checked Reference Key: 70446
# Checked Reference Key: 74228
# Checked Reference Key: 74243
# Checked Reference Key: 74541
# Checked Reference Key: 75393
# Checked Reference Key: 76362
# Checked Reference Key: 78427
# Checked Reference Key: 80358
# Checked Reference Key: 93381
# Checked Reference Key: 94304
# Checked Reference Key: 95528
# Checked Reference Key: 98350
# Checked Reference Key: 99139
# Checked Reference Key: 103922
# Checked Reference Key: 104245
# Checked Reference Key: 107603
# Checked Reference Key: 108434
# Checked Reference Key: 108490
# Checked Reference Key: 112118
# Checked Reference Key: 119405
# Checked Reference Key: 120697
# Checked Reference Key: 121940
# Checked Reference Key: 123636
# Checked Reference Key: 125718
# Checked Reference Key: 126694
# Checked Reference Key: 126790
# Checked Reference Key: 127262
# Checked Reference Key: 128328
# Checked Reference Key: 131147
# Checked Reference Key: 131635
# Checked Reference Key: 131831
# Checked Reference Key: 138127
# Checked Reference Key: 138797
# Checked Reference Key: 139026
# Checked Reference Key: 139606
# Checked Reference Key: 139807
# Checked Reference Key: 140423
# Checked Reference Key: 140919
# Checked Reference Key: 141506
# Checked Reference Key: 142015
# Checked Reference Key: 142592
# Checked Reference Key: 143874
# Checked Reference Key: 145448
# Checked Reference Key: 147588
# Checked Reference Key: 147847
# Checked Reference Key: 148625
# Checked Reference Key: 149838
# Checked Reference Key: 150651
# Checked Reference Key: 152811
# Checked Reference Key: 156797
# Checked Reference Key: 158952
# Checked Reference Key: 164852
# Checked Reference Key: 165673
# Checked Reference Key: 166444
# Checked Reference Key: 167413
# Checked Reference Key: 169701
# Checked Reference Key: 170116
# Checked Reference Key: 171911
# Checked Reference Key: 172313
# Checked Reference Key: 173693
# Checked Reference Key: 174721
# Checked Reference Key: 174921
# Checked Reference Key: 180574
# Checked Reference Key: 181753
# Checked Reference Key: 184029
# Checked Reference Key: 197884
# Checked Reference Key: 201008
# Checked Reference Key: 205555
# Checked Reference Key: 205914
# Checked Reference Key: 215087
# Checked Reference Key: 215769
# Checked Reference Key: 216544
# Checked Reference Key: 219157
# Checked Reference Key: 220049
# Checked Reference Key: 220218
# Checked Reference Key: 223198
# Checked Reference Key: 225502
# Checked Reference Key: 226012
# Checked Reference Key: 226447
# Checked Reference Key: 227167
# Checked Reference Key: 228145
# Checked Reference Key: 228770
# Checked Reference Key: 229663
# Checked Reference Key: 230607
# Checked Reference Key: 230925
# Checked Reference Key: 231109
# Checked Reference Key: 231447
# Checked Reference Key: 232579
# Checked Reference Key: 233478
# Checked Reference Key: 236423
# Checked Reference Key: 237253
# Checked Reference Key: 240756
# Checked Reference Key: 252731
# Checked Reference Key: 257096
# Checked Reference Key: 259067
# Checked Reference Key: 259956
# Checked Reference Key: 262400
# Checked Reference Key: 263271
# Checked Reference Key: 263760
# Checked Reference Key: 263859
# Checked Reference Key: 266240
# Checked Reference Key: 266612
# Checked Reference Key: 267548
# Checked Reference Key: 268188
# Checked Reference Key: 268681
# Checked Reference Key: 270039
# Checked Reference Key: 270062
# Checked Reference Key: 276283
# Checked Reference Key: 276710
# Checked Reference Key: 277246
# Checked Reference Key: 278318
# Checked Reference Key: 278424
# Checked Reference Key: 285040
# Checked Reference Key: 288034
# Checked Reference Key: 289418
# Checked Reference Key: 290682
# Checked Reference Key: 294290
# Checked Reference Key: 294890
# Checked Reference Key: 299787
# Checked Reference Key: 309284
# Checked Reference Key: 311796
# Checked Reference Key: 311980
# Checked Reference Key: 312821
# Checked Reference Key: 313113
# Checked Reference Key: 315936
# Checked Reference Key: 316455
# Checked Reference Key: 319447
# Checked Reference Key: 319823
# Checked Reference Key: 320440
# Checked Reference Key: 322118
# Checked Reference Key: 322206
# Checked Reference Key: 322578
# Checked Reference Key: 323042
# Checked Reference Key: 323695
# Checked Reference Key: 325318
# Checked Reference Key: 326170
# Checked Reference Key: 327383
# Checked Reference Key: 328098
# Checked Reference Key: 328687
# Checked Reference Key: 330362
# Checked Reference Key: 331970
# Checked Reference Key: 334119
# Checked Reference Key: 334983
# Checked Reference Key: 335231
# Checked Reference Key: 335299
# Checked Reference Key: 336420
# Checked Reference Key: 336782
# Checked Reference Key: 337895
# Checked Reference Key: 339513
# Checked Reference Key: 342090
# Checked Reference Key: 343417
# Checked Reference Key: 343426
# Checked Reference Key: 344380
# Checked Reference Key: 344541
# Checked Reference Key: 345067
# Checked Reference Key: 345130
# Checked Reference Key: 347508
# Checked Reference Key: 348511
# Checked Reference Key: 349284
# Checked Reference Key: 349487
# Checked Reference Key: 350808
# Checked Reference Key: 352399
# Checked Reference Key: 352690
# Checked Reference Key: 353128
# Checked Reference Key: 354237
# Checked Reference Key: 354924
# Checked Reference Key: 356255
# Checked Reference Key: 356639
# Checked Reference Key: 357422
# Checked Reference Key: 359022
# Checked Reference Key: 359395
# Checked Reference Key: 359771
# Checked Reference Key: 359965
# Checked Reference Key: 360312
# Checked Reference Key: 360471
# Checked Reference Key: 361677
# Checked Reference Key: 361947
# Checked Reference Key: 363205
# Checked Reference Key: 363494
# Checked Reference Key: 363706
# Checked Reference Key: 364208
# Checked Reference Key: 364844
# Checked Reference Key: 365879
# Checked Reference Key: 367059
# Checked Reference Key: 368158
# Checked Reference Key: 368202
# Checked Reference Key: 370547
# Checked Reference Key: 372765
# Checked Reference Key: 373355
# Checked Reference Key: 373659
# Checked Reference Key: 374342
# Checked Reference Key: 375101
# Checked Reference Key: 375289
# Checked Reference Key: 375390
# Checked Reference Key: 378743
# Checked Reference Key: 379141
# Checked Reference Key: 379501
# Checked Reference Key: 379752
# Checked Reference Key: 380036
# Checked Reference Key: 380091
# Checked Reference Key: 380172
# Checked Reference Key: 380623
# Checked Reference Key: 381646
# Checked Reference Key: 382411
# Checked Reference Key: 383340
# Checked Reference Key: 383687
# Checked Reference Key: 384838
# Checked Reference Key: 385463
# Checked Reference Key: 385486
# Checked Reference Key: 385681
# Checked Reference Key: 385827
# Checked Reference Key: 386067
# Checked Reference Key: 386303
# Checked Reference Key: 386683
# Checked Reference Key: 387897
# Checked Reference Key: 389259
# Checked Reference Key: 389506
# Checked Reference Key: 390468
# Checked Reference Key: 391490
# Checked Reference Key: 391560
# Checked Reference Key: 391602
# Checked Reference Key: 391920
# Checked Reference Key: 392400
# Checked Reference Key: 392951
# Checked Reference Key: 393150
# Checked Reference Key: 393577
# Checked Reference Key: 394274
# Checked Reference Key: 395271
# Checked Reference Key: 397089
# Checked Reference Key: 397554
# Checked Reference Key: 399079
# Checked Reference Key: 400846
# Checked Reference Key: 401500
# Checked Reference Key: 401770
# Checked Reference Key: 402897
# Checked Reference Key: 403420
# Checked Reference Key: 404307
# Checked Reference Key: 404909
# Checked Reference Key: 405376
# Checked Reference Key: 406386
# Checked Reference Key: 406560
# Checked Reference Key: 407226
# Checked Reference Key: 407667
# Checked Reference Key: 407886
# Checked Reference Key: 408784
# Checked Reference Key: 408923
# Checked Reference Key: 410549
# Checked Reference Key: 410811
# Checked Reference Key: 415561
# Checked Reference Key: 417000
# Checked Reference Key: 417284
# Checked Reference Key: 417598
# Checked Reference Key: 417970
# Checked Reference Key: 418667
# Checked Reference Key: 418944
# Checked Reference Key: 419270
# Checked Reference Key: 420439
# Checked Reference Key: 421653
# Checked Reference Key: 422177
# Checked Reference Key: 424954
# Checked Reference Key: 425831
# Checked Reference Key: 426317
# Checked Reference Key: 427188
# Checked Reference Key: 431856
# Checked Reference Key: 432095
# Checked Reference Key: 432421
# Checked Reference Key: 432775
# Checked Reference Key: 433508
# Checked Reference Key: 435477
# Checked Reference Key: 437857
# Checked Reference Key: 437901
# Checked Reference Key: 438799
# Checked Reference Key: 441327
# Checked Reference Key: 443115
# Checked Reference Key: 443465
# Checked Reference Key: 449648
# Checked Reference Key: 451288
# Checked Reference Key: 452799
# Checked Reference Key: 453082
# Checked Reference Key: 453964
# Checked Reference Key: 455695
# Checked Reference Key: 455837
# Checked Reference Key: 456204
# Checked Reference Key: 468762
# Checked Reference Key: 469371
# Checked Reference Key: 476680
# Checked Reference Key: 478812
# Checked Reference Key: 482218
# Checked Reference Key: 486019
# Checked Reference Key: 511981
# Checked Reference Key: 514914
# Checked Reference Key: 515333
# Checked Reference Key: 521746
# Checked Reference Key: 530283
# Checked Reference Key: 532393
# Checked Reference Key: 535374
# Checked Reference Key: 535848
# Checked Reference Key: 540578
# Checked Reference Key: 543430
# Checked Reference Key: 548486
# Checked Reference Key: 551092
# Checked Reference Key: 553225
# Checked Reference Key: 553533
# Checked Reference Key: 555990
# Checked Reference Key: 556130
# Checked Reference Key: 558489
# Checked Reference Key: 560174
# Checked Reference Key: 561917
# Checked Reference Key: 563357
# Checked Reference Key: 563828
# Checked Reference Key: 565200
# Checked Reference Key: 566190
# Checked Reference Key: 571154
# Checked Reference Key: 572572
# Checked Reference Key: 572652
# Checked Reference Key: 573778
# Checked Reference Key: 574354
# Checked Reference Key: 575271
# Checked Reference Key: 576287
# Checked Reference Key: 576765
# Checked Reference Key: 577054
# Checked Reference Key: 577619
# Checked Reference Key: 582435
# Checked Reference Key: 586294
# Checked Reference Key: 586428
# Checked Reference Key: 587059
# Checked Reference Key: 587317
# Checked Reference Key: 588372
# Checked Reference Key: 588806
# Checked Reference Key: 589101
# Checked Reference Key: 589771
# Checked Reference Key: 590915
# Checked Reference Key: 591436
# Checked Reference Key: 592175
# Checked Reference Key: 592180
# Checked Reference Key: 593037
# Checked Reference Key: 594765
# Checked Reference Key: 596639
# Checked Reference Key: 598791
# Checked Reference Key: 599999
# Checked Reference Key: 600077
# Checked Reference Key: 600372
# Checked Reference Key: 600591
# Checked Reference Key: 601581
# Checked Reference Key: 606047
# Checked Reference Key: 606800
# Checked Reference Key: 607194
# Checked Reference Key: 607479
# Checked Reference Key: 607656
# Checked Reference Key: 609478
# Checked Reference Key: 610835
# Checked Reference Key: 612122
# Checked Reference Key: 614336
# Checked Reference Key: 617240
# Checked Reference Key: 624454
# Checked Reference Key: 631468
# Checked Reference Key: 633535
# Checked Reference Key: 633779
# Checked Reference Key: 639794
# Checked Reference Key: 640594
# Checked Reference Key: 643224
# Checked Reference Key: 644216
# Checked Reference Key: 645178
# Checked Reference Key: 646901
# Checked Reference Key: 647743
# Checked Reference Key: 649616
# Checked Reference Key: 649990
# Checked Reference Key: 650309
# Checked Reference Key: 650835
# Checked Reference Key: 651372
# Checked Reference Key: 652306
# Checked Reference Key: 652744
# Checked Reference Key: 653528
# Checked Reference Key: 654308
# Checked Reference Key: 654975
# Checked Reference Key: 656156
# Checked Reference Key: 656542
# Checked Reference Key: 657738
# Checked Reference Key: 659272
# Checked Reference Key: 660542
# Checked Reference Key: 660630
# Checked Reference Key: 660941
# Checked Reference Key: 661948
# Checked Reference Key: 662484
# Checked Reference Key: 663225
# Checked Reference Key: 665578
# Checked Reference Key: 666672
# Checked Reference Key: 666906
# Checked Reference Key: 670594
# Checked Reference Key: 689430
# Checked Reference Key: 705566
# Checked Reference Key: 705852
# Checked Reference Key: 707061
# Checked Reference Key: 707225
# Checked Reference Key: 708669
# Checked Reference Key: 708799
# Checked Reference Key: 708857
# Checked Reference Key: 709301
# Checked Reference Key: 709913
# Checked Reference Key: 710305
# Checked Reference Key: 710870
# Checked Reference Key: 713143
# Checked Reference Key: 715071
# Checked Reference Key: 715303
# Checked Reference Key: 717106
# Checked Reference Key: 718444
# Checked Reference Key: 718866
# Checked Reference Key: 719386
# Checked Reference Key: 719581
# Checked Reference Key: 724660
# Checked Reference Key: 724788
# Checked Reference Key: 725058
# Checked Reference Key: 726332
# Checked Reference Key: 727452
# Checked Reference Key: 728201
# Checked Reference Key: 728950
# Checked Reference Key: 732889
# Checked Reference Key: 734644
# Checked Reference Key: 735024
# Checked Reference Key: 735092
# Checked Reference Key: 735711
# Checked Reference Key: 737391
# Checked Reference Key: 737472
# Checked Reference Key: 740793
# Checked Reference Key: 743287
# Checked Reference Key: 744923
# Checked Reference Key: 746300
# Checked Reference Key: 746510
# Checked Reference Key: 747295
# Checked Reference Key: 747581
# Checked Reference Key: 749146
# Checked Reference Key: 750646
# Checked Reference Key: 750702
# Checked Reference Key: 753250
# Checked Reference Key: 753399
# Checked Reference Key: 755012
# Checked Reference Key: 755317
# Checked Reference Key: 756971
# Checked Reference Key: 757187
# Checked Reference Key: 757492
# Checked Reference Key: 759092
# Checked Reference Key: 760215
# Checked Reference Key: 762306
# Checked Reference Key: 764185
# Checked Reference Key: 764874
# Checked Reference Key: 765942
# Checked Reference Key: 766289
# Checked Reference Key: 768495
# Checked Reference Key: 770473
# Checked Reference Key: 770485
# Checked Reference Key: 770971
# Checked Reference Key: 775827
# Checked Reference Key: 784826
# Checked Reference Key: 788963
# Checked Reference Key: 789907
# Checked Reference Key: 802621
# Checked Reference Key: 803417
# Checked Reference Key: 804483
# Checked Reference Key: 804517
# Checked Reference Key: 805138
# Checked Reference Key: 807265
# Checked Reference Key: 808064
# Checked Reference Key: 811535
# Checked Reference Key: 813406
# Checked Reference Key: 815316
# Checked Reference Key: 815778
# Checked Reference Key: 815948
# Checked Reference Key: 816549
# Checked Reference Key: 818652
# Checked Reference Key: 819973
# Checked Reference Key: 820013
# Checked Reference Key: 820861
# Checked Reference Key: 822707
# Checked Reference Key: 822778
# Checked Reference Key: 822980
# Checked Reference Key: 825019
# Checked Reference Key: 828439
# Checked Reference Key: 828625
# Checked Reference Key: 829517
# Checked Reference Key: 830789
# Checked Reference Key: 831100
# Checked Reference Key: 832680
# Checked Reference Key: 832682
# Checked Reference Key: 833618
# Checked Reference Key: 836002
# Checked Reference Key: 836462
# Checked Reference Key: 837718
# Checked Reference Key: 839620
# Checked Reference Key: 839693
# Checked Reference Key: 839989
# Checked Reference Key: 840130
# Checked Reference Key: 840162
# Checked Reference Key: 840844
# Checked Reference Key: 841164
# Checked Reference Key: 842146
# Checked Reference Key: 844888
# Checked Reference Key: 845003
# Checked Reference Key: 845152
# Checked Reference Key: 845311
# Checked Reference Key: 845456
# Checked Reference Key: 845555
# Checked Reference Key: 845799
# Checked Reference Key: 847936
# Checked Reference Key: 848399
# Checked Reference Key: 848418
# Checked Reference Key: 848616
# Checked Reference Key: 848974
# Checked Reference Key: 849181
# Checked Reference Key: 849498
# Checked Reference Key: 849546
# Checked Reference Key: 849565
# Checked Reference Key: 850303
# Checked Reference Key: 850541
# Checked Reference Key: 850755
# Checked Reference Key: 851071
# Checked Reference Key: 851186
# Checked Reference Key: 851319
# Checked Reference Key: 851327
# Checked Reference Key: 852302
# Checked Reference Key: 852675
# Checked Reference Key: 857211
# Checked Reference Key: 857259
# Checked Reference Key: 857948
# Checked Reference Key: 859856
# Checked Reference Key: 860464
# Checked Reference Key: 862799
# Checked Reference Key: 864066
# Checked Reference Key: 864352
# Checked Reference Key: 864571
# Checked Reference Key: 864726
# Checked Reference Key: 864817
# Checked Reference Key: 865139
# Checked Reference Key: 865328
# Checked Reference Key: 865367
# Checked Reference Key: 865418
# Checked Reference Key: 866935
# Checked Reference Key: 868398
# Checked Reference Key: 868618
# Checked Reference Key: 868782
# Checked Reference Key: 869080
# Checked Reference Key: 869509
# Checked Reference Key: 869870
# Checked Reference Key: 870098
# Checked Reference Key: 870151
# Checked Reference Key: 870476
# Checked Reference Key: 871371
# Checked Reference Key: 872394
# Checked Reference Key: 874250
# Checked Reference Key: 876336
# Checked Reference Key: 879243
# Checked Reference Key: 879663
# Checked Reference Key: 879960
# Checked Reference Key: 880473
# Checked Reference Key: 880859
# Checked Reference Key: 881907
# Checked Reference Key: 884629
# Checked Reference Key: 887677
# Checked Reference Key: 887738
# Checked Reference Key: 888009
# Checked Reference Key: 889645
# Checked Reference Key: 890236
# Checked Reference Key: 892782
# Checked Reference Key: 893726
# Checked Reference Key: 894362
# Checked Reference Key: 894652
# Checked Reference Key: 894989
# Checked Reference Key: 895233
# Checked Reference Key: 896037
# Checked Reference Key: 896046
# Checked Reference Key: 896139
# Checked Reference Key: 896399
# Checked Reference Key: 896451
# Checked Reference Key: 896674
# Checked Reference Key: 897240
# Checked Reference Key: 901921
# Checked Reference Key: 902874
# Checked Reference Key: 904259
# Checked Reference Key: 904426
# Checked Reference Key: 904524
# Checked Reference Key: 907306
# Checked Reference Key: 909453
# Checked Reference Key: 909582
# Checked Reference Key: 911038
# Checked Reference Key: 912282
# Checked Reference Key: 916742
# Checked Reference Key: 921697
# Checked Reference Key: 922452
# Checked Reference Key: 922704
# Checked Reference Key: 923497
# Checked Reference Key: 924406
# Checked Reference Key: 926192
# Checked Reference Key: 927667
# Checked Reference Key: 927872
# Checked Reference Key: 930716
# Checked Reference Key: 931015
# Checked Reference Key: 932005
# Checked Reference Key: 937097
# Checked Reference Key: 941872
# Checked Reference Key: 953644
# Checked Reference Key: 954825
# Checked Reference Key: 967798
# Checked Reference Key: 968136
# Checked Reference Key: 972655
# Checked Reference Key: 974585
# Checked Reference Key: 974924
# Checked Reference Key: 974927
# Checked Reference Key: 975354
# Checked Reference Key: 977856
# Checked Reference Key: 980641
# Checked Reference Key: 1005443
# Checked Reference Key: 1007038
# Checked Reference Key: 1007456
# Checked Reference Key: 1009810
# Checked Reference Key: 1010514
# Checked Reference Key: 1010599
# Checked Reference Key: 1011370
# Checked Reference Key: 1013920
# Checked Reference Key: 1015083
# Checked Reference Key: 1018052
# Checked Reference Key: 1018113
# Checked Reference Key: 1018940
# Checked Reference Key: 1020824
# Checked Reference Key: 1022239
# Checked Reference Key: 1023071
# Checked Reference Key: 1025969
# Checked Reference Key: 1028278
# Checked Reference Key: 1028955
# Checked Reference Key: 1029557
# Checked Reference Key: 1031226
# Checked Reference Key: 1031455
# Checked Reference Key: 1031968
# Checked Reference Key: 1037669
# Checked Reference Key: 1039441
# Checked Reference Key: 1040285
# Checked Reference Key: 1040339
# Checked Reference Key: 1040537
# Checked Reference Key: 1044183
# Checked Reference Key: 1044592
# Checked Reference Key: 1045309
# Checked Reference Key: 1045353
# Checked Reference Key: 1047510
# Checked Reference Key: 1048668
# Checked Reference Key: 1048686
# Checked Reference Key: 1048996
# Checked Reference Key: 1051829
# Checked Reference Key: 1053774
# Checked Reference Key: 1054193
# Checked Reference Key: 1055759
# Checked Reference Key: 1056841
# Checked Reference Key: 1057752
# Checked Reference Key: 1058162
# Checked Reference Key: 1059665
# Checked Reference Key: 1060418
# Checked Reference Key: 1060772
# Checked Reference Key: 1061040
# Checked Reference Key: 1061066
# Checked Reference Key: 1061079
# Checked Reference Key: 1061111
# Checked Reference Key: 1064181
# Checked Reference Key: 1065557
# Checked Reference Key: 1066256
# Checked Reference Key: 1066478
# Checked Reference Key: 1066820
# Checked Reference Key: 1068386
# Checked Reference Key: 1068679
# Checked Reference Key: 1068903
# Checked Reference Key: 1070399
# Checked Reference Key: 1070875
# Checked Reference Key: 1070886
# Checked Reference Key: 1070932
# Checked Reference Key: 1071438
# Checked Reference Key: 1071466
# Checked Reference Key: 1072691
# Checked Reference Key: 1073810
# Checked Reference Key: 1073832
# Checked Reference Key: 1073864
# Checked Reference Key: 1074454
# Checked Reference Key: 1076291
# Checked Reference Key: 1077851
# Checked Reference Key: 1078715
# Checked Reference Key: 1080074
# Checked Reference Key: 1080905
# Checked Reference Key: 1080962
# Checked Reference Key: 1082894
# Checked Reference Key: 1083629
# Checked Reference Key: 1083810
# Checked Reference Key: 1084357
# Checked Reference Key: 1086360
# Checked Reference Key: 1087602
# Checked Reference Key: 1089184
# Checked Reference Key: 1092412
# Checked Reference Key: 1093842
# Checked Reference Key: 1094436
# Checked Reference Key: 1101397
# Checked Reference Key: 1103909
# Checked Reference Key: 1103942
# Checked Reference Key: 1103978
# Checked Reference Key: 1105658
# Checked Reference Key: 1105863
# Checked Reference Key: 1109769
# Checked Reference Key: 1109891
# Checked Reference Key: 1111116
# Checked Reference Key: 1111316
# Checked Reference Key: 1111775
# Checked Reference Key: 1113368
# Checked Reference Key: 1114396
# Checked Reference Key: 1114487
# Checked Reference Key: 1114869
# Checked Reference Key: 1115666
# Checked Reference Key: 1117630
# Checked Reference Key: 1118337
# Checked Reference Key: 1118339
# Checked Reference Key: 1118979
# Checked Reference Key: 1119798
# Checked Reference Key: 1120815
# Checked Reference Key: 1121455
# Checked Reference Key: 1122479
# Checked Reference Key: 1123530
# Checked Reference Key: 1124168
# Checked Reference Key: 1124629
# Checked Reference Key: 1124836
# Checked Reference Key: 1125363
# Checked Reference Key: 1125495
# Checked Reference Key: 1125706
# Checked Reference Key: 1126107
# Checked Reference Key: 1126267
# Checked Reference Key: 1126813
# Checked Reference Key: 1127972
# Checked Reference Key: 1128131
# Checked Reference Key: 1128340
# Checked Reference Key: 1128750
# Checked Reference Key: 1129670
# Checked Reference Key: 1129887
# Checked Reference Key: 1132014
# Checked Reference Key: 1132379
# Checked Reference Key: 1133069
# Checked Reference Key: 1133171
# Checked Reference Key: 1134860
# Checked Reference Key: 1137286
# Checked Reference Key: 1142116
# Checked Reference Key: 1144412
# Checked Reference Key: 1144518
# Checked Reference Key: 1144724
# Checked Reference Key: 1145880
# Checked Reference Key: 1147112
# Checked Reference Key: 1147125
# Checked Reference Key: 1148348
# Checked Reference Key: 1148689
# Checked Reference Key: 1149501
# Checked Reference Key: 1158277
# Checked Reference Key: 1165278
# Checked Reference Key: 1170018
# Checked Reference Key: 1170312
# Checked Reference Key: 1170801
# Checked Reference Key: 1171125
# Checked Reference Key: 1172034
# Checked Reference Key: 1172466
# Checked Reference Key: 1172745
# Checked Reference Key: 1174058
# Checked Reference Key: 1176066
# Checked Reference Key: 1176375
# Checked Reference Key: 1177560
# Checked Reference Key: 1180349
# Checked Reference Key: 1186804
# Checked Reference Key: 1192095
# Checked Reference Key: 1194426
# Checked Reference Key: 1195553
# Checked Reference Key: 1207896
# Checked Reference Key: 1208106
# Checked Reference Key: 1208892
# Checked Reference Key: 1209103
# Checked Reference Key: 1245324
# Checked Reference Key: 1245562
# Checked Reference Key: 1245745
# Checked Reference Key: 1246173
# Checked Reference Key: 1248230
# Checked Reference Key: 1248354
# Checked Reference Key: 1248926
# Checked Reference Key: 1249060
# Checked Reference Key: 1249135
# Checked Reference Key: 1249995
# Checked Reference Key: 1251117
# Checked Reference Key: 1251178
# Checked Reference Key: 1251208
# Checked Reference Key: 1251281
# Checked Reference Key: 1251326
# Checked Reference Key: 1251434
# Checked Reference Key: 1252059
# Checked Reference Key: 1252143
# Checked Reference Key: 1252721
# Checked Reference Key: 1253208
# Checked Reference Key: 1253423
# Checked Reference Key: 1254284
# Checked Reference Key: 1254422
# Checked Reference Key: 1255260
# Checked Reference Key: 1255308
# Checked Reference Key: 1255737
# Checked Reference Key: 1256660
# Checked Reference Key: 1262169
# Checked Reference Key: 1263799
# Checked Reference Key: 1264845
# Checked Reference Key: 1265454
# Checked Reference Key: 1265659
# Checked Reference Key: 1266620
# Checked Reference Key: 1267678
# Checked Reference Key: 1270934
# Checked Reference Key: 1271054
# Checked Reference Key: 1271735
# Checked Reference Key: 1272942
# Checked Reference Key: 1273289
# Checked Reference Key: 1274511
# Checked Reference Key: 1276935
# Checked Reference Key: 1278621
# Checked Reference Key: 1282278
# Checked Reference Key: 1284938
# Checked Reference Key: 1286256
# Checked Reference Key: 1288106
# Checked Reference Key: 1289283
# Checked Reference Key: 1291951
# Checked Reference Key: 1292328
# Checked Reference Key: 1292382
# Checked Reference Key: 1293685
# Checked Reference Key: 1293688
# Checked Reference Key: 1299984
# Checked Reference Key: 1300706
# Checked Reference Key: 1301055
# Checked Reference Key: 1301235
# Checked Reference Key: 1303598
# Checked Reference Key: 1305245
# Checked Reference Key: 1306600
# Checked Reference Key: 1306909
# Checked Reference Key: 1311959
# Checked Reference Key: 1315436
# Checked Reference Key: 1317897
# Checked Reference Key: 1318763
# Checked Reference Key: 1320397
# Checked Reference Key: 1323659
# Checked Reference Key: 1324091
# Checked Reference Key: 1324712
# Checked Reference Key: 1325438
# Checked Reference Key: 1325764
# Checked Reference Key: 1326148
# Checked Reference Key: 1327146
# Checked Reference Key: 1327542
# Checked Reference Key: 1327757
# Checked Reference Key: 1329412
# Checked Reference Key: 1329996
# Checked Reference Key: 1330147
# Checked Reference Key: 1331252
# Checked Reference Key: 1331529
# Checked Reference Key: 1331969
# Checked Reference Key: 1333233
# Checked Reference Key: 1335079
# Checked Reference Key: 1340471
# Checked Reference Key: 1340494
# Checked Reference Key: 1340803
# Checked Reference Key: 1346924
# Checked Reference Key: 1349054
# Checked Reference Key: 1349502
# Checked Reference Key: 1350032
# Checked Reference Key: 1350105
# Checked Reference Key: 1350293
# Checked Reference Key: 1350625
# Checked Reference Key: 1351479
# Checked Reference Key: 1353783
# Checked Reference Key: 1353986
# Checked Reference Key: 1354697
# Checked Reference Key: 1355628
# Checked Reference Key: 1355820
# Checked Reference Key: 1356925
# Checked Reference Key: 1359797
# Checked Reference Key: 1363190
# Checked Reference Key: 1364582
# Checked Reference Key: 1364972
# Checked Reference Key: 1365983
# Checked Reference Key: 1367018
# Checked Reference Key: 1367357
# Checked Reference Key: 1370602
# Checked Reference Key: 1371615
# Checked Reference Key: 1376191
# Checked Reference Key: 1376570
# Checked Reference Key: 1377994
# Checked Reference Key: 1382305
# Checked Reference Key: 1385905
# Checked Reference Key: 1393443
# Checked Reference Key: 1402583
# Checked Reference Key: 1404591
# Checked Reference Key: 1412765
# Checked Reference Key: 1419439
# Checked Reference Key: 1422213
# Checked Reference Key: 1423792
# Checked Reference Key: 1426166
# Checked Reference Key: 1466008
# Checked Reference Key: 1466218
# Checked Reference Key: 1467344
# Checked Reference Key: 1469328
# Checked Reference Key: 1469822
# Checked Reference Key: 1469919
# Checked Reference Key: 1470127
# Checked Reference Key: 1471905
# Checked Reference Key: 1472420
# Checked Reference Key: 1473179
# Checked Reference Key: 1473250
# Checked Reference Key: 1474363
# Checked Reference Key: 1474594
# Checked Reference Key: 1474826
# Checked Reference Key: 1476281
# Checked Reference Key: 1477941
# Checked Reference Key: 1479119
# Checked Reference Key: 1479928
# Checked Reference Key: 1479945
# Checked Reference Key: 1480524
# Checked Reference Key: 1480685
# Checked Reference Key: 1480758
# Checked Reference Key: 1481142
# Checked Reference Key: 1481347
# Checked Reference Key: 1482158
# Checked Reference Key: 1482222
# Checked Reference Key: 1482380
# Checked Reference Key: 1482573
# Checked Reference Key: 1483294
# Checked Reference Key: 1483427
# Checked Reference Key: 1484461
# Checked Reference Key: 1484608
# Checked Reference Key: 1484996
# Checked Reference Key: 1485976
# Checked Reference Key: 1485998
# Checked Reference Key: 1486132
# Checked Reference Key: 1488135
# Checked Reference Key: 1488187
# Checked Reference Key: 1488309
# Checked Reference Key: 1489385
# Checked Reference Key: 1490097
# Checked Reference Key: 1490191
# Checked Reference Key: 1491559
# Checked Reference Key: 1493635
# Checked Reference Key: 1494110
# Checked Reference Key: 1494494
# Checked Reference Key: 1496905
# Checked Reference Key: 1497086
# Checked Reference Key: 1497848
# Checked Reference Key: 1498148
# Checked Reference Key: 1498428
# Checked Reference Key: 1498918
# Checked Reference Key: 1500484
# Checked Reference Key: 1501097
# Checked Reference Key: 1501328
# Checked Reference Key: 1502764
# Checked Reference Key: 1502878
# Checked Reference Key: 1502908
# Checked Reference Key: 1503383
# Checked Reference Key: 1503447
# Checked Reference Key: 1503532
# Checked Reference Key: 1503628
# Checked Reference Key: 1504330
# Checked Reference Key: 1504948
# Checked Reference Key: 1504984
# Checked Reference Key: 1505336
# Checked Reference Key: 1505572
# Checked Reference Key: 1505670
# Checked Reference Key: 1505879
# Checked Reference Key: 1506597
# Checked Reference Key: 1507092
# Checked Reference Key: 1508034
# Checked Reference Key: 1508521
# Checked Reference Key: 1508778
# Checked Reference Key: 1511919
# Checked Reference Key: 1513156
# Checked Reference Key: 1515610
# Checked Reference Key: 1515637
# Checked Reference Key: 1515754
# Checked Reference Key: 1515788
# Checked Reference Key: 1516815
# Checked Reference Key: 1517636
# Checked Reference Key: 1518561
# Checked Reference Key: 1519397
# Checked Reference Key: 1521476
# Checked Reference Key: 1522981
# Checked Reference Key: 1524215
# Checked Reference Key: 1525571
# Checked Reference Key: 1526119
# Checked Reference Key: 1526453
# Checked Reference Key: 1528818
# Checked Reference Key: 1528846
# Checked Reference Key: 1529178
# Checked Reference Key: 1529585
# Checked Reference Key: 1529665
# Checked Reference Key: 1531032
# Checked Reference Key: 1532645
# Checked Reference Key: 1532838
# Checked Reference Key: 1533815
# Checked Reference Key: 1534285
# Checked Reference Key: 1535373
# Checked Reference Key: 1536303
# Checked Reference Key: 1536524
# Checked Reference Key: 1538945
# Checked Reference Key: 1539654
# Checked Reference Key: 1540472
# Checked Reference Key: 1541628
# Checked Reference Key: 1545696
# Checked Reference Key: 1549336
# Checked Reference Key: 1550106
# Checked Reference Key: 1556646
# Checked Reference Key: 1557569
# Checked Reference Key: 1562580
# Checked Reference Key: 1567023
# Checked Reference Key: 1568238
# Checked Reference Key: 1569280
# Checked Reference Key: 1569307
# Checked Reference Key: 1572667
# Checked Reference Key: 1573923
# Checked Reference Key: 1575550
# Checked Reference Key: 1577102
# Checked Reference Key: 1578219
# Checked Reference Key: 1594980
# Checked Reference Key: 1595181
# Checked Reference Key: 1596391
# Checked Reference Key: 1597670
# Checked Reference Key: 1600024
# Checked Reference Key: 1602326
# Checked Reference Key: 1602507
# Checked Reference Key: 1602712
# Checked Reference Key: 1606032
# Checked Reference Key: 1606170
# Checked Reference Key: 1606833
# Checked Reference Key: 1606925
# Checked Reference Key: 1608822
# Checked Reference Key: 1610923
# Checked Reference Key: 1611875
# Checked Reference Key: 1613090
# Checked Reference Key: 1614800
# Checked Reference Key: 1617161
# Checked Reference Key: 1617589
# Checked Reference Key: 1617645
# Checked Reference Key: 1617896
# Checked Reference Key: 1618287
# Checked Reference Key: 1620494
# Checked Reference Key: 1621703
# Checked Reference Key: 1623344
# Checked Reference Key: 1623831
# Checked Reference Key: 1625378
# Checked Reference Key: 1625398
# Checked Reference Key: 1628232
# Checked Reference Key: 1634253
# Checked Reference Key: 1636813
# Checked Reference Key: 1637208
# Checked Reference Key: 1638370
# Checked Reference Key: 1639028
# Checked Reference Key: 1644969
# Checked Reference Key: 1645661
# Checked Reference Key: 1646020
# Checked Reference Key: 1648957
# Checked Reference Key: 1649225
# Checked Reference Key: 1650442
# Checked Reference Key: 1650912
# Checked Reference Key: 1651432
# Checked Reference Key: 1651639
# Checked Reference Key: 1652809
# Checked Reference Key: 1653577
# Checked Reference Key: 1654029
# Checked Reference Key: 1656207
# Checked Reference Key: 1657121
# Checked Reference Key: 1658328
# Checked Reference Key: 1658663
# Checked Reference Key: 1658680
# Checked Reference Key: 1658823
# Checked Reference Key: 1659082
# Checked Reference Key: 1659289
# Checked Reference Key: 1659637
# Checked Reference Key: 1659979
# Checked Reference Key: 1662324
# Checked Reference Key: 1662516
# Checked Reference Key: 1662850
# Checked Reference Key: 1663833
# Checked Reference Key: 1665293
# Checked Reference Key: 1665507
# Checked Reference Key: 1665830
# Checked Reference Key: 1667506
# Checked Reference Key: 1667885
# Checked Reference Key: 1667888
# Checked Reference Key: 1668372
# Checked Reference Key: 1669749
# Checked Reference Key: 1673850
# Checked Reference Key: 1681844
# Checked Reference Key: 1682938
# Checked Reference Key: 1688130
# Checked Reference Key: 1688189
# Checked Reference Key: 1688554
# Checked Reference Key: 1688560
# Checked Reference Key: 1689146
# Checked Reference Key: 1689642
# Checked Reference Key: 1690488
# Checked Reference Key: 1690996
# Checked Reference Key: 1692542
# Checked Reference Key: 1693018
# Checked Reference Key: 1693782
# Checked Reference Key: 1696665
# Checked Reference Key: 1696787
# Checked Reference Key: 1697775
# Checked Reference Key: 1701732
# Checked Reference Key: 1703355
# Checked Reference Key: 1704623
# Checked Reference Key: 1710622
# Checked Reference Key: 1712335
# Checked Reference Key: 1714751
# Checked Reference Key: 1715149
# Checked Reference Key: 1717563
# Checked Reference Key: 1726434
# Checked Reference Key: 1743929
# Checked Reference Key: 1744247
# Checked Reference Key: 1752104
# Checked Reference Key: 1753156
# Checked Reference Key: 1762490
# Checked Reference Key: 1764286
# Checked Reference Key: 1792197
# Checked Reference Key: 1794123
# Checked Reference Key: 1795440
# Checked Reference Key: 1796563
# Checked Reference Key: 1797671
# Checked Reference Key: 1797794
# Checked Reference Key: 1798361
# Checked Reference Key: 1798684
# Checked Reference Key: 1800818
# Checked Reference Key: 1801469
# Checked Reference Key: 1801974
# Checked Reference Key: 1802021
# Checked Reference Key: 1802041
# Checked Reference Key: 1802164
# Checked Reference Key: 1802891
# Checked Reference Key: 1802945
# Checked Reference Key: 1804228
# Checked Reference Key: 1804674
# Checked Reference Key: 1805185
# Checked Reference Key: 1805595
# Checked Reference Key: 1808993
# Checked Reference Key: 1809679
# Checked Reference Key: 1810108
# Checked Reference Key: 1811511
# Checked Reference Key: 1811633
# Checked Reference Key: 1812154
# Checked Reference Key: 1814970
# Checked Reference Key: 1816150
# Checked Reference Key: 1818590
# Checked Reference Key: 1820540
# Checked Reference Key: 1821912
# Checked Reference Key: 1822131
# Checked Reference Key: 1822295
# Checked Reference Key: 1822580
# Checked Reference Key: 1823450
# Checked Reference Key: 1823487
# Checked Reference Key: 1827309
# Checked Reference Key: 1827329
# Checked Reference Key: 1830393
# Checked Reference Key: 1830807
# Checked Reference Key: 1830930
# Checked Reference Key: 1831822
# Checked Reference Key: 1832561
# Checked Reference Key: 1832614
# Checked Reference Key: 1832626
# Checked Reference Key: 1832780
# Checked Reference Key: 1834218
# Checked Reference Key: 1834433
# Checked Reference Key: 1835685
# Checked Reference Key: 1835746
# Checked Reference Key: 1838726
# Checked Reference Key: 1840417
# Checked Reference Key: 1840420
# Checked Reference Key: 1842146
# Checked Reference Key: 1844095
# Checked Reference Key: 1844905
# Checked Reference Key: 1845736
# Checked Reference Key: 1848787
# Checked Reference Key: 1849696
# Checked Reference Key: 1849961
# Checked Reference Key: 1850638
# Checked Reference Key: 1850804
# Checked Reference Key: 1851026
# Checked Reference Key: 1851818
# Checked Reference Key: 1852428
# Checked Reference Key: 1852952
# Checked Reference Key: 1853590
# Checked Reference Key: 1854858
# Checked Reference Key: 1855816
# Checked Reference Key: 1856053
# Checked Reference Key: 1856577
# Checked Reference Key: 1857395
# Checked Reference Key: 1857912
# Checked Reference Key: 1858303
# Checked Reference Key: 1859368
# Checked Reference Key: 1859575
# Checked Reference Key: 1861852
# Checked Reference Key: 1862909
# Checked Reference Key: 1863321
# Checked Reference Key: 1864749
# Checked Reference Key: 1865309
# Checked Reference Key: 1865379
# Checked Reference Key: 1865652
# Checked Reference Key: 1866363
# Checked Reference Key: 1867926
# Checked Reference Key: 1875203
# Checked Reference Key: 1876074
# Checked Reference Key: 1884907
# Checked Reference Key: 1884983
# Checked Reference Key: 1885052
# Checked Reference Key: 1885106
# Checked Reference Key: 1886122
# Checked Reference Key: 1886298
# Checked Reference Key: 1887932
# Checked Reference Key: 1890367
# Checked Reference Key: 1891851
# Checked Reference Key: 1892821
# Checked Reference Key: 1894699
# Checked Reference Key: 1894752
# Checked Reference Key: 1895676
# Checked Reference Key: 1895885
# Checked Reference Key: 1896864
# Checked Reference Key: 1898951
# Checked Reference Key: 1901092
# Checked Reference Key: 1902548
# Checked Reference Key: 1903335
# Checked Reference Key: 1904356
# Checked Reference Key: 1907393
# Checked Reference Key: 1907633
# Checked Reference Key: 1909604
# Checked Reference Key: 1912992
# Checked Reference Key: 1915346
# Checked Reference Key: 1920315
# Checked Reference Key: 1921105
# Checked Reference Key: 1925071
# Checked Reference Key: 1925772
# Checked Reference Key: 1926745
# Checked Reference Key: 1927330
# Checked Reference Key: 1936026
# Checked Reference Key: 1937867
# Checked Reference Key: 1946283
# Checked Reference Key: 1946844
# Checked Reference Key: 1947231
# Checked Reference Key: 1951931
# Checked Reference Key: 2003797
# Checked Reference Key: 2004256
# Checked Reference Key: 2004978
# Checked Reference Key: 2006354
# Checked Reference Key: 2006720
# Checked Reference Key: 2008602
# Checked Reference Key: 2009880
# Checked Reference Key: 2010540
# Checked Reference Key: 2012193
# Checked Reference Key: 2012229
# Checked Reference Key: 2012617
# Checked Reference Key: 2012967
# Checked Reference Key: 2013666
# Checked Reference Key: 2013788
# Checked Reference Key: 2016473
# Checked Reference Key: 2017396
# Checked Reference Key: 2018548
# Checked Reference Key: 2020033
# Checked Reference Key: 2020826
# Checked Reference Key: 2021578
# Checked Reference Key: 2022057
# Checked Reference Key: 2022121
# Checked Reference Key: 2022265
# Checked Reference Key: 2022693
# Checked Reference Key: 2024394
# Checked Reference Key: 2025041
# Checked Reference Key: 2030024
# Checked Reference Key: 2031359
# Checked Reference Key: 2031467
# Checked Reference Key: 2031554
# Checked Reference Key: 2033616
# Checked Reference Key: 2033774
# Checked Reference Key: 2034190
# Checked Reference Key: 2039835
# Checked Reference Key: 2039931
# Checked Reference Key: 2042010
# Checked Reference Key: 2047211
# Checked Reference Key: 2050895
# Checked Reference Key: 2057123
# Checked Reference Key: 2057478
# Checked Reference Key: 2059736
# Checked Reference Key: 2060099
# Checked Reference Key: 2060124
# Checked Reference Key: 2060471
# Checked Reference Key: 2060815
# Checked Reference Key: 2060968
# Checked Reference Key: 2061121
# Checked Reference Key: 2061222
# Checked Reference Key: 2061293
# Checked Reference Key: 2061561
# Checked Reference Key: 2062534
# Checked Reference Key: 2063153
# Checked Reference Key: 2063987
# Checked Reference Key: 2063990
# Checked Reference Key: 2064106
# Checked Reference Key: 2064599
# Checked Reference Key: 2064722
# Checked Reference Key: 2065229
# Checked Reference Key: 2065765
# Checked Reference Key: 2066759
# Checked Reference Key: 2067805
# Checked Reference Key: 2069043
# Checked Reference Key: 2070202
# Checked Reference Key: 2071621
# Checked Reference Key: 2074014
# Checked Reference Key: 2075556
# Checked Reference Key: 2077940
# Checked Reference Key: 2078288
# Checked Reference Key: 2079028
# Checked Reference Key: 2079067
# Checked Reference Key: 2079390
# Checked Reference Key: 2083593
# Checked Reference Key: 2085606
# Checked Reference Key: 2086065
# Checked Reference Key: 2086566
# Checked Reference Key: 2088930
# Checked Reference Key: 2090826
# Checked Reference Key: 2091352
# Checked Reference Key: 2091555
# Checked Reference Key: 2096821
# Checked Reference Key: 2103776
# Checked Reference Key: 2104571
# Checked Reference Key: 2105405
# Checked Reference Key: 2106900
# Checked Reference Key: 2107136
# Checked Reference Key: 2107582
# Checked Reference Key: 2107892
# Checked Reference Key: 2108235
# Checked Reference Key: 2108482
# Checked Reference Key: 2109029
# Checked Reference Key: 2109668
# Checked Reference Key: 2111448
# Checked Reference Key: 2111823
# Checked Reference Key: 2112333
# Checked Reference Key: 2112748
# Checked Reference Key: 2113113
# Checked Reference Key: 2113330
# Checked Reference Key: 2113527
# Checked Reference Key: 2115895
# Checked Reference Key: 2116447
# Checked Reference Key: 2116709
# Checked Reference Key: 2117005
# Checked Reference Key: 2117283
# Checked Reference Key: 2117470
# Checked Reference Key: 2118238
# Checked Reference Key: 2118552
# Checked Reference Key: 2118671
# Checked Reference Key: 2119231
# Checked Reference Key: 2119482
# Checked Reference Key: 2119509
# Checked Reference Key: 2119654
# Checked Reference Key: 2119918
# Checked Reference Key: 2120140
# Checked Reference Key: 2120357
# Checked Reference Key: 2121191
# Checked Reference Key: 2121254
# Checked Reference Key: 2121727
# Checked Reference Key: 2121775
# Checked Reference Key: 2122475
# Checked Reference Key: 2122491
# Checked Reference Key: 2123578
# Checked Reference Key: 2123867
# Checked Reference Key: 2125071
# Checked Reference Key: 2125892
# Checked Reference Key: 2126647
# Checked Reference Key: 2127096
# Checked Reference Key: 2127180
# Checked Reference Key: 2127683
# Checked Reference Key: 2128459
# Checked Reference Key: 2129297
# Checked Reference Key: 2129669
# Checked Reference Key: 2130160
# Checked Reference Key: 2133692
# Checked Reference Key: 2133928
# Checked Reference Key: 2134035
# Checked Reference Key: 2134078
# Checked Reference Key: 2134320
# Checked Reference Key: 2134471
# Checked Reference Key: 2135420
# Checked Reference Key: 2136676
# Checked Reference Key: 2137325
# Checked Reference Key: 2138633
# Checked Reference Key: 2139128
# Checked Reference Key: 2139351
# Checked Reference Key: 2139353
# Checked Reference Key: 2139858
# Checked Reference Key: 2140438
# Checked Reference Key: 2140597
# Checked Reference Key: 2140853
# Checked Reference Key: 2141008
# Checked Reference Key: 2141805
# Checked Reference Key: 2141985
# Checked Reference Key: 2142217
# Checked Reference Key: 2143038
# Checked Reference Key: 2143948
# Checked Reference Key: 2144165
# Checked Reference Key: 2146016
# Checked Reference Key: 2151605
# Checked Reference Key: 2155363
# Checked Reference Key: 2156202
# Checked Reference Key: 2156847
# Checked Reference Key: 2157120
# Checked Reference Key: 2161035
# Checked Reference Key: 2161871
# Checked Reference Key: 2167752
# Checked Reference Key: 2168989
# Checked Reference Key: 2172274
# Checked Reference Key: 2172597
# Checked Reference Key: 2173142
# Checked Reference Key: 2173403
# Checked Reference Key: 2173653
# Checked Reference Key: 2173875
# Checked Reference Key: 2174012
# Checked Reference Key: 2174077
# Checked Reference Key: 2175691
# Checked Reference Key: 2175800
# Checked Reference Key: 2176337
# Checked Reference Key: 2176796
# Checked Reference Key: 2177009
# Checked Reference Key: 2177410
# Checked Reference Key: 2180053
# Checked Reference Key: 2181426
# Checked Reference Key: 2181541
# Checked Reference Key: 2181773
# Checked Reference Key: 2183739
# Checked Reference Key: 2185017
# Checked Reference Key: 2185261
# Checked Reference Key: 2186873
# Checked Reference Key: 2188539
# Checked Reference Key: 2189022
# Checked Reference Key: 2196382
# Checked Reference Key: 2196878
# Checked Reference Key: 2201708
# Checked Reference Key: 2202211
# Checked Reference Key: 2206305
# Checked Reference Key: 2207612
# Checked Reference Key: 2208343
# Checked Reference Key: 2211221
# Checked Reference Key: 2211643
# Checked Reference Key: 2212257
# Checked Reference Key: 2213314
# Checked Reference Key: 2213584
# Checked Reference Key: 2214449
# Checked Reference Key: 2214807
# Checked Reference Key: 2214986
# Checked Reference Key: 2218715
# Checked Reference Key: 2220368
# Checked Reference Key: 2221578
# Checked Reference Key: 2221962
# Checked Reference Key: 2222878
# Checked Reference Key: 2229802
# Checked Reference Key: 2234900
# Checked Reference Key: 2239870
# Checked Reference Key: 2245861
# Checked Reference Key: 2246774
# Checked Reference Key: 2248524
# Checked Reference Key: 2263418
# Checked Reference Key: 2273387
# Checked Reference Key: 2279687
# Checked Reference Key: 2287986
# Checked Reference Key: 2288070
# Checked Reference Key: 2288377
# Checked Reference Key: 2291322
# Checked Reference Key: 2296147
# Checked Reference Key: 2319957
# Checked Reference Key: 2320047
# Checked Reference Key: 2320080
# Checked Reference Key: 2320392
# Checked Reference Key: 2320954
# Checked Reference Key: 2321434
# Checked Reference Key: 2321444
# Checked Reference Key: 2321447
# Checked Reference Key: 2321544
# Checked Reference Key: 2321806
# Checked Reference Key: 2322449
# Checked Reference Key: 2322636
# Checked Reference Key: 2323377
# Checked Reference Key: 2324066
# Checked Reference Key: 2325141
# Checked Reference Key: 2326557
# Checked Reference Key: 2328252
# Checked Reference Key: 2328792
# Checked Reference Key: 2328848
# Checked Reference Key: 2329178
# Checked Reference Key: 2330310
# Checked Reference Key: 2330598
# Checked Reference Key: 2331520
# Checked Reference Key: 2332405
# Checked Reference Key: 2332865
# Checked Reference Key: 2333214
# Checked Reference Key: 2333923
# Checked Reference Key: 2333950
# Checked Reference Key: 2334670
# Checked Reference Key: 2334754
# Checked Reference Key: 2335047
# Checked Reference Key: 2335310
# Checked Reference Key: 2337135
# Checked Reference Key: 2337208
# Checked Reference Key: 2337246
# Checked Reference Key: 2337560
# Checked Reference Key: 2338124
# Checked Reference Key: 2338243
# Checked Reference Key: 2339108
# Checked Reference Key: 2339678
# Checked Reference Key: 2341518
# Checked Reference Key: 2342147
# Checked Reference Key: 2342239
# Checked Reference Key: 2342707
# Checked Reference Key: 2344869
# Checked Reference Key: 2344926
# Checked Reference Key: 2345294
# Checked Reference Key: 2346316
# Checked Reference Key: 2346327
# Checked Reference Key: 2346962
# Checked Reference Key: 2348311
# Checked Reference Key: 2348723
# Checked Reference Key: 2349087
# Checked Reference Key: 2349476
# Checked Reference Key: 2350579
# Checked Reference Key: 2350720
# Checked Reference Key: 2351046
# Checked Reference Key: 2352164
# Checked Reference Key: 2353553
# Checked Reference Key: 2354173
# Checked Reference Key: 2354517
# Checked Reference Key: 2354663
# Checked Reference Key: 2354844
# Checked Reference Key: 2354893
# Checked Reference Key: 2355545
# Checked Reference Key: 2357032
# Checked Reference Key: 2357297
# Checked Reference Key: 2357988
# Checked Reference Key: 2358197
# ...
# Checked Reference Key: 7133819
# Checked Reference Key: 7135055
# Checked Reference Key: 7145136
# Checked Reference Key: 7147746
# Checked Reference Key: 7152968
# Checked Reference Key: 7160009
# Checked Reference Key: 7160566
# Checked Reference Key: 7169466
# Checked Reference Key: 7169971
# Checked Reference Key: 7170848
# Checked Reference Key: 7174188
# Checked Reference Key: 7181533
# Checked Reference Key: 7184431
# Checked Reference Key: 7186553
# Checked Reference Key: 7187402
# Checked Reference Key: 7190981
# Checked Reference Key: 7193408
# Checked Reference Key: 7201116
# Checked Reference Key: 7203551
# Checked Reference Key: 7211667
# Checked Reference Key: 7212541
# Checked Reference Key: 7217888
# Checked Reference Key: 7218080
# Checked Reference Key: 7226857
# Checked Reference Key: 7230819
# Checked Reference Key: 7233014
# Checked Reference Key: 7235806
# Checked Reference Key: 7240239
# Checked Reference Key: 7243381
# Checked Reference Key: 7247568
# Checked Reference Key: 7248530
# Checked Reference Key: 7250384
# Checked Reference Key: 7252528
# Checked Reference Key: 7252906
# Checked Reference Key: 7258156
# Checked Reference Key: 7259139
# Checked Reference Key: 7260626
# Checked Reference Key: 7262998
# Checked Reference Key: 7268204
# Checked Reference Key: 7270558
# Checked Reference Key: 7274076
# Checked Reference Key: 7276300
# Checked Reference Key: 7281080
# Checked Reference Key: 7284771
# Checked Reference Key: 7286923
# Checked Reference Key: 7287776
# Checked Reference Key: 7291011
# Checked Reference Key: 7293312
# Checked Reference Key: 7297210
# Checked Reference Key: 7298471
# Checked Reference Key: 7301657
# Checked Reference Key: 7302988
# Checked Reference Key: 7311196
# Checked Reference Key: 7312769
# Checked Reference Key: 7313968
# Checked Reference Key: 7314672
# Checked Reference Key: 7316311
# Checked Reference Key: 7321690
# Checked Reference Key: 7335030
# Checked Reference Key: 7335767
# Checked Reference Key: 7337401
# Checked Reference Key: 7349122
# Checked Reference Key: 7349967
# Checked Reference Key: 7361138
# Checked Reference Key: 7363816
# Checked Reference Key: 7364237
# Checked Reference Key: 7365344
# Checked Reference Key: 7366648
# Checked Reference Key: 7366728
# Checked Reference Key: 7367219
# Checked Reference Key: 7369263
# Checked Reference Key: 7370761
# Checked Reference Key: 7380772
# Checked Reference Key: 7386421
# Checked Reference Key: 7394280
# Checked Reference Key: 7397099
# Checked Reference Key: 7410282
# Checked Reference Key: 7411027
# Checked Reference Key: 7413348
# Checked Reference Key: 7415165
# Checked Reference Key: 7417321
# Checked Reference Key: 7417520
# Checked Reference Key: 7418507
# Checked Reference Key: 7423977
# Checked Reference Key: 7426584
# Checked Reference Key: 7430080
# Checked Reference Key: 7431509
# Checked Reference Key: 7431999
# Checked Reference Key: 7437069
# Checked Reference Key: 7440914
# Checked Reference Key: 7443391
# Checked Reference Key: 7449108
# Checked Reference Key: 7450976
# Checked Reference Key: 7456603
# Checked Reference Key: 7467838
# Checked Reference Key: 7467980
# Checked Reference Key: 7472263
# Checked Reference Key: 7473445
# Checked Reference Key: 7475533
# Checked Reference Key: 7479733
# Checked Reference Key: 7482136
# Checked Reference Key: 7482305
# Checked Reference Key: 7482676
# Checked Reference Key: 7487615
# Checked Reference Key: 7489872
# Checked Reference Key: 7490854
# Checked Reference Key: 7495924
# Checked Reference Key: 7497703
# Checked Reference Key: 7498936
# Checked Reference Key: 7500086
# Checked Reference Key: 7501090
# Checked Reference Key: 7503069
# Checked Reference Key: 7508912
# Checked Reference Key: 7509006
# Checked Reference Key: 7509977
# Checked Reference Key: 7511754
# Checked Reference Key: 7512310
# Checked Reference Key: 7516785
# Checked Reference Key: 7518235
# Checked Reference Key: 7525359
# Checked Reference Key: 7525652
# Checked Reference Key: 7526849
# Checked Reference Key: 7534018
# Checked Reference Key: 7543504
# Checked Reference Key: 7543965
# Checked Reference Key: 7547689
# Checked Reference Key: 7547696
# Checked Reference Key: 7548874
# Checked Reference Key: 7556039
# Checked Reference Key: 7556425
# Checked Reference Key: 7557614
# Checked Reference Key: 7559222
# Checked Reference Key: 7560227
# Checked Reference Key: 7567888
# Checked Reference Key: 7578024
# Checked Reference Key: 7586450
# Checked Reference Key: 7602318
# Checked Reference Key: 7602470
# Checked Reference Key: 7603075
# Checked Reference Key: 7603345
# Checked Reference Key: 7604237
# Checked Reference Key: 7610610
# Checked Reference Key: 7614447
# Checked Reference Key: 7616257
# Checked Reference Key: 7617043
# Checked Reference Key: 7621427
# Checked Reference Key: 7622082
# Checked Reference Key: 7626772
# Checked Reference Key: 7627362
# Checked Reference Key: 7630941
# Checked Reference Key: 7631194
# Checked Reference Key: 7638677
# Checked Reference Key: 7643433
# Checked Reference Key: 7665276
# Checked Reference Key: 7672293
# Checked Reference Key: 7678694
# Checked Reference Key: 7685006
# Checked Reference Key: 7695395
# Checked Reference Key: 7696539
# Checked Reference Key: 7697869
# Checked Reference Key: 7699285
# Checked Reference Key: 7700504
# Checked Reference Key: 7700819
# Checked Reference Key: 7701081
# Checked Reference Key: 7706840
# Checked Reference Key: 7707494
# Checked Reference Key: 7715569
# Checked Reference Key: 7718232
# Checked Reference Key: 7718751
# Checked Reference Key: 7728518
# Checked Reference Key: 7730673
# Checked Reference Key: 7733874
# Checked Reference Key: 7738587
# Checked Reference Key: 7739936
# Checked Reference Key: 7747504
# Checked Reference Key: 7748095
# Checked Reference Key: 7753210
# Checked Reference Key: 7754652
# Checked Reference Key: 7754962
# Checked Reference Key: 7756792
# Checked Reference Key: 7758237
# Checked Reference Key: 7760006
# Checked Reference Key: 7765832
# Checked Reference Key: 7767457
# Checked Reference Key: 7775946
# Checked Reference Key: 7779907
# Checked Reference Key: 7783483
# Checked Reference Key: 7783698
# Checked Reference Key: 7788282
# Checked Reference Key: 7799207
# Checked Reference Key: 7801121
# Checked Reference Key: 7810389
# Checked Reference Key: 7819038
# Checked Reference Key: 7826076
# Checked Reference Key: 7826806
# Checked Reference Key: 7837591
# Checked Reference Key: 7840906
# Checked Reference Key: 7843977
# Checked Reference Key: 7845195
# Checked Reference Key: 7845831
# Checked Reference Key: 7846262
# Checked Reference Key: 7851786
# Checked Reference Key: 7853633
# Checked Reference Key: 7861693
# Checked Reference Key: 7866882
# Checked Reference Key: 7871662
# Checked Reference Key: 7873836
# Checked Reference Key: 7875428
# Checked Reference Key: 7877468
# Checked Reference Key: 7879498
# Checked Reference Key: 7882653
# Checked Reference Key: 7887642
# Checked Reference Key: 7888950
# Checked Reference Key: 7898135
# Checked Reference Key: 7898335
# Checked Reference Key: 7901097
# Checked Reference Key: 7911184
# Checked Reference Key: 7914286
# Checked Reference Key: 7916199
# Checked Reference Key: 7917859
# Checked Reference Key: 7918975
# Checked Reference Key: 7928584
# Checked Reference Key: 7929399
# Checked Reference Key: 7929915
# Checked Reference Key: 7931629
# Checked Reference Key: 7934549
# Checked Reference Key: 7943428
# Checked Reference Key: 7946292
# Checked Reference Key: 7947419
# Checked Reference Key: 7950778
# Checked Reference Key: 7958875
# Checked Reference Key: 7968238
# Checked Reference Key: 7995270
# Checked Reference Key: 7996027
# Checked Reference Key: 7996935
# Checked Reference Key: 7997419
# Checked Reference Key: 8010703
# Checked Reference Key: 8015007
# Checked Reference Key: 8019398
# Checked Reference Key: 8029866
# Checked Reference Key: 8034864
# Checked Reference Key: 8040054
# Checked Reference Key: 8041506
# Checked Reference Key: 8045967
# Checked Reference Key: 8047376
# Checked Reference Key: 8047920
# Checked Reference Key: 8051400
# Checked Reference Key: 8057449
# Checked Reference Key: 8059843
# Checked Reference Key: 8062633
# Checked Reference Key: 8071786
# Checked Reference Key: 8076883
# Checked Reference Key: 8083102
# Checked Reference Key: 8084526
# Checked Reference Key: 8086349
# Checked Reference Key: 8086964
# Checked Reference Key: 8087304
# Checked Reference Key: 8089624
# Checked Reference Key: 8094854
# Checked Reference Key: 8094886
# Checked Reference Key: 8098032
# Checked Reference Key: 8102644
# Checked Reference Key: 8112198
# Checked Reference Key: 8116290
# Checked Reference Key: 8117394
# Checked Reference Key: 8126195
# Checked Reference Key: 8128639
# Checked Reference Key: 8129267
# Checked Reference Key: 8129717
# Checked Reference Key: 8135314
# Checked Reference Key: 8135337
# Checked Reference Key: 8135765
# Checked Reference Key: 8138484
# Checked Reference Key: 8139173
# Checked Reference Key: 8139426
# Checked Reference Key: 8140018
# Checked Reference Key: 8143177
# Checked Reference Key: 8143308
# Checked Reference Key: 8149104
# Checked Reference Key: 8159719
# Checked Reference Key: 8162442
# Checked Reference Key: 8162614
# Checked Reference Key: 8174185
# Checked Reference Key: 8175562
# Checked Reference Key: 8176921
# Checked Reference Key: 8179899
# Checked Reference Key: 8182818
# Checked Reference Key: 8183296
# Checked Reference Key: 8184949
# Checked Reference Key: 8185938
# Checked Reference Key: 8186895
# Checked Reference Key: 8198921
# Checked Reference Key: 8203581
# Checked Reference Key: 8205092
# Checked Reference Key: 8211049
# Checked Reference Key: 8213478
# Checked Reference Key: 8215894
# Checked Reference Key: 8216644
# Checked Reference Key: 8219848
# Checked Reference Key: 8221748
# Checked Reference Key: 8228035
# Checked Reference Key: 8229546
# Checked Reference Key: 8232742
# Checked Reference Key: 8239425
# Checked Reference Key: 8240258
# Checked Reference Key: 8240373
# Checked Reference Key: 8240614
# Checked Reference Key: 8241809
# Checked Reference Key: 8242846
# Checked Reference Key: 8242894
# Checked Reference Key: 8245982
# Checked Reference Key: 8254497
# Checked Reference Key: 8255416
# Checked Reference Key: 8255627
# Checked Reference Key: 8259705
# Checked Reference Key: 8260040
# Checked Reference Key: 8261672
# Checked Reference Key: 8265234
# Checked Reference Key: 8265355
# Checked Reference Key: 8269744
# Checked Reference Key: 8271820
# Checked Reference Key: 8289876
# Checked Reference Key: 8299292
# Checked Reference Key: 8303417
# Checked Reference Key: 8303762
# Checked Reference Key: 8308537
# Checked Reference Key: 8310565
# Checked Reference Key: 8316830
# Checked Reference Key: 8318052
# Checked Reference Key: 8325212
# Checked Reference Key: 8325931
# Checked Reference Key: 8349728
# Checked Reference Key: 8357537
# Checked Reference Key: 8360026
# Checked Reference Key: 8360259
# Checked Reference Key: 8368437
# Checked Reference Key: 8377643
# Checked Reference Key: 8378201
# Checked Reference Key: 8382340
# Checked Reference Key: 8384088
# Checked Reference Key: 8393995
# Checked Reference Key: 8394083
# Checked Reference Key: 8395604
# Checked Reference Key: 8395634
# Checked Reference Key: 8396071
# Checked Reference Key: 8397157
# Checked Reference Key: 8397765
# Checked Reference Key: 8400410
# Checked Reference Key: 8419220
# Checked Reference Key: 8425733
# Checked Reference Key: 8428694
# Checked Reference Key: 8447901
# Checked Reference Key: 8451597
# Checked Reference Key: 8453705
# Checked Reference Key: 8457793
# Checked Reference Key: 8463440
# Checked Reference Key: 8465830
# Checked Reference Key: 8471736
# Checked Reference Key: 8485380
# Checked Reference Key: 8509011
# Checked Reference Key: 8515477
# Checked Reference Key: 8516873
# Checked Reference Key: 8517291
# Checked Reference Key: 8517694
# Checked Reference Key: 8524735
# Checked Reference Key: 8531604
# Checked Reference Key: 8537361
# Checked Reference Key: 8538105
# Checked Reference Key: 8567598
# Checked Reference Key: 8569662
# Checked Reference Key: 8572105
# Checked Reference Key: 8591981
# Checked Reference Key: 8593909
# Checked Reference Key: 8598996
# Checked Reference Key: 8617927
# Checked Reference Key: 8618625
# Checked Reference Key: 8621191
# Checked Reference Key: 8626078
# Checked Reference Key: 8633649
# Checked Reference Key: 8644197
# Checked Reference Key: 8644851
# Checked Reference Key: 8655809
# Checked Reference Key: 8663229
# Checked Reference Key: 8663516
# Checked Reference Key: 8668328
# Checked Reference Key: 8668447
# Checked Reference Key: 8669488
# Checked Reference Key: 8671574
# Checked Reference Key: 8673520
# Checked Reference Key: 8686287
# Checked Reference Key: 8689044
# Checked Reference Key: 8691074
# Checked Reference Key: 8692445
# Checked Reference Key: 8698008
# Checked Reference Key: 8699442
# Checked Reference Key: 8701556
# Checked Reference Key: 8703250
# Checked Reference Key: 8705575
# Checked Reference Key: 8719722
# Checked Reference Key: 8723172
# Checked Reference Key: 8723629
# Checked Reference Key: 8728526
# Checked Reference Key: 8766580
# Checked Reference Key: 8771039
# Checked Reference Key: 8773105
# Checked Reference Key: 8777461
# Checked Reference Key: 8779499
# Checked Reference Key: 8781748
# Checked Reference Key: 8784179
# Checked Reference Key: 8785447
# Checked Reference Key: 8811064
# Checked Reference Key: 8818638
# Checked Reference Key: 8820840
# Checked Reference Key: 8827563
# Checked Reference Key: 8835361
# Checked Reference Key: 8840252
# Checked Reference Key: 8844972
# Checked Reference Key: 8850719
# Checked Reference Key: 8852376
# Checked Reference Key: 8859391
# Checked Reference Key: 8865712
# Checked Reference Key: 8866513
# Checked Reference Key: 8874983
# Checked Reference Key: 8879027
# Checked Reference Key: 8880110
# Checked Reference Key: 8882897
# Checked Reference Key: 8897227
# Checked Reference Key: 8905915
# Checked Reference Key: 8907443
# Checked Reference Key: 8907639
# Checked Reference Key: 8924270
# Checked Reference Key: 8940823
# Checked Reference Key: 8948709
# Checked Reference Key: 8952341
# Checked Reference Key: 8952380
# Checked Reference Key: 8962621
# Checked Reference Key: 8964919
# Checked Reference Key: 8969752
# Checked Reference Key: 8980160
# Checked Reference Key: 9003815
# Checked Reference Key: 9023142
# Checked Reference Key: 9032638
# Checked Reference Key: 9036504
# Checked Reference Key: 9055464
# Checked Reference Key: 9057338
# Checked Reference Key: 9063069
# Checked Reference Key: 9084417
# Checked Reference Key: 9085286
# Checked Reference Key: 9089245
# Checked Reference Key: 9107410
# Checked Reference Key: 9119289
# Checked Reference Key: 9133749
# Checked Reference Key: 9141154
# Checked Reference Key: 9172386
# Checked Reference Key: 9185886
# Checked Reference Key: 9198468
# Checked Reference Key: 9205317
# Checked Reference Key: 9208058
# Checked Reference Key: 9210827
# Checked Reference Key: 9210977
# Checked Reference Key: 9224996
# Checked Reference Key: 9226386
# Checked Reference Key: 9226802
# Checked Reference Key: 9235842
# Checked Reference Key: 9236231
# Checked Reference Key: 9237222
# Checked Reference Key: 9248281
# Checked Reference Key: 9256628
# Checked Reference Key: 9264270
# Checked Reference Key: 9264667
# Checked Reference Key: 9272635
# Checked Reference Key: 9274473
# Checked Reference Key: 9293313
# Checked Reference Key: 9296299
# Checked Reference Key: 9304517
# Checked Reference Key: 9311621
# Checked Reference Key: 9322168
# Checked Reference Key: 9328838
# Checked Reference Key: 9346546
# Checked Reference Key: 9359062
# Checked Reference Key: 9409024
# Checked Reference Key: 9418803
# Checked Reference Key: 9426208
# Checked Reference Key: 9429497
# Checked Reference Key: 9443292
# Checked Reference Key: 9453493
# Checked Reference Key: 9464297
# Checked Reference Key: 9486942
# Checked Reference Key: 9489649
# Checked Reference Key: 9496602
# Checked Reference Key: 9497893
# Checked Reference Key: 9502795
# Checked Reference Key: 9503911
# Checked Reference Key: 9504519
# Checked Reference Key: 9514533
# Checked Reference Key: 9519960
# Checked Reference Key: 9524380
# Checked Reference Key: 9535379
# Checked Reference Key: 9538235
# Checked Reference Key: 9546613
# Checked Reference Key: 9548159
# Checked Reference Key: 9553193
# Checked Reference Key: 9559725
# Checked Reference Key: 9562466
# Checked Reference Key: 9572072
# Checked Reference Key: 9584819
# Checked Reference Key: 9591784
# Checked Reference Key: 9611044
# Checked Reference Key: 9615227
# Checked Reference Key: 9631256
# Checked Reference Key: 9638620
# Checked Reference Key: 9645208
# Checked Reference Key: 9660705
# Checked Reference Key: 9665405
# Checked Reference Key: 9670571
# Checked Reference Key: 9674276
