# %%
# import libraries
import os
import pandas as pd
import glob
import warnings
import datetime

# define file paths
year = 2024
DATA_PATH = f"./presumed_infection/2.Data/New Data/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*resumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def filter_presumed(year): # filter presumed infection cases for a specific year
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Institution (IPAS)' not in presumed_df.columns or 'HN Number' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Institution (IPAS)' not in demographic_df.columns or 'HN Number' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    mask = demographic_df.apply(lambda row: (row['Institution (IPAS)'], row['HN Number']) in presumed_tuples, axis=1)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def filter_presumed_RK(year): # filter presumed infection cases for a specific year using Reference Key
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}_RK.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Reference Key' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Reference Key' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(presumed_df['Reference Key'].tolist())
    mask = demographic_df['Reference Key'].isin(presumed_tuples)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def check_missing_presumed(year):
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Filtered demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH) 
    demo_df = pd.read_csv(DEMO_PATH)
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    demo_tuples = set(zip(demo_df['Institution (IPAS)'], demo_df['HN Number']))
    missing_tuples = presumed_tuples - demo_tuples
    missing_count = len(missing_tuples)
    print(f"Year {year}: {missing_count} presumed infection cases not found in demographic data")
    if missing_count > 0:
        missing_df = pd.DataFrame(list(missing_tuples), columns=['Institution (IPAS)', 'HN Number'])
        OUTPUT_PATH = os.path.join(DATA_PATH, f'Demographics/{year}/missing_presumed_{year}.csv')
        missing_df.to_csv(OUTPUT_PATH, index=False)
        print(f"Missing cases saved to {OUTPUT_PATH}")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, crea, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/{data_type.title()}/{year}/"
        pattern = "*resumedInfection_" + data_type.title() + "_"
    elif data_type == "crea": # alternative filename handling for crea
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/"
        pattern = "*resumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/"
        pattern = "*resumedInfection_lactate_"
    elif data_type == "bili": # alternative filename handling for bili
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"
    elif data_type == "plt": # alternative filename handling for plt
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def retrieve_blood_dates(Ref_Key, date_df):
    df = date_df[date_df['Reference Key'] == Ref_Key].copy()
    if 'blood culture date' in df.columns and not df.empty:
        blood_dates = pd.to_datetime(df['blood culture date'], errors='coerce').dropna().unique()
        return [date.strftime('%Y-%m-%d') for date in blood_dates]
    return []

def check_date_in_window(target_date, blood_dates_array):
    if not blood_dates_array or not target_date:
        return False
    target = pd.to_datetime(target_date)
    for blood_date_str in blood_dates_array:
        blood_date = pd.to_datetime(blood_date_str)
        date_diff = abs((target - blood_date).days)
        if date_diff <= 2:
            return True
    return False

# %%
# def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
#     df = date_df[date_df['Reference Key'] == Ref_Key].copy() # using first entry only, use array to store all dates if needed
#     if 'blood culture date' in df.columns and not df.empty:
#         blood_culture_date = pd.to_datetime(df.iloc[0]['blood culture date'], errors='coerce')
#         deadline_date = blood_culture_date + pd.Timedelta(days=2) # 2 days after blood culture (deadline)
#         return deadline_date.strftime('%Y-%m-%d')
#     return None

    # if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
    #     admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
    #     deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
    #     return deadline_date.strftime('%Y-%m-%d')
    # return None

# %%
def check_vasopressor(Ref_Key, df, blood_dates_array): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin unused
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'Drug Name' in df.columns and 'Prescription Start Date' in df.columns and not df.empty:
        df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
        for drug in vasopressor_list:
            drug_mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False)
            drug_dates = df.loc[drug_mask, 'Prescription Start Date'].dropna().unique()
            for admin_date in drug_dates:
                if check_date_in_window(admin_date, blood_dates_array):
                    one_day_before = admin_date - datetime.timedelta(days=1) # To count as a new vasopressor, that specific vasopressor cannot have been administered in the prior calendar day
                    if not drug_mask.any() or one_day_before not in drug_dates:
                        return True
    return False

# %%
def check_ventilation(Ref_Key, year, resp_fail_df, blood_dates_array): # check if mechanical ventilation is initiated
    df_filtered = resp_fail_df[(resp_fail_df['Reference Key'] == Ref_Key) & (resp_fail_df['year'] == year)].copy()
    if df_filtered.empty:
        return False
    if 'RespFailOnsetDate' in df_filtered.columns:
        for onset_date in df_filtered['RespFailOnsetDate']:
            if check_date_in_window(onset_date, blood_dates_array):
                return True
    return False

# %%
def filter_renal(): # filter end-stage renal disease patients (unused)
    DXPX_PATH = DATA_PATH + f"demographic/demographic_{year}.csv"
    df = pd.read_csv(DXPX_PATH)
    disease_list = []
    if 'Reference Key' in df.columns and 'Dx/Px Description (HAMDCT)' in df.columns:
        df['renal'] = df['Dx/Px Description (HAMDCT)'].str.lower().str.contains('|'.join(disease_list), case=False, na=False) 
        result_df = df[['Reference Key', 'renal']].drop_duplicates()       
        return result_df
    else:
        print("Required columns not found")
        return pd.DataFrame(columns=['Reference Key', 'renal'])
    
# only keeps first occurence(?), need change to eGFR>20

# %%
def check_creatinine(Ref_Key, df, blood_dates_array): # check if creatinine level is abnormal
    # renal_df = filter_renal()
    # if not renal_df.empty and Ref_Key in renal_df['Reference Key'].values:
    #     if renal_df.loc[renal_df['Reference Key'] == Ref_Key, 'renal'].iloc[0]:
    #         return False
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].min()
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= baseline * 2:
                    return True
    return False

# %%
def check_bili(Ref_Key, df, blood_dates_array): # check if bilirubin level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].min() # baseline calculated with all data
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                value_mgdl = value * 0.058467
                baseline_mgdl = baseline * 0.058467
                if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                    return True
    return False

# %%
def check_plt(Ref_Key, df, blood_dates_array): # check if platelet count is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].max() # baseline calculated with all data
        if baseline >= 100:
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    if value < 100 and value <= baseline * 0.5:
                        return True
    return False

# %%
def check_lact(Ref_Key, df, blood_dates_array): # check if lactate level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= 2.0:
                    return True
    return False

# %%
def check_ase(year):
    KEY_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv" # assuming demographic file contains all Reference Keys
    df = pd.read_csv(KEY_PATH )
    keys = df['Reference Key'].unique()
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv" # admission date placeholder for blood culture date
    date_df = pd.read_csv(DATE_PATH) # deadline date
    INOTROPE_PATH = DATA_PATH + f"Lab_Test_Results/Inotrope/{year}/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    # PROCEDURE_PATH = DATA_PATH + f"Lab_Test_Results/Procedure/{year}/procedure_{year}.csv" # no date?
    # procedure_df = pd.read_csv(PROCEDURE_PATH)
    CREATININE_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/crea_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    BILI_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    LACT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    RESP_PATH = DATA_PATH + f"RespFailList.csv"
    resp_fail_df = pd.read_csv(RESP_PATH)
    
    results = []
    for key in keys: 
        blood_dates_array = retrieve_blood_dates(key, date_df) # retrieve blood culture dates
        if check_vasopressor(key, inotrope_df, blood_dates_array): # check vasopressor
            results.append({'Reference Key': key, 'vasopressor': True})
        else:
            results.append({'Reference Key': key, 'vasopressor': False})

        if check_ventilation(key, year, resp_fail_df, blood_dates_array): # check ventilation
            results[-1]['ventilation'] = True
        else:
            results[-1]['ventilation'] = False

        if check_creatinine(key, creatinine_df, blood_dates_array): # check creatinine
            results[-1]['creatinine'] = True
        else:
            results[-1]['creatinine'] = False

        if check_bili(key, bili_df, blood_dates_array): # check bilirubin
            results[-1]['bili'] = True
        else:
            results[-1]['bili'] = False

        if check_plt(key, plt_df, blood_dates_array): # check platelet
            results[-1]['plt'] = True
        else: 
            results[-1]['plt'] = False

        if check_lact(key, lact_df, blood_dates_array): # check lactate
            results[-1]['lact'] = True
        else: 
            results[-1]['lact'] = False
        
        print(f"Checked Reference Key: {key}")

    results_df = pd.DataFrame(results)
    output_dir = os.path.join(DATA_PATH, 'Output', 'ase')
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'ase_{year}.csv')
    results_df.to_csv(output_file, index=False)
    print(f"ASE vasopressor results saved to {output_file}")

# %%
def create_ASE_list(file, year): # create list of ase patients with institution by matching ase filter output
    ase_df = pd.read_csv(file)
    ase_df['Overall'] = ase_df.iloc[:, 1:7].any(axis=1)
    true_ase_df = ase_df[ase_df['Overall'] == True]
    demo_path = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    demo_df = pd.read_csv(demo_path)
    merged_df = pd.merge(true_ase_df[['Reference Key']], demo_df[['Reference Key', 'HN Number', 'Institution (IPAS)']], on='Reference Key', how='left')
    output_file = os.path.join(DATA_PATH, f'ASE_patient_list_{year}.csv')
    merged_df.to_csv(output_file, index=False)
    print(f"ASE patient list saved to {output_file}")
    return merged_df

# %%
def ase_percentages(file):
    df = pd.read_csv(file)
    percentages = {}
    for column in df.columns[1:7]:  # First 6 OD columns
        if df[column].dtype == bool or df[column].isin([True, False, 'TRUE', 'FALSE']).all():
            true_count = (df[column] == True).sum() + (df[column] == 'TRUE').sum()
            total_count = len(df[column])
            percentage = (true_count / total_count * 100) if total_count > 0 else 0
            percentages[column] = round(percentage, 2)
    return percentages

# %%
for year in range(2022,2023): # 2025 currently missing
    # merge_demographic(year)
    # filter_presumed(year)
    # filter_presumed_RK(year)
    # check_missing_presumed(year)
    data_types = ["inotrope", "procedure", "crea", "bili", "plt", "lact"]
    for data_type in data_types:
        merge_data(data_type, year)
# Out:
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 0
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_Procedure_
# Found 0 files for year 0
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_Crea_
# Found 0 files for year 0
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 0
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 0
# Processing year: 0
# No files found for year 0 with pattern *resumedInfection_lactate_
# Found 0 files for year 0
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 1
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_Procedure_
# Found 0 files for year 1
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_Crea_
# Found 0 files for year 1
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 1
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 1
# Processing year: 1
# No files found for year 1 with pattern *resumedInfection_lactate_
# Found 0 files for year 1
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_Crea_
# Found 0 files for year 2
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2
# Processing year: 2
# No files found for year 2 with pattern *resumedInfection_lactate_
# Found 0 files for year 2
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 3
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_Procedure_
# Found 0 files for year 3
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_Crea_
# Found 0 files for year 3
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 3
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 3
# Processing year: 3
# No files found for year 3 with pattern *resumedInfection_lactate_
# Found 0 files for year 3
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 4
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_Procedure_
# Found 0 files for year 4
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_Crea_
# Found 0 files for year 4
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 4
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 4
# Processing year: 4
# No files found for year 4 with pattern *resumedInfection_lactate_
# Found 0 files for year 4
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 5
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_Procedure_
# Found 0 files for year 5
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_Crea_
# Found 0 files for year 5
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 5
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 5
# Processing year: 5
# No files found for year 5 with pattern *resumedInfection_lactate_
# Found 0 files for year 5
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 6
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_Procedure_
# Found 0 files for year 6
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_Crea_
# Found 0 files for year 6
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 6
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 6
# Processing year: 6
# No files found for year 6 with pattern *resumedInfection_lactate_
# Found 0 files for year 6
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 7
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_Procedure_
# Found 0 files for year 7
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_Crea_
# Found 0 files for year 7
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 7
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 7
# Processing year: 7
# No files found for year 7 with pattern *resumedInfection_lactate_
# Found 0 files for year 7
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 8
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_Procedure_
# Found 0 files for year 8
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_Crea_
# Found 0 files for year 8
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 8
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 8
# Processing year: 8
# No files found for year 8 with pattern *resumedInfection_lactate_
# Found 0 files for year 8
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 9
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_Procedure_
# Found 0 files for year 9
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_Crea_
# Found 0 files for year 9
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 9
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 9
# Processing year: 9
# No files found for year 9 with pattern *resumedInfection_lactate_
# Found 0 files for year 9
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 10
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_Procedure_
# Found 0 files for year 10
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_Crea_
# Found 0 files for year 10
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 10
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 10
# Processing year: 10
# No files found for year 10 with pattern *resumedInfection_lactate_
# Found 0 files for year 10
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 11
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_Procedure_
# Found 0 files for year 11
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_Crea_
# Found 0 files for year 11
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 11
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 11
# Processing year: 11
# No files found for year 11 with pattern *resumedInfection_lactate_
# Found 0 files for year 11
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 12
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_Procedure_
# Found 0 files for year 12
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_Crea_
# Found 0 files for year 12
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 12
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 12
# Processing year: 12
# No files found for year 12 with pattern *resumedInfection_lactate_
# Found 0 files for year 12
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 13
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_Procedure_
# Found 0 files for year 13
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_Crea_
# Found 0 files for year 13
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 13
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 13
# Processing year: 13
# No files found for year 13 with pattern *resumedInfection_lactate_
# Found 0 files for year 13
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 14
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_Procedure_
# Found 0 files for year 14
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_Crea_
# Found 0 files for year 14
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 14
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 14
# Processing year: 14
# No files found for year 14 with pattern *resumedInfection_lactate_
# Found 0 files for year 14
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 15
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_Procedure_
# Found 0 files for year 15
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_Crea_
# Found 0 files for year 15
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 15
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 15
# Processing year: 15
# No files found for year 15 with pattern *resumedInfection_lactate_
# Found 0 files for year 15
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 16
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_Procedure_
# Found 0 files for year 16
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_Crea_
# Found 0 files for year 16
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 16
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 16
# Processing year: 16
# No files found for year 16 with pattern *resumedInfection_lactate_
# Found 0 files for year 16
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 17
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_Procedure_
# Found 0 files for year 17
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_Crea_
# Found 0 files for year 17
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 17
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 17
# Processing year: 17
# No files found for year 17 with pattern *resumedInfection_lactate_
# Found 0 files for year 17
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 18
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_Procedure_
# Found 0 files for year 18
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_Crea_
# Found 0 files for year 18
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 18
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 18
# Processing year: 18
# No files found for year 18 with pattern *resumedInfection_lactate_
# Found 0 files for year 18
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 19
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_Procedure_
# Found 0 files for year 19
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_Crea_
# Found 0 files for year 19
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 19
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 19
# Processing year: 19
# No files found for year 19 with pattern *resumedInfection_lactate_
# Found 0 files for year 19
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 20
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_Procedure_
# Found 0 files for year 20
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_Crea_
# Found 0 files for year 20
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 20
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 20
# Processing year: 20
# No files found for year 20 with pattern *resumedInfection_lactate_
# Found 0 files for year 20
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 21
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_Procedure_
# Found 0 files for year 21
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_Crea_
# Found 0 files for year 21
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 21
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 21
# Processing year: 21
# No files found for year 21 with pattern *resumedInfection_lactate_
# Found 0 files for year 21
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 22
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_Procedure_
# Found 0 files for year 22
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_Crea_
# Found 0 files for year 22
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 22
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 22
# Processing year: 22
# No files found for year 22 with pattern *resumedInfection_lactate_
# Found 0 files for year 22
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 23
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_Procedure_
# Found 0 files for year 23
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_Crea_
# Found 0 files for year 23
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 23
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 23
# Processing year: 23
# No files found for year 23 with pattern *resumedInfection_lactate_
# Found 0 files for year 23
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 24
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_Procedure_
# Found 0 files for year 24
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_Crea_
# Found 0 files for year 24
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 24
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 24
# Processing year: 24
# No files found for year 24 with pattern *resumedInfection_lactate_
# Found 0 files for year 24
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 25
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_Procedure_
# Found 0 files for year 25
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_Crea_
# Found 0 files for year 25
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 25
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 25
# Processing year: 25
# No files found for year 25 with pattern *resumedInfection_lactate_
# Found 0 files for year 25
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 26
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_Procedure_
# Found 0 files for year 26
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_Crea_
# Found 0 files for year 26
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 26
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 26
# Processing year: 26
# No files found for year 26 with pattern *resumedInfection_lactate_
# Found 0 files for year 26
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 27
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_Procedure_
# Found 0 files for year 27
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_Crea_
# Found 0 files for year 27
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 27
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 27
# Processing year: 27
# No files found for year 27 with pattern *resumedInfection_lactate_
# Found 0 files for year 27
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 28
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_Procedure_
# Found 0 files for year 28
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_Crea_
# Found 0 files for year 28
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 28
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 28
# Processing year: 28
# No files found for year 28 with pattern *resumedInfection_lactate_
# Found 0 files for year 28
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 29
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_Procedure_
# Found 0 files for year 29
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_Crea_
# Found 0 files for year 29
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 29
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 29
# Processing year: 29
# No files found for year 29 with pattern *resumedInfection_lactate_
# Found 0 files for year 29
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 30
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_Procedure_
# Found 0 files for year 30
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_Crea_
# Found 0 files for year 30
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 30
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 30
# Processing year: 30
# No files found for year 30 with pattern *resumedInfection_lactate_
# Found 0 files for year 30
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 31
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_Procedure_
# Found 0 files for year 31
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_Crea_
# Found 0 files for year 31
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 31
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 31
# Processing year: 31
# No files found for year 31 with pattern *resumedInfection_lactate_
# Found 0 files for year 31
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 32
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_Procedure_
# Found 0 files for year 32
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_Crea_
# Found 0 files for year 32
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 32
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 32
# Processing year: 32
# No files found for year 32 with pattern *resumedInfection_lactate_
# Found 0 files for year 32
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 33
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_Procedure_
# Found 0 files for year 33
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_Crea_
# Found 0 files for year 33
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 33
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 33
# Processing year: 33
# No files found for year 33 with pattern *resumedInfection_lactate_
# Found 0 files for year 33
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 34
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_Procedure_
# Found 0 files for year 34
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_Crea_
# Found 0 files for year 34
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 34
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 34
# Processing year: 34
# No files found for year 34 with pattern *resumedInfection_lactate_
# Found 0 files for year 34
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 35
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_Procedure_
# Found 0 files for year 35
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_Crea_
# Found 0 files for year 35
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 35
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 35
# Processing year: 35
# No files found for year 35 with pattern *resumedInfection_lactate_
# Found 0 files for year 35
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 36
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_Procedure_
# Found 0 files for year 36
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_Crea_
# Found 0 files for year 36
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 36
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 36
# Processing year: 36
# No files found for year 36 with pattern *resumedInfection_lactate_
# Found 0 files for year 36
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 37
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_Procedure_
# Found 0 files for year 37
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_Crea_
# Found 0 files for year 37
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 37
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 37
# Processing year: 37
# No files found for year 37 with pattern *resumedInfection_lactate_
# Found 0 files for year 37
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 38
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_Procedure_
# Found 0 files for year 38
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_Crea_
# Found 0 files for year 38
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 38
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 38
# Processing year: 38
# No files found for year 38 with pattern *resumedInfection_lactate_
# Found 0 files for year 38
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 39
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_Procedure_
# Found 0 files for year 39
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_Crea_
# Found 0 files for year 39
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 39
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 39
# Processing year: 39
# No files found for year 39 with pattern *resumedInfection_lactate_
# Found 0 files for year 39
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 40
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_Procedure_
# Found 0 files for year 40
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_Crea_
# Found 0 files for year 40
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 40
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 40
# Processing year: 40
# No files found for year 40 with pattern *resumedInfection_lactate_
# Found 0 files for year 40
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 41
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_Procedure_
# Found 0 files for year 41
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_Crea_
# Found 0 files for year 41
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 41
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 41
# Processing year: 41
# No files found for year 41 with pattern *resumedInfection_lactate_
# Found 0 files for year 41
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 42
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_Procedure_
# Found 0 files for year 42
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_Crea_
# Found 0 files for year 42
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 42
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 42
# Processing year: 42
# No files found for year 42 with pattern *resumedInfection_lactate_
# Found 0 files for year 42
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 43
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_Procedure_
# Found 0 files for year 43
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_Crea_
# Found 0 files for year 43
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 43
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 43
# Processing year: 43
# No files found for year 43 with pattern *resumedInfection_lactate_
# Found 0 files for year 43
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 44
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_Procedure_
# Found 0 files for year 44
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_Crea_
# Found 0 files for year 44
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 44
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 44
# Processing year: 44
# No files found for year 44 with pattern *resumedInfection_lactate_
# Found 0 files for year 44
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 45
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_Procedure_
# Found 0 files for year 45
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_Crea_
# Found 0 files for year 45
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 45
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 45
# Processing year: 45
# No files found for year 45 with pattern *resumedInfection_lactate_
# Found 0 files for year 45
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 46
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_Procedure_
# Found 0 files for year 46
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_Crea_
# Found 0 files for year 46
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 46
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 46
# Processing year: 46
# No files found for year 46 with pattern *resumedInfection_lactate_
# Found 0 files for year 46
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 47
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_Procedure_
# Found 0 files for year 47
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_Crea_
# Found 0 files for year 47
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 47
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 47
# Processing year: 47
# No files found for year 47 with pattern *resumedInfection_lactate_
# Found 0 files for year 47
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 48
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_Procedure_
# Found 0 files for year 48
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_Crea_
# Found 0 files for year 48
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 48
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 48
# Processing year: 48
# No files found for year 48 with pattern *resumedInfection_lactate_
# Found 0 files for year 48
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 49
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_Procedure_
# Found 0 files for year 49
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_Crea_
# Found 0 files for year 49
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 49
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 49
# Processing year: 49
# No files found for year 49 with pattern *resumedInfection_lactate_
# Found 0 files for year 49
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 50
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_Procedure_
# Found 0 files for year 50
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_Crea_
# Found 0 files for year 50
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 50
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 50
# Processing year: 50
# No files found for year 50 with pattern *resumedInfection_lactate_
# Found 0 files for year 50
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 51
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_Procedure_
# Found 0 files for year 51
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_Crea_
# Found 0 files for year 51
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 51
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 51
# Processing year: 51
# No files found for year 51 with pattern *resumedInfection_lactate_
# Found 0 files for year 51
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 52
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_Procedure_
# Found 0 files for year 52
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_Crea_
# Found 0 files for year 52
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 52
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 52
# Processing year: 52
# No files found for year 52 with pattern *resumedInfection_lactate_
# Found 0 files for year 52
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 53
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_Procedure_
# Found 0 files for year 53
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_Crea_
# Found 0 files for year 53
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 53
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 53
# Processing year: 53
# No files found for year 53 with pattern *resumedInfection_lactate_
# Found 0 files for year 53
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 54
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_Procedure_
# Found 0 files for year 54
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_Crea_
# Found 0 files for year 54
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 54
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 54
# Processing year: 54
# No files found for year 54 with pattern *resumedInfection_lactate_
# Found 0 files for year 54
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 55
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_Procedure_
# Found 0 files for year 55
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_Crea_
# Found 0 files for year 55
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 55
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 55
# Processing year: 55
# No files found for year 55 with pattern *resumedInfection_lactate_
# Found 0 files for year 55
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 56
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_Procedure_
# Found 0 files for year 56
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_Crea_
# Found 0 files for year 56
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 56
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 56
# Processing year: 56
# No files found for year 56 with pattern *resumedInfection_lactate_
# Found 0 files for year 56
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 57
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_Procedure_
# Found 0 files for year 57
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_Crea_
# Found 0 files for year 57
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 57
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 57
# Processing year: 57
# No files found for year 57 with pattern *resumedInfection_lactate_
# Found 0 files for year 57
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 58
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_Procedure_
# Found 0 files for year 58
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_Crea_
# Found 0 files for year 58
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 58
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 58
# Processing year: 58
# No files found for year 58 with pattern *resumedInfection_lactate_
# Found 0 files for year 58
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 59
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_Procedure_
# Found 0 files for year 59
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_Crea_
# Found 0 files for year 59
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 59
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 59
# Processing year: 59
# No files found for year 59 with pattern *resumedInfection_lactate_
# Found 0 files for year 59
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 60
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_Procedure_
# Found 0 files for year 60
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_Crea_
# Found 0 files for year 60
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 60
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 60
# Processing year: 60
# No files found for year 60 with pattern *resumedInfection_lactate_
# Found 0 files for year 60
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 61
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_Procedure_
# Found 0 files for year 61
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_Crea_
# Found 0 files for year 61
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 61
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 61
# Processing year: 61
# No files found for year 61 with pattern *resumedInfection_lactate_
# Found 0 files for year 61
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 62
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_Procedure_
# Found 0 files for year 62
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_Crea_
# Found 0 files for year 62
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 62
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 62
# Processing year: 62
# No files found for year 62 with pattern *resumedInfection_lactate_
# Found 0 files for year 62
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 63
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_Procedure_
# Found 0 files for year 63
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_Crea_
# Found 0 files for year 63
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 63
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 63
# Processing year: 63
# No files found for year 63 with pattern *resumedInfection_lactate_
# Found 0 files for year 63
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 64
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_Procedure_
# Found 0 files for year 64
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_Crea_
# Found 0 files for year 64
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 64
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 64
# Processing year: 64
# No files found for year 64 with pattern *resumedInfection_lactate_
# Found 0 files for year 64
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 65
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_Procedure_
# Found 0 files for year 65
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_Crea_
# Found 0 files for year 65
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 65
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 65
# Processing year: 65
# No files found for year 65 with pattern *resumedInfection_lactate_
# Found 0 files for year 65
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 66
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_Procedure_
# Found 0 files for year 66
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_Crea_
# Found 0 files for year 66
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 66
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 66
# Processing year: 66
# No files found for year 66 with pattern *resumedInfection_lactate_
# Found 0 files for year 66
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 67
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_Procedure_
# Found 0 files for year 67
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_Crea_
# Found 0 files for year 67
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 67
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 67
# Processing year: 67
# No files found for year 67 with pattern *resumedInfection_lactate_
# Found 0 files for year 67
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 68
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_Procedure_
# Found 0 files for year 68
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_Crea_
# Found 0 files for year 68
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 68
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 68
# Processing year: 68
# No files found for year 68 with pattern *resumedInfection_lactate_
# Found 0 files for year 68
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 69
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_Procedure_
# Found 0 files for year 69
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_Crea_
# Found 0 files for year 69
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 69
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 69
# Processing year: 69
# No files found for year 69 with pattern *resumedInfection_lactate_
# Found 0 files for year 69
# Processing year: 70
# No files found for year 70 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 70
# Processing year: 70
# No files found for year 70 with pattern *resumedInfection_Procedure_
# Found 0 files for year 70
# Processing year: 70
# No files found for year 70 with pattern *resumedInfection_Crea_
# Found 0 files for year 70
# Processing year: 70
# No files found for year 70 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 70
# Processing year: 70
# No files found for year 70 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 70
# ...
# Processing year: 1999
# No files found for year 1999 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 1999
# Processing year: 1999
# No files found for year 1999 with pattern *resumedInfection_lactate_
# Found 0 files for year 1999
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2000
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2000
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_Crea_
# Found 0 files for year 2000
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2000
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2000
# Processing year: 2000
# No files found for year 2000 with pattern *resumedInfection_lactate_
# Found 0 files for year 2000
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2001
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2001
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_Crea_
# Found 0 files for year 2001
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2001
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2001
# Processing year: 2001
# No files found for year 2001 with pattern *resumedInfection_lactate_
# Found 0 files for year 2001
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2002
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2002
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_Crea_
# Found 0 files for year 2002
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2002
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2002
# Processing year: 2002
# No files found for year 2002 with pattern *resumedInfection_lactate_
# Found 0 files for year 2002
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2003
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2003
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_Crea_
# Found 0 files for year 2003
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2003
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2003
# Processing year: 2003
# No files found for year 2003 with pattern *resumedInfection_lactate_
# Found 0 files for year 2003
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2004
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2004
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_Crea_
# Found 0 files for year 2004
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2004
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2004
# Processing year: 2004
# No files found for year 2004 with pattern *resumedInfection_lactate_
# Found 0 files for year 2004
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2005
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2005
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_Crea_
# Found 0 files for year 2005
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2005
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2005
# Processing year: 2005
# No files found for year 2005 with pattern *resumedInfection_lactate_
# Found 0 files for year 2005
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2006
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2006
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_Crea_
# Found 0 files for year 2006
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2006
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2006
# Processing year: 2006
# No files found for year 2006 with pattern *resumedInfection_lactate_
# Found 0 files for year 2006
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2007
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2007
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_Crea_
# Found 0 files for year 2007
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2007
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2007
# Processing year: 2007
# No files found for year 2007 with pattern *resumedInfection_lactate_
# Found 0 files for year 2007
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2008
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2008
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_Crea_
# Found 0 files for year 2008
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2008
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2008
# Processing year: 2008
# No files found for year 2008 with pattern *resumedInfection_lactate_
# Found 0 files for year 2008
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2009
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2009
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_Crea_
# Found 0 files for year 2009
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2009
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2009
# Processing year: 2009
# No files found for year 2009 with pattern *resumedInfection_lactate_
# Found 0 files for year 2009
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2010
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2010
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_Crea_
# Found 0 files for year 2010
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2010
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2010
# Processing year: 2010
# No files found for year 2010 with pattern *resumedInfection_lactate_
# Found 0 files for year 2010
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2011
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2011
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_Crea_
# Found 0 files for year 2011
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2011
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2011
# Processing year: 2011
# No files found for year 2011 with pattern *resumedInfection_lactate_
# Found 0 files for year 2011
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2012
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2012
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_Crea_
# Found 0 files for year 2012
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2012
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2012
# Processing year: 2012
# No files found for year 2012 with pattern *resumedInfection_lactate_
# Found 0 files for year 2012
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2013
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2013
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_Crea_
# Found 0 files for year 2013
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2013
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2013
# Processing year: 2013
# No files found for year 2013 with pattern *resumedInfection_lactate_
# Found 0 files for year 2013
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2014
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2014
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_Crea_
# Found 0 files for year 2014
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2014
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2014
# Processing year: 2014
# No files found for year 2014 with pattern *resumedInfection_lactate_
# Found 0 files for year 2014
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2015
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2015
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_Crea_
# Found 0 files for year 2015
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2015
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2015
# Processing year: 2015
# No files found for year 2015 with pattern *resumedInfection_lactate_
# Found 0 files for year 2015
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2016
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2016
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_Crea_
# Found 0 files for year 2016
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2016
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2016
# Processing year: 2016
# No files found for year 2016 with pattern *resumedInfection_lactate_
# Found 0 files for year 2016
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2017
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2017
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_Crea_
# Found 0 files for year 2017
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2017
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2017
# Processing year: 2017
# No files found for year 2017 with pattern *resumedInfection_lactate_
# Found 0 files for year 2017
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2018
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2018
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_Crea_
# Found 0 files for year 2018
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2018
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2018
# Processing year: 2018
# No files found for year 2018 with pattern *resumedInfection_lactate_
# Found 0 files for year 2018
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2019
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2019
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_Crea_
# Found 0 files for year 2019
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2019
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2019
# Processing year: 2019
# No files found for year 2019 with pattern *resumedInfection_lactate_
# Found 0 files for year 2019
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2020
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2020
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_Crea_
# Found 0 files for year 2020
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2020
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2020
# Processing year: 2020
# No files found for year 2020 with pattern *resumedInfection_lactate_
# Found 0 files for year 2020
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_Inotrope_
# Found 0 files for year 2021
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_Procedure_
# Found 0 files for year 2021
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_Crea_
# Found 0 files for year 2021
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2021
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_Bili_Plt_
# Found 0 files for year 2021
# Processing year: 2021
# No files found for year 2021 with pattern *resumedInfection_lactate_
# Found 0 files for year 2021

# %%
warnings.filterwarnings('ignore')
for year in range(2022): # no 2019
    check_ase(year)

# %%
file = "./presumed_infection/2.Data/Output/ase/ase_2014.csv"
create_ASE_list(file, 2014)

# %%
file = "./presumed_infection/2.Data/Output/ase/ase_2016.csv"
ase_percentages(file)

# %%
def extract_true_cases():
    """Extract all Reference Keys with at least one True across all years"""
    output_dir = "./presumed_infection/2.Data/Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    true_cases = []
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Check if any of the condition columns are True (excluding Reference Key)
        condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
        df['has_true'] = df[condition_cols].any(axis=1)
        
        # Extract Reference Keys with at least one True
        year_true = df[df['has_true']]['Reference Key'].tolist()
        
        for ref_key in year_true:
            true_cases.append({'Reference Key': ref_key, 'Year': year})
    
    true_cases_df = pd.DataFrame(true_cases)
    output_file = os.path.join(output_dir, 'true_cases_all_years.csv')
    true_cases_df.to_csv(output_file, index=False)
    print(f"True cases saved to {output_file}, total {len(true_cases_df)} cases")
    
    return true_cases_df

def summarize_statistics():
    """Summarize statistics by year and overall"""
    output_dir = "./presumed_infection/2.Data/Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_stats = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    overall_counts = {col: 0 for col in condition_cols}
    overall_total = 0
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        year_stats = {'Year': year, 'Total_Patients': len(df)}
        
        for col in condition_cols:
            count = df[col].sum()
            percentage = (count / len(df) * 100) if len(df) > 0 else 0
            year_stats[f'{col}_count'] = count
            year_stats[f'{col}_pct'] = round(percentage, 2)
            
            overall_counts[col] += count
        
        year_stats['Patients_with_any'] = df[condition_cols].any(axis=1).sum()
        year_stats['Any_pct'] = round(year_stats['Patients_with_any'] / len(df) * 100, 2) if len(df) > 0 else 0
        
        overall_total += len(df)
        all_stats.append(year_stats)
    
    # Overall statistics
    overall_stats = {'Year': 'OVERALL', 'Total_Patients': overall_total}
    
    for col in condition_cols:
        percentage = (overall_counts[col] / overall_total * 100) if overall_total > 0 else 0
        overall_stats[f'{col}_count'] = overall_counts[col]
        overall_stats[f'{col}_pct'] = round(percentage, 2)
    
    # Calculate overall patients with any condition (need to read all files again to avoid double-counting)
    all_any_count = 0
    for file in files:
        df = pd.read_csv(file)
        all_any_count += df[condition_cols].any(axis=1).sum()
    
    overall_stats['Patients_with_any'] = all_any_count
    overall_stats['Any_pct'] = round(all_any_count / overall_total * 100, 2) if overall_total > 0 else 0
    
    all_stats.append(overall_stats)
    
    stats_df = pd.DataFrame(all_stats)
    
    # Save statistics
    stats_file = os.path.join(output_dir, 'statistics_summary.csv')
    stats_df.to_csv(stats_file, index=False)
    print(f"Statistics saved to {stats_file}")
    
    return stats_df

# Alternative: More detailed summary with distribution of number of conditions
def summarize_detailed():
    """Detailed summary including distribution of number of conditions per patient"""
    output_dir = "./presumed_infection/2.Data/Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_detailed = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Count number of true conditions per patient
        df['condition_count'] = df[condition_cols].sum(axis=1)
        
        year_detailed = {
            'Year': year,
            'Total_Patients': len(df),
            'Patients_with_0': (df['condition_count'] == 0).sum(),
            'Patients_with_1': (df['condition_count'] == 1).sum(),
            'Patients_with_2': (df['condition_count'] == 2).sum(),
            'Patients_with_3': (df['condition_count'] == 3).sum(),
            'Patients_with_4': (df['condition_count'] == 4).sum(),
            'Patients_with_5': (df['condition_count'] == 5).sum(),
            'Patients_with_6': (df['condition_count'] == 6).sum(),
            'Avg_conditions': round(df['condition_count'].mean(), 2)
        }
        
        # Add percentages
        for i in range(7):
            pct_col = f'Pct_with_{i}'
            count = year_detailed[f'Patients_with_{i}']
            year_detailed[pct_col] = round(count / len(df) * 100, 2) if len(df) > 0 else 0
        
        all_detailed.append(year_detailed)
    
    # Calculate overall
    detailed_df = pd.DataFrame(all_detailed)
    
    # Save detailed statistics
    detailed_file = os.path.join(output_dir, 'detailed_statistics.csv')
    detailed_df.to_csv(detailed_file, index=False)
    print(f"Detailed statistics saved to {detailed_file}")
    
    return detailed_df

# Run all functions
if __name__ == "__main__":
    true_cases = extract_true_cases()
    stats = summarize_statistics()
    detailed = summarize_detailed()
    
    print("\nSummary Statistics:")
    print(stats.to_string(index=False))
