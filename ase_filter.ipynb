# %%
# import libraries
import os
import pandas as pd
import glob
import warnings
import datetime

# define file paths
year = 2024
DATA_PATH = f"./presumed_infection/2.Data/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*_presumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def filter_presumed(year): # filter presumed infection cases for a specific year
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Institution (IPAS)' not in presumed_df.columns or 'HN Number' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Institution (IPAS)' not in demographic_df.columns or 'HN Number' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    mask = demographic_df.apply(lambda row: (row['Institution (IPAS)'], row['HN Number']) in presumed_tuples, axis=1)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def filter_presumed_RK(year): # filter presumed infection cases for a specific year using Reference Key
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}_RK.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Reference Key' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Reference Key' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(presumed_df['Reference Key'].tolist())
    mask = demographic_df['Reference Key'].isin(presumed_tuples)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def check_missing_presumed(year):
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Filtered demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH) 
    demo_df = pd.read_csv(DEMO_PATH)
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    demo_tuples = set(zip(demo_df['Institution (IPAS)'], demo_df['HN Number']))
    missing_tuples = presumed_tuples - demo_tuples
    missing_count = len(missing_tuples)
    print(f"Year {year}: {missing_count} presumed infection cases not found in demographic data")
    if missing_count > 0:
        missing_df = pd.DataFrame(list(missing_tuples), columns=['Institution (IPAS)', 'HN Number'])
        OUTPUT_PATH = os.path.join(DATA_PATH, f'Demographics/{year}/missing_presumed_{year}.csv')
        missing_df.to_csv(OUTPUT_PATH, index=False)
        print(f"Missing cases saved to {OUTPUT_PATH}")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, crea, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/{data_type.title()}/{year}/"
        pattern = "*_presumedInfection_" + data_type.title() + "_"
    elif data_type == "crea": # alternative filename handling for crea
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/"
        pattern = "*_presumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/"
        pattern = "*_presumedInfection_lactate_"
    elif data_type == "bili": # alternative filename handling for bili
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/"
        pattern = "*_presumedInfection_Bili_Plt_"
    elif data_type == "plt": # alternative filename handling for plt
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/"
        pattern = "*_presumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def retrieve_blood_dates(Ref_Key, date_df):
    df = date_df[date_df['Reference Key'] == Ref_Key].copy()
    if 'blood culture date' in df.columns and not df.empty:
        blood_dates = pd.to_datetime(df['blood culture date'], errors='coerce').dropna().unique()
        return [date.strftime('%Y-%m-%d') for date in blood_dates]
    return []

def check_date_in_window(target_date, blood_dates_array):
    if not blood_dates_array or not target_date:
        return False
    target = pd.to_datetime(target_date)
    for blood_date_str in blood_dates_array:
        blood_date = pd.to_datetime(blood_date_str)
        date_diff = abs((target - blood_date).days)
        if date_diff <= 2:
            return True
    return False

# %%
# def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
#     df = date_df[date_df['Reference Key'] == Ref_Key].copy() # using first entry only, use array to store all dates if needed
#     if 'blood culture date' in df.columns and not df.empty:
#         blood_culture_date = pd.to_datetime(df.iloc[0]['blood culture date'], errors='coerce')
#         deadline_date = blood_culture_date + pd.Timedelta(days=2) # 2 days after blood culture (deadline)
#         return deadline_date.strftime('%Y-%m-%d')
#     return None

    # if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
    #     admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
    #     deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
    #     return deadline_date.strftime('%Y-%m-%d')
    # return None

# %%
def check_vasopressor(Ref_Key, df, blood_dates_array): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin unused
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'Drug Name' in df.columns and 'Prescription Start Date' in df.columns and not df.empty:
        df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
        for drug in vasopressor_list:
            drug_mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False)
            drug_dates = df.loc[drug_mask, 'Prescription Start Date'].dropna().unique()
            for admin_date in drug_dates:
                if check_date_in_window(admin_date, blood_dates_array):
                    one_day_before = admin_date - datetime.timedelta(days=1) # To count as a new vasopressor, that specific vasopressor cannot have been administered in the prior calendar day
                    if not drug_mask.any() or one_day_before not in drug_dates:
                        return True
    return False

# %%
def check_ventilation(Ref_Key, year, resp_fail_df, blood_dates_array): # check if mechanical ventilation is initiated
    df_filtered = resp_fail_df[(resp_fail_df['Reference Key'] == Ref_Key) & (resp_fail_df['year'] == year)].copy()
    if df_filtered.empty:
        return False
    if 'RespFailOnsetDate' in df_filtered.columns:
        for onset_date in df_filtered['RespFailOnsetDate']:
            if check_date_in_window(onset_date, blood_dates_array):
                return True
    return False

# %%
def filter_renal(): # filter end-stage renal disease patients (unused)
    DXPX_PATH = DATA_PATH + f"demographic/demographic_{year}.csv"
    df = pd.read_csv(DXPX_PATH)
    disease_list = []
    if 'Reference Key' in df.columns and 'Dx/Px Description (HAMDCT)' in df.columns:
        df['renal'] = df['Dx/Px Description (HAMDCT)'].str.lower().str.contains('|'.join(disease_list), case=False, na=False) 
        result_df = df[['Reference Key', 'renal']].drop_duplicates()       
        return result_df
    else:
        print("Required columns not found")
        return pd.DataFrame(columns=['Reference Key', 'renal'])
    
# only keeps first occurence(?), need change to eGFR>20

# %%
def check_creatinine(Ref_Key, df, blood_dates_array): # check if creatinine level is abnormal
    # renal_df = filter_renal()
    # if not renal_df.empty and Ref_Key in renal_df['Reference Key'].values:
    #     if renal_df.loc[renal_df['Reference Key'] == Ref_Key, 'renal'].iloc[0]:
    #         return False
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].min()
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= baseline * 2:
                    return True
    return False

# %%
def check_bili(Ref_Key, df, blood_dates_array): # check if bilirubin level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].min() # baseline calculated with all data
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                value_mgdl = value * 0.058467
                baseline_mgdl = baseline * 0.058467
                if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                    return True
    return False

# %%
def check_plt(Ref_Key, df, blood_dates_array): # check if platelet count is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        baseline = df['LIS Result: Numeric Result'].max() # baseline calculated with all data
        if baseline >= 100:
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    if value < 100 and value <= baseline * 0.5:
                        return True
    return False

# %%
def check_lact(Ref_Key, df, blood_dates_array): # check if lactate level is abnormal
    df = df[df['Reference Key'] == Ref_Key].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= 2.0:
                    return True
    return False

# %%
def check_ase(year):
    KEY_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv" # assuming demographic file contains all Reference Keys
    df = pd.read_csv(KEY_PATH )
    keys = df['Reference Key'].unique()
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv" # admission date placeholder for blood culture date
    date_df = pd.read_csv(DATE_PATH) # deadline date
    INOTROPE_PATH = DATA_PATH + f"Lab_Test_Results/Inotrope/{year}/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    # PROCEDURE_PATH = DATA_PATH + f"Lab_Test_Results/Procedure/{year}/procedure_{year}.csv" # no date?
    # procedure_df = pd.read_csv(PROCEDURE_PATH)
    CREATININE_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/crea_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    BILI_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    LACT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    RESP_PATH = DATA_PATH + f"RespFailList.csv"
    resp_fail_df = pd.read_csv(RESP_PATH)
    
    results = []
    for key in keys: 
        blood_dates_array = retrieve_blood_dates(key, date_df) # retrieve blood culture dates
        if check_vasopressor(key, inotrope_df, blood_dates_array): # check vasopressor
            results.append({'Reference Key': key, 'vasopressor': True})
        else:
            results.append({'Reference Key': key, 'vasopressor': False})

        if check_ventilation(key, year, resp_fail_df, blood_dates_array): # check ventilation
            results[-1]['ventilation'] = True
        else:
            results[-1]['ventilation'] = False

        if check_creatinine(key, creatinine_df, blood_dates_array): # check creatinine
            results[-1]['creatinine'] = True
        else:
            results[-1]['creatinine'] = False

        if check_bili(key, bili_df, blood_dates_array): # check bilirubin
            results[-1]['bili'] = True
        else:
            results[-1]['bili'] = False

        if check_plt(key, plt_df, blood_dates_array): # check platelet
            results[-1]['plt'] = True
        else: 
            results[-1]['plt'] = False

        if check_lact(key, lact_df, blood_dates_array): # check lactate
            results[-1]['lact'] = True
        else: 
            results[-1]['lact'] = False
        
        print(f"Checked Reference Key: {key}")

    results_df = pd.DataFrame(results)
    output_dir = os.path.join(DATA_PATH, 'Output', 'ase')
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'ase_{year}.csv')
    results_df.to_csv(output_file, index=False)
    print(f"ASE vasopressor results saved to {output_file}")

# %%
def create_ASE_list(file, year): # create list of ase patients with institution by matching ase filter output
    ase_df = pd.read_csv(file)
    ase_df['Overall'] = ase_df.iloc[:, 1:7].any(axis=1)
    true_ase_df = ase_df[ase_df['Overall'] == True]
    demo_path = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    demo_df = pd.read_csv(demo_path)
    merged_df = pd.merge(true_ase_df[['Reference Key']], demo_df[['Reference Key', 'HN Number', 'Institution (IPAS)']], on='Reference Key', how='left')
    output_file = os.path.join(DATA_PATH, f'ASE_patient_list_{year}.csv')
    merged_df.to_csv(output_file, index=False)
    print(f"ASE patient list saved to {output_file}")
    return merged_df

# %%
def ase_percentages(file):
    df = pd.read_csv(file)
    percentages = {}
    for column in df.columns[1:7]:  # First 6 OD columns
        if df[column].dtype == bool or df[column].isin([True, False, 'TRUE', 'FALSE']).all():
            true_count = (df[column] == True).sum() + (df[column] == 'TRUE').sum()
            total_count = len(df[column])
            percentage = (true_count / total_count * 100) if total_count > 0 else 0
            percentages[column] = round(percentage, 2)
    return percentages

# %%
for year in range(2014, 2025): # 2025 currently missing
    # merge_demographic(year)
    # filter_presumed(year)
    # filter_presumed_RK(year)
    # check_missing_presumed(year)
    data_types = ["inotrope", "procedure", "crea", "bili", "plt", "lact"]
    for data_type in data_types:
        merge_data(data_type, year)
# Out:
# Processing year: 2014
# Found 23 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2014/inotrope_2014.csv, 54600 total rows
# Processing year: 2014
# Found 23 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2014/procedure_2014.csv, 5595 total rows
# Processing year: 2014
# Found 23 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2014/crea_2014.csv, 720799 total rows
# Processing year: 2014
# Found 22 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2014/bili_2014.csv, 500917 total rows
# Processing year: 2014
# Found 22 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2014/plt_2014.csv, 624115 total rows
# Processing year: 2014
# Found 23 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2014/lact_2014.csv, 7996 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2015/inotrope_2015.csv, 61203 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2015/procedure_2015.csv, 5117 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2015/crea_2015.csv, 724220 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2015/bili_2015.csv, 533305 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2015/plt_2015.csv, 661464 total rows
# Processing year: 2015
# Found 24 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2015/lact_2015.csv, 8270 total rows
# Processing year: 2016
# Found 25 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2016/inotrope_2016.csv, 69236 total rows
# Processing year: 2016
# Found 21 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2016/procedure_2016.csv, 4705 total rows
# Processing year: 2016
# Found 25 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2016/crea_2016.csv, 818515 total rows
# Processing year: 2016
# Found 21 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2016/bili_2016.csv, 500811 total rows
# Processing year: 2016
# Found 21 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2016/plt_2016.csv, 612578 total rows
# Processing year: 2016
# Found 21 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2016/lact_2016.csv, 9508 total rows
# Processing year: 2017
# Found 32 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2017/inotrope_2017.csv, 119634 total rows
# Processing year: 2017
# Found 17 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2017/procedure_2017.csv, 4030 total rows
# Processing year: 2017
# Found 27 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2017/crea_2017.csv, 1000044 total rows
# Processing year: 2017
# Found 17 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2017/bili_2017.csv, 425949 total rows
# Processing year: 2017
# Found 17 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2017/plt_2017.csv, 511014 total rows
# Processing year: 2017
# Found 17 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2017/lact_2017.csv, 10987 total rows
# Processing year: 2018
# Found 13 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2018/inotrope_2018.csv, 86931 total rows
# Processing year: 2018
# Found 20 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2018/procedure_2018.csv, 4345 total rows
# Processing year: 2018
# Found 28 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2018/crea_2018.csv, 1022219 total rows
# Processing year: 2018
# Found 20 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2018/bili_2018.csv, 498796 total rows
# Processing year: 2018
# Found 20 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2018/plt_2018.csv, 597379 total rows
# Processing year: 2018
# Found 20 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2018/lact_2018.csv, 20187 total rows
# Processing year: 2019
# Found 17 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2019/inotrope_2019.csv, 115810 total rows
# Processing year: 2019
# Found 34 files for year 2019
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_32756\1671836017.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(dfs, ignore_index=True)
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2019/procedure_2019.csv, 6130 total rows
# Processing year: 2019
# Found 34 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2019/crea_2019.csv, 1105910 total rows
# Processing year: 2019
# Found 34 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2019/bili_2019.csv, 818432 total rows
# Processing year: 2019
# Found 34 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2019/plt_2019.csv, 985884 total rows
# Processing year: 2019
# Found 34 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2019/lact_2019.csv, 40347 total rows
# Processing year: 2020
# Found 16 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2020/inotrope_2020.csv, 114962 total rows
# Processing year: 2020
# Found 29 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2020/procedure_2020.csv, 5324 total rows
# Processing year: 2020
# Found 29 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2020/crea_2020.csv, 1007919 total rows
# Processing year: 2020
# Found 29 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2020/bili_2020.csv, 758506 total rows
# Processing year: 2020
# Found 29 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2020/plt_2020.csv, 901016 total rows
# Processing year: 2020
# Found 29 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2020/lact_2020.csv, 43773 total rows
# Processing year: 2021
# Found 16 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2021/inotrope_2021.csv, 129401 total rows
# Processing year: 2021
# Found 31 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2021/procedure_2021.csv, 5321 total rows
# Processing year: 2021
# Found 31 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2021/crea_2021.csv, 1145685 total rows
# Processing year: 2021
# Found 31 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2021/bili_2021.csv, 852389 total rows
# Processing year: 2021
# Found 31 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2021/plt_2021.csv, 1015619 total rows
# Processing year: 2021
# Found 32 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2021/lact_2021.csv, 66512 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2022/inotrope_2022.csv, 131521 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2022/procedure_2022.csv, 5113 total rows
# Processing year: 2022
# Found 37 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2022/crea_2022.csv, 1457861 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2022/bili_2022.csv, 779785 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2022/plt_2022.csv, 917747 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2022/lact_2022.csv, 68281 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2023/inotrope_2023.csv, 146295 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2023/procedure_2023.csv, 4982 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2023/crea_2023.csv, 1088969 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2023/bili_2023.csv, 820161 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2023/plt_2023.csv, 956759 total rows
# Processing year: 2023
# Found 31 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2023/lact_2023.csv, 76742 total rows
# Processing year: 2024
# Found 34 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2024/inotrope_2024.csv, 147188 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2024/procedure_2024.csv, 5776 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2024/crea_2024.csv, 1210378 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2024/bili_2024.csv, 857258 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2024/plt_2024.csv, 1059032 total rows
# Processing year: 2024
# Found 34 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2024/lact_2024.csv, 90564 total rows

# %%
warnings.filterwarnings('ignore')
for year in range(2014, 2025):
    check_ase(year)
# Out:
# Checked Reference Key: 44
# Checked Reference Key: 1598
# Checked Reference Key: 1941
# Checked Reference Key: 2287
# Checked Reference Key: 2370
# Checked Reference Key: 2603
# Checked Reference Key: 2761
# Checked Reference Key: 3387
# Checked Reference Key: 5757
# Checked Reference Key: 6731
# Checked Reference Key: 7605
# Checked Reference Key: 8541
# Checked Reference Key: 9474
# Checked Reference Key: 11309
# Checked Reference Key: 11553
# Checked Reference Key: 12187
# Checked Reference Key: 12493
# Checked Reference Key: 13683
# Checked Reference Key: 13799
# Checked Reference Key: 13846
# Checked Reference Key: 14954
# Checked Reference Key: 15043
# Checked Reference Key: 9529103
# Checked Reference Key: 9531660
# Checked Reference Key: 9545975
# Checked Reference Key: 9583783
# Checked Reference Key: 9610370
# Checked Reference Key: 9630521
# Checked Reference Key: 9634136
# Checked Reference Key: 9676484
# Checked Reference Key: 9697279
# Checked Reference Key: 9726391
# Checked Reference Key: 9782278
# Checked Reference Key: 9783133
# Checked Reference Key: 9788592
# Checked Reference Key: 9801890
# Checked Reference Key: 9806709
# Checked Reference Key: 9818197
# Checked Reference Key: 9888525
# Checked Reference Key: 9896659
# Checked Reference Key: 9912726
# Checked Reference Key: 9922894
# Checked Reference Key: 9940420
# Checked Reference Key: 9952556
# Checked Reference Key: 9957450
# Checked Reference Key: 9982296
# Checked Reference Key: 9984645
# Checked Reference Key: 10010875
# Checked Reference Key: 10010997
# Checked Reference Key: 10012622
# Checked Reference Key: 10029996
# Checked Reference Key: 10032457
# Checked Reference Key: 10035334
# Checked Reference Key: 10039505
# Checked Reference Key: 10086543
# Checked Reference Key: 10119371
# Checked Reference Key: 10152680
# Checked Reference Key: 10189663
# Checked Reference Key: 10205173
# Checked Reference Key: 10208001
# Checked Reference Key: 10232218
# Checked Reference Key: 10246702
# Checked Reference Key: 10273503
# Checked Reference Key: 10291851
# Checked Reference Key: 10319428
# Checked Reference Key: 10333332
# Checked Reference Key: 10341927
# Checked Reference Key: 10342794
# Checked Reference Key: 10343803
# Checked Reference Key: 10365955
# Checked Reference Key: 10373775
# Checked Reference Key: 10391630
# Checked Reference Key: 10428981
# Checked Reference Key: 10442164
# Checked Reference Key: 10475830
# Checked Reference Key: 10487131
# Checked Reference Key: 10510302
# Checked Reference Key: 10540662
# Checked Reference Key: 10574086
# Checked Reference Key: 10580002
# Checked Reference Key: 10583814
# Checked Reference Key: 10617917
# Checked Reference Key: 10639357
# Checked Reference Key: 10662509
# Checked Reference Key: 10680826
# Checked Reference Key: 10687974
# Checked Reference Key: 10703970
# Checked Reference Key: 10705258
# Checked Reference Key: 10710503
# Checked Reference Key: 10711865
# Checked Reference Key: 10714061
# Checked Reference Key: 10718143
# Checked Reference Key: 10724740
# Checked Reference Key: 10738028
# Checked Reference Key: 10740884
# Checked Reference Key: 10752731
# Checked Reference Key: 10756331
# Checked Reference Key: 10770797
# Checked Reference Key: 10819974
# Checked Reference Key: 10841971
# Checked Reference Key: 10860435
# Checked Reference Key: 10863075
# Checked Reference Key: 10874422
# Checked Reference Key: 10887098
# Checked Reference Key: 10887658
# Checked Reference Key: 10890426
# Checked Reference Key: 10897236
# Checked Reference Key: 10903372
# Checked Reference Key: 10903820
# Checked Reference Key: 10904618
# Checked Reference Key: 10909306
# Checked Reference Key: 10910605
# Checked Reference Key: 10911066
# Checked Reference Key: 10912092
# Checked Reference Key: 10917456
# Checked Reference Key: 10917742
# Checked Reference Key: 10918987
# Checked Reference Key: 10920401
# Checked Reference Key: 10920816
# Checked Reference Key: 10921059
# Checked Reference Key: 10921254
# Checked Reference Key: 10921587
# Checked Reference Key: 10921700
# Checked Reference Key: 10922082
# Checked Reference Key: 10922687
# Checked Reference Key: 10922783
# Checked Reference Key: 10922822
# Checked Reference Key: 10922870
# Checked Reference Key: 10922945
# Checked Reference Key: 10923174
# Checked Reference Key: 10923231
# Checked Reference Key: 10923314
# Checked Reference Key: 10923320
# Checked Reference Key: 10923442
# Checked Reference Key: 10923610
# Checked Reference Key: 10923619
# Checked Reference Key: 10923628
# Checked Reference Key: 10923800
# Checked Reference Key: 10923944
# Checked Reference Key: 10923961
# Checked Reference Key: 10924160
# Checked Reference Key: 10924358
# Checked Reference Key: 10924362
# Checked Reference Key: 10924406
# Checked Reference Key: 10924803
# Checked Reference Key: 10924819
# Checked Reference Key: 10924939
# Checked Reference Key: 10924942
# Checked Reference Key: 10925013
# Checked Reference Key: 10925168
# Checked Reference Key: 10925177
# Checked Reference Key: 10925582
# Checked Reference Key: 10925694
# Checked Reference Key: 10926175
# Checked Reference Key: 10927016
# Checked Reference Key: 10927315
# Checked Reference Key: 10927336
# Checked Reference Key: 10927421
# Checked Reference Key: 10927527
# Checked Reference Key: 10928190
# Checked Reference Key: 10928236
# Checked Reference Key: 10928237
# Checked Reference Key: 10928377
# Checked Reference Key: 10928379
# Checked Reference Key: 10928418
# Checked Reference Key: 10928422
# Checked Reference Key: 10928447
# Checked Reference Key: 10928540
# Checked Reference Key: 10928656
# Checked Reference Key: 10928690
# Checked Reference Key: 10929018
# Checked Reference Key: 10929248
# Checked Reference Key: 10929853
# Checked Reference Key: 10942925
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[43], line 3
#       1 warnings.filterwarnings('ignore')
#       2 for year in range(2014, 2025):
# ----> 3     check_ase(year)
#
# Cell In[40], line 59, in check_ase(year)
#      57 results_df = pd.DataFrame(results)
#      58 output_file = os.path.join(DATA_PATH, f'/Output/ase/ase_{year}.csv')
# ---> 59 results_df.to_csv(output_file, index=False)
#      60 print(f"ASE vasopressor results saved to {output_file}")
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '\Output\ase'

# %%
file = "./presumed_infection/2.Data/Output/ase/ase_2014.csv"
create_ASE_list(file, 2014)
# Out:
# ASE patient list saved to ./presumed_infection/2024/ASE_patient_list_2024.csv
#         Reference Key    HN Number Institution (IPAS)
# 0               26473  HN24001457B                HHH
# 1               26473  HN24001457B                HHH
# 2               26473  HN24001457B                HHH
# 3               26473  HN24001457B                HHH
# 4               26473  HN24001457B                HHH
# ...               ...          ...                ...
# 263265       13633488  HN243652012                PMH
# 263266       13633488  HN243652012                PMH
# 263267       13633488  HN243652012                PMH
# 263268       13633488  HN243652012                PMH
# 263269       13633488  HN243652012                PMH
#
# [263270 rows x 3 columns]

# %%
file = "./presumed_infection/2.Data/Output/ase/ase_2014.csv"
ase_percentages(file)
# Out:
# {'vasopressor': 2.23,
#  'ventilation': 1.02,
#  'creatinine': 12.09,
#  'bili': 6.86,
#  'plt': 5.04,
#  'lact': 1.9}
