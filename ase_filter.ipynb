# %%
# import libraries
import os
import pandas as pd
import glob
import warnings
import datetime

# define file paths
year = 2024
# DATA_PATH = f"./presumed_infection/2.Data/New Data/"
DATA_PATH = f"./presumed_infection/2.Data/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*resumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def filter_presumed(year): # filter presumed infection cases for a specific year
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Institution (IPAS)' not in presumed_df.columns or 'HN Number' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Institution (IPAS)' not in demographic_df.columns or 'HN Number' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    mask = demographic_df.apply(lambda row: (row['Institution (IPAS)'], row['HN Number']) in presumed_tuples, axis=1)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def filter_presumed_RK(year): # filter presumed infection cases for a specific year using Reference Key
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}_RK.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Reference Key' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Reference Key' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(presumed_df['Reference Key'].tolist())
    mask = demographic_df['Reference Key'].isin(presumed_tuples)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def check_missing_presumed(year):
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Filtered demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH) 
    demo_df = pd.read_csv(DEMO_PATH)
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    demo_tuples = set(zip(demo_df['Institution (IPAS)'], demo_df['HN Number']))
    missing_tuples = presumed_tuples - demo_tuples
    missing_count = len(missing_tuples)
    print(f"Year {year}: {missing_count} presumed infection cases not found in demographic data")
    if missing_count > 0:
        missing_df = pd.DataFrame(list(missing_tuples), columns=['Institution (IPAS)', 'HN Number'])
        OUTPUT_PATH = os.path.join(DATA_PATH, f'Demographics/{year}/missing_presumed_{year}.csv')
        missing_df.to_csv(OUTPUT_PATH, index=False)
        print(f"Missing cases saved to {OUTPUT_PATH}")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, crea, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/{data_type.title()}/{year}/"
        pattern = "*resumedInfection_" + data_type.title() + "_"
    elif data_type == "crea": # alternative filename handling for crea
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/"
        pattern = "*resumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/"
        pattern = "*resumedInfection_lactate_"
    elif data_type == "bili": # alternative filename handling for bili
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"
    elif data_type == "plt": # alternative filename handling for plt
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def retrieve_blood_dates(HN, institution, date_df):
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    if 'blood culture date' in df.columns and not df.empty:
        blood_dates = pd.to_datetime(df['blood culture date'], errors='coerce').dropna().unique()
        return [date.strftime('%Y-%m-%d') for date in blood_dates]
    return []

def check_date_in_window(target_date, blood_dates_array):
    if not blood_dates_array or not target_date:
        return False
    target = pd.to_datetime(target_date)
    for blood_date_str in blood_dates_array:
        blood_date = pd.to_datetime(blood_date_str)
        date_diff = abs((target - blood_date).days)
        if date_diff <= 2:
            return True
    return False

# %%
# def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
#     df = date_df[date_df['Reference Key'] == Ref_Key].copy() # using first entry only, use array to store all dates if needed
#     if 'blood culture date' in df.columns and not df.empty:
#         blood_culture_date = pd.to_datetime(df.iloc[0]['blood culture date'], errors='coerce')
#         deadline_date = blood_culture_date + pd.Timedelta(days=2) # 2 days after blood culture (deadline)
#         return deadline_date.strftime('%Y-%m-%d')
#     return None

    # if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
    #     admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
    #     deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
    #     return deadline_date.strftime('%Y-%m-%d')
    # return None

# %%
def check_vasopressor(df, blood_dates_array): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin unused
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    if df.empty:
        return False, None
    if 'Drug Name' not in df.columns or 'Prescription Start Date' not in df.columns:
        return False, None
    df = df.copy()
    df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
    for drug in vasopressor_list:
        drug_mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False)
        drug_dates = df.loc[drug_mask, 'Prescription Start Date'].dropna().unique()
        for admin_date in drug_dates:
            if check_date_in_window(admin_date, blood_dates_array):
                one_day_before = admin_date - datetime.timedelta(days=1) # To count as a new vasopressor, that specific vasopressor cannot have been administered in the prior calendar day
                if not drug_mask.any() or one_day_before not in drug_dates:
                    return True, admin_date
    return False, None

# %%
def check_ventilation(df, blood_dates_array): # check if mechanical ventilation is initiated
    if df.empty:
        return False, None
    if 'RespFailOnsetDate' not in df.columns:
        return False, None
    for onset_date in df['RespFailOnsetDate']:
        if check_date_in_window(onset_date, blood_dates_array):
            return True, onset_date
    return False, None

# %%
def filter_renal(): # filter end-stage renal disease patients (unused)
    DXPX_PATH = DATA_PATH + f"demographic/demographic_{year}.csv"
    df = pd.read_csv(DXPX_PATH)
    disease_list = []
    if 'Reference Key' in df.columns and 'Dx/Px Description (HAMDCT)' in df.columns:
        df['renal'] = df['Dx/Px Description (HAMDCT)'].str.lower().str.contains('|'.join(disease_list), case=False, na=False) 
        result_df = df[['Reference Key', 'renal']].drop_duplicates()       
        return result_df
    else:
        print("Required columns not found")
        return pd.DataFrame(columns=['Reference Key', 'renal'])
    
# only keeps first occurence(?), need change to eGFR>20

# %%
def check_creatinine(df, blood_dates_array, CO): # check if creatinine level is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    if CO: # CO baseline lowest during hospitalization
        baseline = df['LIS Result: Numeric Result'].min()
        for _, row in window_df.iterrows():
            if row['LIS Result: Numeric Result'] >= baseline * 2:
                return True, row['LIS Reference Date']
    else: # HO baseline within window
        baseline = window_df['LIS Result: Numeric Result'].min()
        for _, row in window_df.iterrows():
            if row['LIS Result: Numeric Result'] >= baseline * 2:
                return True, row['LIS Reference Date']
    return False, None

# %%
def check_bili(df, blood_dates_array, CO): # check if bilirubin level is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    if CO: # CO baseline lowest during hospitalization
        baseline = df['LIS Result: Numeric Result'].min()
        baseline_mgdl = baseline * 0.058467 # convert umol/L to mg/dL
        for _, row in window_df.iterrows():
            value_mgdl = row['LIS Result: Numeric Result'] * 0.058467
            if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                return True, row['LIS Reference Date']
    else: # HO baseline within window
        baseline = window_df['LIS Result: Numeric Result'].min()
        baseline_mgdl = baseline * 0.058467
        for _, row in window_df.iterrows():
            value_mgdl = row['LIS Result: Numeric Result'] * 0.058467
            if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                return True, row['LIS Reference Date']
    return False, None

# %%
def check_plt(df, blood_dates_array, CO): # check if platelet count is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    if CO: # CO baseline highest during hospitalization
        baseline = df['LIS Result: Numeric Result'].max()
        for _, row in window_df.iterrows():
            if row['LIS Result: Numeric Result'] < 100 and row['LIS Result: Numeric Result'] <= baseline * 0.5:
                return True, row['LIS Reference Date']
    else: # HO baseline within window
        baseline = window_df['LIS Result: Numeric Result'].max()
        window_df = window_df.sort_values('LIS Reference Date')
        for _, row in window_df.iterrows():
            if row['LIS Result: Numeric Result'] < 100 and row['LIS Result: Numeric Result'] <= baseline * 0.5:
                return True, row['LIS Reference Date']
    return False, None

# %%
def check_lact(df, blood_dates_array): # check if lactate level is abnormal
    if df.empty:
        return False, None
    if 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
    df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
    for _, row in df.iterrows():
        if check_date_in_window(row['LIS Reference Date'], blood_dates_array):
            if row['LIS Result: Numeric Result'] >= 2.0:
                return True, row['LIS Reference Date']
    return False, None

# %%
def check_CO(HN, institution, date_df, demo_df): # TRUE if community onset, FALSE if hospital onset (unused)
    # TRUE if blood culture date/first QAD date is within 2 days of admission date
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    if df.empty:
        print("missing date data")
        return False
    demo_row = demo_df[(demo_df['HN Number'] == HN) & (demo_df['Institution (IPAS)'] == institution)] 
    if demo_row.empty:
        print("missing demographic data")
        return False
    admission_date = pd.to_datetime(demo_row['Admission Date (yyyy-mm-dd)'].iloc[0])
    blood_date = pd.to_datetime(df['blood culture date'].iloc[0]) if 'blood culture date' in df.columns else None
    qad_date = pd.to_datetime(df['first_qad_date'].iloc[0]) if 'first_qad_date' in df.columns else None
    if blood_date is not None and abs((blood_date - admission_date).days) <= 2:
        return True
    if qad_date is not None and abs((qad_date - admission_date).days) <= 2:
        return True
    return False

# %%
def check_ase(year): # reimplemented (composite key) using AI for optimization
    KEY_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    df = pd.read_csv(KEY_PATH)
    print(f"Loaded demographic data: {len(df)} rows")
    df['composite_key'] = df['HN Number'].astype(str) + '_' + df['Institution (IPAS)'].astype(str)
    df = df.drop_duplicates(subset=['composite_key'])
    print(f"After deduplication: {len(df)} rows")
    keys = df[['HN Number', 'Institution (IPAS)']].drop_duplicates().values.tolist()
    print(f"Found {len(keys)} unique patient-institution combinations")
    
    if len(keys) == 0:
        print("ERROR: No keys found!")
        return
    
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv"
    date_df = pd.read_csv(DATE_PATH)
    print(f"Loaded date data: {len(date_df)} rows")
    date_df['composite_key'] = date_df['HN Number'].astype(str) + '_' + date_df['Institution (IPAS)'].astype(str)
    date_df = date_df.set_index('composite_key')
    print(f"Indexed date data")
    
    INOTROPE_PATH = DATA_PATH + f"Lab_Test_Results/Inotrope/{year}/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    print(f"Loaded inotrope data: {len(inotrope_df)} rows")
    inotrope_df['composite_key'] = inotrope_df['HN Number'].astype(str) + '_' + inotrope_df['Institution (IPAS)'].astype(str)
    inotrope_df = inotrope_df.set_index('composite_key')
    print(f"Indexed inotrope data")
    
    CREATININE_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/crea_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    print(f"Loaded creatinine data: {len(creatinine_df)} rows")
    creatinine_df['composite_key'] = creatinine_df['HN Number'].astype(str) + '_' + creatinine_df['Institution (IPAS)'].astype(str)
    creatinine_df = creatinine_df.set_index('composite_key')
    print(f"Indexed creatinine data")
    
    BILI_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    print(f"Loaded bilirubin data: {len(bili_df)} rows")
    bili_df['composite_key'] = bili_df['HN Number'].astype(str) + '_' + bili_df['Institution (IPAS)'].astype(str)
    bili_df = bili_df.set_index('composite_key')
    print(f"Indexed bilirubin data")
    
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    print(f"Loaded platelet data: {len(plt_df)} rows")
    plt_df['composite_key'] = plt_df['HN Number'].astype(str) + '_' + plt_df['Institution (IPAS)'].astype(str)
    plt_df = plt_df.set_index('composite_key')
    print(f"Indexed platelet data")
    
    LACT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    print(f"Loaded lactate data: {len(lact_df)} rows")
    lact_df['composite_key'] = lact_df['HN Number'].astype(str) + '_' + lact_df['Institution (IPAS)'].astype(str)
    lact_df = lact_df.set_index('composite_key')
    print(f"Indexed lactate data")
    
    RESP_PATH = DATA_PATH + f"RespFailList.csv"
    resp_fail_df = pd.read_csv(RESP_PATH)
    print(f"Loaded RespFailList data: {len(resp_fail_df)} rows")
    resp_fail_df['composite_key'] = resp_fail_df['HN Number'].astype(str) + '_' + resp_fail_df['Institution (IPAS)'].astype(str)
    resp_fail_df = resp_fail_df.set_index('composite_key')
    print(f"Indexed RespFailList data")
    
    results = []
    output_file = os.path.join(DATA_PATH, 'Output', 'ase', f'ase_{year}.csv')
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    demo_dict = df.set_index('composite_key').to_dict('index')
    print(f"Created demo_dict with {len(demo_dict)} entries")
    
    admission_dict = {}
    total_patients = len(demo_dict)
    print(f"Extracting admission dates for {total_patients} patients...")
    
    demo_df = pd.DataFrame.from_dict(demo_dict, orient='index')
    demo_df.index.name = 'composite_key'
    demo_df['Admission Date (yyyy-mm-dd)'] = pd.to_datetime(demo_df['Admission Date (yyyy-mm-dd)'], errors='coerce')
    admission_dict = demo_df['Admission Date (yyyy-mm-dd)'].to_dict()
    print(f"Extracted admission dates for {len(admission_dict)} patients")

    co_dict = {}
    print(f"Pre-calculating CO for {total_patients} patients...")
    
    for idx, (composite_key, admission_date) in enumerate(admission_dict.items()):
        if idx % 10000 == 0 and idx > 0:
            print(f"  Pre-calculating CO: {idx}/{total_patients} patients processed")
        
        if admission_date is None:
            co_dict[composite_key] = False
            continue
        
        try:
            date_rows = date_df.loc[[composite_key]]
        except KeyError:
            co_dict[composite_key] = False
            continue
        
        if date_rows.empty:
            co_dict[composite_key] = False
            continue
        
        first_row = date_rows.iloc[0]
        blood_date = pd.to_datetime(first_row.get('blood culture date')) if 'blood culture date' in first_row else None
        qad_date = pd.to_datetime(first_row.get('first_qad_date')) if 'first_qad_date' in first_row else None
        
        if blood_date is not None and abs((blood_date - admission_date).days) <= 2:
            co_dict[composite_key] = True
        elif qad_date is not None and abs((qad_date - admission_date).days) <= 2:
            co_dict[composite_key] = True
        else:
            co_dict[composite_key] = False
    
    print(f"CO pre-calculation complete. {len(co_dict)} entries")
    
    total_keys = len(keys)
    print(f"Starting main loop for {total_keys} patients...")
    
    # temp = 0 # testing variable
    for i, key in enumerate(keys):
        # if temp >= 100:
        #     break
        # temp += 1
        if i % 1000 == 0 and idx > 0:
            print(f"  Processing main loop: {i}/{total_keys} patients completed")
        
        HN = key[0]
        institution = key[1]
        composite_key = str(HN) + '_' + str(institution)
        
        admission_date = admission_dict.get(composite_key)
        
        try:
            date_rows = date_df.loc[[composite_key]]
            blood_dates_array = date_rows['blood culture date'].tolist() if not date_rows.empty else []
        except KeyError:
            blood_dates_array = []
        
        CO = co_dict.get(composite_key, False)
        
        try:
            inotrope_subdf = inotrope_df.loc[[composite_key]]
        except KeyError:
            inotrope_subdf = pd.DataFrame()
        
        try:
            creatinine_subdf = creatinine_df.loc[[composite_key]]
        except KeyError:
            creatinine_subdf = pd.DataFrame()
        
        try:
            bili_subdf = bili_df.loc[[composite_key]]
        except KeyError:
            bili_subdf = pd.DataFrame()
        
        try:
            plt_subdf = plt_df.loc[[composite_key]]
        except KeyError:
            plt_subdf = pd.DataFrame()
        
        try:
            lact_subdf = lact_df.loc[[composite_key]]
        except KeyError:
            lact_subdf = pd.DataFrame()
        
        try:
            resp_subdf = resp_fail_df.loc[[composite_key]]
        except KeyError:
            resp_subdf = pd.DataFrame()
        
        vasopressor_result, vasopressor_date = check_vasopressor(inotrope_subdf, blood_dates_array)
        ventilation_result, ventilation_date = check_ventilation(resp_subdf, blood_dates_array)
        creatinine_result, creatinine_date = check_creatinine(creatinine_subdf, blood_dates_array, CO)
        bili_result, bili_date = check_bili(bili_subdf, blood_dates_array, CO)
        plt_result, plt_date = check_plt(plt_subdf, blood_dates_array, CO)
        lact_result, lact_date = check_lact(lact_subdf, blood_dates_array)
        
        all_dates = []
        if vasopressor_date is not None:
            all_dates.append(pd.to_datetime(vasopressor_date))
        if ventilation_date is not None:
            all_dates.append(pd.to_datetime(ventilation_date))
        if creatinine_date is not None:
            all_dates.append(pd.to_datetime(creatinine_date))
        if bili_date is not None:
            all_dates.append(pd.to_datetime(bili_date))
        if plt_date is not None:
            all_dates.append(pd.to_datetime(plt_date))
        if lact_date is not None:
            all_dates.append(pd.to_datetime(lact_date))
        
        within_48h = False
        if all_dates and admission_date is not None:
            earliest_date = min(all_dates)
            within_48h = abs((earliest_date - admission_date).days) <= 2
        
        result = {
            'HN Number': HN,
            'Institution (IPAS)': institution,
            'vasopressor': vasopressor_result,
            'ventilation': ventilation_result,
            'creatinine': creatinine_result,
            'bili': bili_result,
            'plt': plt_result,
            'lact': lact_result,
            'CO': CO,
            'within_48h': within_48h
        }
        results.append(result)
    
    print(f"Main loop complete. Collected {len(results)} results")
    
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_file, index=False)
    print(f"ASE results saved to {output_file}")

# %%
def create_ASE_list(file, year): # create list of ase patients with institution by matching ase filter output (unused)
    ase_df = pd.read_csv(file, dtype={'Reference Key': str}, low_memory=False)
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    ase_df['Overall'] = ase_df[condition_cols].any(axis=1)
    true_ase_df = ase_df[ase_df['Overall'] == True].copy()
    output_file = os.path.join(DATA_PATH, f'ASE_patient_list_{year}.csv')
    true_ase_df[['HN Number', 'Institution (IPAS)']].to_csv(output_file, index=False)
    return true_ase_df[['HN Number', 'Institution (IPAS)']]

# %%
def ase_percentages(file):
    df = pd.read_csv(file)
    percentages = {}
    for column in df.columns[2:8]:  # 6 OD columns
        if df[column].dtype == bool or df[column].isin([True, False, 'TRUE', 'FALSE']).all():
            true_count = (df[column] == True).sum() + (df[column] == 'TRUE').sum()
            total_count = len(df[column])
            percentage = (true_count / total_count * 100) if total_count > 0 else 0
            percentages[column] = round(percentage, 2)
    return percentages

# %%
for year in range(2022,2023): # 2025 currently missing
    merge_demographic(year)
    # filter_presumed(year)
    # filter_presumed_RK(year)
    # check_missing_presumed(year)
    data_types = ["inotrope", "procedure", "crea", "bili", "plt", "lact"]
    for data_type in data_types:
        merge_data(data_type, year)
# Out:
# Processing year: 2022
# Found 32 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Demographics/2022/demographic_2022.csv, 923493 total rows
# Processing year: 2022
# Found 28 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2022/inotrope_2022.csv, 164678 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2022/procedure_2022.csv, 5113 total rows
# Processing year: 2022
# Found 44 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2022/crea_2022.csv, 1696636 total rows
# Processing year: 2022
# Found 44 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2022/bili_2022.csv, 907663 total rows
# Processing year: 2022
# Found 44 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2022/plt_2022.csv, 1069411 total rows
# Processing year: 2022
# Found 28 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2022/lact_2022.csv, 84446 total rows

# %%
warnings.filterwarnings('ignore')
for year in range(2022, 2023): # no 2019 (need download)
    check_ase(year)
# Out:
# Loaded demographic data: 923493 rows
# After deduplication: 197988 rows
# Found 197988 unique patient-institution combinations
# Loaded date data: 139901 rows
# Indexed date data
# Loaded inotrope data: 164678 rows
# Indexed inotrope data
# Loaded creatinine data: 1696636 rows
# Indexed creatinine data
# Loaded bilirubin data: 907663 rows
# Indexed bilirubin data
# Loaded platelet data: 1069411 rows
# Indexed platelet data
# Loaded lactate data: 84446 rows
# Indexed lactate data
# Loaded RespFailList data: 101505 rows
# Indexed RespFailList data
# Created demo_dict with 197988 entries
# Extracting admission dates for 197988 patients...
# Extracted admission dates for 197988 patients
# Pre-calculating CO for 197988 patients...
#   Pre-calculating CO: 10000/197988 patients processed
#   Pre-calculating CO: 20000/197988 patients processed
#   Pre-calculating CO: 30000/197988 patients processed
#   Pre-calculating CO: 40000/197988 patients processed
#   Pre-calculating CO: 50000/197988 patients processed
#   Pre-calculating CO: 60000/197988 patients processed
#   Pre-calculating CO: 70000/197988 patients processed
#   Pre-calculating CO: 80000/197988 patients processed
#   Pre-calculating CO: 90000/197988 patients processed
#   Pre-calculating CO: 100000/197988 patients processed
#   Pre-calculating CO: 110000/197988 patients processed
#   Pre-calculating CO: 120000/197988 patients processed
#   Pre-calculating CO: 130000/197988 patients processed
#   Pre-calculating CO: 140000/197988 patients processed
#   Pre-calculating CO: 150000/197988 patients processed
#   Pre-calculating CO: 160000/197988 patients processed
#   Pre-calculating CO: 170000/197988 patients processed
#   Pre-calculating CO: 180000/197988 patients processed
#   Pre-calculating CO: 190000/197988 patients processed
# CO pre-calculation complete. 197988 entries
# Starting main loop for 197988 patients...
#   Processing main loop: 0/197988 patients completed
#   Processing main loop: 1000/197988 patients completed
#   Processing main loop: 2000/197988 patients completed
#   Processing main loop: 3000/197988 patients completed
#   Processing main loop: 4000/197988 patients completed
#   Processing main loop: 5000/197988 patients completed
#   Processing main loop: 6000/197988 patients completed
#   Processing main loop: 7000/197988 patients completed
#   Processing main loop: 8000/197988 patients completed
#   Processing main loop: 9000/197988 patients completed
#   Processing main loop: 10000/197988 patients completed
#   Processing main loop: 11000/197988 patients completed
#   Processing main loop: 12000/197988 patients completed
#   Processing main loop: 13000/197988 patients completed
#   Processing main loop: 14000/197988 patients completed
#   Processing main loop: 15000/197988 patients completed
#   Processing main loop: 16000/197988 patients completed
#   Processing main loop: 17000/197988 patients completed
#   Processing main loop: 18000/197988 patients completed
#   Processing main loop: 19000/197988 patients completed
#   Processing main loop: 20000/197988 patients completed
#   Processing main loop: 21000/197988 patients completed
#   Processing main loop: 22000/197988 patients completed
#   Processing main loop: 23000/197988 patients completed
#   Processing main loop: 24000/197988 patients completed
#   Processing main loop: 25000/197988 patients completed
#   Processing main loop: 26000/197988 patients completed
#   Processing main loop: 27000/197988 patients completed
#   Processing main loop: 28000/197988 patients completed
#   Processing main loop: 29000/197988 patients completed
#   Processing main loop: 30000/197988 patients completed
#   Processing main loop: 31000/197988 patients completed
#   Processing main loop: 32000/197988 patients completed
#   Processing main loop: 33000/197988 patients completed
#   Processing main loop: 34000/197988 patients completed
#   Processing main loop: 35000/197988 patients completed
#   Processing main loop: 36000/197988 patients completed
#   Processing main loop: 37000/197988 patients completed
#   Processing main loop: 38000/197988 patients completed
#   Processing main loop: 39000/197988 patients completed
#   Processing main loop: 40000/197988 patients completed
#   Processing main loop: 41000/197988 patients completed
#   Processing main loop: 42000/197988 patients completed
#   Processing main loop: 43000/197988 patients completed
#   Processing main loop: 44000/197988 patients completed
#   Processing main loop: 45000/197988 patients completed
#   Processing main loop: 46000/197988 patients completed
#   Processing main loop: 47000/197988 patients completed
#   Processing main loop: 48000/197988 patients completed
#   Processing main loop: 49000/197988 patients completed
#   Processing main loop: 50000/197988 patients completed
#   Processing main loop: 51000/197988 patients completed
#   Processing main loop: 52000/197988 patients completed
#   Processing main loop: 53000/197988 patients completed
#   Processing main loop: 54000/197988 patients completed
#   Processing main loop: 55000/197988 patients completed
#   Processing main loop: 56000/197988 patients completed
#   Processing main loop: 57000/197988 patients completed
#   Processing main loop: 58000/197988 patients completed
#   Processing main loop: 59000/197988 patients completed
#   Processing main loop: 60000/197988 patients completed
#   Processing main loop: 61000/197988 patients completed
#   Processing main loop: 62000/197988 patients completed
#   Processing main loop: 63000/197988 patients completed
#   Processing main loop: 64000/197988 patients completed
#   Processing main loop: 65000/197988 patients completed
#   Processing main loop: 66000/197988 patients completed
#   Processing main loop: 67000/197988 patients completed
#   Processing main loop: 68000/197988 patients completed
#   Processing main loop: 69000/197988 patients completed
#   Processing main loop: 70000/197988 patients completed
#   Processing main loop: 71000/197988 patients completed
#   Processing main loop: 72000/197988 patients completed
#   Processing main loop: 73000/197988 patients completed
#   Processing main loop: 74000/197988 patients completed
#   Processing main loop: 75000/197988 patients completed
#   Processing main loop: 76000/197988 patients completed
#   Processing main loop: 77000/197988 patients completed
#   Processing main loop: 78000/197988 patients completed
#   Processing main loop: 79000/197988 patients completed
#   Processing main loop: 80000/197988 patients completed
#   Processing main loop: 81000/197988 patients completed
#   Processing main loop: 82000/197988 patients completed
#   Processing main loop: 83000/197988 patients completed
#   Processing main loop: 84000/197988 patients completed
#   Processing main loop: 85000/197988 patients completed
#   Processing main loop: 86000/197988 patients completed
#   Processing main loop: 87000/197988 patients completed
#   Processing main loop: 88000/197988 patients completed
#   Processing main loop: 89000/197988 patients completed
#   Processing main loop: 90000/197988 patients completed
#   Processing main loop: 91000/197988 patients completed
#   Processing main loop: 92000/197988 patients completed
#   Processing main loop: 93000/197988 patients completed
#   Processing main loop: 94000/197988 patients completed
#   Processing main loop: 95000/197988 patients completed
#   Processing main loop: 96000/197988 patients completed
#   Processing main loop: 97000/197988 patients completed
#   Processing main loop: 98000/197988 patients completed
#   Processing main loop: 99000/197988 patients completed
#   Processing main loop: 100000/197988 patients completed
#   Processing main loop: 101000/197988 patients completed
#   Processing main loop: 102000/197988 patients completed
#   Processing main loop: 103000/197988 patients completed
#   Processing main loop: 104000/197988 patients completed
#   Processing main loop: 105000/197988 patients completed
#   Processing main loop: 106000/197988 patients completed
#   Processing main loop: 107000/197988 patients completed
#   Processing main loop: 108000/197988 patients completed
#   Processing main loop: 109000/197988 patients completed
#   Processing main loop: 110000/197988 patients completed
#   Processing main loop: 111000/197988 patients completed
#   Processing main loop: 112000/197988 patients completed
#   Processing main loop: 113000/197988 patients completed
#   Processing main loop: 114000/197988 patients completed
#   Processing main loop: 115000/197988 patients completed
#   Processing main loop: 116000/197988 patients completed
#   Processing main loop: 117000/197988 patients completed
#   Processing main loop: 118000/197988 patients completed
#   Processing main loop: 119000/197988 patients completed
#   Processing main loop: 120000/197988 patients completed
#   Processing main loop: 121000/197988 patients completed
#   Processing main loop: 122000/197988 patients completed
#   Processing main loop: 123000/197988 patients completed
#   Processing main loop: 124000/197988 patients completed
#   Processing main loop: 125000/197988 patients completed
#   Processing main loop: 126000/197988 patients completed
#   Processing main loop: 127000/197988 patients completed
#   Processing main loop: 128000/197988 patients completed
#   Processing main loop: 129000/197988 patients completed
#   Processing main loop: 130000/197988 patients completed
#   Processing main loop: 131000/197988 patients completed
#   Processing main loop: 132000/197988 patients completed
#   Processing main loop: 133000/197988 patients completed
#   Processing main loop: 134000/197988 patients completed
#   Processing main loop: 135000/197988 patients completed
#   Processing main loop: 136000/197988 patients completed
#   Processing main loop: 137000/197988 patients completed
#   Processing main loop: 138000/197988 patients completed
#   Processing main loop: 139000/197988 patients completed
#   Processing main loop: 140000/197988 patients completed
#   Processing main loop: 141000/197988 patients completed
#   Processing main loop: 142000/197988 patients completed
#   Processing main loop: 143000/197988 patients completed
#   Processing main loop: 144000/197988 patients completed
#   Processing main loop: 145000/197988 patients completed
#   Processing main loop: 146000/197988 patients completed
#   Processing main loop: 147000/197988 patients completed
#   Processing main loop: 148000/197988 patients completed
#   Processing main loop: 149000/197988 patients completed
#   Processing main loop: 150000/197988 patients completed
#   Processing main loop: 151000/197988 patients completed
#   Processing main loop: 152000/197988 patients completed
#   Processing main loop: 153000/197988 patients completed
#   Processing main loop: 154000/197988 patients completed
#   Processing main loop: 155000/197988 patients completed
#   Processing main loop: 156000/197988 patients completed
#   Processing main loop: 157000/197988 patients completed
#   Processing main loop: 158000/197988 patients completed
#   Processing main loop: 159000/197988 patients completed
#   Processing main loop: 160000/197988 patients completed
#   Processing main loop: 161000/197988 patients completed
#   Processing main loop: 162000/197988 patients completed
#   Processing main loop: 163000/197988 patients completed
#   Processing main loop: 164000/197988 patients completed
#   Processing main loop: 165000/197988 patients completed
#   Processing main loop: 166000/197988 patients completed
#   Processing main loop: 167000/197988 patients completed
#   Processing main loop: 168000/197988 patients completed
#   Processing main loop: 169000/197988 patients completed
#   Processing main loop: 170000/197988 patients completed
#   Processing main loop: 171000/197988 patients completed
#   Processing main loop: 172000/197988 patients completed
#   Processing main loop: 173000/197988 patients completed
#   Processing main loop: 174000/197988 patients completed
#   Processing main loop: 175000/197988 patients completed
#   Processing main loop: 176000/197988 patients completed
#   Processing main loop: 177000/197988 patients completed
#   Processing main loop: 178000/197988 patients completed
#   Processing main loop: 179000/197988 patients completed
#   Processing main loop: 180000/197988 patients completed
#   Processing main loop: 181000/197988 patients completed
#   Processing main loop: 182000/197988 patients completed
#   Processing main loop: 183000/197988 patients completed
#   Processing main loop: 184000/197988 patients completed
#   Processing main loop: 185000/197988 patients completed
#   Processing main loop: 186000/197988 patients completed
#   Processing main loop: 187000/197988 patients completed
#   Processing main loop: 188000/197988 patients completed
#   Processing main loop: 189000/197988 patients completed
#   Processing main loop: 190000/197988 patients completed
#   Processing main loop: 191000/197988 patients completed
#   Processing main loop: 192000/197988 patients completed
#   Processing main loop: 193000/197988 patients completed
#   Processing main loop: 194000/197988 patients completed
#   Processing main loop: 195000/197988 patients completed
#   Processing main loop: 196000/197988 patients completed
#   Processing main loop: 197000/197988 patients completed
# Main loop complete. Collected 197988 results
# ASE results saved to ./presumed_infection/2.Data/Output\ase\ase_2022.csv

# %%
file = DATA_PATH + "Output/ase/ase_2022.csv"
create_ASE_list(file, 2022)
# Out:
#           HN Number Institution (IPAS)
# 6       HN22108480I                NDH
# 10      HN220336081                QMH
# 13      HN220294297                PYN
# 16      HN220311887                QMH
# 20      HN220303725                PYN
# ...             ...                ...
# 197970  HN220294862                TMH
# 197975  HN22014993J                KWH
# 197982  HN220267111                YCH
# 197986  HN221455444                TMH
# 197987  HN22100162H                NDH
#
# [30354 rows x 2 columns]

# %%
file = DATA_PATH + "Output/ase/ase_2022.csv"
ase_percentages(file)
# Out:
# {'vasopressor': 4.55,
#  'ventilation': 0.97,
#  'creatinine': 6.19,
#  'bili': 3.06,
#  'plt': 3.07,
#  'lact': 5.07}

# %%
from glob import glob

# AI generated summarization code
def extract_true_cases():
    """Extract all HN+Institution pairs with at least one True across all years"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    true_cases = []
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Check if any of the condition columns are True
        condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
        df['has_true'] = df[condition_cols].any(axis=1)
        
        # Extract HN+Institution pairs with at least one True
        year_true = df[df['has_true']][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        
        for _, row in year_true.iterrows():
            true_cases.append({
                'HN Number': row['HN Number'], 
                'Institution (IPAS)': row['Institution (IPAS)'],
                'Year': year
            })
    
    true_cases_df = pd.DataFrame(true_cases)
    output_file = os.path.join(output_dir, 'true_cases_all_years.csv')
    true_cases_df.to_csv(output_file, index=False)
    print(f"True cases saved to {output_file}, total {len(true_cases_df)} cases")
    
    return true_cases_df

def summarize_statistics():
    """Summarize statistics by year and overall including CO and 48h"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_stats = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    extra_cols = ['CO', 'within_48h']
    
    overall_counts = {col: 0 for col in condition_cols + extra_cols}
    overall_total = 0
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Use unique HN+Institution combinations for patient count
        unique_patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
        patient_count = len(unique_patients)
        
        year_stats = {'Year': year, 'Total_Patients': patient_count}
        
        # Calculate condition counts per patient
        for col in condition_cols + extra_cols:
            # Count patients with this condition True
            patients_with_condition = df[df[col]][['HN Number', 'Institution (IPAS)']].drop_duplicates()
            count = len(patients_with_condition)
            percentage = (count / patient_count * 100) if patient_count > 0 else 0
            year_stats[f'{col}_count'] = count
            year_stats[f'{col}_pct'] = round(percentage, 2)
            
            overall_counts[col] += count
        
        # Patients with any condition
        patients_with_any = df[df[condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        any_count = len(patients_with_any)
        year_stats['Patients_with_any'] = any_count
        year_stats['Any_pct'] = round(any_count / patient_count * 100, 2) if patient_count > 0 else 0
        
        overall_total += patient_count
        all_stats.append(year_stats)
    
    # Overall statistics
    overall_stats = {'Year': 'OVERALL', 'Total_Patients': overall_total}
    
    for col in condition_cols + extra_cols:
        percentage = (overall_counts[col] / overall_total * 100) if overall_total > 0 else 0
        overall_stats[f'{col}_count'] = overall_counts[col]
        overall_stats[f'{col}_pct'] = round(percentage, 2)
    
    # Calculate overall patients with any condition
    all_any_patients = set()
    for file in files:
        df = pd.read_csv(file)
        any_patients = df[df[condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        for _, row in any_patients.iterrows():
            all_any_patients.add((row['HN Number'], row['Institution (IPAS)']))
    
    overall_stats['Patients_with_any'] = len(all_any_patients)
    overall_stats['Any_pct'] = round(len(all_any_patients) / overall_total * 100, 2) if overall_total > 0 else 0
    
    all_stats.append(overall_stats)
    
    stats_df = pd.DataFrame(all_stats)
    
    # Save statistics
    stats_file = os.path.join(output_dir, 'statistics_summary.csv')
    stats_df.to_csv(stats_file, index=False)
    print(f"Statistics saved to {stats_file}")
    
    return stats_df

def summarize_detailed():
    """Detailed summary including distribution of number of conditions per patient and CO/48h analysis"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_detailed = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Create patient-condition matrix
        patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
        
        # Count conditions per patient
        condition_counts = []
        co_true_count = 0
        within_48h_true_count = 0
        
        for _, patient in patients.iterrows():
            hn = patient['HN Number']
            inst = patient['Institution (IPAS)']
            patient_rows = df[(df['HN Number'] == hn) & (df['Institution (IPAS)'] == inst)]
            
            # Count unique conditions that are True at least once
            condition_count = 0
            for col in condition_cols:
                if patient_rows[col].any():
                    condition_count += 1
            
            condition_counts.append(condition_count)
            
            # Check CO and 48h for this patient
            if patient_rows['CO'].any():
                co_true_count += 1
            if patient_rows['within_48h'].any():
                within_48h_true_count += 1
        
        # Calculate distribution
        year_detailed = {
            'Year': year,
            'Total_Patients': len(patients),
            'Patients_with_0': condition_counts.count(0),
            'Patients_with_1': condition_counts.count(1),
            'Patients_with_2': condition_counts.count(2),
            'Patients_with_3': condition_counts.count(3),
            'Patients_with_4': condition_counts.count(4),
            'Patients_with_5': condition_counts.count(5),
            'Patients_with_6': condition_counts.count(6),
            'Avg_conditions': round(sum(condition_counts) / len(condition_counts), 2) if condition_counts else 0,
            'CO_True': co_true_count,
            'CO_Pct': round(co_true_count / len(patients) * 100, 2) if len(patients) > 0 else 0,
            'within_48h_True': within_48h_true_count,
            'within_48h_Pct': round(within_48h_true_count / len(patients) * 100, 2) if len(patients) > 0 else 0
        }
        
        # Add percentages for condition counts
        for i in range(7):
            pct_col = f'Pct_with_{i}'
            count = year_detailed[f'Patients_with_{i}']
            year_detailed[pct_col] = round(count / len(patients) * 100, 2) if len(patients) > 0 else 0
        
        all_detailed.append(year_detailed)
    
    detailed_df = pd.DataFrame(all_detailed)
    
    # Save detailed statistics
    detailed_file = os.path.join(output_dir, 'detailed_statistics.csv')
    detailed_df.to_csv(detailed_file, index=False)
    print(f"Detailed statistics saved to {detailed_file}")
    
    return detailed_df

# Run all functions
if __name__ == "__main__":
    true_cases = extract_true_cases()
    stats = summarize_statistics()
    detailed = summarize_detailed()
    
    print("\nSummary Statistics:")
    print(stats.to_string(index=False))
# Out:
# True cases saved to ./presumed_infection/2.Data/Output/ase/true_cases_all_years.csv, total 30354 cases
# Statistics saved to ./presumed_infection/2.Data/Output/ase/statistics_summary.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 186
#     184 true_cases = extract_true_cases()
#     185 stats = summarize_statistics()
# --> 186 detailed = summarize_detailed()
#     188 print("\nSummary Statistics:")
#     189 print(stats.to_string(index=False))
#
# Cell In[45], line 131, in summarize_detailed()
#     129 hn = patient['HN Number']
#     130 inst = patient['Institution (IPAS)']
# --> 131 patient_rows = df[(df['HN Number'] == hn) & (df['Institution (IPAS)'] == inst)]
#     133 # Count unique conditions that are True at least once
#     134 condition_count = 0
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\Vincent Yeung\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:130, in comp_method_OBJECT_ARRAY(op, x, y)
#     128 else:
#     129     result = libops.scalar_compare(x.ravel(), y, op)
# --> 130 return result.reshape(x.shape)
#
# KeyboardInterrupt:
