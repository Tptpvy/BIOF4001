# %%
# import libraries
import os
import pandas as pd
import glob
import warnings
import datetime

# define file paths
year = 2024
# DATA_PATH = f"./presumed_infection/2.Data/New Data/"
DATA_PATH = f"./presumed_infection/2.Data/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*resumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def filter_presumed(year): # filter presumed infection cases for a specific year
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Institution (IPAS)' not in presumed_df.columns or 'HN Number' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Institution (IPAS)' not in demographic_df.columns or 'HN Number' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    mask = demographic_df.apply(lambda row: (row['Institution (IPAS)'], row['HN Number']) in presumed_tuples, axis=1)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def filter_presumed_RK(year): # filter presumed infection cases for a specific year using Reference Key
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}_RK.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Reference Key' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Reference Key' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(presumed_df['Reference Key'].tolist())
    mask = demographic_df['Reference Key'].isin(presumed_tuples)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def check_missing_presumed(year):
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Filtered demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH) 
    demo_df = pd.read_csv(DEMO_PATH)
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    demo_tuples = set(zip(demo_df['Institution (IPAS)'], demo_df['HN Number']))
    missing_tuples = presumed_tuples - demo_tuples
    missing_count = len(missing_tuples)
    print(f"Year {year}: {missing_count} presumed infection cases not found in demographic data")
    if missing_count > 0:
        missing_df = pd.DataFrame(list(missing_tuples), columns=['Institution (IPAS)', 'HN Number'])
        OUTPUT_PATH = os.path.join(DATA_PATH, f'Demographics/{year}/missing_presumed_{year}.csv')
        missing_df.to_csv(OUTPUT_PATH, index=False)
        print(f"Missing cases saved to {OUTPUT_PATH}")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, crea, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/{data_type.title()}/{year}/"
        pattern = "*resumedInfection_" + data_type.title() + "_"
    elif data_type == "crea": # alternative filename handling for crea
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/"
        pattern = "*resumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/"
        pattern = "*resumedInfection_lactate_"
    elif data_type == "bili": # alternative filename handling for bili
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"
    elif data_type == "plt": # alternative filename handling for plt
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def retrieve_blood_dates(HN, institution, date_df):
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    if 'blood culture date' in df.columns and not df.empty:
        blood_dates = pd.to_datetime(df['blood culture date'], errors='coerce').dropna().unique()
        return [date.strftime('%Y-%m-%d') for date in blood_dates]
    return []

def check_date_in_window(target_date, blood_dates_array):
    if not blood_dates_array or not target_date:
        return False
    target = pd.to_datetime(target_date)
    for blood_date_str in blood_dates_array:
        blood_date = pd.to_datetime(blood_date_str)
        date_diff = abs((target - blood_date).days)
        if date_diff <= 2:
            return True
    return False

# %%
# def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
#     df = date_df[date_df['Reference Key'] == Ref_Key].copy() # using first entry only, use array to store all dates if needed
#     if 'blood culture date' in df.columns and not df.empty:
#         blood_culture_date = pd.to_datetime(df.iloc[0]['blood culture date'], errors='coerce')
#         deadline_date = blood_culture_date + pd.Timedelta(days=2) # 2 days after blood culture (deadline)
#         return deadline_date.strftime('%Y-%m-%d')
#     return None

    # if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
    #     admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
    #     deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
    #     return deadline_date.strftime('%Y-%m-%d')
    # return None

# %%
def check_vasopressor(HN, institution, df, blood_dates_array): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin unused
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    df = df[(df['HN Number'] == HN) & (df['Institution (IPAS)'] == institution)].copy()
    if 'Drug Name' in df.columns and 'Prescription Start Date' in df.columns and not df.empty:
        df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
        for drug in vasopressor_list:
            drug_mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False)
            drug_dates = df.loc[drug_mask, 'Prescription Start Date'].dropna().unique()
            for admin_date in drug_dates:
                if check_date_in_window(admin_date, blood_dates_array):
                    one_day_before = admin_date - datetime.timedelta(days=1) # To count as a new vasopressor, that specific vasopressor cannot have been administered in the prior calendar day
                    if not drug_mask.any() or one_day_before not in drug_dates:
                        return True
    return False

# %%
def check_ventilation(HN, institution, year, resp_fail_df, blood_dates_array): # check if mechanical ventilation is initiated
    df_filtered = resp_fail_df[(resp_fail_df['HN Number'] == HN) & (resp_fail_df['Institution (IPAS)'] == institution) & (resp_fail_df['year'] == year)].copy()
    if df_filtered.empty:
        return False
    if 'RespFailOnsetDate' in df_filtered.columns:
        for onset_date in df_filtered['RespFailOnsetDate']:
            if check_date_in_window(onset_date, blood_dates_array):
                return True
    return False

# %%
def filter_renal(): # filter end-stage renal disease patients (unused)
    DXPX_PATH = DATA_PATH + f"demographic/demographic_{year}.csv"
    df = pd.read_csv(DXPX_PATH)
    disease_list = []
    if 'Reference Key' in df.columns and 'Dx/Px Description (HAMDCT)' in df.columns:
        df['renal'] = df['Dx/Px Description (HAMDCT)'].str.lower().str.contains('|'.join(disease_list), case=False, na=False) 
        result_df = df[['Reference Key', 'renal']].drop_duplicates()       
        return result_df
    else:
        print("Required columns not found")
        return pd.DataFrame(columns=['Reference Key', 'renal'])
    
# only keeps first occurence(?), need change to eGFR>20

# %%
def check_creatinine(HN, institution, df, blood_dates_array, CO): # check if creatinine level is abnormal
    # renal_df = filter_renal()
    # if not renal_df.empty and Ref_Key in renal_df['Reference Key'].values:
    #     if renal_df.loc[renal_df['Reference Key'] == Ref_Key, 'renal'].iloc[0]:
    #         return False
    df = df[(df['HN Number'] == HN) & (df['Institution (IPAS)'] == institution)].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if CO: 
            baseline = df['LIS Result: Numeric Result'].min()
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    if value >= baseline * 2:
                        return True
        else:
            baseline = float('inf')
            valid_dates = []
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    valid_dates.append(date)
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    baseline = value if value < baseline else baseline
            for date in valid_dates:
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= baseline * 2:
                    return True
    return False

# %%
def check_bili(HN, institution, df, blood_dates_array, CO): # check if bilirubin level is abnormal
    df = df[(df['HN Number'] == HN) & (df['Institution (IPAS)'] == institution)].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if CO: 
            baseline = df['LIS Result: Numeric Result'].min()
        else:
            baseline = float('inf')
            valid_dates = []
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    valid_dates.append(date)
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    baseline = value if value < baseline else baseline
            for date in valid_dates:
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                value_mgdl = value * 0.058467
                baseline_mgdl = baseline * 0.058467
                if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
                    return True
    return False

# %%
def check_plt(HN, institution, df, blood_dates_array, CO): # check if platelet count is abnormal
    df = df[(df['HN Number'] == HN) & (df['Institution (IPAS)'] == institution)].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        if CO: 
            baseline = df['LIS Result: Numeric Result'].max() # baseline calculated with all data
        else:
            baseline = float('-inf')
            valid_dates = []
            for date in df['LIS Reference Date']:
                if check_date_in_window(date, blood_dates_array):
                    valid_dates.append(date)
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    baseline = value if value > baseline else baseline
            if baseline >= 100:
                for date in valid_dates:
                    value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                    if value < 100 and value <= baseline * 0.5:
                        return True
    return False

# %%
def check_lact(HN, institution, df, blood_dates_array): # check if lactate level is abnormal
    df = df[(df['HN Number'] == HN) & (df['Institution (IPAS)'] == institution)].copy()
    if 'LIS Result: Numeric Result' in df.columns and not df.empty:
        df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
        df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
        for date in df['LIS Reference Date']:
            if check_date_in_window(date, blood_dates_array):
                value = df.loc[df['LIS Reference Date'] == date, 'LIS Result: Numeric Result'].iloc[0]
                if value >= 2.0:
                    return True
    return False

# %%
def check_CO(HN, institution, date_df, demo_df): # TRUE if community onset, FALSE if hospital onset
    # TRUE if blood culture date/first QAD date is within 2 days of admission date
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    demo_row = demo_df[(demo_df['HN Number'] == HN) & (demo_df['Institution (IPAS)'] == institution)] 
    admission_date = pd.to_datetime(demo_row['Admission Date'].iloc[0])
    blood_date = pd.to_datetime(df['blood culture date'].iloc[0]) if 'blood culture date' in df.columns else None
    qad_date = pd.to_datetime(df['first_qad_date'].iloc[0]) if 'first_qad_date' in df.columns else None
    if blood_date is not None and abs((blood_date - admission_date).days) <= 2:
        return True
    if qad_date is not None and abs((qad_date - admission_date).days) <= 2:
        return True
    return False

# %%
def check_ase(year):
    KEY_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv" # assuming demographic file contains all HN number and Institution combinations
    df = pd.read_csv(KEY_PATH)
    keys = df[['HN Number', 'Institution (IPAS)']].drop_duplicates().values.tolist()
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv" # blood culture date and first qad date
    date_df = pd.read_csv(DATE_PATH) # deadline date
    INOTROPE_PATH = DATA_PATH + f"Lab_Test_Results/Inotrope/{year}/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    # PROCEDURE_PATH = DATA_PATH + f"Lab_Test_Results/Procedure/{year}/procedure_{year}.csv" # no date?
    # procedure_df = pd.read_csv(PROCEDURE_PATH)
    CREATININE_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/crea_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    BILI_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    LACT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    RESP_PATH = DATA_PATH + f"RespFailList.csv"
    resp_fail_df = pd.read_csv(RESP_PATH)
    
    results = []
    for key in keys:
        HN = key[0]
        institution = key[1] 
        blood_dates_array = retrieve_blood_dates(HN, institution, date_df) # retrieve blood culture dates
        CO = check_CO(HN, institution, date_df, df) # check community onset or hospital onset
        if check_vasopressor(HN, institution, inotrope_df, blood_dates_array): # check vasopressor
            results.append({'HN Number': HN, 'Institution (IPAS)': institution, 'vasopressor': True})
        else:
            results.append({'HN Number': HN, 'Institution (IPAS)': institution, 'vasopressor': False})

        if check_ventilation(HN, institution, year, resp_fail_df, blood_dates_array): # check ventilation
            results[-1]['ventilation'] = True
        else:
            results[-1]['ventilation'] = False

        if check_creatinine(HN, institution, creatinine_df, blood_dates_array, CO): # check creatinine
            results[-1]['creatinine'] = True
        else:
            results[-1]['creatinine'] = False

        if check_bili(HN, institution, bili_df, blood_dates_array, CO): # check bilirubin
            results[-1]['bili'] = True
        else:
            results[-1]['bili'] = False

        if check_plt(HN, institution, plt_df, blood_dates_array, CO): # check platelet
            results[-1]['plt'] = True
        else: 
            results[-1]['plt'] = False

        if check_lact(HN, institution, lact_df, blood_dates_array): # check lactate
            results[-1]['lact'] = True
        else: 
            results[-1]['lact'] = False
        
        print(f"Checked Patient: {key}")

    results_df = pd.DataFrame(results)
    output_dir = os.path.join(DATA_PATH, 'Output', 'ase')
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'ase_{year}.csv')
    results_df.to_csv(output_file, index=False)
    print(f"ASE results saved to {output_file}")

# %%
def create_ASE_list(file, year): # create list of ase patients with institution by matching ase filter output
    ase_df = pd.read_csv(file, dtype={'Reference Key': str}, low_memory=False)
    ase_df['Overall'] = ase_df.iloc[:, 1:7].any(axis=1)
    true_ase_df = ase_df[ase_df['Overall'] == True].copy()
    output_file = os.path.join(DATA_PATH, f'ASE_patient_list_{year}.csv')
    true_ase_df[['HN Number', 'Institution (IPAS)']].to_csv(output_file, index=False)
    return true_ase_df[['HN Number', 'Institution (IPAS)']]

# %%
def ase_percentages(file):
    df = pd.read_csv(file)
    percentages = {}
    for column in df.columns[2:8]:  # 6 OD columns
        if df[column].dtype == bool or df[column].isin([True, False, 'TRUE', 'FALSE']).all():
            true_count = (df[column] == True).sum() + (df[column] == 'TRUE').sum()
            total_count = len(df[column])
            percentage = (true_count / total_count * 100) if total_count > 0 else 0
            percentages[column] = round(percentage, 2)
    return percentages

# %%
for year in range(2022,2023): # 2025 currently missing
    merge_demographic(year)
    # filter_presumed(year)
    # filter_presumed_RK(year)
    # check_missing_presumed(year)
    data_types = ["inotrope", "procedure", "crea", "bili", "plt", "lact"]
    for data_type in data_types:
        merge_data(data_type, year)
# Out:
# Processing year: 2022
# Found 32 files for year 2022
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\941033044.py:13: DtypeWarning: Columns (0,15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\941033044.py:13: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Demographics/2022/demographic_2022.csv, 923493 total rows
# Processing year: 2022
# Found 28 files for year 2022
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Inotrope/2022/inotrope_2022.csv, 164678 total rows
# Processing year: 2022
# Found 27 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Procedure/2022/procedure_2022.csv, 5113 total rows
# Processing year: 2022
# Found 44 files for year 2022
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Creatinine/2022/crea_2022.csv, 1696636 total rows
# Processing year: 2022
# Found 44 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Bilirubin/2022/bili_2022.csv, 907663 total rows
# Processing year: 2022
# Found 44 files for year 2022
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_20120\3308921293.py:26: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2022/plt_2022.csv, 1069411 total rows
# Processing year: 2022
# Found 28 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Lactate/2022/lact_2022.csv, 84446 total rows

# %%
warnings.filterwarnings('ignore')
for year in range(2022, 2023): # no 2019
    check_ase(year)
# Out:
# Checked Reference Key: 254
# Checked Reference Key: 562
# Checked Reference Key: 688
# Checked Reference Key: 1301
# Checked Reference Key: 1582
# Checked Reference Key: 1846
# Checked Reference Key: 2158
# Checked Reference Key: 2773
# Checked Reference Key: 2987
# Checked Reference Key: 3315
# Checked Reference Key: 3740
# Checked Reference Key: 4619
# Checked Reference Key: 4665
# Checked Reference Key: 4727
# Checked Reference Key: 6604
# Checked Reference Key: 7242
# Checked Reference Key: 7645
# Checked Reference Key: 7749
# Checked Reference Key: 7751
# Checked Reference Key: 8771
# Checked Reference Key: 10242
# Checked Reference Key: 10471
# Checked Reference Key: 11115
# Checked Reference Key: 11165
# Checked Reference Key: 11226
# Checked Reference Key: 11794
# Checked Reference Key: 11980
# Checked Reference Key: 12103
# Checked Reference Key: 12806
# Checked Reference Key: 12848
# Checked Reference Key: 13570
# Checked Reference Key: 14265
# Checked Reference Key: 14574
# Checked Reference Key: 14965
# Checked Reference Key: 15043
# Checked Reference Key: 15736
# Checked Reference Key: 15824
# Checked Reference Key: 16360
# Checked Reference Key: 16450
# Checked Reference Key: 16921
# Checked Reference Key: 16981
# Checked Reference Key: 17784
# Checked Reference Key: 17866
# Checked Reference Key: 17920
# Checked Reference Key: 18172
# Checked Reference Key: 18649
# Checked Reference Key: 18864
# Checked Reference Key: 21621
# Checked Reference Key: 21749
# Checked Reference Key: 22951
# Checked Reference Key: 23368
# Checked Reference Key: 23794
# Checked Reference Key: 24339
# Checked Reference Key: 25055
# Checked Reference Key: 25309
# Checked Reference Key: 26135
# Checked Reference Key: 26211
# Checked Reference Key: 26437
# Checked Reference Key: 26536
# Checked Reference Key: 27710
# Checked Reference Key: 27857
# Checked Reference Key: 28267
# Checked Reference Key: 28620
# Checked Reference Key: 28865
# Checked Reference Key: 29450
# Checked Reference Key: 29772
# Checked Reference Key: 29904
# Checked Reference Key: 30024
# Checked Reference Key: 30763
# Checked Reference Key: 31510
# Checked Reference Key: 33921
# Checked Reference Key: 34331
# Checked Reference Key: 35498
# Checked Reference Key: 35619
# Checked Reference Key: 35676
# Checked Reference Key: 38752
# Checked Reference Key: 39085
# Checked Reference Key: 39164
# Checked Reference Key: 39641
# Checked Reference Key: 39703
# Checked Reference Key: 40229
# Checked Reference Key: 41377
# Checked Reference Key: 41850
# Checked Reference Key: 43370
# Checked Reference Key: 43635
# Checked Reference Key: 43872
# Checked Reference Key: 44456
# Checked Reference Key: 44542
# Checked Reference Key: 44801
# Checked Reference Key: 45339
# Checked Reference Key: 46050
# Checked Reference Key: 46922
# Checked Reference Key: 47160
# Checked Reference Key: 47479
# Checked Reference Key: 50165
# Checked Reference Key: 51571
# Checked Reference Key: 51871
# Checked Reference Key: 54963
# Checked Reference Key: 56325
# Checked Reference Key: 56844
# Checked Reference Key: 57052
# Checked Reference Key: 60103
# Checked Reference Key: 61388
# Checked Reference Key: 63455
# Checked Reference Key: 63694
# Checked Reference Key: 64911
# Checked Reference Key: 65003
# Checked Reference Key: 66104
# Checked Reference Key: 67119
# Checked Reference Key: 68037
# Checked Reference Key: 68121
# Checked Reference Key: 68457
# Checked Reference Key: 68719
# Checked Reference Key: 68820
# Checked Reference Key: 68842
# Checked Reference Key: 68862
# Checked Reference Key: 70087
# Checked Reference Key: 70127
# Checked Reference Key: 70702
# Checked Reference Key: 71326
# Checked Reference Key: 71567
# Checked Reference Key: 71732
# Checked Reference Key: 72039
# Checked Reference Key: 72166
# Checked Reference Key: 73702
# Checked Reference Key: 74351
# Checked Reference Key: 74499
# Checked Reference Key: 74976
# Checked Reference Key: 75190
# Checked Reference Key: 76304
# Checked Reference Key: 76362
# Checked Reference Key: 77170
# Checked Reference Key: 79379
# Checked Reference Key: 80544
# Checked Reference Key: 81266
# Checked Reference Key: 81444
# Checked Reference Key: 81622
# Checked Reference Key: 81799
# Checked Reference Key: 81969
# Checked Reference Key: 82221
# Checked Reference Key: 82440
# Checked Reference Key: 83312
# Checked Reference Key: 87238
# Checked Reference Key: 87256
# Checked Reference Key: 87279
# Checked Reference Key: 87336
# Checked Reference Key: 87776
# Checked Reference Key: 88541
# Checked Reference Key: 88702
# Checked Reference Key: 88821
# Checked Reference Key: 89550
# Checked Reference Key: 89930
# Checked Reference Key: 90050
# Checked Reference Key: 90303
# Checked Reference Key: 91030
# Checked Reference Key: 91201
# Checked Reference Key: 91361
# Checked Reference Key: 91588
# Checked Reference Key: 91619
# Checked Reference Key: 91925
# Checked Reference Key: 92023
# Checked Reference Key: 92099
# Checked Reference Key: 92520
# Checked Reference Key: 92969
# Checked Reference Key: 92993
# Checked Reference Key: 93923
# Checked Reference Key: 94227
# Checked Reference Key: 94238
# Checked Reference Key: 94406
# Checked Reference Key: 94688
# Checked Reference Key: 94780
# Checked Reference Key: 94968
# Checked Reference Key: 95623
# Checked Reference Key: 95632
# Checked Reference Key: 95785
# Checked Reference Key: 95844
# Checked Reference Key: 96307
# Checked Reference Key: 96661
# Checked Reference Key: 96908
# Checked Reference Key: 97233
# Checked Reference Key: 97434
# Checked Reference Key: 98714
# Checked Reference Key: 98951
# Checked Reference Key: 99179
# Checked Reference Key: 100298
# Checked Reference Key: 100668
# Checked Reference Key: 100714
# Checked Reference Key: 101180
# Checked Reference Key: 103389
# Checked Reference Key: 104464
# Checked Reference Key: 104756
# Checked Reference Key: 104778
# Checked Reference Key: 104988
# Checked Reference Key: 105925
# Checked Reference Key: 106391
# Checked Reference Key: 106633
# Checked Reference Key: 107458
# Checked Reference Key: 108205
# Checked Reference Key: 108583
# Checked Reference Key: 108795
# Checked Reference Key: 109599
# Checked Reference Key: 109711
# Checked Reference Key: 110111
# Checked Reference Key: 117513
# Checked Reference Key: 117552
# Checked Reference Key: 117605
# Checked Reference Key: 117865
# Checked Reference Key: 117931
# Checked Reference Key: 117970
# Checked Reference Key: 118584
# Checked Reference Key: 118725
# Checked Reference Key: 119007
# Checked Reference Key: 119028
# Checked Reference Key: 119146
# Checked Reference Key: 119454
# Checked Reference Key: 119582
# Checked Reference Key: 119664
# Checked Reference Key: 119799
# Checked Reference Key: 120168
# Checked Reference Key: 120327
# Checked Reference Key: 120371
# Checked Reference Key: 120586
# Checked Reference Key: 120924
# Checked Reference Key: 120939
# Checked Reference Key: 121190
# Checked Reference Key: 121520
# Checked Reference Key: 121839
# Checked Reference Key: 121906
# Checked Reference Key: 122244
# Checked Reference Key: 122387
# Checked Reference Key: 122713
# Checked Reference Key: 122775
# Checked Reference Key: 122859
# Checked Reference Key: 122919
# Checked Reference Key: 123265
# Checked Reference Key: 123501
# Checked Reference Key: 123646
# Checked Reference Key: 123956
# Checked Reference Key: 124892
# Checked Reference Key: 125627
# Checked Reference Key: 125963
# Checked Reference Key: 125980
# Checked Reference Key: 126228
# Checked Reference Key: 126330
# Checked Reference Key: 126426
# Checked Reference Key: 126483
# Checked Reference Key: 126543
# Checked Reference Key: 126680
# Checked Reference Key: 126719
# Checked Reference Key: 126905
# Checked Reference Key: 127147
# Checked Reference Key: 127167
# Checked Reference Key: 127292
# Checked Reference Key: 127430
# Checked Reference Key: 127565
# Checked Reference Key: 127590
# Checked Reference Key: 128124
# Checked Reference Key: 128197
# Checked Reference Key: 128301
# Checked Reference Key: 128304
# Checked Reference Key: 128332
# Checked Reference Key: 128981
# Checked Reference Key: 129209
# Checked Reference Key: 129398
# Checked Reference Key: 129438
# Checked Reference Key: 129804
# Checked Reference Key: 130053
# Checked Reference Key: 130714
# Checked Reference Key: 131053
# Checked Reference Key: 131079
# Checked Reference Key: 131657
# Checked Reference Key: 131710
# Checked Reference Key: 131933
# Checked Reference Key: 131965
# Checked Reference Key: 131994
# Checked Reference Key: 132057
# Checked Reference Key: 132097
# Checked Reference Key: 132144
# Checked Reference Key: 132427
# Checked Reference Key: 132526
# Checked Reference Key: 132948
# Checked Reference Key: 133012
# Checked Reference Key: 133206
# Checked Reference Key: 133342
# Checked Reference Key: 133784
# Checked Reference Key: 133866
# Checked Reference Key: 133998
# Checked Reference Key: 134114
# Checked Reference Key: 134297
# Checked Reference Key: 134394
# Checked Reference Key: 134480
# Checked Reference Key: 134507
# Checked Reference Key: 134663
# Checked Reference Key: 134872
# Checked Reference Key: 135040
# Checked Reference Key: 135153
# Checked Reference Key: 135272
# Checked Reference Key: 135571
# Checked Reference Key: 135629
# Checked Reference Key: 135814
# Checked Reference Key: 136679
# Checked Reference Key: 136754
# Checked Reference Key: 137238
# Checked Reference Key: 137502
# Checked Reference Key: 137549
# Checked Reference Key: 137613
# Checked Reference Key: 137703
# Checked Reference Key: 138255
# Checked Reference Key: 138436
# Checked Reference Key: 138649
# Checked Reference Key: 138919
# Checked Reference Key: 138964
# Checked Reference Key: 139028
# Checked Reference Key: 140219
# Checked Reference Key: 140239
# Checked Reference Key: 140339
# Checked Reference Key: 140409
# Checked Reference Key: 140608
# Checked Reference Key: 140843
# Checked Reference Key: 141075
# Checked Reference Key: 141488
# Checked Reference Key: 141611
# Checked Reference Key: 141695
# Checked Reference Key: 141699
# Checked Reference Key: 141743
# Checked Reference Key: 141977
# Checked Reference Key: 142070
# Checked Reference Key: 142582
# Checked Reference Key: 142694
# Checked Reference Key: 142813
# Checked Reference Key: 142877
# Checked Reference Key: 143444
# Checked Reference Key: 143543
# Checked Reference Key: 143591
# Checked Reference Key: 143660
# Checked Reference Key: 143764
# Checked Reference Key: 143909
# Checked Reference Key: 144508
# Checked Reference Key: 144518
# Checked Reference Key: 144988
# Checked Reference Key: 145395
# Checked Reference Key: 145573
# Checked Reference Key: 145582
# Checked Reference Key: 145965
# Checked Reference Key: 146177
# Checked Reference Key: 146464
# Checked Reference Key: 148216
# Checked Reference Key: 148684
# Checked Reference Key: 149076
# Checked Reference Key: 149304
# Checked Reference Key: 149858
# Checked Reference Key: 150839
# Checked Reference Key: 152010
# Checked Reference Key: 152056
# Checked Reference Key: 152137
# Checked Reference Key: 152965
# Checked Reference Key: 152996
# Checked Reference Key: 153099
# Checked Reference Key: 153423
# Checked Reference Key: 154099
# Checked Reference Key: 154766
# Checked Reference Key: 155085
# Checked Reference Key: 155145
# Checked Reference Key: 155683
# Checked Reference Key: 155983
# Checked Reference Key: 156032
# Checked Reference Key: 156268
# Checked Reference Key: 157279
# Checked Reference Key: 158098
# Checked Reference Key: 158481
# Checked Reference Key: 159928
# Checked Reference Key: 159952
# Checked Reference Key: 160874
# Checked Reference Key: 161761
# Checked Reference Key: 161774
# Checked Reference Key: 162265
# Checked Reference Key: 162549
# Checked Reference Key: 162876
# Checked Reference Key: 163236
# Checked Reference Key: 163381
# Checked Reference Key: 164753
# Checked Reference Key: 164867
# Checked Reference Key: 165071
# Checked Reference Key: 165096
# Checked Reference Key: 165186
# Checked Reference Key: 165467
# Checked Reference Key: 165592
# Checked Reference Key: 165683
# Checked Reference Key: 165798
# Checked Reference Key: 165940
# Checked Reference Key: 165964
# Checked Reference Key: 166064
# Checked Reference Key: 166071
# Checked Reference Key: 166193
# Checked Reference Key: 166344
# Checked Reference Key: 166385
# Checked Reference Key: 167068
# Checked Reference Key: 167707
# Checked Reference Key: 168096
# Checked Reference Key: 168233
# Checked Reference Key: 168286
# Checked Reference Key: 168598
# Checked Reference Key: 168614
# Checked Reference Key: 168645
# Checked Reference Key: 168674
# Checked Reference Key: 168698
# Checked Reference Key: 169316
# Checked Reference Key: 169446
# Checked Reference Key: 169724
# Checked Reference Key: 170121
# Checked Reference Key: 170713
# Checked Reference Key: 170969
# Checked Reference Key: 171139
# Checked Reference Key: 171559
# Checked Reference Key: 171681
# Checked Reference Key: 172777
# Checked Reference Key: 172993
# Checked Reference Key: 173092
# Checked Reference Key: 173641
# Checked Reference Key: 174057
# Checked Reference Key: 174205
# Checked Reference Key: 174235
# Checked Reference Key: 174721
# Checked Reference Key: 174901
# Checked Reference Key: 175081
# Checked Reference Key: 175107
# Checked Reference Key: 175819
# Checked Reference Key: 177729
# Checked Reference Key: 178200
# Checked Reference Key: 179031
# Checked Reference Key: 179260
# Checked Reference Key: 179691
# Checked Reference Key: 179721
# Checked Reference Key: 180354
# Checked Reference Key: 181793
# Checked Reference Key: 183344
# Checked Reference Key: 183443
# Checked Reference Key: 184168
# Checked Reference Key: 184598
# Checked Reference Key: 186767
# Checked Reference Key: 187219
# Checked Reference Key: 187504
# Checked Reference Key: 188154
# Checked Reference Key: 189081
# Checked Reference Key: 189513
# Checked Reference Key: 189593
# Checked Reference Key: 190178
# Checked Reference Key: 190183
# Checked Reference Key: 190430
# Checked Reference Key: 190586
# Checked Reference Key: 192791
# Checked Reference Key: 201191
# Checked Reference Key: 208806
# Checked Reference Key: 209541
# Checked Reference Key: 212277
# Checked Reference Key: 215637
# Checked Reference Key: 216006
# Checked Reference Key: 216027
# Checked Reference Key: 216121
# Checked Reference Key: 217412
# Checked Reference Key: 217457
# Checked Reference Key: 217785
# Checked Reference Key: 218022
# Checked Reference Key: 218037
# Checked Reference Key: 218302
# Checked Reference Key: 218379
# Checked Reference Key: 218413
# Checked Reference Key: 219091
# Checked Reference Key: 219185
# Checked Reference Key: 219656
# Checked Reference Key: 220303
# Checked Reference Key: 220770
# Checked Reference Key: 221309
# Checked Reference Key: 221448
# Checked Reference Key: 221721
# Checked Reference Key: 222225
# Checked Reference Key: 222715
# Checked Reference Key: 223027
# Checked Reference Key: 223028
# Checked Reference Key: 223050
# Checked Reference Key: 223577
# Checked Reference Key: 224060
# Checked Reference Key: 224235
# Checked Reference Key: 224407
# Checked Reference Key: 224824
# Checked Reference Key: 225488
# Checked Reference Key: 225876
# Checked Reference Key: 226057
# Checked Reference Key: 226186
# Checked Reference Key: 226447
# Checked Reference Key: 226515
# Checked Reference Key: 226684
# Checked Reference Key: 227472
# Checked Reference Key: 228162
# Checked Reference Key: 228181
# Checked Reference Key: 228310
# Checked Reference Key: 228398
# Checked Reference Key: 228530
# Checked Reference Key: 228729
# Checked Reference Key: 228770
# Checked Reference Key: 229107
# Checked Reference Key: 229244
# Checked Reference Key: 229710
# Checked Reference Key: 229734
# Checked Reference Key: 229937
# Checked Reference Key: 230003
# Checked Reference Key: 230104
# Checked Reference Key: 231009
# Checked Reference Key: 231092
# Checked Reference Key: 231353
# Checked Reference Key: 231597
# Checked Reference Key: 231920
# Checked Reference Key: 231950
# Checked Reference Key: 232123
# Checked Reference Key: 232336
# Checked Reference Key: 232700
# Checked Reference Key: 233010
# Checked Reference Key: 233185
# Checked Reference Key: 233466
# Checked Reference Key: 233519
# Checked Reference Key: 233741
# Checked Reference Key: 234137
# Checked Reference Key: 234205
# Checked Reference Key: 235237
# Checked Reference Key: 235454
# Checked Reference Key: 235571
# Checked Reference Key: 235838
# Checked Reference Key: 235857
# Checked Reference Key: 235999
# Checked Reference Key: 236096
# Checked Reference Key: 236268
# Checked Reference Key: 236354
# Checked Reference Key: 236446
# Checked Reference Key: 236838
# Checked Reference Key: 237534
# Checked Reference Key: 238144
# Checked Reference Key: 239069
# Checked Reference Key: 239176
# Checked Reference Key: 240255
# Checked Reference Key: 243680
# Checked Reference Key: 251836
# Checked Reference Key: 251845
# Checked Reference Key: 251957
# Checked Reference Key: 251970
# Checked Reference Key: 252011
# Checked Reference Key: 252551
# Checked Reference Key: 252595
# Checked Reference Key: 252961
# Checked Reference Key: 253144
# Checked Reference Key: 253259
# Checked Reference Key: 253441
# Checked Reference Key: 253493
# Checked Reference Key: 253618
# Checked Reference Key: 253929
# Checked Reference Key: 253958
# Checked Reference Key: 254101
# Checked Reference Key: 254226
# Checked Reference Key: 254355
# Checked Reference Key: 254387
# Checked Reference Key: 255150
# Checked Reference Key: 256138
# Checked Reference Key: 256382
# Checked Reference Key: 257297
# Checked Reference Key: 257904
# Checked Reference Key: 257910
# Checked Reference Key: 258754
# Checked Reference Key: 258856
# Checked Reference Key: 261969
# Checked Reference Key: 263586
# Checked Reference Key: 263602
# Checked Reference Key: 264088
# Checked Reference Key: 264389
# Checked Reference Key: 264931
# Checked Reference Key: 265363
# Checked Reference Key: 265482
# Checked Reference Key: 266101
# Checked Reference Key: 267372
# Checked Reference Key: 267604
# Checked Reference Key: 267785
# Checked Reference Key: 268125
# Checked Reference Key: 268277
# Checked Reference Key: 268609
# Checked Reference Key: 269103
# Checked Reference Key: 269884
# Checked Reference Key: 270315
# Checked Reference Key: 270403
# Checked Reference Key: 270438
# Checked Reference Key: 271750
# Checked Reference Key: 271751
# Checked Reference Key: 271977
# Checked Reference Key: 272168
# Checked Reference Key: 272214
# Checked Reference Key: 272437
# Checked Reference Key: 272599
# Checked Reference Key: 272908
# Checked Reference Key: 273559
# Checked Reference Key: 273771
# Checked Reference Key: 274350
# Checked Reference Key: 274444
# Checked Reference Key: 274927
# Checked Reference Key: 275205
# Checked Reference Key: 275264
# Checked Reference Key: 275925
# Checked Reference Key: 276318
# Checked Reference Key: 276334
# Checked Reference Key: 276663
# Checked Reference Key: 276803
# Checked Reference Key: 277628
# Checked Reference Key: 277830
# Checked Reference Key: 277872
# Checked Reference Key: 277971
# Checked Reference Key: 277975
# Checked Reference Key: 278123
# Checked Reference Key: 278948
# Checked Reference Key: 279045
# Checked Reference Key: 279262
# Checked Reference Key: 279319
# Checked Reference Key: 279473
# Checked Reference Key: 280685
# Checked Reference Key: 281017
# Checked Reference Key: 281372
# Checked Reference Key: 281642
# Checked Reference Key: 281726
# Checked Reference Key: 282141
# Checked Reference Key: 282668
# Checked Reference Key: 282911
# Checked Reference Key: 283435
# Checked Reference Key: 283554
# Checked Reference Key: 284062
# Checked Reference Key: 284238
# Checked Reference Key: 284495
# Checked Reference Key: 284993
# Checked Reference Key: 285031
# Checked Reference Key: 285837
# Checked Reference Key: 286422
# Checked Reference Key: 286461
# Checked Reference Key: 286514
# Checked Reference Key: 286612
# Checked Reference Key: 286839
# Checked Reference Key: 286865
# Checked Reference Key: 287179
# Checked Reference Key: 287659
# Checked Reference Key: 287777
# Checked Reference Key: 288751
# Checked Reference Key: 289148
# Checked Reference Key: 289558
# Checked Reference Key: 289836
# Checked Reference Key: 290041
# Checked Reference Key: 290196
# Checked Reference Key: 290222
# Checked Reference Key: 290231
# Checked Reference Key: 290474
# Checked Reference Key: 290688
# Checked Reference Key: 291186
# Checked Reference Key: 291373
# Checked Reference Key: 291534
# Checked Reference Key: 291936
# Checked Reference Key: 292215
# Checked Reference Key: 292464
# Checked Reference Key: 292598
# Checked Reference Key: 293229
# Checked Reference Key: 293778
# Checked Reference Key: 293920
# Checked Reference Key: 293926
# Checked Reference Key: 294249
# Checked Reference Key: 295043
# Checked Reference Key: 295915
# Checked Reference Key: 296142
# Checked Reference Key: 296706
# Checked Reference Key: 297265
# Checked Reference Key: 298200
# Checked Reference Key: 298887
# Checked Reference Key: 299983
# Checked Reference Key: 301048
# Checked Reference Key: 303657
# Checked Reference Key: 304518
# Checked Reference Key: 305204
# Checked Reference Key: 307013
# Checked Reference Key: 308712
# Checked Reference Key: 308846
# Checked Reference Key: 309354
# Checked Reference Key: 309695
# Checked Reference Key: 309796
# Checked Reference Key: 309865
# Checked Reference Key: 310108
# Checked Reference Key: 310801
# Checked Reference Key: 311749
# Checked Reference Key: 312462
# Checked Reference Key: 312651
# Checked Reference Key: 312749
# Checked Reference Key: 312958
# Checked Reference Key: 313014
# Checked Reference Key: 313877
# Checked Reference Key: 314613
# Checked Reference Key: 315070
# Checked Reference Key: 315390
# Checked Reference Key: 316083
# Checked Reference Key: 316455
# Checked Reference Key: 316580
# Checked Reference Key: 317613
# Checked Reference Key: 318509
# Checked Reference Key: 318583
# Checked Reference Key: 318762
# Checked Reference Key: 319568
# Checked Reference Key: 319641
# Checked Reference Key: 319661
# Checked Reference Key: 319778
# Checked Reference Key: 320759
# Checked Reference Key: 320772
# Checked Reference Key: 321061
# Checked Reference Key: 321363
# Checked Reference Key: 321688
# Checked Reference Key: 322664
# Checked Reference Key: 322686
# Checked Reference Key: 323351
# Checked Reference Key: 323493
# Checked Reference Key: 323618
# Checked Reference Key: 323660
# Checked Reference Key: 324105
# Checked Reference Key: 324811
# Checked Reference Key: 325573
# Checked Reference Key: 326091
# Checked Reference Key: 326199
# Checked Reference Key: 326695
# Checked Reference Key: 327692
# Checked Reference Key: 327767
# Checked Reference Key: 329304
# Checked Reference Key: 329782
# Checked Reference Key: 329881
# Checked Reference Key: 330142
# Checked Reference Key: 330601
# Checked Reference Key: 330779
# Checked Reference Key: 331031
# Checked Reference Key: 332184
# Checked Reference Key: 332390
# Checked Reference Key: 332484
# Checked Reference Key: 332849
# Checked Reference Key: 332924
# Checked Reference Key: 333037
# Checked Reference Key: 333644
# Checked Reference Key: 334107
# Checked Reference Key: 334272
# Checked Reference Key: 334286
# Checked Reference Key: 334714
# Checked Reference Key: 335318
# Checked Reference Key: 335493
# Checked Reference Key: 335734
# Checked Reference Key: 336012
# Checked Reference Key: 336643
# Checked Reference Key: 336958
# Checked Reference Key: 337292
# Checked Reference Key: 337376
# Checked Reference Key: 337706
# Checked Reference Key: 338071
# Checked Reference Key: 338289
# Checked Reference Key: 338814
# Checked Reference Key: 339117
# Checked Reference Key: 339450
# Checked Reference Key: 339796
# Checked Reference Key: 339830
# Checked Reference Key: 339834
# Checked Reference Key: 340537
# Checked Reference Key: 340564
# Checked Reference Key: 342507
# Checked Reference Key: 343305
# Checked Reference Key: 343345
# Checked Reference Key: 343354
# Checked Reference Key: 343954
# Checked Reference Key: 344019
# Checked Reference Key: 344943
# Checked Reference Key: 345850
# Checked Reference Key: 345997
# Checked Reference Key: 346134
# Checked Reference Key: 346152
# Checked Reference Key: 346186
# Checked Reference Key: 346267
# Checked Reference Key: 346742
# Checked Reference Key: 346788
# Checked Reference Key: 348501
# Checked Reference Key: 348638
# Checked Reference Key: 349284
# Checked Reference Key: 349525
# Checked Reference Key: 349582
# Checked Reference Key: 349946
# Checked Reference Key: 350901
# Checked Reference Key: 350989
# Checked Reference Key: 351232
# Checked Reference Key: 351252
# Checked Reference Key: 351830
# Checked Reference Key: 352376
# Checked Reference Key: 352677
# Checked Reference Key: 353017
# Checked Reference Key: 353040
# Checked Reference Key: 353048
# Checked Reference Key: 353313
# Checked Reference Key: 353534
# Checked Reference Key: 354405
# Checked Reference Key: 355246
# Checked Reference Key: 355949
# Checked Reference Key: 356023
# Checked Reference Key: 356471
# Checked Reference Key: 356545
# Checked Reference Key: 356813
# Checked Reference Key: 356923
# Checked Reference Key: 357655
# Checked Reference Key: 357707
# Checked Reference Key: 358090
# Checked Reference Key: 358822
# Checked Reference Key: 359061
# Checked Reference Key: 359463
# Checked Reference Key: 360004
# Checked Reference Key: 360153
# Checked Reference Key: 360366
# Checked Reference Key: 360923
# Checked Reference Key: 361465
# Checked Reference Key: 361984
# Checked Reference Key: 362409
# Checked Reference Key: 362625
# Checked Reference Key: 362738
# Checked Reference Key: 362792
# Checked Reference Key: 363221
# Checked Reference Key: 363236
# Checked Reference Key: 363246
# Checked Reference Key: 363291
# Checked Reference Key: 363302
# Checked Reference Key: 363487
# Checked Reference Key: 363555
# Checked Reference Key: 364067
# Checked Reference Key: 364927
# Checked Reference Key: 365791
# Checked Reference Key: 366599
# Checked Reference Key: 366777
# Checked Reference Key: 367193
# Checked Reference Key: 367384
# Checked Reference Key: 368472
# Checked Reference Key: 369762
# Checked Reference Key: 370042
# Checked Reference Key: 370245
# Checked Reference Key: 370328
# Checked Reference Key: 370497
# Checked Reference Key: 371074
# Checked Reference Key: 372348
# Checked Reference Key: 372735
# Checked Reference Key: 373193
# Checked Reference Key: 373479
# Checked Reference Key: 373527
# Checked Reference Key: 373551
# Checked Reference Key: 373694
# Checked Reference Key: 374009
# Checked Reference Key: 374169
# Checked Reference Key: 374199
# Checked Reference Key: 374272
# Checked Reference Key: 374379
# Checked Reference Key: 374632
# Checked Reference Key: 375592
# Checked Reference Key: 375951
# Checked Reference Key: 376080
# Checked Reference Key: 376111
# Checked Reference Key: 376304
# Checked Reference Key: 377587
# Checked Reference Key: 378332
# Checked Reference Key: 378649
# Checked Reference Key: 379254
# Checked Reference Key: 379468
# Checked Reference Key: 380385
# Checked Reference Key: 380423
# Checked Reference Key: 380590
# Checked Reference Key: 380890
# Checked Reference Key: 381072
# Checked Reference Key: 381337
# Checked Reference Key: 381503
# Checked Reference Key: 381573
# Checked Reference Key: 381800
# Checked Reference Key: 382178
# Checked Reference Key: 383228
# Checked Reference Key: 383326
# Checked Reference Key: 383785
# Checked Reference Key: 384218
# Checked Reference Key: 384364
# Checked Reference Key: 384700
# Checked Reference Key: 385317
# Checked Reference Key: 385544
# Checked Reference Key: 385579
# Checked Reference Key: 385755
# Checked Reference Key: 386239
# Checked Reference Key: 386284
# Checked Reference Key: 386302
# Checked Reference Key: 386334
# Checked Reference Key: 386343
# Checked Reference Key: 386492
# Checked Reference Key: 387249
# Checked Reference Key: 387973
# Checked Reference Key: 388209
# Checked Reference Key: 388565
# Checked Reference Key: 388613
# Checked Reference Key: 389044
# Checked Reference Key: 389818
# Checked Reference Key: 389973
# Checked Reference Key: 390892
# Checked Reference Key: 391080
# Checked Reference Key: 392521
# Checked Reference Key: 393438
# Checked Reference Key: 393616
# Checked Reference Key: 393697
# Checked Reference Key: 393959
# Checked Reference Key: 394150
# Checked Reference Key: 394361
# Checked Reference Key: 394477
# Checked Reference Key: 394953
# Checked Reference Key: 395611
# Checked Reference Key: 396303
# Checked Reference Key: 396382
# Checked Reference Key: 396806
# Checked Reference Key: 396876
# Checked Reference Key: 397014
# Checked Reference Key: 397568
# Checked Reference Key: 398160
# Checked Reference Key: 398899
# Checked Reference Key: 399072
# Checked Reference Key: 399160
# Checked Reference Key: 400426
# Checked Reference Key: 401018
# Checked Reference Key: 401045
# Checked Reference Key: 401641
# Checked Reference Key: 402720
# Checked Reference Key: 402742
# Checked Reference Key: 403618
# Checked Reference Key: 403838
# Checked Reference Key: 404155
# Checked Reference Key: 404171
# Checked Reference Key: 404406
# Checked Reference Key: 404432
# Checked Reference Key: 405203
# Checked Reference Key: 405319
# Checked Reference Key: 405571
# Checked Reference Key: 406074
# Checked Reference Key: 406419
# Checked Reference Key: 406472
# Checked Reference Key: 407729
# Checked Reference Key: 407960
# Checked Reference Key: 408209
# Checked Reference Key: 408976
# Checked Reference Key: 409335
# Checked Reference Key: 409715
# Checked Reference Key: 410718
# Checked Reference Key: 411221
# Checked Reference Key: 411975
# Checked Reference Key: 413237
# Checked Reference Key: 414180
# Checked Reference Key: 414215
# Checked Reference Key: 416343
# Checked Reference Key: 417134
# Checked Reference Key: 417532
# Checked Reference Key: 418513
# Checked Reference Key: 420103
# Checked Reference Key: 420404
# Checked Reference Key: 420678
# Checked Reference Key: 420926
# Checked Reference Key: 420967
# Checked Reference Key: 421158
# Checked Reference Key: 421351
# Checked Reference Key: 421948
# Checked Reference Key: 422509
# Checked Reference Key: 423059
# Checked Reference Key: 423100
# Checked Reference Key: 423140
# Checked Reference Key: 423258
# Checked Reference Key: 424192
# Checked Reference Key: 424212
# Checked Reference Key: 424533
# Checked Reference Key: 424846
# Checked Reference Key: 424976
# Checked Reference Key: 425302
# Checked Reference Key: 425445
# Checked Reference Key: 425470
# Checked Reference Key: 425526
# Checked Reference Key: 425635
# Checked Reference Key: 425693
# Checked Reference Key: 425820
# Checked Reference Key: 425965
# Checked Reference Key: 426121
# Checked Reference Key: 427671
# Checked Reference Key: 429368
# Checked Reference Key: 429409
# Checked Reference Key: 429443
# Checked Reference Key: 430167
# Checked Reference Key: 431056
# Checked Reference Key: 431302
# Checked Reference Key: 431584
# Checked Reference Key: 431653
# Checked Reference Key: 431830
# Checked Reference Key: 432773
# Checked Reference Key: 433831
# Checked Reference Key: 434351
# Checked Reference Key: 434586
# Checked Reference Key: 434936
# Checked Reference Key: 435389
# Checked Reference Key: 435533
# Checked Reference Key: 436159
# Checked Reference Key: 436271
# Checked Reference Key: 436677
# Checked Reference Key: 436933
# Checked Reference Key: 437354
# Checked Reference Key: 437522
# Checked Reference Key: 437524
# Checked Reference Key: 437641
# Checked Reference Key: 438521
# Checked Reference Key: 438663
# Checked Reference Key: 438827
# Checked Reference Key: 438914
# Checked Reference Key: 439182
# Checked Reference Key: 439224
# Checked Reference Key: 439225
# Checked Reference Key: 439953
# Checked Reference Key: 440176
# Checked Reference Key: 440564
# Checked Reference Key: 441417
# Checked Reference Key: 442232
# Checked Reference Key: 443212
# Checked Reference Key: 445910
# Checked Reference Key: 446739
# Checked Reference Key: 446815
# Checked Reference Key: 447066
# Checked Reference Key: 447174
# Checked Reference Key: 447425
# Checked Reference Key: 448277
# Checked Reference Key: 449239
# Checked Reference Key: 451046
# Checked Reference Key: 451232
# Checked Reference Key: 451443
# Checked Reference Key: 451903
# Checked Reference Key: 452264
# Checked Reference Key: 453695
# Checked Reference Key: 453748
# Checked Reference Key: 454846
# Checked Reference Key: 455346
# Checked Reference Key: 455370
# Checked Reference Key: 455984
# Checked Reference Key: 457956
# Checked Reference Key: 458042
# Checked Reference Key: 458121
# Checked Reference Key: 458131
# Checked Reference Key: 458740
# Checked Reference Key: 460736
# Checked Reference Key: 463946
# Checked Reference Key: 468094
# Checked Reference Key: 468226
# Checked Reference Key: 470000
# Checked Reference Key: 470478
# Checked Reference Key: 474070
# Checked Reference Key: 483415
# Checked Reference Key: 483539
# Checked Reference Key: 485114
# Checked Reference Key: 486402
# Checked Reference Key: 511388
# Checked Reference Key: 511967
# Checked Reference Key: 512012
# Checked Reference Key: 512318
# Checked Reference Key: 512546
# Checked Reference Key: 512648
# Checked Reference Key: 513056
# Checked Reference Key: 513532
# Checked Reference Key: 513567
# Checked Reference Key: 513777
# Checked Reference Key: 514306
# Checked Reference Key: 515140
# Checked Reference Key: 515522
# Checked Reference Key: 515541
# Checked Reference Key: 516726
# Checked Reference Key: 516823
# Checked Reference Key: 523775
# Checked Reference Key: 523915
# Checked Reference Key: 524334
# Checked Reference Key: 524493
# Checked Reference Key: 524752
# Checked Reference Key: 524867
# Checked Reference Key: 524997
# Checked Reference Key: 525032
# Checked Reference Key: 525459
# Checked Reference Key: 525990
# Checked Reference Key: 526001
# Checked Reference Key: 526417
# Checked Reference Key: 526776
# Checked Reference Key: 527286
# Checked Reference Key: 527811
# Checked Reference Key: 528363
# Checked Reference Key: 528374
# Checked Reference Key: 528523
# Checked Reference Key: 529319
# Checked Reference Key: 529416
# Checked Reference Key: 529530
# Checked Reference Key: 529551
# Checked Reference Key: 529656
# Checked Reference Key: 529674
# Checked Reference Key: 530473
# Checked Reference Key: 530880
# Checked Reference Key: 530931
# Checked Reference Key: 531401
# Checked Reference Key: 531796
# Checked Reference Key: 532220
# Checked Reference Key: 532222
# Checked Reference Key: 532454
# Checked Reference Key: 532561
# Checked Reference Key: 532628
# Checked Reference Key: 532735
# Checked Reference Key: 532961
# Checked Reference Key: 533049
# Checked Reference Key: 534370
# Checked Reference Key: 534784
# Checked Reference Key: 534974
# Checked Reference Key: 535469
# Checked Reference Key: 535727
# Checked Reference Key: 535852
# Checked Reference Key: 538599
# Checked Reference Key: 539277
# Checked Reference Key: 539452
# Checked Reference Key: 540600
# Checked Reference Key: 541765
# Checked Reference Key: 542020
# Checked Reference Key: 545293
# Checked Reference Key: 546335
# Checked Reference Key: 546946
# Checked Reference Key: 547257
# Checked Reference Key: 547960
# Checked Reference Key: 548278
# Checked Reference Key: 548322
# Checked Reference Key: 548454
# Checked Reference Key: 548486
# Checked Reference Key: 548506
# Checked Reference Key: 548793
# Checked Reference Key: 548937
# Checked Reference Key: 549168
# Checked Reference Key: 549172
# Checked Reference Key: 549486
# Checked Reference Key: 549508
# Checked Reference Key: 549553
# Checked Reference Key: 550083
# Checked Reference Key: 550321
# Checked Reference Key: 550927
# Checked Reference Key: 553034
# Checked Reference Key: 553200
# Checked Reference Key: 554039
# Checked Reference Key: 554492
# Checked Reference Key: 554802
# Checked Reference Key: 554964
# Checked Reference Key: 555029
# Checked Reference Key: 555155
# Checked Reference Key: 555460
# Checked Reference Key: 556823
# Checked Reference Key: 557274
# Checked Reference Key: 557520
# Checked Reference Key: 558065
# Checked Reference Key: 558605
# Checked Reference Key: 558955
# Checked Reference Key: 559417
# Checked Reference Key: 559692
# Checked Reference Key: 560116
# Checked Reference Key: 560554
# Checked Reference Key: 560720
# Checked Reference Key: 560878
# Checked Reference Key: 561282
# Checked Reference Key: 562106
# Checked Reference Key: 562165
# Checked Reference Key: 562253
# Checked Reference Key: 562311
# Checked Reference Key: 562325
# Checked Reference Key: 562569
# Checked Reference Key: 562817
# Checked Reference Key: 563351
# Checked Reference Key: 563357
# Checked Reference Key: 563409
# Checked Reference Key: 564405
# Checked Reference Key: 564752
# Checked Reference Key: 565004
# Checked Reference Key: 565214
# Checked Reference Key: 565479
# Checked Reference Key: 565522
# Checked Reference Key: 565927
# Checked Reference Key: 566107
# Checked Reference Key: 569020
# Checked Reference Key: 569169
# Checked Reference Key: 569379
# Checked Reference Key: 569452
# Checked Reference Key: 570251
# Checked Reference Key: 570726
# Checked Reference Key: 570838
# Checked Reference Key: 570912
# Checked Reference Key: 571204
# Checked Reference Key: 571608
# Checked Reference Key: 572009
# Checked Reference Key: 572160
# Checked Reference Key: 572178
# Checked Reference Key: 572683
# Checked Reference Key: 572972
# Checked Reference Key: 572973
# Checked Reference Key: 573040
# Checked Reference Key: 573058
# Checked Reference Key: 573647
# Checked Reference Key: 573891
# Checked Reference Key: 573982
# Checked Reference Key: 574037
# Checked Reference Key: 574115
# Checked Reference Key: 575178
# Checked Reference Key: 575996
# Checked Reference Key: 577952
# Checked Reference Key: 578149
# Checked Reference Key: 578704
# Checked Reference Key: 579153
# Checked Reference Key: 579314
# Checked Reference Key: 579414
# Checked Reference Key: 580246
# Checked Reference Key: 580815
# Checked Reference Key: 581993
# Checked Reference Key: 582307
# Checked Reference Key: 585605
# Checked Reference Key: 585642
# Checked Reference Key: 585756
# Checked Reference Key: 586022
# Checked Reference Key: 586058
# Checked Reference Key: 586496
# Checked Reference Key: 586766
# Checked Reference Key: 586878
# Checked Reference Key: 586941
# Checked Reference Key: 587107
# Checked Reference Key: 588402
# Checked Reference Key: 588439
# Checked Reference Key: 588464
# Checked Reference Key: 588904
# Checked Reference Key: 589308
# Checked Reference Key: 590079
# Checked Reference Key: 591093
# Checked Reference Key: 592601
# Checked Reference Key: 592972
# Checked Reference Key: 593152
# Checked Reference Key: 593260
# Checked Reference Key: 593797
# Checked Reference Key: 594361
# Checked Reference Key: 595046
# Checked Reference Key: 595776
# Checked Reference Key: 596039
# Checked Reference Key: 597778
# Checked Reference Key: 598841
# Checked Reference Key: 598842
# Checked Reference Key: 599112
# Checked Reference Key: 599251
# Checked Reference Key: 599449
# Checked Reference Key: 600374
# Checked Reference Key: 600814
# Checked Reference Key: 600834
# Checked Reference Key: 601484
# Checked Reference Key: 602087
# Checked Reference Key: 602206
# Checked Reference Key: 602799
# Checked Reference Key: 603312
# Checked Reference Key: 603423
# Checked Reference Key: 604006
# Checked Reference Key: 604108
# Checked Reference Key: 604884
# Checked Reference Key: 604989
# Checked Reference Key: 606163
# Checked Reference Key: 606339
# Checked Reference Key: 606735
# Checked Reference Key: 607332
# Checked Reference Key: 607470
# Checked Reference Key: 608220
# Checked Reference Key: 609359
# Checked Reference Key: 609950
# Checked Reference Key: 611213
# Checked Reference Key: 611754
# Checked Reference Key: 611832
# Checked Reference Key: 611966
# Checked Reference Key: 612525
# Checked Reference Key: 613071
# Checked Reference Key: 613551
# Checked Reference Key: 613709
# Checked Reference Key: 613870
# Checked Reference Key: 614870
# Checked Reference Key: 615494
# Checked Reference Key: 615949
# Checked Reference Key: 615952
# Checked Reference Key: 615964
# Checked Reference Key: 615976
# Checked Reference Key: 616021
# Checked Reference Key: 616506
# Checked Reference Key: 616512
# Checked Reference Key: 616956
# Checked Reference Key: 621476
# Checked Reference Key: 622581
# Checked Reference Key: 624291
# Checked Reference Key: 625424
# Checked Reference Key: 626446
# Checked Reference Key: 630529
# Checked Reference Key: 633009
# Checked Reference Key: 636026
# Checked Reference Key: 639651
# Checked Reference Key: 639788
# Checked Reference Key: 639974
# Checked Reference Key: 640177
# Checked Reference Key: 640319
# Checked Reference Key: 640333
# Checked Reference Key: 640695
# Checked Reference Key: 641098
# Checked Reference Key: 641730
# Checked Reference Key: 641953
# Checked Reference Key: 642044
# Checked Reference Key: 642129
# Checked Reference Key: 642624
# Checked Reference Key: 643340
# Checked Reference Key: 643456
# Checked Reference Key: 644168
# Checked Reference Key: 644572
# Checked Reference Key: 645196
# Checked Reference Key: 645804
# Checked Reference Key: 645949
# Checked Reference Key: 646330
# Checked Reference Key: 646590
# Checked Reference Key: 646673
# Checked Reference Key: 646903
# Checked Reference Key: 647255
# Checked Reference Key: 647530
# Checked Reference Key: 648272
# Checked Reference Key: 648290
# Checked Reference Key: 648305
# Checked Reference Key: 648715
# Checked Reference Key: 649274
# Checked Reference Key: 649471
# Checked Reference Key: 649768
# Checked Reference Key: 650199
# Checked Reference Key: 650863
# Checked Reference Key: 651074
# Checked Reference Key: 651363
# Checked Reference Key: 651786
# Checked Reference Key: 651959
# Checked Reference Key: 652091
# Checked Reference Key: 653152
# Checked Reference Key: 653293
# Checked Reference Key: 653786
# Checked Reference Key: 653979
# Checked Reference Key: 655287
# Checked Reference Key: 655765
# Checked Reference Key: 655906
# Checked Reference Key: 655975
# Checked Reference Key: 656098
# Checked Reference Key: 657093
# Checked Reference Key: 657414
# Checked Reference Key: 657557
# Checked Reference Key: 657621
# Checked Reference Key: 657730
# Checked Reference Key: 658001
# Checked Reference Key: 658018
# Checked Reference Key: 658494
# Checked Reference Key: 658951
# Checked Reference Key: 659171
# Checked Reference Key: 659279
# Checked Reference Key: 659318
# Checked Reference Key: 659468
# Checked Reference Key: 659518
# Checked Reference Key: 660081
# Checked Reference Key: 661756
# Checked Reference Key: 661848
# Checked Reference Key: 662043
# Checked Reference Key: 662443
# Checked Reference Key: 662963
# Checked Reference Key: 663053
# Checked Reference Key: 663635
# Checked Reference Key: 664218
# Checked Reference Key: 665172
# Checked Reference Key: 665598
# Checked Reference Key: 665703
# Checked Reference Key: 666150
# Checked Reference Key: 668451
# Checked Reference Key: 668747
# Checked Reference Key: 668916
# Checked Reference Key: 668983
# Checked Reference Key: 669776
# Checked Reference Key: 670060
# Checked Reference Key: 670394
# Checked Reference Key: 670522
# Checked Reference Key: 670804
# Checked Reference Key: 670880
# Checked Reference Key: 671449
# Checked Reference Key: 671452
# Checked Reference Key: 672192
# Checked Reference Key: 672465
# Checked Reference Key: 673124
# Checked Reference Key: 673612
# Checked Reference Key: 674162
# Checked Reference Key: 674172
# Checked Reference Key: 674300
# Checked Reference Key: 675591
# Checked Reference Key: 675669
# Checked Reference Key: 675923
# Checked Reference Key: 678167
# Checked Reference Key: 678937
# Checked Reference Key: 679879
# Checked Reference Key: 679940
# Checked Reference Key: 680258
# Checked Reference Key: 680712
# Checked Reference Key: 680841
# Checked Reference Key: 682277
# Checked Reference Key: 682669
# Checked Reference Key: 683680
# Checked Reference Key: 684267
# Checked Reference Key: 684631
# Checked Reference Key: 684982
# Checked Reference Key: 685931
# Checked Reference Key: 691237
# Checked Reference Key: 691295
# Checked Reference Key: 691633
# Checked Reference Key: 705969
# Checked Reference Key: 706095
# Checked Reference Key: 706321
# Checked Reference Key: 706465
# Checked Reference Key: 707263
# Checked Reference Key: 707390
# Checked Reference Key: 707683
# Checked Reference Key: 708338
# Checked Reference Key: 709162
# Checked Reference Key: 709406
# Checked Reference Key: 710013
# Checked Reference Key: 711010
# Checked Reference Key: 711118
# Checked Reference Key: 711671
# Checked Reference Key: 711749
# Checked Reference Key: 712011
# Checked Reference Key: 712626
# Checked Reference Key: 713183
# Checked Reference Key: 713332
# Checked Reference Key: 713999
# Checked Reference Key: 714004
# Checked Reference Key: 714057
# Checked Reference Key: 714060
# Checked Reference Key: 714140
# Checked Reference Key: 714246
# Checked Reference Key: 714464
# Checked Reference Key: 714663
# Checked Reference Key: 714701
# Checked Reference Key: 714783
# Checked Reference Key: 714877
# Checked Reference Key: 715148
# Checked Reference Key: 715544
# Checked Reference Key: 715816
# Checked Reference Key: 716347
# Checked Reference Key: 717328
# Checked Reference Key: 717412
# Checked Reference Key: 717475
# Checked Reference Key: 717488
# Checked Reference Key: 717571
# Checked Reference Key: 717759
# Checked Reference Key: 718273
# Checked Reference Key: 718359
# Checked Reference Key: 718617
# Checked Reference Key: 719481
# Checked Reference Key: 719553
# Checked Reference Key: 719561
# Checked Reference Key: 719958
# Checked Reference Key: 720461
# Checked Reference Key: 720497
# Checked Reference Key: 720507
# Checked Reference Key: 720541
# Checked Reference Key: 720596
# Checked Reference Key: 720809
# Checked Reference Key: 721230
# Checked Reference Key: 721327
# Checked Reference Key: 721391
# Checked Reference Key: 721735
# Checked Reference Key: 722164
# Checked Reference Key: 722583
# Checked Reference Key: 723050
# Checked Reference Key: 723335
# Checked Reference Key: 723377
# Checked Reference Key: 724233
# Checked Reference Key: 725540
# Checked Reference Key: 725610
# Checked Reference Key: 725658
# Checked Reference Key: 725704
# Checked Reference Key: 725791
# Checked Reference Key: 726248
# Checked Reference Key: 726691
# Checked Reference Key: 726778
# Checked Reference Key: 727168
# Checked Reference Key: 727435
# Checked Reference Key: 727710
# Checked Reference Key: 728974
# Checked Reference Key: 729246
# Checked Reference Key: 729557
# Checked Reference Key: 729745
# Checked Reference Key: 729879
# Checked Reference Key: 730000
# Checked Reference Key: 730616
# Checked Reference Key: 730760
# Checked Reference Key: 731215
# Checked Reference Key: 731359
# Checked Reference Key: 731538
# Checked Reference Key: 731701
# Checked Reference Key: 731885
# Checked Reference Key: 731977
# Checked Reference Key: 732497
# Checked Reference Key: 733513
# Checked Reference Key: 733630
# Checked Reference Key: 733984
# Checked Reference Key: 734552
# Checked Reference Key: 735203
# Checked Reference Key: 735223
# Checked Reference Key: 735488
# Checked Reference Key: 736734
# Checked Reference Key: 737733
# Checked Reference Key: 737896
# Checked Reference Key: 740043
# Checked Reference Key: 740798
# Checked Reference Key: 741067
# Checked Reference Key: 741159
# Checked Reference Key: 741270
# Checked Reference Key: 741415
# Checked Reference Key: 741722
# Checked Reference Key: 742806
# Checked Reference Key: 743309
# Checked Reference Key: 743456
# Checked Reference Key: 743720
# Checked Reference Key: 743966
# Checked Reference Key: 744126
# Checked Reference Key: 744559
# Checked Reference Key: 744646
# Checked Reference Key: 745194
# Checked Reference Key: 746110
# Checked Reference Key: 746196
# Checked Reference Key: 747229
# Checked Reference Key: 747297
# Checked Reference Key: 748157
# Checked Reference Key: 748273
# Checked Reference Key: 748711
# Checked Reference Key: 748769
# Checked Reference Key: 749150
# Checked Reference Key: 749192
# Checked Reference Key: 749490
# Checked Reference Key: 749832
# Checked Reference Key: 750152
# Checked Reference Key: 750209
# Checked Reference Key: 750222
# Checked Reference Key: 750337
# Checked Reference Key: 750391
# Checked Reference Key: 750821
# Checked Reference Key: 751607
# Checked Reference Key: 752110
# Checked Reference Key: 752142
# Checked Reference Key: 752942
# Checked Reference Key: 753061
# Checked Reference Key: 753688
# Checked Reference Key: 753905
# Checked Reference Key: 755280
# Checked Reference Key: 755819
# Checked Reference Key: 756533
# Checked Reference Key: 757612
# Checked Reference Key: 757623
# Checked Reference Key: 757899
# Checked Reference Key: 759261
# Checked Reference Key: 759402
# Checked Reference Key: 761412
# Checked Reference Key: 761590
# Checked Reference Key: 761799
# Checked Reference Key: 762400
# Checked Reference Key: 762546
# Checked Reference Key: 762809
# Checked Reference Key: 764304
# Checked Reference Key: 764487
# Checked Reference Key: 764515
# Checked Reference Key: 764629
# Checked Reference Key: 764682
# Checked Reference Key: 765448
# Checked Reference Key: 765759
# Checked Reference Key: 765957
# Checked Reference Key: 766014
# Checked Reference Key: 766506
# Checked Reference Key: 766602
# Checked Reference Key: 766624
# Checked Reference Key: 767558
# Checked Reference Key: 767661
# Checked Reference Key: 769369
# Checked Reference Key: 769648
# Checked Reference Key: 770393
# Checked Reference Key: 770480
# Checked Reference Key: 770545
# Checked Reference Key: 771803
# Checked Reference Key: 772823
# Checked Reference Key: 773624
# Checked Reference Key: 774356
# Checked Reference Key: 774368
# Checked Reference Key: 774397
# Checked Reference Key: 774507
# Checked Reference Key: 775028
# Checked Reference Key: 776015
# Checked Reference Key: 776399
# Checked Reference Key: 776658
# Checked Reference Key: 776926
# Checked Reference Key: 778659
# Checked Reference Key: 778766
# Checked Reference Key: 779726
# Checked Reference Key: 780893
# Checked Reference Key: 780971
# Checked Reference Key: 781174
# Checked Reference Key: 781359
# Checked Reference Key: 784246
# Checked Reference Key: 784554
# Checked Reference Key: 786140
# Checked Reference Key: 786473
# Checked Reference Key: 790468
# ...
# Checked Reference Key: 12109259
# Checked Reference Key: 12114482
# Checked Reference Key: 12116747
# Checked Reference Key: 12117967
# Checked Reference Key: 12121180
# Checked Reference Key: 12125671
# Checked Reference Key: 12129432
# Checked Reference Key: 12136578
# Checked Reference Key: 12138595
# Checked Reference Key: 12144675
# Checked Reference Key: 12147781
# Checked Reference Key: 12148329
# Checked Reference Key: 12150557
# Checked Reference Key: 12152098
# Checked Reference Key: 12155173
# Checked Reference Key: 12162910
# Checked Reference Key: 12165772
# Checked Reference Key: 12167473
# Checked Reference Key: 12167774
# Checked Reference Key: 12168102
# Checked Reference Key: 12171065
# Checked Reference Key: 12177691
# Checked Reference Key: 12179294
# Checked Reference Key: 12191809
# Checked Reference Key: 12194604
# Checked Reference Key: 12200736
# Checked Reference Key: 12201704
# Checked Reference Key: 12205281
# Checked Reference Key: 12209278
# Checked Reference Key: 12216799
# Checked Reference Key: 12217822
# Checked Reference Key: 12218272
# Checked Reference Key: 12220938
# Checked Reference Key: 12222679
# Checked Reference Key: 12223087
# Checked Reference Key: 12224060
# Checked Reference Key: 12231660
# Checked Reference Key: 12237531
# Checked Reference Key: 12246826
# Checked Reference Key: 12247520
# Checked Reference Key: 12249086
# Checked Reference Key: 12251978
# Checked Reference Key: 12252018
# Checked Reference Key: 12260473
# Checked Reference Key: 12263332
# Checked Reference Key: 12263544
# Checked Reference Key: 12265375
# Checked Reference Key: 12266193
# Checked Reference Key: 12279048
# Checked Reference Key: 12279079
# Checked Reference Key: 12279971
# Checked Reference Key: 12280030
# Checked Reference Key: 12281549
# Checked Reference Key: 12287439
# Checked Reference Key: 12291220
# Checked Reference Key: 12292190
# Checked Reference Key: 12292765
# Checked Reference Key: 12293042
# Checked Reference Key: 12294834
# Checked Reference Key: 12295305
# Checked Reference Key: 12295888
# Checked Reference Key: 12300908
# Checked Reference Key: 12310183
# Checked Reference Key: 12314465
# Checked Reference Key: 12315845
# Checked Reference Key: 12324201
# Checked Reference Key: 12326274
# Checked Reference Key: 12326538
# Checked Reference Key: 12328496
# Checked Reference Key: 12328509
# Checked Reference Key: 12329515
# Checked Reference Key: 12333394
# Checked Reference Key: 12336246
# Checked Reference Key: 12336405
# Checked Reference Key: 12337099
# Checked Reference Key: 12339816
# Checked Reference Key: 12344094
# Checked Reference Key: 12344924
# Checked Reference Key: 12345334
# Checked Reference Key: 12348170
# Checked Reference Key: 12356385
# Checked Reference Key: 12358131
# Checked Reference Key: 12361453
# Checked Reference Key: 12361584
# Checked Reference Key: 12362323
# Checked Reference Key: 12364242
# Checked Reference Key: 12364596
# Checked Reference Key: 12368194
# Checked Reference Key: 12372881
# Checked Reference Key: 12374016
# Checked Reference Key: 12374034
# Checked Reference Key: 12374080
# Checked Reference Key: 12376806
# Checked Reference Key: 12376954
# Checked Reference Key: 12379742
# Checked Reference Key: 12380692
# Checked Reference Key: 12382650
# Checked Reference Key: 12384037
# Checked Reference Key: 12384084
# Checked Reference Key: 12385720
# Checked Reference Key: 12391532
# Checked Reference Key: 12401205
# Checked Reference Key: 12401419
# Checked Reference Key: 12402417
# Checked Reference Key: 12407412
# Checked Reference Key: 12407832
# Checked Reference Key: 12408795
# Checked Reference Key: 12420294
# Checked Reference Key: 12423072
# Checked Reference Key: 12435631
# Checked Reference Key: 12438279
# Checked Reference Key: 12439289
# Checked Reference Key: 12441363
# Checked Reference Key: 12445822
# Checked Reference Key: 12445881
# Checked Reference Key: 12448955
# Checked Reference Key: 12449221
# Checked Reference Key: 12455905
# Checked Reference Key: 12455913
# Checked Reference Key: 12458391
# Checked Reference Key: 12462780
# Checked Reference Key: 12468243
# Checked Reference Key: 12469312
# Checked Reference Key: 12477738
# Checked Reference Key: 12480624
# Checked Reference Key: 12482187
# Checked Reference Key: 12482438
# Checked Reference Key: 12484634
# Checked Reference Key: 12492472
# Checked Reference Key: 12496134
# Checked Reference Key: 12496187
# Checked Reference Key: 12497951
# Checked Reference Key: 12498439
# Checked Reference Key: 12501952
# Checked Reference Key: 12509252
# Checked Reference Key: 12509744
# Checked Reference Key: 12509853
# Checked Reference Key: 12512909
# Checked Reference Key: 12516549
# Checked Reference Key: 12517731
# Checked Reference Key: 12518710
# Checked Reference Key: 12522336
# Checked Reference Key: 12538747
# Checked Reference Key: 12540098
# Checked Reference Key: 12541524
# Checked Reference Key: 12541608
# Checked Reference Key: 12544096
# Checked Reference Key: 12544857
# Checked Reference Key: 12546419
# Checked Reference Key: 12548014
# Checked Reference Key: 12560343
# Checked Reference Key: 12560828
# Checked Reference Key: 12563666
# Checked Reference Key: 12564112
# Checked Reference Key: 12566532
# Checked Reference Key: 12568716
# Checked Reference Key: 12573349
# Checked Reference Key: 12575646
# Checked Reference Key: 12575746
# Checked Reference Key: 12580482
# Checked Reference Key: 12581127
# Checked Reference Key: 12588164
# Checked Reference Key: 12591176
# Checked Reference Key: 12591971
# Checked Reference Key: 12593666
# Checked Reference Key: 12596816
# Checked Reference Key: 12597755
# Checked Reference Key: 12605780
# Checked Reference Key: 12607280
# Checked Reference Key: 12609446
# Checked Reference Key: 12611268
# Checked Reference Key: 12615427
# Checked Reference Key: 12616899
# Checked Reference Key: 12617455
# Checked Reference Key: 12619774
# Checked Reference Key: 12620477
# Checked Reference Key: 12622372
# Checked Reference Key: 12626265
# Checked Reference Key: 12626714
# Checked Reference Key: 12628163
# Checked Reference Key: 12634114
# Checked Reference Key: 12634801
# Checked Reference Key: 12641756
# Checked Reference Key: 12641778
# Checked Reference Key: 12645116
# Checked Reference Key: 12646740
# Checked Reference Key: 12653240
# Checked Reference Key: 12655212
# Checked Reference Key: 12656471
# Checked Reference Key: 12666834
# Checked Reference Key: 12673286
# Checked Reference Key: 12674346
# Checked Reference Key: 12676364
# Checked Reference Key: 12679862
# Checked Reference Key: 12680779
# Checked Reference Key: 12681918
# Checked Reference Key: 12684018
# Checked Reference Key: 12684811
# Checked Reference Key: 12685752
# Checked Reference Key: 12689907
# Checked Reference Key: 12695084
# Checked Reference Key: 12695955
# Checked Reference Key: 12698980
# Checked Reference Key: 12699017
# Checked Reference Key: 12699510
# Checked Reference Key: 12699603
# Checked Reference Key: 12702308
# Checked Reference Key: 12703897
# Checked Reference Key: 12706598
# Checked Reference Key: 12709834
# Checked Reference Key: 12711394
# Checked Reference Key: 12714148
# Checked Reference Key: 12714700
# Checked Reference Key: 12715454
# Checked Reference Key: 12715694
# Checked Reference Key: 12716110
# Checked Reference Key: 12716616
# Checked Reference Key: 12719810
# Checked Reference Key: 12724307
# Checked Reference Key: 12728284
# Checked Reference Key: 12730234
# Checked Reference Key: 12731363
# Checked Reference Key: 12736722
# Checked Reference Key: 12736792
# Checked Reference Key: 12738016
# Checked Reference Key: 12738822
# Checked Reference Key: 12740331
# Checked Reference Key: 12743325
# Checked Reference Key: 12744073
# Checked Reference Key: 12745141
# Checked Reference Key: 12747789
# Checked Reference Key: 12748462
# Checked Reference Key: 12750938
# Checked Reference Key: 12752866
# Checked Reference Key: 12755091
# Checked Reference Key: 12755274
# Checked Reference Key: 12756087
# Checked Reference Key: 12757000
# Checked Reference Key: 12761090
# Checked Reference Key: 12766921
# Checked Reference Key: 12780240
# Checked Reference Key: 12782505
# Checked Reference Key: 12783129
# Checked Reference Key: 12783735
# Checked Reference Key: 12784294
# Checked Reference Key: 12786962
# Checked Reference Key: 12792795
# Checked Reference Key: 12795999
# Checked Reference Key: 12797358
# Checked Reference Key: 12799815
# Checked Reference Key: 12806982
# Checked Reference Key: 12809341
# Checked Reference Key: 12812542
# Checked Reference Key: 12813563
# Checked Reference Key: 12814454
# Checked Reference Key: 12831764
# Checked Reference Key: 12832381
# Checked Reference Key: 12834610
# Checked Reference Key: 12835058
# Checked Reference Key: 12840782
# Checked Reference Key: 12844256
# Checked Reference Key: 12846262
# Checked Reference Key: 12847270
# Checked Reference Key: 12848016
# Checked Reference Key: 12853973
# Checked Reference Key: 12856749
# Checked Reference Key: 12859859
# Checked Reference Key: 12861751
# Checked Reference Key: 12862850
# Checked Reference Key: 12865855
# Checked Reference Key: 12869295
# Checked Reference Key: 12869553
# Checked Reference Key: 12870267
# Checked Reference Key: 12874376
# Checked Reference Key: 12874732
# Checked Reference Key: 12879704
# Checked Reference Key: 12883266
# Checked Reference Key: 12889559
# Checked Reference Key: 12891252
# Checked Reference Key: 12892785
# Checked Reference Key: 12893255
# Checked Reference Key: 12895279
# Checked Reference Key: 12896896
# Checked Reference Key: 12897903
# Checked Reference Key: 12898098
# Checked Reference Key: 12899180
# Checked Reference Key: 12900384
# Checked Reference Key: 12902071
# Checked Reference Key: 12904042
# Checked Reference Key: 12904805
# Checked Reference Key: 12905024
# Checked Reference Key: 12905795
# Checked Reference Key: 12905836
# Checked Reference Key: 12905931
# Checked Reference Key: 12906276
# Checked Reference Key: 12906282
# Checked Reference Key: 12906854
# Checked Reference Key: 12906891
# Checked Reference Key: 12906995
# Checked Reference Key: 12907271
# Checked Reference Key: 12907636
# Checked Reference Key: 12907880
# Checked Reference Key: 12907894
# Checked Reference Key: 12908084
# Checked Reference Key: 12908297
# Checked Reference Key: 12908310
# Checked Reference Key: 12908884
# Checked Reference Key: 12908995
# Checked Reference Key: 12909420
# Checked Reference Key: 12909545
# Checked Reference Key: 12909575
# Checked Reference Key: 12910022
# Checked Reference Key: 12910310
# Checked Reference Key: 12910501
# Checked Reference Key: 12910753
# Checked Reference Key: 12911262
# Checked Reference Key: 12911315
# Checked Reference Key: 12911408
# Checked Reference Key: 12911469
# Checked Reference Key: 12911582
# Checked Reference Key: 12912200
# Checked Reference Key: 12912261
# Checked Reference Key: 12912722
# Checked Reference Key: 12912980
# Checked Reference Key: 12913224
# Checked Reference Key: 12913553
# Checked Reference Key: 12913873
# Checked Reference Key: 12914228
# Checked Reference Key: 12914464
# Checked Reference Key: 12914769
# Checked Reference Key: 12914808
# Checked Reference Key: 12914847
# Checked Reference Key: 12915620
# Checked Reference Key: 12915684
# Checked Reference Key: 12915901
# Checked Reference Key: 12916534
# Checked Reference Key: 12916833
# Checked Reference Key: 12916989
# Checked Reference Key: 12917143
# Checked Reference Key: 12917782
# Checked Reference Key: 12918060
# Checked Reference Key: 12918336
# Checked Reference Key: 12918509
# Checked Reference Key: 12918911
# Checked Reference Key: 12918918
# Checked Reference Key: 12918979
# Checked Reference Key: 12919060
# Checked Reference Key: 12919219
# Checked Reference Key: 12919907
# Checked Reference Key: 12919948
# Checked Reference Key: 12920019
# Checked Reference Key: 12920206
# Checked Reference Key: 12920361
# Checked Reference Key: 12920665
# Checked Reference Key: 12921296
# Checked Reference Key: 12921340
# Checked Reference Key: 12922063
# Checked Reference Key: 12922141
# Checked Reference Key: 12922607
# Checked Reference Key: 12922616
# Checked Reference Key: 12922683
# Checked Reference Key: 12922794
# Checked Reference Key: 12922849
# Checked Reference Key: 12923134
# Checked Reference Key: 12923246
# Checked Reference Key: 12923386
# Checked Reference Key: 12923909
# Checked Reference Key: 12924480
# Checked Reference Key: 12924727
# Checked Reference Key: 12924873
# Checked Reference Key: 12924921
# Checked Reference Key: 12925248
# Checked Reference Key: 12925614
# Checked Reference Key: 12925880
# Checked Reference Key: 12925965
# Checked Reference Key: 12925994
# Checked Reference Key: 12926431
# Checked Reference Key: 12926453
# Checked Reference Key: 12926593
# Checked Reference Key: 12926643
# Checked Reference Key: 12926654
# Checked Reference Key: 12926854
# Checked Reference Key: 12927069
# Checked Reference Key: 12927725
# Checked Reference Key: 12927744
# Checked Reference Key: 12928062
# Checked Reference Key: 12928154
# Checked Reference Key: 12928182
# Checked Reference Key: 12928530
# Checked Reference Key: 12929145
# Checked Reference Key: 12929146
# Checked Reference Key: 12929193
# Checked Reference Key: 12930508
# Checked Reference Key: 12930728
# Checked Reference Key: 12931665
# Checked Reference Key: 12931681
# Checked Reference Key: 12932074
# Checked Reference Key: 12932314
# Checked Reference Key: 12932364
# Checked Reference Key: 12932504
# Checked Reference Key: 12933445
# Checked Reference Key: 12933606
# Checked Reference Key: 12933730
# Checked Reference Key: 12934062
# Checked Reference Key: 12935179
# Checked Reference Key: 12935232
# Checked Reference Key: 12935549
# Checked Reference Key: 12936357
# Checked Reference Key: 12936776
# Checked Reference Key: 12937178
# Checked Reference Key: 12937236
# Checked Reference Key: 12937253
# Checked Reference Key: 12937679
# Checked Reference Key: 12938046
# Checked Reference Key: 12938202
# Checked Reference Key: 12938575
# Checked Reference Key: 12938793
# Checked Reference Key: 12938813
# Checked Reference Key: 12938844
# Checked Reference Key: 12939575
# Checked Reference Key: 12939804
# Checked Reference Key: 12940155
# Checked Reference Key: 12940461
# Checked Reference Key: 12940506
# Checked Reference Key: 12941090
# Checked Reference Key: 12942123
# Checked Reference Key: 12942223
# Checked Reference Key: 12942351
# Checked Reference Key: 12942508
# Checked Reference Key: 12942935
# Checked Reference Key: 12942956
# Checked Reference Key: 12943452
# Checked Reference Key: 12943648
# Checked Reference Key: 12943649
# Checked Reference Key: 12944125
# Checked Reference Key: 12944356
# Checked Reference Key: 12944371
# Checked Reference Key: 12944988
# Checked Reference Key: 12945372
# Checked Reference Key: 12945631
# Checked Reference Key: 12945658
# Checked Reference Key: 12946087
# Checked Reference Key: 12946390
# Checked Reference Key: 12946443
# Checked Reference Key: 12946627
# Checked Reference Key: 12946739
# Checked Reference Key: 12947045
# Checked Reference Key: 12947061
# Checked Reference Key: 12947309
# Checked Reference Key: 12947899
# Checked Reference Key: 12948071
# Checked Reference Key: 12948116
# Checked Reference Key: 12948584
# Checked Reference Key: 12949047
# Checked Reference Key: 12949391
# Checked Reference Key: 12949698
# Checked Reference Key: 12949884
# Checked Reference Key: 12949953
# Checked Reference Key: 12949997
# Checked Reference Key: 12950068
# Checked Reference Key: 12950604
# Checked Reference Key: 12950733
# Checked Reference Key: 12951467
# Checked Reference Key: 12951521
# Checked Reference Key: 12951844
# Checked Reference Key: 12952045
# Checked Reference Key: 12952396
# Checked Reference Key: 12952664
# Checked Reference Key: 12952728
# Checked Reference Key: 12953781
# Checked Reference Key: 12953804
# Checked Reference Key: 12954068
# Checked Reference Key: 12954113
# Checked Reference Key: 12954167
# Checked Reference Key: 12955261
# Checked Reference Key: 12955647
# Checked Reference Key: 12955864
# Checked Reference Key: 12956155
# Checked Reference Key: 12956343
# Checked Reference Key: 12956542
# Checked Reference Key: 12957073
# Checked Reference Key: 12957303
# Checked Reference Key: 12962391
# Checked Reference Key: 12966931
# Checked Reference Key: 12968116
# Checked Reference Key: 12973819
# Checked Reference Key: 12983002
# Checked Reference Key: 13001071
# Checked Reference Key: 13022478
# Checked Reference Key: 13030753
# Checked Reference Key: 13064066
# Checked Reference Key: 13067024
# Checked Reference Key: 13084259
# Checked Reference Key: 13142843
# Checked Reference Key: 13394404
# Checked Reference Key: No. of Records :83676
# ASE vasopressor results saved to ./presumed_infection/2.Data/New Data/Output\ase\ase_2022.csv

# %%
file = DATA_PATH + "Output/ase/ase_2022.csv"
create_ASE_list(file, 2022)
# Out:
#       Reference Key    HN Number Institution (IPAS)
# 0               254  HN22000895D                PYN
# 1               254  HN22000895D                PYN
# 2               254  HN22000895D                PYN
# 3               254  HN22000895D                PYN
# 4               254  HN22000895D                PYN
# ...             ...          ...                ...
# 29962       7241228  HN222108682                PMH
# 29963       7241228  HN222108682                PMH
# 29964       7241228  HN222108682                PMH
# 29965       7241228  HN222108682                PMH
# 29966       7241228  HN222108682                PMH
#
# [29967 rows x 3 columns]

# %%
file = DATA_PATH + "Output/ase/ase_2022.csv"
ase_percentages(file)
# Out:
# {'vasopressor': 6.17,
#  'ventilation': 1.41,
#  'creatinine': 6.52,
#  'bili': 3.44,
#  'plt': 0.0,
#  'lact': 0.0}

# %%
from glob import glob

# AI generated summarization code
def extract_true_cases():
    """Extract all HN+Institution pairs with at least one True across all years"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    true_cases = []
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Check if any of the condition columns are True
        condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
        df['has_true'] = df[condition_cols].any(axis=1)
        
        # Extract HN+Institution pairs with at least one True
        year_true = df[df['has_true']][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        
        for _, row in year_true.iterrows():
            true_cases.append({
                'HN Number': row['HN Number'], 
                'Institution (IPAS)': row['Institution (IPAS)'],
                'Year': year
            })
    
    true_cases_df = pd.DataFrame(true_cases)
    output_file = os.path.join(output_dir, 'true_cases_all_years.csv')
    true_cases_df.to_csv(output_file, index=False)
    print(f"True cases saved to {output_file}, total {len(true_cases_df)} cases")
    
    return true_cases_df

def summarize_statistics():
    """Summarize statistics by year and overall"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_stats = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    overall_counts = {col: 0 for col in condition_cols}
    overall_total = 0
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Use unique HN+Institution combinations for patient count
        unique_patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
        patient_count = len(unique_patients)
        
        year_stats = {'Year': year, 'Total_Patients': patient_count}
        
        # Calculate condition counts per patient
        for col in condition_cols:
            # Count patients with this condition True at least once
            patients_with_condition = df[df[col]][['HN Number', 'Institution (IPAS)']].drop_duplicates()
            count = len(patients_with_condition)
            percentage = (count / patient_count * 100) if patient_count > 0 else 0
            year_stats[f'{col}_count'] = count
            year_stats[f'{col}_pct'] = round(percentage, 2)
            
            overall_counts[col] += count
        
        # Patients with any condition
        patients_with_any = df[df[condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        any_count = len(patients_with_any)
        year_stats['Patients_with_any'] = any_count
        year_stats['Any_pct'] = round(any_count / patient_count * 100, 2) if patient_count > 0 else 0
        
        overall_total += patient_count
        all_stats.append(year_stats)
    
    # Overall statistics
    overall_stats = {'Year': 'OVERALL', 'Total_Patients': overall_total}
    
    for col in condition_cols:
        percentage = (overall_counts[col] / overall_total * 100) if overall_total > 0 else 0
        overall_stats[f'{col}_count'] = overall_counts[col]
        overall_stats[f'{col}_pct'] = round(percentage, 2)
    
    # Calculate overall patients with any condition
    all_any_patients = set()
    for file in files:
        df = pd.read_csv(file)
        any_patients = df[df[condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
        for _, row in any_patients.iterrows():
            all_any_patients.add((row['HN Number'], row['Institution (IPAS)']))
    
    overall_stats['Patients_with_any'] = len(all_any_patients)
    overall_stats['Any_pct'] = round(len(all_any_patients) / overall_total * 100, 2) if overall_total > 0 else 0
    
    all_stats.append(overall_stats)
    
    stats_df = pd.DataFrame(all_stats)
    
    # Save statistics
    stats_file = os.path.join(output_dir, 'statistics_summary.csv')
    stats_df.to_csv(stats_file, index=False)
    print(f"Statistics saved to {stats_file}")
    
    return stats_df

def summarize_detailed():
    """Detailed summary including distribution of number of conditions per patient"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    all_detailed = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    for file in files:
        year = file.split('_')[-1].split('.')[0]
        df = pd.read_csv(file)
        
        # Create patient-condition matrix
        patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
        
        # Count conditions per patient
        condition_counts = []
        for _, patient in patients.iterrows():
            hn = patient['HN Number']
            inst = patient['Institution (IPAS)']
            patient_rows = df[(df['HN Number'] == hn) & (df['Institution (IPAS)'] == inst)]
            
            # Count unique conditions that are True at least once
            condition_count = 0
            for col in condition_cols:
                if patient_rows[col].any():
                    condition_count += 1
            
            condition_counts.append(condition_count)
        
        # Calculate distribution
        year_detailed = {
            'Year': year,
            'Total_Patients': len(patients),
            'Patients_with_0': condition_counts.count(0),
            'Patients_with_1': condition_counts.count(1),
            'Patients_with_2': condition_counts.count(2),
            'Patients_with_3': condition_counts.count(3),
            'Patients_with_4': condition_counts.count(4),
            'Patients_with_5': condition_counts.count(5),
            'Patients_with_6': condition_counts.count(6),
            'Avg_conditions': round(sum(condition_counts) / len(condition_counts), 2) if condition_counts else 0
        }
        
        # Add percentages
        for i in range(7):
            pct_col = f'Pct_with_{i}'
            count = year_detailed[f'Patients_with_{i}']
            year_detailed[pct_col] = round(count / len(patients) * 100, 2) if len(patients) > 0 else 0
        
        all_detailed.append(year_detailed)
    
    detailed_df = pd.DataFrame(all_detailed)
    
    # Save detailed statistics
    detailed_file = os.path.join(output_dir, 'detailed_statistics.csv')
    detailed_df.to_csv(detailed_file, index=False)
    print(f"Detailed statistics saved to {detailed_file}")
    
    return detailed_df

# Run all functions
if __name__ == "__main__":
    true_cases = extract_true_cases()
    stats = summarize_statistics()
    detailed = summarize_detailed()
    
    print("\nSummary Statistics:")
    print(stats.to_string(index=False))
# Out:
# True cases saved to ./presumed_infection/2.Data/Output/ase/true_cases_all_years.csv, total 232276 cases
# Statistics saved to ./presumed_infection/2.Data/Output/ase/statistics_summary.csv
# Detailed statistics saved to ./presumed_infection/2.Data/New Data/Output/ase/detailed_statistics.csv
#
# Summary Statistics:
#    Year  Total_Patients  vasopressor_count  vasopressor_pct  ventilation_count  ventilation_pct  creatinine_count  creatinine_pct  bili_count  bili_pct  plt_count  plt_pct  lact_count  lact_pct  Patients_with_any  Any_pct
#    2014           85578               2745             3.21               3894             4.55             12196           14.25        7349      8.59       5930     6.93        1939      2.27              21540    25.17
#    2015           88152               3372             3.83               3185             3.61             12196           13.84        7518      8.53       6267     7.11        2135      2.42              21827    24.76
#    2016           96614               3577             3.70               3934             4.07             13423           13.89        6706      6.94       5614     5.81        2277      2.36              22755    23.55
#    2017          116732               2427             2.08               1355             1.16              6940            5.95        4637      3.97       3619     3.10        1692      1.45              12765    10.94
#    2018          113458               6286             5.54               1816             1.60             15126           13.33        6724      5.93       5213     4.59        3537      3.12              24815    21.87
#    2020          105574               1860             1.76                910             0.86              3780            3.58        2098      1.99       1932     1.83        2134      2.02               7510     7.11
#    2021          110986               4852             4.37               1336             1.20             10071            9.07        5328      4.80       4586     4.13        5440      4.90              18950    17.07
#    2022          128866               7792             6.05               1604             1.24             17087           13.26        6953      5.40       6631     5.15        8348      6.48              29061    22.55
#    2023          112098              10040             8.96               3692             3.29             17809           15.89        8483      7.57       8011     7.15       11661     10.40              34171    30.48
#    2024          126033              11052             8.77               4452             3.53             19679           15.61        9278      7.36       8727     6.92       14703     11.67              38882    30.85
# OVERALL         1084091              54003             4.98              26178             2.41            128307           11.84       65074      6.00      56530     5.21       53866      4.97             232276    21.43
