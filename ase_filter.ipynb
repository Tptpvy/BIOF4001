# %%
# import libraries
import os
import pandas as pd
import glob
import warnings
import datetime

# define file paths
year = 2024
# DATA_PATH = f"./presumed_infection/2.Data/New Data/"
DATA_PATH = f"./presumed_infection/2.Data/"

# assumption: each lab data has ./csv folder (or ./csv_file for bili_plt), bili_plt split into bili and plt

# %%
def merge_demographic(year): # merge demographic data for a specific year
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/"
    os.makedirs(OUTPUT_PATH, exist_ok=True)
    pattern = "*resumedInfection_Demographic_"
    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            if 'Year' not in df.columns: # add year column for identification
                df['Year'] = year

            if '28_day_mortality' not in df.columns: # calculate 28-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['28_day_mortality'] = (df['Days_To_Death'] <= 28) & (df['Days_To_Death'] >= 0)
                df['28_day_mortality'] = df['28_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')

            if '7_day_mortality' not in df.columns: # calculate 7-day mortality
                df['Admission_Date'] = pd.to_datetime(df['Admission Date (yyyy-mm-dd)'], errors='coerce')
                df['Death_Date'] = pd.to_datetime(df['Date of Registered Death'], errors='coerce')
                mask = df['Admission_Date'].notna() & df['Death_Date'].notna()
                df.loc[mask, 'Days_To_Death'] = (df.loc[mask, 'Death_Date'] - df.loc[mask, 'Admission_Date']).dt.days
                df['7_day_mortality'] = (df['Days_To_Death'] <= 7) & (df['Days_To_Death'] >= 0)
                df['7_day_mortality'] = df['7_day_mortality'].fillna(False)
                df = df.drop(['Admission_Date', 'Death_Date', 'Days_To_Death'], axis=1, errors='ignore')
                
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"demographic_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def filter_presumed(year): # filter presumed infection cases for a specific year
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Institution (IPAS)' not in presumed_df.columns or 'HN Number' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Institution (IPAS)' not in demographic_df.columns or 'HN Number' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    mask = demographic_df.apply(lambda row: (row['Institution (IPAS)'], row['HN Number']) in presumed_tuples, axis=1)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def filter_presumed_RK(year): # filter presumed infection cases for a specific year using Reference Key
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/demographic_{year}.csv"
    OUTPUT_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}_RK.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH)
    demographic_df = pd.read_csv(DEMO_PATH)
    if 'Reference Key' not in presumed_df.columns:
        print(f"Required columns not found in presumed list for {year}")
        return
    if 'Reference Key' not in demographic_df.columns:
        print(f"Required columns not found in demographic data for {year}")
        return
    presumed_tuples = set(presumed_df['Reference Key'].tolist())
    mask = demographic_df['Reference Key'].isin(presumed_tuples)
    filtered_df = demographic_df[mask]
    filtered_df.to_csv(OUTPUT_PATH, index=False)
    print(f"Filtered demographic data for {year} saved to {OUTPUT_PATH}, {len(filtered_df)} rows")

# %%
def check_missing_presumed(year):
    PRESUMED_PATH = DATA_PATH + f"Presumed_Infection_List/Presumed_Infection_List_{year}.csv"
    DEMO_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    if not os.path.exists(PRESUMED_PATH):
        print(f"Presumed infection list for {year} not found")
        return
    if not os.path.exists(DEMO_PATH):
        print(f"Filtered demographic data for {year} not found")
        return
    presumed_df = pd.read_csv(PRESUMED_PATH) 
    demo_df = pd.read_csv(DEMO_PATH)
    presumed_tuples = set(zip(presumed_df['Institution (IPAS)'], presumed_df['HN Number']))
    demo_tuples = set(zip(demo_df['Institution (IPAS)'], demo_df['HN Number']))
    missing_tuples = presumed_tuples - demo_tuples
    missing_count = len(missing_tuples)
    print(f"Year {year}: {missing_count} presumed infection cases not found in demographic data")
    if missing_count > 0:
        missing_df = pd.DataFrame(list(missing_tuples), columns=['Institution (IPAS)', 'HN Number'])
        OUTPUT_PATH = os.path.join(DATA_PATH, f'Demographics/{year}/missing_presumed_{year}.csv')
        missing_df.to_csv(OUTPUT_PATH, index=False)
        print(f"Missing cases saved to {OUTPUT_PATH}")

# %%
def merge_data(data_type, year): # merge data for a specific year (inotrope, procedure, crea, bili, plt, lact)
    if data_type == "inotrope" or data_type == "procedure":
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/{data_type.title()}/{year}/"
        pattern = "*resumedInfection_" + data_type.title() + "_"
    elif data_type == "crea": # alternative filename handling for crea
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/"
        pattern = "*resumedInfection_Crea_"
    elif data_type == "lact": # alternative filename handling for lact
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/"
        pattern = "*resumedInfection_lactate_"
    elif data_type == "bili": # alternative filename handling for bili
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"
    elif data_type == "plt": # alternative filename handling for plt
        OUTPUT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/"
        pattern = "*resumedInfection_Bili_Plt_"

    print(f"Processing year: {year}")
    files = glob.glob(OUTPUT_PATH + f"{pattern}{year}*.csv")
    if not files:
        print(f"No files found for year {year} with pattern {pattern}")
    print(f"Found {len(files)} files for year {year}")
    dfs = []
    for file in files:
        try:
            df = pd.read_csv(file, dtype={'HN Number': str}, low_memory=False)
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}")
            continue
    if dfs:
        combined_df = pd.concat(dfs, ignore_index=True)
        output_file = os.path.join(OUTPUT_PATH, f"{data_type}_{year}.csv")
        combined_df.to_csv(output_file, index=False)
        print(f"Saved combined data for year {year} to {output_file}, {len(combined_df)} total rows")

# %%
def retrieve_blood_dates(HN, institution, date_df):
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    if 'blood culture date' in df.columns and not df.empty:
        blood_dates = pd.to_datetime(df['blood culture date'], errors='coerce').dropna().unique()
        return [date.strftime('%Y-%m-%d') for date in blood_dates]
    return []

def check_date_in_window(target_date, blood_dates_array):
    if not blood_dates_array or not target_date:
        return False
    target = pd.to_datetime(target_date)
    for blood_date_str in blood_dates_array:
        blood_date = pd.to_datetime(blood_date_str)
        date_diff = abs((target - blood_date).days)
        if date_diff <= 2:
            return True
    return False

# %%
# def patient_date_deadline(Ref_Key, date_df): # Ref Key is numeric not string
#     df = date_df[date_df['Reference Key'] == Ref_Key].copy() # using first entry only, use array to store all dates if needed
#     if 'blood culture date' in df.columns and not df.empty:
#         blood_culture_date = pd.to_datetime(df.iloc[0]['blood culture date'], errors='coerce')
#         deadline_date = blood_culture_date + pd.Timedelta(days=2) # 2 days after blood culture (deadline)
#         return deadline_date.strftime('%Y-%m-%d')
#     return None

    # if 'Admission Date (yyyy-mm-dd)' in df.columns and not df.empty:
    #     admission_date = pd.to_datetime(df.iloc[0]['Admission Date (yyyy-mm-dd)'], errors='coerce')
    #     deadline_date = admission_date + pd.Timedelta(days=2) # 2 days after admission (deadline)
    #     return deadline_date.strftime('%Y-%m-%d')
    # return None

# %%
def check_vasopressor(df, blood_dates_array): # check if new vasopressor is administered
    # noradrenaline is norepinephrine, adrenaline is epinephrine, vasopressin unused
    vasopressor_list = ["NORADRENALINE (BITARTRATE)", "DOPAMINE HCL", "ADRENALINE (ACID TARTRATE)", "PHENYLEPHRINE HCL", "VASOPRESSIN"] # contains the string
    if df.empty:
        return False, None
    if 'Drug Name' not in df.columns or 'Prescription Start Date' not in df.columns:
        return False, None
    df = df.copy()
    df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
    for drug in vasopressor_list:
        drug_mask = df['Drug Name'].str.contains(drug, case=True, na=False, regex=False)
        drug_dates = df.loc[drug_mask, 'Prescription Start Date'].dropna().unique()
        for admin_date in drug_dates:
            if check_date_in_window(admin_date, blood_dates_array):
                one_day_before = admin_date - datetime.timedelta(days=1) # To count as a new vasopressor, that specific vasopressor cannot have been administered in the prior calendar day
                if not drug_mask.any() or one_day_before not in drug_dates:
                    return True, admin_date
    return False, None

# %%
def check_ventilation(df, blood_dates_array): # check if mechanical ventilation is initiated
    if df.empty:
        return False, None
    if 'RespFailOnsetDate' not in df.columns:
        return False, None
    for onset_date in df['RespFailOnsetDate']:
        if check_date_in_window(onset_date, blood_dates_array):
            return True, onset_date
    return False, None

# %%
def filter_renal(): # filter end-stage renal disease patients (unused)
    DXPX_PATH = DATA_PATH + f"demographic/demographic_{year}.csv"
    df = pd.read_csv(DXPX_PATH)
    disease_list = []
    if 'Reference Key' in df.columns and 'Dx/Px Description (HAMDCT)' in df.columns:
        df['renal'] = df['Dx/Px Description (HAMDCT)'].str.lower().str.contains('|'.join(disease_list), case=False, na=False) 
        result_df = df[['Reference Key', 'renal']].drop_duplicates()       
        return result_df
    else:
        print("Required columns not found")
        return pd.DataFrame(columns=['Reference Key', 'renal'])
    
# only keeps first occurence(?), need change to eGFR>20

# %%
def check_creatinine(df, blood_dates_array): # check if creatinine level is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    baseline = df['LIS Result: Numeric Result'].min() # baseline lowest during hospitalization
    for _, row in window_df.iterrows():
        if row['LIS Result: Numeric Result'] >= baseline * 2:
            return True, row['LIS Reference Date']
    return False, None

# %%
def check_bili(df, blood_dates_array): # check if bilirubin level is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    baseline = df['LIS Result: Numeric Result'].min() # baseline lowest during hospitalization
    baseline_mgdl = baseline * 0.058467 # convert umol/L to mg/dL
    for _, row in window_df.iterrows():
        value_mgdl = row['LIS Result: Numeric Result'] * 0.058467
        if value_mgdl >= 2.0 and value_mgdl >= baseline_mgdl * 2:
            return True, row['LIS Reference Date']
    return False, None

# %%
def check_plt(df, blood_dates_array): # check if platelet count is abnormal
    if df.empty or 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Date'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce').dt.date
    window_mask = df['LIS Reference Date'].apply(lambda x: check_date_in_window(x, blood_dates_array))
    window_df = df[window_mask]
    if window_df.empty:
        return False, None
    baseline = df['LIS Result: Numeric Result'].max() # baseline is highest during hospitalization
    for _, row in window_df.iterrows():
        if row['LIS Result: Numeric Result'] < 100 and row['LIS Result: Numeric Result'] <= baseline * 0.5:
            return True, row['LIS Reference Date']
    return False, None

# %%
def check_lact(df, blood_dates_array): # check if lactate level is abnormal
    if df.empty:
        return False, None
    if 'LIS Result: Numeric Result' not in df.columns:
        return False, None
    df = df.copy()
    df['LIS Reference Datetime'] = pd.to_datetime(df['LIS Reference Datetime'], errors='coerce')
    df['LIS Reference Date'] = df['LIS Reference Datetime'].dt.date
    for _, row in df.iterrows():
        if check_date_in_window(row['LIS Reference Date'], blood_dates_array):
            if row['LIS Result: Numeric Result'] >= 2.0:
                return True, row['LIS Reference Date']
    return False, None

# %%
def check_CO(HN, institution, date_df, demo_df): # TRUE if community onset, FALSE if hospital onset (unused)
    # TRUE if blood culture date/first QAD date is within 2 days of admission date
    df = date_df[(date_df['HN Number'] == HN) & (date_df['Institution (IPAS)'] == institution)].copy()
    if df.empty:
        print("missing date data")
        return False
    demo_row = demo_df[(demo_df['HN Number'] == HN) & (demo_df['Institution (IPAS)'] == institution)] 
    if demo_row.empty:
        print("missing demographic data")
        return False
    admission_date = pd.to_datetime(demo_row['Admission Date (yyyy-mm-dd)'].iloc[0])
    blood_date = pd.to_datetime(df['blood culture date'].iloc[0]) if 'blood culture date' in df.columns else None
    qad_date = pd.to_datetime(df['first_qad_date'].iloc[0]) if 'first_qad_date' in df.columns else None
    if blood_date is not None and abs((blood_date - admission_date).days) <= 2:
        return True
    if qad_date is not None and abs((qad_date - admission_date).days) <= 2:
        return True
    return False

# %%
def check_ase(year): # reimplemented (composite key) using AI for optimization
    KEY_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    df = pd.read_csv(KEY_PATH)
    print(f"Loaded demographic data: {len(df)} rows")
    df['composite_key'] = df['HN Number'].astype(str) + '_' + df['Institution (IPAS)'].astype(str)
    df = df.drop_duplicates(subset=['composite_key'])
    print(f"After deduplication: {len(df)} rows")
    keys = df[['HN Number', 'Institution (IPAS)']].drop_duplicates().values.tolist()
    print(f"Found {len(keys)} unique patient-institution combinations")
    
    if len(keys) == 0:
        print("ERROR: No keys found!")
        return
    
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv"
    date_df = pd.read_csv(DATE_PATH)
    print(f"Loaded date data: {len(date_df)} rows")
    date_df['composite_key'] = date_df['HN Number'].astype(str) + '_' + date_df['Institution (IPAS)'].astype(str)
    date_df = date_df.set_index('composite_key')
    print(f"Indexed date data")
    
    INOTROPE_PATH = DATA_PATH + f"Lab_Test_Results/Inotrope/{year}/inotrope_{year}.csv"
    inotrope_df = pd.read_csv(INOTROPE_PATH)
    print(f"Loaded inotrope data: {len(inotrope_df)} rows")
    inotrope_df['composite_key'] = inotrope_df['HN Number'].astype(str) + '_' + inotrope_df['Institution (IPAS)'].astype(str)
    inotrope_df = inotrope_df.set_index('composite_key')
    print(f"Indexed inotrope data")
    
    CREATININE_PATH = DATA_PATH + f"Lab_Test_Results/Creatinine/{year}/crea_{year}.csv"
    creatinine_df = pd.read_csv(CREATININE_PATH)
    print(f"Loaded creatinine data: {len(creatinine_df)} rows")
    creatinine_df['composite_key'] = creatinine_df['HN Number'].astype(str) + '_' + creatinine_df['Institution (IPAS)'].astype(str)
    creatinine_df = creatinine_df.set_index('composite_key')
    print(f"Indexed creatinine data")
    
    BILI_PATH = DATA_PATH + f"Lab_Test_Results/Bilirubin/{year}/bili_{year}.csv"
    bili_df = pd.read_csv(BILI_PATH)
    print(f"Loaded bilirubin data: {len(bili_df)} rows")
    bili_df['composite_key'] = bili_df['HN Number'].astype(str) + '_' + bili_df['Institution (IPAS)'].astype(str)
    bili_df = bili_df.set_index('composite_key')
    print(f"Indexed bilirubin data")
    
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    print(f"Loaded platelet data: {len(plt_df)} rows")
    plt_df['composite_key'] = plt_df['HN Number'].astype(str) + '_' + plt_df['Institution (IPAS)'].astype(str)
    plt_df = plt_df.set_index('composite_key')
    print(f"Indexed platelet data")
    
    LACT_PATH = DATA_PATH + f"Lab_Test_Results/Lactate/{year}/lact_{year}.csv"
    lact_df = pd.read_csv(LACT_PATH)
    print(f"Loaded lactate data: {len(lact_df)} rows")
    lact_df['composite_key'] = lact_df['HN Number'].astype(str) + '_' + lact_df['Institution (IPAS)'].astype(str)
    lact_df = lact_df.set_index('composite_key')
    print(f"Indexed lactate data")
    
    RESP_PATH = DATA_PATH + f"RespFailList.csv"
    resp_fail_df = pd.read_csv(RESP_PATH)
    print(f"Loaded RespFailList data: {len(resp_fail_df)} rows")
    resp_fail_df['composite_key'] = resp_fail_df['HN Number'].astype(str) + '_' + resp_fail_df['Institution (IPAS)'].astype(str)
    resp_fail_df = resp_fail_df.set_index('composite_key')
    print(f"Indexed RespFailList data")
    
    results = []
    output_file = os.path.join(DATA_PATH, 'Output', 'ase', f'ase_{year}.csv')
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    demo_dict = df.set_index('composite_key').to_dict('index')
    print(f"Created demo_dict with {len(demo_dict)} entries")
    
    admission_dict = {}
    total_patients = len(demo_dict)
    print(f"Extracting admission dates for {total_patients} patients...")
    
    demo_df = pd.DataFrame.from_dict(demo_dict, orient='index')
    demo_df.index.name = 'composite_key'
    demo_df['Admission Date (yyyy-mm-dd)'] = pd.to_datetime(demo_df['Admission Date (yyyy-mm-dd)'], errors='coerce')
    admission_dict = demo_df['Admission Date (yyyy-mm-dd)'].to_dict()
    print(f"Extracted admission dates for {len(admission_dict)} patients")
    
    total_keys = len(keys)
    print(f"Starting main loop for {total_keys} patients...")
    
    for i, key in enumerate(keys):
        if i % 1000 == 0 and i > 0:
            print(f"  Processing main loop: {i}/{total_keys} patients completed")
        
        HN = key[0]
        institution = key[1]
        composite_key = str(HN) + '_' + str(institution)
        
        admission_date = admission_dict.get(composite_key)
        
        try:
            date_rows = date_df.loc[[composite_key]]
            blood_dates_array = date_rows['blood culture date'].tolist() if not date_rows.empty else []
        except KeyError:
            blood_dates_array = []
        
        try:
            inotrope_subdf = inotrope_df.loc[[composite_key]]
        except KeyError:
            inotrope_subdf = pd.DataFrame()
        
        try:
            creatinine_subdf = creatinine_df.loc[[composite_key]]
        except KeyError:
            creatinine_subdf = pd.DataFrame()
        
        try:
            bili_subdf = bili_df.loc[[composite_key]]
        except KeyError:
            bili_subdf = pd.DataFrame()
        
        try:
            plt_subdf = plt_df.loc[[composite_key]]
        except KeyError:
            plt_subdf = pd.DataFrame()
        
        try:
            lact_subdf = lact_df.loc[[composite_key]]
        except KeyError:
            lact_subdf = pd.DataFrame()
        
        try:
            resp_subdf = resp_fail_df.loc[[composite_key]]
        except KeyError:
            resp_subdf = pd.DataFrame()
        
        vasopressor_result, vasopressor_date = check_vasopressor(inotrope_subdf, blood_dates_array)
        ventilation_result, ventilation_date = check_ventilation(resp_subdf, blood_dates_array)
        creatinine_result, creatinine_date = check_creatinine(creatinine_subdf, blood_dates_array)
        bili_result, bili_date = check_bili(bili_subdf, blood_dates_array)
        plt_result, plt_date = check_plt(plt_subdf, blood_dates_array)
        lact_result, lact_date = check_lact(lact_subdf, blood_dates_array)
        
        all_dates = []
        if vasopressor_date is not None:
            all_dates.append(pd.to_datetime(vasopressor_date))
        if ventilation_date is not None:
            all_dates.append(pd.to_datetime(ventilation_date))
        if creatinine_date is not None:
            all_dates.append(pd.to_datetime(creatinine_date))
        if bili_date is not None:
            all_dates.append(pd.to_datetime(bili_date))
        if plt_date is not None:
            all_dates.append(pd.to_datetime(plt_date))
        if lact_date is not None:
            all_dates.append(pd.to_datetime(lact_date))
        
        within_48h = False
        if all_dates and admission_date is not None:
            earliest_date = min(all_dates)
            within_48h = abs((earliest_date - admission_date).days) < 2
        
        result = {
            'HN Number': HN,
            'Institution (IPAS)': institution,
            'vasopressor': vasopressor_result,
            'ventilation': ventilation_result,
            'creatinine': creatinine_result,
            'bili': bili_result,
            'plt': plt_result,
            'lact': lact_result,
            'CO': within_48h
        }
        results.append(result)
    
    print(f"Main loop complete. Collected {len(results)} results")
    
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_file, index=False)
    print(f"ASE results saved to {output_file}")

# %%
def check_ase_plt(year):
    KEY_PATH = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
    df = pd.read_csv(KEY_PATH)
    print(f"Loaded demographic data: {len(df)} rows")
    df['composite_key'] = df['HN Number'].astype(str) + '_' + df['Institution (IPAS)'].astype(str)
    df = df.drop_duplicates(subset=['composite_key'])
    print(f"After deduplication: {len(df)} rows")
    keys = df[['HN Number', 'Institution (IPAS)']].drop_duplicates().values.tolist()
    print(f"Found {len(keys)} unique patient-institution combinations")
    
    if len(keys) == 0:
        print("ERROR: No keys found!")
        return
    
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv"
    date_df = pd.read_csv(DATE_PATH)
    print(f"Loaded date data: {len(date_df)} rows")
    date_df['composite_key'] = date_df['HN Number'].astype(str) + '_' + date_df['Institution (IPAS)'].astype(str)
    date_df = date_df.set_index('composite_key')
    print(f"Indexed date data")
    
    PLT_PATH = DATA_PATH + f"Lab_Test_Results/Platelet/{year}/plt_{year}.csv"
    plt_df = pd.read_csv(PLT_PATH)
    print(f"Loaded platelet data: {len(plt_df)} rows")
    plt_df['composite_key'] = plt_df['HN Number'].astype(str) + '_' + plt_df['Institution (IPAS)'].astype(str)
    plt_df = plt_df.set_index('composite_key')
    print(f"Indexed platelet data")
    
    results = []
    output_file = os.path.join(DATA_PATH, 'Output', 'plt', f'plt_{year}.csv')
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    demo_dict = df.set_index('composite_key').to_dict('index')
    print(f"Created demo_dict with {len(demo_dict)} entries")
    
    admission_dict = {}
    total_patients = len(demo_dict)
    print(f"Extracting admission dates for {total_patients} patients...")
    
    demo_df = pd.DataFrame.from_dict(demo_dict, orient='index')
    demo_df.index.name = 'composite_key'
    demo_df['Admission Date (yyyy-mm-dd)'] = pd.to_datetime(demo_df['Admission Date (yyyy-mm-dd)'], errors='coerce')
    admission_dict = demo_df['Admission Date (yyyy-mm-dd)'].to_dict()
    print(f"Extracted admission dates for {len(admission_dict)} patients")
    
    total_keys = len(keys)
    print(f"Starting main loop for {total_keys} patients...")
    
    for i, key in enumerate(keys):
        if i % 1000 == 0 and i > 0:
            print(f"  Processing main loop: {i}/{total_keys} patients completed")
        
        HN = key[0]
        institution = key[1]
        composite_key = str(HN) + '_' + str(institution)
        
        admission_date = admission_dict.get(composite_key)
        
        try:
            date_rows = date_df.loc[[composite_key]]
            blood_dates_array = date_rows['blood culture date'].tolist() if not date_rows.empty else []
        except KeyError:
            blood_dates_array = []
        
        try:
            plt_subdf = plt_df.loc[[composite_key]]
        except KeyError:
            plt_subdf = pd.DataFrame()
        
        plt_result, plt_date = check_plt(plt_subdf, blood_dates_array)
        
        all_dates = []
        plt_true_date = None
        if plt_date is not None:
            plt_true_date = plt_date
            all_dates.append(pd.to_datetime(plt_date))
        
        within_48h = False
        if all_dates and admission_date is not None:
            earliest_date = min(all_dates)
            within_48h = abs((earliest_date - admission_date).days) < 2
        
        result = {
            'HN Number': HN,
            'Institution (IPAS)': institution,
            'plt': plt_result,
            'CO': within_48h,
            'plt_true_date': plt_true_date
        }
        results.append(result)
    
    print(f"Main loop complete. Collected {len(results)} results")
    
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_file, index=False)
    print(f"ASE results saved to {output_file}")

# %%
def create_ASE_list(file, year): # create list of ase patients with institution by matching ase filter output (unused)
    ase_df = pd.read_csv(file, dtype={'Reference Key': str}, low_memory=False)
    # condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    condition_cols = ['plt']
    ase_df['Overall'] = ase_df[condition_cols].any(axis=1)
    true_ase_df = ase_df[ase_df['Overall'] == True].copy()
    output_file = os.path.join(DATA_PATH, f'plt_patient_list_{year}.csv')
    true_ase_df[['HN Number', 'Institution (IPAS)']].to_csv(output_file, index=False)
    return true_ase_df[['HN Number', 'Institution (IPAS)']]

# %%
def ase_percentages(file):
    df = pd.read_csv(file)
    percentages = {}
    for column in df.columns[2:9]:  # 6 OD columns + CO
        if df[column].dtype == bool or df[column].isin([True, False, 'TRUE', 'FALSE']).all():
            true_count = (df[column] == True).sum() + (df[column] == 'TRUE').sum()
            total_count = len(df[column])
            percentage = (true_count / total_count * 100) if total_count > 0 else 0
            percentages[column] = round(percentage, 2)
    return percentages

# %%
for year in range(2003,2026):
    merge_demographic(year)
    filter_presumed(year)
    # filter_presumed_RK(year)
    # check_missing_presumed(year)
    data_types = ["inotrope", "procedure", "crea", "bili", "plt", "lact"]
    data_types = ["plt"]
    for data_type in data_types:
        merge_data(data_type, year)
# Out:
# Processing year: 2003
# Found 13 files for year 2003
# Saved combined data for year 2003 to ./presumed_infection/2.Data/Demographics/2003/demographic_2003.csv, 181619 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2003 saved to ./presumed_infection/2.Data/Demographics/2003/filtered_demographic_2003.csv, 27640 rows
# Processing year: 2003
# Found 12 files for year 2003
# Saved combined data for year 2003 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2003/plt_2003.csv, 318842 total rows
# Processing year: 2004
# Found 15 files for year 2004
# Saved combined data for year 2004 to ./presumed_infection/2.Data/Demographics/2004/demographic_2004.csv, 200437 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2004 saved to ./presumed_infection/2.Data/Demographics/2004/filtered_demographic_2004.csv, 31202 rows
# Processing year: 2004
# Found 15 files for year 2004
# Saved combined data for year 2004 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2004/plt_2004.csv, 363105 total rows
# Processing year: 2005
# Found 16 files for year 2005
# Saved combined data for year 2005 to ./presumed_infection/2.Data/Demographics/2005/demographic_2005.csv, 216308 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2005 saved to ./presumed_infection/2.Data/Demographics/2005/filtered_demographic_2005.csv, 34036 rows
# Processing year: 2005
# Found 15 files for year 2005
# Saved combined data for year 2005 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2005/plt_2005.csv, 360433 total rows
# Processing year: 2006
# Found 15 files for year 2006
# Saved combined data for year 2006 to ./presumed_infection/2.Data/Demographics/2006/demographic_2006.csv, 212700 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2006 saved to ./presumed_infection/2.Data/Demographics/2006/filtered_demographic_2006.csv, 35124 rows
# Processing year: 2006
# Found 14 files for year 2006
# Saved combined data for year 2006 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2006/plt_2006.csv, 353725 total rows
# Processing year: 2007
# Found 15 files for year 2007
# Saved combined data for year 2007 to ./presumed_infection/2.Data/Demographics/2007/demographic_2007.csv, 224127 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2007 saved to ./presumed_infection/2.Data/Demographics/2007/filtered_demographic_2007.csv, 32264 rows
# Processing year: 2007
# Found 14 files for year 2007
# Saved combined data for year 2007 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2007/plt_2007.csv, 350843 total rows
# Processing year: 2008
# Found 17 files for year 2008
# Saved combined data for year 2008 to ./presumed_infection/2.Data/Demographics/2008/demographic_2008.csv, 316545 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2008 saved to ./presumed_infection/2.Data/Demographics/2008/filtered_demographic_2008.csv, 42446 rows
# Processing year: 2008
# Found 15 files for year 2008
# Saved combined data for year 2008 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2008/plt_2008.csv, 379966 total rows
# Processing year: 2009
# Found 18 files for year 2009
# Saved combined data for year 2009 to ./presumed_infection/2.Data/Demographics/2009/demographic_2009.csv, 509607 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2009 saved to ./presumed_infection/2.Data/Demographics/2009/filtered_demographic_2009.csv, 72782 rows
# Processing year: 2009
# Found 15 files for year 2009
# Saved combined data for year 2009 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2009/plt_2009.csv, 368776 total rows
# Processing year: 2010
# Found 19 files for year 2010
# Saved combined data for year 2010 to ./presumed_infection/2.Data/Demographics/2010/demographic_2010.csv, 675354 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2010 saved to ./presumed_infection/2.Data/Demographics/2010/filtered_demographic_2010.csv, 98418 rows
# Processing year: 2010
# Found 12 files for year 2010
# Saved combined data for year 2010 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2010/plt_2010.csv, 277090 total rows
# Processing year: 2011
# Found 19 files for year 2011
# Saved combined data for year 2011 to ./presumed_infection/2.Data/Demographics/2011/demographic_2011.csv, 583002 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2011 saved to ./presumed_infection/2.Data/Demographics/2011/filtered_demographic_2011.csv, 86258 rows
# Processing year: 2011
# Found 13 files for year 2011
# Saved combined data for year 2011 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2011/plt_2011.csv, 312402 total rows
# Processing year: 2012
# Found 20 files for year 2012
# Saved combined data for year 2012 to ./presumed_infection/2.Data/Demographics/2012/demographic_2012.csv, 575261 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2012 saved to ./presumed_infection/2.Data/Demographics/2012/filtered_demographic_2012.csv, 81619 rows
# Processing year: 2012
# Found 16 files for year 2012
# Saved combined data for year 2012 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2012/plt_2012.csv, 390179 total rows
# Processing year: 2013
# Found 20 files for year 2013
# Saved combined data for year 2013 to ./presumed_infection/2.Data/Demographics/2013/demographic_2013.csv, 515621 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2013 saved to ./presumed_infection/2.Data/Demographics/2013/filtered_demographic_2013.csv, 71481 rows
# Processing year: 2013
# Found 16 files for year 2013
# Saved combined data for year 2013 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2013/plt_2013.csv, 422976 total rows
# Processing year: 2014
# Found 24 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Demographics/2014/demographic_2014.csv, 579613 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2014 saved to ./presumed_infection/2.Data/Demographics/2014/filtered_demographic_2014.csv, 128862 rows
# Processing year: 2014
# Found 23 files for year 2014
# Saved combined data for year 2014 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2014/plt_2014.csv, 625625 total rows
# Processing year: 2015
# Found 25 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Demographics/2015/demographic_2015.csv, 583834 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2015 saved to ./presumed_infection/2.Data/Demographics/2015/filtered_demographic_2015.csv, 212962 rows
# Processing year: 2015
# Found 25 files for year 2015
# Saved combined data for year 2015 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2015/plt_2015.csv, 671479 total rows
# Processing year: 2016
# Found 26 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Demographics/2016/demographic_2016.csv, 673725 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2016 saved to ./presumed_infection/2.Data/Demographics/2016/filtered_demographic_2016.csv, 373160 rows
# Processing year: 2016
# Found 26 files for year 2016
# Saved combined data for year 2016 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2016/plt_2016.csv, 672765 total rows
# Processing year: 2017
# Found 28 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Demographics/2017/demographic_2017.csv, 751505 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2017 saved to ./presumed_infection/2.Data/Demographics/2017/filtered_demographic_2017.csv, 300348 rows
# Processing year: 2017
# Found 18 files for year 2017
# Saved combined data for year 2017 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2017/plt_2017.csv, 514501 total rows
# Processing year: 2018
# Found 29 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Demographics/2018/demographic_2018.csv, 713748 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2018 saved to ./presumed_infection/2.Data/Demographics/2018/filtered_demographic_2018.csv, 643237 rows
# Processing year: 2018
# Found 21 files for year 2018
# Saved combined data for year 2018 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2018/plt_2018.csv, 605445 total rows
# Processing year: 2019
# Found 35 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Demographics/2019/demographic_2019.csv, 740488 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2019 saved to ./presumed_infection/2.Data/Demographics/2019/filtered_demographic_2019.csv, 683449 rows
# Processing year: 2019
# Found 35 files for year 2019
# Saved combined data for year 2019 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2019/plt_2019.csv, 994276 total rows
# Processing year: 2020
# Found 30 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Demographics/2020/demographic_2020.csv, 660600 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2020 saved to ./presumed_infection/2.Data/Demographics/2020/filtered_demographic_2020.csv, 612158 rows
# Processing year: 2020
# Found 30 files for year 2020
# Saved combined data for year 2020 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2020/plt_2020.csv, 909901 total rows
# Processing year: 2021
# Found 32 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Demographics/2021/demographic_2021.csv, 698666 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2021 saved to ./presumed_infection/2.Data/Demographics/2021/filtered_demographic_2021.csv, 652058 rows
# Processing year: 2021
# Found 32 files for year 2021
# Saved combined data for year 2021 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2021/plt_2021.csv, 1024653 total rows
# Processing year: 2022
# Found 32 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Demographics/2022/demographic_2022.csv, 923493 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2022 saved to ./presumed_infection/2.Data/Demographics/2022/filtered_demographic_2022.csv, 657628 rows
# Processing year: 2022
# Found 44 files for year 2022
# Saved combined data for year 2022 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2022/plt_2022.csv, 1069411 total rows
# Processing year: 2023
# Found 32 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Demographics/2023/demographic_2023.csv, 722438 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (0,15,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2023 saved to ./presumed_infection/2.Data/Demographics/2023/filtered_demographic_2023.csv, 675387 rows
# Processing year: 2023
# Found 32 files for year 2023
# Saved combined data for year 2023 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2023/plt_2023.csv, 965411 total rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Demographics/2024/demographic_2024.csv, 714449 total rows
# Filtered demographic data for 2024 saved to ./presumed_infection/2.Data/Demographics/2024/filtered_demographic_2024.csv, 666448 rows
# Processing year: 2024
# Found 35 files for year 2024
# Saved combined data for year 2024 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2024/plt_2024.csv, 1059032 total rows
# Processing year: 2025
# Found 34 files for year 2025
# Saved combined data for year 2025 to ./presumed_infection/2.Data/Demographics/2025/demographic_2025.csv, 701014 total rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_15960\565514375.py:12: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic_df = pd.read_csv(DEMO_PATH)
# Filtered demographic data for 2025 saved to ./presumed_infection/2.Data/Demographics/2025/filtered_demographic_2025.csv, 694237 rows
# Processing year: 2025
# Found 33 files for year 2025
# Saved combined data for year 2025 to ./presumed_infection/2.Data/Lab_Test_Results/Platelet/2025/plt_2025.csv, 1074738 total rows

# %%
warnings.filterwarnings('ignore')
for year in range(2003, 2026): # no 2019 (need download)
    check_ase_plt(year)
# Out:
# Loaded demographic data: 27640 rows
# After deduplication: 6970 rows
# Found 6970 unique patient-institution combinations
# Loaded date data: 120078 rows
# Indexed date data
# Loaded platelet data: 318842 rows
# Indexed platelet data
# Created demo_dict with 6970 entries
# Extracting admission dates for 6970 patients...
# Extracted admission dates for 6970 patients
# Starting main loop for 6970 patients...
#   Processing main loop: 1000/6970 patients completed
#   Processing main loop: 2000/6970 patients completed
#   Processing main loop: 3000/6970 patients completed
#   Processing main loop: 4000/6970 patients completed
#   Processing main loop: 5000/6970 patients completed
#   Processing main loop: 6000/6970 patients completed
# Main loop complete. Collected 6970 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2003.csv
# Loaded demographic data: 31202 rows
# After deduplication: 7669 rows
# Found 7669 unique patient-institution combinations
# Loaded date data: 143501 rows
# Indexed date data
# Loaded platelet data: 363105 rows
# Indexed platelet data
# Created demo_dict with 7669 entries
# Extracting admission dates for 7669 patients...
# Extracted admission dates for 7669 patients
# Starting main loop for 7669 patients...
#   Processing main loop: 1000/7669 patients completed
#   Processing main loop: 2000/7669 patients completed
#   Processing main loop: 3000/7669 patients completed
#   Processing main loop: 4000/7669 patients completed
#   Processing main loop: 5000/7669 patients completed
#   Processing main loop: 6000/7669 patients completed
#   Processing main loop: 7000/7669 patients completed
# Main loop complete. Collected 7669 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2004.csv
# Loaded demographic data: 34036 rows
# After deduplication: 8171 rows
# Found 8171 unique patient-institution combinations
# Loaded date data: 152133 rows
# Indexed date data
# Loaded platelet data: 360433 rows
# Indexed platelet data
# Created demo_dict with 8171 entries
# Extracting admission dates for 8171 patients...
# Extracted admission dates for 8171 patients
# Starting main loop for 8171 patients...
#   Processing main loop: 1000/8171 patients completed
#   Processing main loop: 2000/8171 patients completed
#   Processing main loop: 3000/8171 patients completed
#   Processing main loop: 4000/8171 patients completed
#   Processing main loop: 5000/8171 patients completed
#   Processing main loop: 6000/8171 patients completed
#   Processing main loop: 7000/8171 patients completed
#   Processing main loop: 8000/8171 patients completed
# Main loop complete. Collected 8171 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2005.csv
# Loaded demographic data: 35124 rows
# After deduplication: 7690 rows
# Found 7690 unique patient-institution combinations
# Loaded date data: 144878 rows
# Indexed date data
# Loaded platelet data: 353725 rows
# Indexed platelet data
# Created demo_dict with 7690 entries
# Extracting admission dates for 7690 patients...
# Extracted admission dates for 7690 patients
# Starting main loop for 7690 patients...
#   Processing main loop: 1000/7690 patients completed
#   Processing main loop: 2000/7690 patients completed
#   Processing main loop: 3000/7690 patients completed
#   Processing main loop: 4000/7690 patients completed
#   Processing main loop: 5000/7690 patients completed
#   Processing main loop: 6000/7690 patients completed
#   Processing main loop: 7000/7690 patients completed
# Main loop complete. Collected 7690 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2006.csv
# Loaded demographic data: 32264 rows
# After deduplication: 6681 rows
# Found 6681 unique patient-institution combinations
# Loaded date data: 168225 rows
# Indexed date data
# Loaded platelet data: 350843 rows
# Indexed platelet data
# Created demo_dict with 6681 entries
# Extracting admission dates for 6681 patients...
# Extracted admission dates for 6681 patients
# Starting main loop for 6681 patients...
#   Processing main loop: 1000/6681 patients completed
#   Processing main loop: 2000/6681 patients completed
#   Processing main loop: 3000/6681 patients completed
#   Processing main loop: 4000/6681 patients completed
#   Processing main loop: 5000/6681 patients completed
#   Processing main loop: 6000/6681 patients completed
# Main loop complete. Collected 6681 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2007.csv
# Loaded demographic data: 42446 rows
# After deduplication: 7320 rows
# Found 7320 unique patient-institution combinations
# Loaded date data: 146758 rows
# Indexed date data
# Loaded platelet data: 379966 rows
# Indexed platelet data
# Created demo_dict with 7320 entries
# Extracting admission dates for 7320 patients...
# Extracted admission dates for 7320 patients
# Starting main loop for 7320 patients...
#   Processing main loop: 1000/7320 patients completed
#   Processing main loop: 2000/7320 patients completed
#   Processing main loop: 3000/7320 patients completed
#   Processing main loop: 4000/7320 patients completed
#   Processing main loop: 5000/7320 patients completed
#   Processing main loop: 6000/7320 patients completed
#   Processing main loop: 7000/7320 patients completed
# Main loop complete. Collected 7320 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2008.csv
# Loaded demographic data: 72782 rows
# After deduplication: 9615 rows
# Found 9615 unique patient-institution combinations
# Loaded date data: 151260 rows
# Indexed date data
# Loaded platelet data: 368776 rows
# Indexed platelet data
# Created demo_dict with 9615 entries
# Extracting admission dates for 9615 patients...
# Extracted admission dates for 9615 patients
# Starting main loop for 9615 patients...
#   Processing main loop: 1000/9615 patients completed
#   Processing main loop: 2000/9615 patients completed
#   Processing main loop: 3000/9615 patients completed
#   Processing main loop: 4000/9615 patients completed
#   Processing main loop: 5000/9615 patients completed
#   Processing main loop: 6000/9615 patients completed
#   Processing main loop: 7000/9615 patients completed
#   Processing main loop: 8000/9615 patients completed
#   Processing main loop: 9000/9615 patients completed
# Main loop complete. Collected 9615 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2009.csv
# Loaded demographic data: 98418 rows
# After deduplication: 10973 rows
# Found 10973 unique patient-institution combinations
# Loaded date data: 168944 rows
# Indexed date data
# Loaded platelet data: 277090 rows
# Indexed platelet data
# Created demo_dict with 10973 entries
# Extracting admission dates for 10973 patients...
# Extracted admission dates for 10973 patients
# Starting main loop for 10973 patients...
#   Processing main loop: 1000/10973 patients completed
#   Processing main loop: 2000/10973 patients completed
#   Processing main loop: 3000/10973 patients completed
#   Processing main loop: 4000/10973 patients completed
#   Processing main loop: 5000/10973 patients completed
#   Processing main loop: 6000/10973 patients completed
#   Processing main loop: 7000/10973 patients completed
#   Processing main loop: 8000/10973 patients completed
#   Processing main loop: 9000/10973 patients completed
#   Processing main loop: 10000/10973 patients completed
# Main loop complete. Collected 10973 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2010.csv
# Loaded demographic data: 86258 rows
# After deduplication: 10398 rows
# Found 10398 unique patient-institution combinations
# Loaded date data: 155948 rows
# Indexed date data
# Loaded platelet data: 312402 rows
# Indexed platelet data
# Created demo_dict with 10398 entries
# Extracting admission dates for 10398 patients...
# Extracted admission dates for 10398 patients
# Starting main loop for 10398 patients...
#   Processing main loop: 1000/10398 patients completed
#   Processing main loop: 2000/10398 patients completed
#   Processing main loop: 3000/10398 patients completed
#   Processing main loop: 4000/10398 patients completed
#   Processing main loop: 5000/10398 patients completed
#   Processing main loop: 6000/10398 patients completed
#   Processing main loop: 7000/10398 patients completed
#   Processing main loop: 8000/10398 patients completed
#   Processing main loop: 9000/10398 patients completed
#   Processing main loop: 10000/10398 patients completed
# Main loop complete. Collected 10398 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2011.csv
# Loaded demographic data: 81619 rows
# After deduplication: 10491 rows
# Found 10491 unique patient-institution combinations
# Loaded date data: 157714 rows
# Indexed date data
# Loaded platelet data: 390179 rows
# Indexed platelet data
# Created demo_dict with 10491 entries
# Extracting admission dates for 10491 patients...
# Extracted admission dates for 10491 patients
# Starting main loop for 10491 patients...
#   Processing main loop: 1000/10491 patients completed
#   Processing main loop: 2000/10491 patients completed
#   Processing main loop: 3000/10491 patients completed
#   Processing main loop: 4000/10491 patients completed
#   Processing main loop: 5000/10491 patients completed
#   Processing main loop: 6000/10491 patients completed
#   Processing main loop: 7000/10491 patients completed
#   Processing main loop: 8000/10491 patients completed
#   Processing main loop: 9000/10491 patients completed
#   Processing main loop: 10000/10491 patients completed
# Main loop complete. Collected 10491 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2012.csv
# Loaded demographic data: 71481 rows
# After deduplication: 10020 rows
# Found 10020 unique patient-institution combinations
# Loaded date data: 148794 rows
# Indexed date data
# Loaded platelet data: 422976 rows
# Indexed platelet data
# Created demo_dict with 10020 entries
# Extracting admission dates for 10020 patients...
# Extracted admission dates for 10020 patients
# Starting main loop for 10020 patients...
#   Processing main loop: 1000/10020 patients completed
#   Processing main loop: 2000/10020 patients completed
#   Processing main loop: 3000/10020 patients completed
#   Processing main loop: 4000/10020 patients completed
#   Processing main loop: 5000/10020 patients completed
#   Processing main loop: 6000/10020 patients completed
#   Processing main loop: 7000/10020 patients completed
#   Processing main loop: 8000/10020 patients completed
#   Processing main loop: 9000/10020 patients completed
#   Processing main loop: 10000/10020 patients completed
# Main loop complete. Collected 10020 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2013.csv
# Loaded demographic data: 128862 rows
# After deduplication: 21394 rows
# Found 21394 unique patient-institution combinations
# Loaded date data: 192824 rows
# Indexed date data
# Loaded platelet data: 625625 rows
# Indexed platelet data
# Created demo_dict with 21394 entries
# Extracting admission dates for 21394 patients...
# Extracted admission dates for 21394 patients
# Starting main loop for 21394 patients...
#   Processing main loop: 1000/21394 patients completed
#   Processing main loop: 2000/21394 patients completed
#   Processing main loop: 3000/21394 patients completed
#   Processing main loop: 4000/21394 patients completed
#   Processing main loop: 5000/21394 patients completed
#   Processing main loop: 6000/21394 patients completed
#   Processing main loop: 7000/21394 patients completed
#   Processing main loop: 8000/21394 patients completed
#   Processing main loop: 9000/21394 patients completed
#   Processing main loop: 10000/21394 patients completed
#   Processing main loop: 11000/21394 patients completed
#   Processing main loop: 12000/21394 patients completed
#   Processing main loop: 13000/21394 patients completed
#   Processing main loop: 14000/21394 patients completed
#   Processing main loop: 15000/21394 patients completed
#   Processing main loop: 16000/21394 patients completed
#   Processing main loop: 17000/21394 patients completed
#   Processing main loop: 18000/21394 patients completed
#   Processing main loop: 19000/21394 patients completed
#   Processing main loop: 20000/21394 patients completed
#   Processing main loop: 21000/21394 patients completed
# Main loop complete. Collected 21394 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2014.csv
# Loaded demographic data: 212962 rows
# After deduplication: 39679 rows
# Found 39679 unique patient-institution combinations
# Loaded date data: 197040 rows
# Indexed date data
# Loaded platelet data: 671479 rows
# Indexed platelet data
# Created demo_dict with 39679 entries
# Extracting admission dates for 39679 patients...
# Extracted admission dates for 39679 patients
# Starting main loop for 39679 patients...
#   Processing main loop: 1000/39679 patients completed
#   Processing main loop: 2000/39679 patients completed
#   Processing main loop: 3000/39679 patients completed
#   Processing main loop: 4000/39679 patients completed
#   Processing main loop: 5000/39679 patients completed
#   Processing main loop: 6000/39679 patients completed
#   Processing main loop: 7000/39679 patients completed
#   Processing main loop: 8000/39679 patients completed
#   Processing main loop: 9000/39679 patients completed
#   Processing main loop: 10000/39679 patients completed
#   Processing main loop: 11000/39679 patients completed
#   Processing main loop: 12000/39679 patients completed
#   Processing main loop: 13000/39679 patients completed
#   Processing main loop: 14000/39679 patients completed
#   Processing main loop: 15000/39679 patients completed
#   Processing main loop: 16000/39679 patients completed
#   Processing main loop: 17000/39679 patients completed
#   Processing main loop: 18000/39679 patients completed
#   Processing main loop: 19000/39679 patients completed
#   Processing main loop: 20000/39679 patients completed
#   Processing main loop: 21000/39679 patients completed
#   Processing main loop: 22000/39679 patients completed
#   Processing main loop: 23000/39679 patients completed
#   Processing main loop: 24000/39679 patients completed
#   Processing main loop: 25000/39679 patients completed
#   Processing main loop: 26000/39679 patients completed
#   Processing main loop: 27000/39679 patients completed
#   Processing main loop: 28000/39679 patients completed
#   Processing main loop: 29000/39679 patients completed
#   Processing main loop: 30000/39679 patients completed
#   Processing main loop: 31000/39679 patients completed
#   Processing main loop: 32000/39679 patients completed
#   Processing main loop: 33000/39679 patients completed
#   Processing main loop: 34000/39679 patients completed
#   Processing main loop: 35000/39679 patients completed
#   Processing main loop: 36000/39679 patients completed
#   Processing main loop: 37000/39679 patients completed
#   Processing main loop: 38000/39679 patients completed
#   Processing main loop: 39000/39679 patients completed
# Main loop complete. Collected 39679 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_
#   Processing main loop: 60000/74332 patients completed
#   Processing main loop: 61000/74332 patients completed
#   Processing main loop: 62000/74332 patients completed
#   Processing main loop: 63000/74332 patients completed
#   Processing main loop: 64000/74332 patients completed
#   Processing main loop: 65000/74332 patients completed
#   Processing main loop: 66000/74332 patients completed
#   Processing main loop: 67000/74332 patients completed
#   Processing main loop: 68000/74332 patients completed
#   Processing main loop: 69000/74332 patients completed
#   Processing main loop: 70000/74332 patients completed
#   Processing main loop: 71000/74332 patients completed
#   Processing main loop: 72000/74332 patients completed
#   Processing main loop: 73000/74332 patients completed
#   Processing main loop: 74000/74332 patients completed
# Main loop complete. Collected 74332 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2016.csv
# Loaded demographic data: 300348 rows
# After deduplication: 59126 rows
# Found 59126 unique patient-institution combinations
# Loaded date data: 132681 rows
# Indexed date data
# Loaded platelet data: 514501 rows
# Indexed platelet data
# Created demo_dict with 59126 entries
# Extracting admission dates for 59126 patients...
# Extracted admission dates for 59126 patients
# Starting main loop for 59126 patients...
#   Processing main loop: 1000/59126 patients completed
#   Processing main loop: 2000/59126 patients completed
#   Processing main loop: 3000/59126 patients completed
#   Processing main loop: 4000/59126 patients completed
#   Processing main loop: 5000/59126 patients completed
#   Processing main loop: 6000/59126 patients completed
#   Processing main loop: 7000/59126 patients completed
#   Processing main loop: 8000/59126 patients completed
#   Processing main loop: 9000/59126 patients completed
#   Processing main loop: 10000/59126 patients completed
#   Processing main loop: 11000/59126 patients completed
#   Processing main loop: 12000/59126 patients completed
#   Processing main loop: 13000/59126 patients completed
#   Processing main loop: 14000/59126 patients completed
#   Processing main loop: 15000/59126 patients completed
#   Processing main loop: 16000/59126 patients completed
#   Processing main loop: 17000/59126 patients completed
#   Processing main loop: 18000/59126 patients completed
#   Processing main loop: 19000/59126 patients completed
#   Processing main loop: 20000/59126 patients completed
#   Processing main loop: 21000/59126 patients completed
#   Processing main loop: 22000/59126 patients completed
#   Processing main loop: 23000/59126 patients completed
#   Processing main loop: 24000/59126 patients completed
#   Processing main loop: 25000/59126 patients completed
#   Processing main loop: 26000/59126 patients completed
#   Processing main loop: 27000/59126 patients completed
#   Processing main loop: 28000/59126 patients completed
#   Processing main loop: 29000/59126 patients completed
#   Processing main loop: 30000/59126 patients completed
#   Processing main loop: 31000/59126 patients completed
#   Processing main loop: 32000/59126 patients completed
#   Processing main loop: 33000/59126 patients completed
#   Processing main loop: 34000/59126 patients completed
#   Processing main loop: 35000/59126 patients completed
#   Processing main loop: 36000/59126 patients completed
#   Processing main loop: 37000/59126 patients completed
#   Processing main loop: 38000/59126 patients completed
#   Processing main loop: 39000/59126 patients completed
#   Processing main loop: 40000/59126 patients completed
#   Processing main loop: 41000/59126 patients completed
#   Processing main loop: 42000/59126 patients completed
#   Processing main loop: 43000/59126 patients completed
#   Processing main loop: 44000/59126 patients completed
#   Processing main loop: 45000/59126 patients completed
#   Processing main loop: 46000/59126 patients completed
#   Processing main loop: 47000/59126 patients completed
#   Processing main loop: 48000/59126 patients completed
#   Processing main loop: 49000/59126 patients completed
#   Processing main loop: 50000/59126 patients completed
#   Processing main loop: 51000/59126 patients completed
#   Processing main loop: 52000/59126 patients completed
#   Processing main loop: 53000/59126 patients completed
#   Processing main loop: 54000/59126 patients completed
#   Processing main loop: 55000/59126 patients completed
#   Processing main loop: 56000/59126 patients completed
#   Processing main loop: 57000/59126 patients completed
#   Processing main loop: 58000/59126 patients completed
#   Processing main loop: 59000/59126 patients completed
# Main loop complete. Collected 59126 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2017.csv
# Loaded demographic data: 643237 rows
# After deduplication: 135831 rows
# Found 135831 unique patient-institution combinations
# Loaded date data: 242892 rows
# Indexed date data
# Loaded platelet data: 605445 rows
# Indexed platelet data
# Created demo_dict with 135831 entries
# Extracting admission dates for 135831 patients...
# Extracted admission dates for 135831 patients
# Starting main loop for 135831 patients...
#   Processing main loop: 1000/135831 patients completed
#   Processing main loop: 2000/135831 patients completed
#   Processing main loop: 3000/135831 patients completed
#   Processing main loop: 4000/135831 patients completed
#   Processing main loop: 5000/135831 patients completed
#   Processing main loop: 6000/135831 patients completed
#   Processing main loop: 7000/135831 patients completed
#   Processing main loop: 8000/135831 patients completed
#   Processing main loop: 9000/135831 patients completed
#   Processing main loop: 10000/135831 patients completed
#   Processing main loop: 11000/135831 patients completed
#   Processing main loop: 12000/135831 patients completed
#   Processing main loop: 13000/135831 patients completed
#   Processing main loop: 14000/135831 patients completed
#   Processing main loop: 15000/135831 patients completed
#   Processing main loop: 16000/135831 patients completed
#   Processing main loop: 17000/135831 patients completed
#   Processing main loop: 18000/135831 patients completed
#   Processing main loop: 19000/135831 patients completed
#   Processing main loop: 20000/135831 patients completed
#   Processing main loop: 21000/135831 patients completed
#   Processing main loop: 22000/135831 patients completed
#   Processing main loop: 23000/135831 patients completed
#   Processing main loop: 24000/135831 patients completed
#   Processing main loop: 25000/135831 patients completed
#   Processing main loop: 26000/135831 patients completed
#   Processing main loop: 27000/135831 patients completed
#   Processing main loop: 28000/135831 patients completed
#   Processing main loop: 29000/135831 patients completed
#   Processing main loop: 30000/135831 patients completed
#   Processing main loop: 31000/135831 patients completed
#   Processing main loop: 32000/135831 patients completed
#   Processing main loop: 33000/135831 patients completed
#   Processing main loop: 34000/135831 patients completed
#   Processing main loop: 35000/135831 patients completed
#   Processing main loop: 36000/135831 patients completed
#   Processing main loop: 37000/135831 patients completed
#   Processing main loop: 38000/135831 patients completed
#   Processing main loop: 39000/135831 patients completed
#   Processing main loop: 40000/135831 patients completed
#   Processing main loop: 41000/135831 patients completed
#   Processing main loop: 42000/135831 patients completed
#   Processing main loop: 43000/135831 patients completed
#   Processing main loop: 44000/135831 patients completed
#   Processing main loop: 45000/135831 patients completed
#   Processing main loop: 46000/135831 patients completed
#   Processing main loop: 47000/135831 patients completed
#   Processing main loop: 48000/135831 patients completed
#   Processing main loop: 49000/135831 patients completed
#   Processing main loop: 50000/135831 patients completed
#   Processing main loop: 51000/135831 patients completed
#   Processing main loop: 52000/135831 patients completed
#   Processing main loop: 53000/135831 patients completed
#   Processing main loop: 54000/135831 patients completed
#   Processing main loop: 55000/135831 patients completed
#   Processing main loop: 56000/135831 patients completed
#   Processing main loop: 57000/135831 patients completed
results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2018.csv
# Loaded demographic data: 683449 rows
# After deduplication: 150759 rows
# Found 150759 unique patient-institution combinations
# Loaded date data: 259206 rows
# Indexed date data
# Loaded platelet data: 994276 rows
# Indexed platelet data
# Created demo_dict with 150759 entries
# Extracting admission dates for 150759 patients...
# Extracted admission dates for 150759 patients
# Starting main loop for 150759 patients...
#   Processing main loop: 1000/150759 patients completed
#   Processing main loop: 2000/150759 patients completed
#   Processing main loop: 3000/150759 patients completed
#   Processing main loop: 4000/150759 patients completed
#   Processing main loop: 5000/150759 patients completed
#   Processing main loop: 6000/150759 patients completed
#   Processing main loop: 7000/150759 patients completed
#   Processing main loop: 8000/150759 patients completed
#   Processing main loop: 9000/150759 patients completed
#   Processing main loop: 10000/150759 patients completed
#   Processing main loop: 11000/150759 patients completed
#   Processing main loop: 12000/150759 patients completed
#   Processing main loop: 13000/150759 patients completed
#   Processing main loop: 14000/150759 patients completed
#   Processing main loop: 15000/150759 patients completed
#   Processing main loop: 16000/150759 patients completed
#   Processing main loop: 17000/150759 patients completed
#   Processing main loop: 18000/150759 patients completed
#   Processing main loop: 19000/150759 patients completed
#   Processing main loop: 20000/150759 patients completed
#   Processing main loop: 21000/150759 patients completed
#   Processing main loop: 22000/150759 patients completed
#   Processing main loop: 23000/150759 patients completed
#   Processing main loop: 24000/150759 patients completed
#   Processing main loop: 25000/150759 patients completed
#   Processing main loop: 26000/150759 patients completed
#   Processing main loop: 27000/150759 patients completed
#   Processing main loop: 28000/150759 patients completed
#   Processing main loop: 29000/150759 patients completed
#   Processing main loop: 30000/150759 patients completed
#   Processing main loop: 31000/150759 patients completed
#   Processing main loop: 32000/150759 patients completed
#   Processing main loop: 33000/150759 patients completed
#   Processing main loop: 34000/150759 patients completed
#   Processing main loop: 35000/150759 patients completed
#   Processing main loop: 36000/150759 patients completed
#   Processing main loop: 37000/150759 patients completed
#   Processing main loop: 38000/150759 patients completed
#   Processing main loop: 39000/150759 patients completed
#   Processing main loop: 40000/150759 patients completed
#   Processing main loop: 41000/150759 patients completed
#   Processing main loop: 42000/150759 patients completed
#   Processing main loop: 43000/150759 patients completed
#   Processing main loop: 44000/150759 patients completed
#   Processing main loop: 45000/150759 patients completed
#   Processing main loop: 46000/150759 patients completed
#   Processing main loop: 47000/150759 patients completed
#   Processing main loop: 48000/150759 patients completed
#   Processing main loop: 49000/150759 patients completed
#   Processing main loop: 50000/150759 patients completed
#   Processing main loop: 51000/150759 patients completed
#   Processing main loop: 52000/150759 patients completed
#   Processing main loop: 53000/150759 patients completed
#   Processing main loop: 54000/150759 patients completed
#   Processing main loop: 55000/150759 patients completed
#   Processing main loop: 56000/150759 patients completed
#   Processing main loop: 57000/150759 patients completed
#   Processing main loop: 58000/150759 patients completed
#   Processing main loop: 59000/150759 patients completed
#   Processing main loop: 60000/150759 patients completed
#   Processing main loop: 61000/150759 patients completed
#   Processing main loop: 62000/150759 patients completed
#   Processing main loop: 63000/150759 patients completed
#   Processing main loop: 64000/150759 patients completed
#   Processing main loop: 65000/150759 patients completed
#   Processing main loop: 66000/150759 patients completed
#   Processing main loop: 67000/150759 patients completed
#   Processing main loop: 68000/150759 patients completed
#   Processing main loop: 69000/150759 patients completed
#   Processing main loop: 70000/150759 patients completed
#   Processing main loop: 71000/150759 patients completed
#   Processing main loop: 72000/150759 patients completed
#   Processing main loop: 73000/150759 patients completed
#   Processing main loop: 74000/150759 patients completed
#   Processing main loop: 75000/150759 patients completed
#   Processing main loop: 76000/150759 patients completed
#   Processing main loop: 77000/150759 patients completed
#   Processing main loop: 78000/150759 patients completed
#   Processing main loop: 79000/150759 patients completed
#   Processing main loop: 80000/150759 patients completed
#   Processing main loop: 81000/150759 patients completed
#   Processing main loop: 82000/150759 patients completed
#   Processing main loop: 83000/150759 patients completed
#   Processing main loop: 84000/150759 patients completed
#   Processing main loop: 85000/150759 patients completed
#   Processing main loop: 86000/150759 patients completed
#   Processing main loop: 87000/150759 patients completed
#   Processing main loop: 88000/150759 patients completed
#   Processing main loop: 89000/150759 patients completed
#   Processing main loop: 90000/150759 patients completed
#   Processing main loop: 91000/150759 patients completed
#   Processing main loop: 92000/150759 patients completed
#   Processing main loop: 93000/150759 patients completed
#   Processing main loop: 94000/150759 patients completed
#   Processing main loop: 95000/150759 patients completed
#   Processing main loop: 96000/150759 patients completed
#   Processing main loop: 97000/150759 patients completed
#   Processing main loop: 98000/150759 patients completed
#   Processing main loop: 99000/150759 patients completed
#   Processing main loop: 100000/150759 patients completed
#   Processing main loop: 101000/150759 patients completed
#   Processing main loop: 102000/150759 patients completed
#   Processing main loop: 103000/150759 patients completed
#   Processing main loop: 104000/150759 patients completed
#   Processing main loop: 105000/150759 patients completed
#   Processing main loop: 106000/150759 patients completed
#   Processing main loop: 107000/150759 patients completed
#   Processing main loop: 108000/150759 patients completed
#   Processing main loop: 109000/150759 patients completed
#   Processing main loop: 110000/150759 patients completed
#   Processing main loop: 111000/150759 patients completed
#   Processing main loop: 112000/150759 patients completed
#   Processing main loop: 113000/150759 patients completed
#   Processing main loop: 114000/150759 patients completed
#   Processing main loop: 115000/150759 patients completed
#   Processing main loop: 116000/150759 patients completed
#   Processing main loop: 117000/150759 patients completed
#   Processing main loop: 118000/150759 patients completed
#   Processing main loop: 119000/150759 patients completed
#   Processing main loop: 120000/150759 patients completed
#   Processing main loop: 121000/150759 patients completed
#   Processing main loop: 122000/150759 patients completed
#   Processing main loop: 123000/150759 patients completed
#   Processing main loop: 124000/150759 patients completed
#   Processing main loop: 125000/150759 patients completed
#   Processing main loop: 126000/150759 patients completed
#   Processing main loop: 127000/150759 patients completed
#   Processing main loop: 128000/150759 patients completed
#   Processing main loop: 129000/150759 patients completed
#   Processing main loop: 130000/150759 patients completed
#   Processing main loop: 131000/150759 patients completed
#   Processing main loop: 132000/150759 patients completed
#   Processing main loop: 133000/150759 patients completed
#   Processing main loop: 134000/150759 patients completed
#   Processing main loop: 135000/150759 patients completed
#   Processing main loop: 136000/150759 patients completed
#   Processing main loop: 137000/150759 patients completed
#   Processing main loop: 138000/150759 patients completed
#   Processing main loop: 139000/150759 patients completed
#   Processing main loop: 140000/150759 patients completed
#   Processing main loop: 141000/150759 patients completed
#   Processing main loop: 142000/150759 patients completed
#   Processing main loop: 143000/150759 patients completed
#   Processing main loop: 144000/150759 patients completed
#   Processing main loop: 145000/150759 patients completed
#   Processing main loop: 146000/150759 patients completed
#   Processing main loop: 147000/150759 patients completed
#   Processing main loop: 148000/150759 patients completed
#   Processing main loop: 149000/150759 patients completed
#   Processing main loop: 150000/150759 patients completed
# Main loop complete. Collected 150759 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_2019.csv
# Loaded demographic data: 612158 rows
# After deduplication: 130054 rows
# Found 130054 unique patient-institution combinations
# Loaded date data: 228530 rows
# Indexed date data
# Loaded platelet data: 909901 rows
# Indexed platelet data
# Created demo_dict with 130054 entries
# Extracting admission dates for 130054 patients...
# Extracted admission dates for 130054 patients
# Starting main loop for 130054 patients...
#   Processing main loop: 1000/130054 patients completed
#   Processing main loop: 2000/130054 patients completed
#   Processing main loop: 3000/130054 patients completed
#   Processing main loop: 4000/130054 patients completed
#   Processing main loop: 5000/130054 patients completed
#   Processing main loop: 6000/130054 patients completed
#   Processing main loop: 7000/130054 patients completed
#   Processing main loop: 8000/130054 patients completed
#   Processing main loop: 9000/130054 patients completed
#   Processing main loop: 10000/130054 patients completed
#   Processing main loop: 11000/130054 patients completed
#   Processing main loop: 12000/130054 patients completed
#   Processing main loop: 13000/130054 patients completed
#   Processing main loop: 14000/130054 patients completed
#   Processing main loop: 15000/130054 patients completed
#   Processing main loop: 16000/130054 patients completed
#   Processing main loop: 17000/130054 patients completed
#   Processing main loop: 18000/130054 patients completed
#   Processing main loop: 19000/130054 patients completed
#   Processing main loop: 20000/130054 patients completed
#   Processing main loop: 21000/130054 patients completed
#   Processing main loop: 22000/130054 patients completed
#   Processing main loop: 23000/130054 patients completed
#   Processing main loop: 24000/130054 patients completed
#   Processing main loop: 25000/130054 patients completed
#   Processing main loop: 26000/130054 patients completed
#   Processing main loop: 27000/130054 patients completed
#   Processing main loop: 28000/130054 patients completed
#   Processing main loop: 29000/130054 patients completed
#   Processing main loop: 30000/130054 patients completed
#   Processing main loop: 31000/130054 patients completed
#   Processing main loop: 32000/130054 patients completed
#   Processing main loop: 33000/130054 patients completed
#   Processing main loop: 34000/130054 patients completed
#   Processing main loop: 35000/130054 patients completed
#   Processing main loop: 36000/130054 patients completed
#   Processing main loop: 37000/130054 patients completed
#   Processing main loop: 38000/130054 patients completed
#   Processing main loop: 39000/130054 patients completed
#   Processing main loop: 40000/130054 patients completed
#   Processing main loop: 41000/130054 patients completed
#   Processing main loop: 42000/130054 patients completed
#   Processing main loop: 43000/130054 patients completed
#   Processing main loop: 44000/130054 patients completed
#   Processing main loop: 45000/130054 patients completed
#   Processing main loop: 46000/130054 patients completed
#   Processing main loop: 47000/130054 patients completed
#   Processing main loop: 48000/130054 patients completed
#   Processing main loop: 49000/130054 patients completed
#   Processing main loop: 50000/130054 patients completed
#   Processing main loop: 51000/130054 patients completed
#   Processing main loop: 52000/130054 patients completed
#   Processing main loop: 53000/130054 patients completed
#   Processing main loop: 54000/130054 patients completed
#   Processing main loop: 55000/130054 patients completed
#   Processing main loop: 56000/130054 patients completed
#   Processing main loop: 57000/130054 patients completed
#   Processing main loop: 58000/130054 patients completed
#   Processing main loop: 59000/130054 patients completed
#   Processing main loop: 60000/130054 patients completed
#   Processing main loop: 61000/130054 patients completed
#   Processing main loop: 62000/130054 patients completed
#   Processing main loop: 63000/130054 patients completed
#   Processing main loop: 64000/130054 patients completed
#   Processing main loop: 65000/130054 patients completed
#   Processing main loop: 66000/130054 patients completed
#   Processing main loop: 67000/130054 patients completed
#   Processing main loop: 68000/130054 patients completed
#   Processing main loop: 69000/130054 patients completed
#   Processing main loop: 70000/130054 patients completed
#   Processing main loop: 71000/130054 patients completed
#   Processing main loop: 72000/130054 patients completed
#   Processing main loop: 73000/130054 patients completed
#   Processing main loop: 74000/130054 patients completed
#   Processing main loop: 75000/130054 patients completed
#   Processing main loop: 76000/130054 patients completed
#   Processing main loop: 77000/130054 patients completed
#   Processing main loop: 78000/130054 patients completed
#   Processing main loop: 79000/130054 patients completed
#   Processing main loop: 80000/130054 patients completed
#   Processing main loop: 81000/130054 patients completed
#   Processing main loop: 82000/130054 patients completed
#   Processing main loop: 83000/130054 patients completed
#   Processing main loop: 84000/130054 patients completed
#   Processing main loop: 85000/130054 patients completed
#   Processing main loop: 86000/130054 patients completed
#   Processing main loop: 87000/130054 patients completed
#   Processing main loop: 88000/130054 patients completed
#   Processing main loop: 89000/130054 patients completed
#   Processing main loop: 90000/130054 patients completed
#   Processing main loop: 91000/130054 patients completed
#   Processing main loop: 92000/130054 patients completed
#   Processing main loop: 93000/130054 patients completed
#   Processing main loop: 94000/130054 patients completed
#   Processing main loop: 95000/130054 patients completed
#   Processing main loop: 96000/130054 patients completed
#   Processing main loop: 97000/130054 patients completed
#   Processing main loop: 98000/130054 patients completed
#   Processing main loop: 99000/130054 patients completed
#   Processing main loop: 100000/130054 patients completed
#   Processing main loop: 101000/130054 patients completed
#   Processing main loop: 102000/130054 patients completed
#   Processing main loop: 103000/130054 patients completed
#   Processing main loop: 104000/130054 patients completed
#   Processing main loop: 105000/130054 patients completed
#   Processing main loop: 106000/130054 patients completed
#   Processing main loop: 107000/130054 patients completed
#   Processing main loop: 108000/130054 patients completed
#   Processing main loop: 109000/130054 patients completed
#   Processing main loop: 110000/130054 patients completed
#   Processing main loop: 111000/130054 patients completed
#   Processing main loop: 112000/130054 patients completed
#   Processing main loop: 113000/130054 patients completed
#   Processing main loop: 114000/130054 patients completed
#   Processing main loop: 115000/130054 patients completed
#   Processing main loop: 116000/130054 patients completed
#   Processing main loop: 117000/130054 patients completed
#   Processing main loop: 118000/130054 patients completed
#   Processing main loop: 119000/130054 patients completed
#   Processing main loop: 120000/130054 patients completed
#   Processing main loop: 121000/130054 patients completed
#   Processing main loop: 122000/130054 patients completed
#   Processing main loop: 123000/130054 patients completed
#   Processing main loop: 124000/130054 patients completed
#   Processing main loop: 125000/130054 patients completed
#   Processing main loop: 126000/130054 patients completed
#   Processing main loop: 127000/130054 patients completed
#   Processing main loop: 128000/130054 patients completed
#   Processing main loop: 129000/130054 patients completed
#   Processing main loop: 130000/130054 patients completed
# Main loop complete. Collected 130054 results
# ASE results saved to ./presumed_infection/2.Data/Output\plt\plt_
#  'plt': 3.82,
#  'lact': 5.07,
#  'CO': 9.8}

# %%
from glob import glob

# AI generated summarization code
def extract_true_cases():
    """Extract all HN+Institution pairs with at least one True across all years"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    if not files:
        print("No ASE files found!")
        return pd.DataFrame()
    
    true_cases = []
    
    for file in files:
        try:
            year = file.split('_')[-1].split('.')[0]
            df = pd.read_csv(file)
            
            if df.empty:
                print(f"File {file} is empty, skipping")
                continue
            
            # Check if any of the condition columns are True
            condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
            # Only use columns that exist
            existing_cols = [col for col in condition_cols if col in df.columns]
            
            if not existing_cols:
                print(f"No condition columns found in {file}, skipping")
                continue
                
            df['has_true'] = df[existing_cols].any(axis=1)
            
            # Extract HN+Institution pairs with at least one True
            if 'has_true' in df.columns and 'HN Number' in df.columns and 'Institution (IPAS)' in df.columns:
                year_true = df[df['has_true']][['HN Number', 'Institution (IPAS)']].drop_duplicates()
                
                for _, row in year_true.iterrows():
                    true_cases.append({
                        'HN Number': row['HN Number'], 
                        'Institution (IPAS)': row['Institution (IPAS)'],
                        'Year': year
                    })
        except Exception as e:
            print(f"Error processing file {file}: {e}")
            continue
    
    true_cases_df = pd.DataFrame(true_cases)
    output_file = os.path.join(output_dir, 'true_cases_all_years.csv')
    true_cases_df.to_csv(output_file, index=False)
    print(f"True cases saved to {output_file}, total {len(true_cases_df)} cases")
    
    return true_cases_df

def summarize_statistics():
    """Summarize statistics by year and overall including CO"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    if not files:
        print("No ASE files found!")
        return pd.DataFrame()
    
    all_stats = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    extra_cols = ['CO']
    
    overall_counts = {col: 0 for col in condition_cols + extra_cols}
    overall_total = 0
    overall_any_count = 0
    
    for file in files:
        try:
            year = file.split('_')[-1].split('.')[0]
            df = pd.read_csv(file)
            
            if df.empty:
                print(f"File {file} is empty, skipping")
                continue
            
            # Use unique HN+Institution combinations for patient count
            unique_patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
            patient_count = len(unique_patients)
            
            year_stats = {'Year': year, 'Total_Patients': patient_count}
            
            # Calculate condition counts per patient
            for col in condition_cols + extra_cols:
                if col in df.columns:
                    # Count patients with this condition True
                    patients_with_condition = df[df[col] == True][['HN Number', 'Institution (IPAS)']].drop_duplicates()
                    count = len(patients_with_condition)
                    percentage = (count / patient_count * 100) if patient_count > 0 else 0
                    year_stats[f'{col}_count'] = count
                    year_stats[f'{col}_pct'] = round(percentage, 2)
                    
                    overall_counts[col] += count
                else:
                    year_stats[f'{col}_count'] = 0
                    year_stats[f'{col}_pct'] = 0
            
            # Patients with any condition
            existing_condition_cols = [col for col in condition_cols if col in df.columns]
            if existing_condition_cols:
                patients_with_any = df[df[existing_condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
                any_count = len(patients_with_any)
                year_stats['Patients_with_any'] = any_count
                year_stats['Any_pct'] = round(any_count / patient_count * 100, 2) if patient_count > 0 else 0
                
                overall_any_count += any_count
            else:
                year_stats['Patients_with_any'] = 0
                year_stats['Any_pct'] = 0
            
            overall_total += patient_count
            all_stats.append(year_stats)
        except Exception as e:
            print(f"Error processing file {file}: {e}")
            continue
    
    # Overall statistics
    overall_stats = {'Year': 'OVERALL', 'Total_Patients': overall_total}
    
    for col in condition_cols + extra_cols:
        percentage = (overall_counts[col] / overall_total * 100) if overall_total > 0 else 0
        overall_stats[f'{col}_count'] = overall_counts[col]
        overall_stats[f'{col}_pct'] = round(percentage, 2)
    
    # Calculate overall patients with any condition
    all_any_patients = set()
    for file in files:
        try:
            df = pd.read_csv(file)
            existing_condition_cols = [col for col in condition_cols if col in df.columns]
            if existing_condition_cols:
                any_patients = df[df[existing_condition_cols].any(axis=1)][['HN Number', 'Institution (IPAS)']].drop_duplicates()
                for _, row in any_patients.iterrows():
                    all_any_patients.add((row['HN Number'], row['Institution (IPAS)']))
        except:
            continue
    
    overall_stats['Patients_with_any'] = len(all_any_patients)
    overall_stats['Any_pct'] = round(len(all_any_patients) / overall_total * 100, 2) if overall_total > 0 else 0
    
    all_stats.append(overall_stats)
    
    stats_df = pd.DataFrame(all_stats)
    
    # Save statistics
    stats_file = os.path.join(output_dir, 'statistics_summary.csv')
    stats_df.to_csv(stats_file, index=False)
    print(f"Statistics saved to {stats_file}")
    
    return stats_df

def summarize_detailed():
    """Detailed summary including distribution of number of conditions per patient and CO analysis"""
    output_dir = DATA_PATH + "Output/ase/"
    files = glob(os.path.join(output_dir, "ase_*.csv"))
    
    if not files:
        print("No ASE files found!")
        return pd.DataFrame()
    
    all_detailed = []
    condition_cols = ['vasopressor', 'ventilation', 'creatinine', 'bili', 'plt', 'lact']
    
    for file in files:
        try:
            year = file.split('_')[-1].split('.')[0]
            df = pd.read_csv(file)
            
            if df.empty:
                continue
            
            # Create patient-condition matrix
            patients = df[['HN Number', 'Institution (IPAS)']].drop_duplicates()
            
            # Count conditions per patient
            condition_counts = []
            co_true_count = 0
            patients_with_any = 0
            
            for _, patient in patients.iterrows():
                hn = patient['HN Number']
                inst = patient['Institution (IPAS)']
                patient_rows = df[(df['HN Number'] == hn) & (df['Institution (IPAS)'] == inst)]
                
                # Count unique conditions that are True at least once
                condition_count = 0
                has_any = False
                for col in condition_cols:
                    if col in patient_rows.columns and patient_rows[col].any():
                        condition_count += 1
                        has_any = True
                
                condition_counts.append(condition_count)
                if has_any:
                    patients_with_any += 1
                
                # Check CO for this patient
                if 'CO' in patient_rows.columns and patient_rows['CO'].any():
                    co_true_count += 1
            
            # Calculate distribution
            year_detailed = {
                'Year': year,
                'Total_Patients': len(patients),
                'Patients_with_0': condition_counts.count(0),
                'Patients_with_1': condition_counts.count(1),
                'Patients_with_2': condition_counts.count(2),
                'Patients_with_3': condition_counts.count(3),
                'Patients_with_4': condition_counts.count(4),
                'Patients_with_5': condition_counts.count(5),
                'Patients_with_6': condition_counts.count(6),
                'Avg_conditions': round(sum(condition_counts) / len(condition_counts), 2) if condition_counts else 0,
                'CO_True': co_true_count,
                'CO_Pct': round(co_true_count / len(patients) * 100, 2) if len(patients) > 0 else 0,
                'CO_among_any': co_true_count,
                'CO_among_any_pct': round(co_true_count / patients_with_any * 100, 2) if patients_with_any > 0 else 0
            }
            
            # Add percentages for condition counts
            for i in range(7):
                pct_col = f'Pct_with_{i}'
                count = year_detailed[f'Patients_with_{i}']
                year_detailed[pct_col] = round(count / len(patients) * 100, 2) if len(patients) > 0 else 0
            
            all_detailed.append(year_detailed)
        except Exception as e:
            print(f"Error processing file {file} for detailed stats: {e}")
            continue
    
    detailed_df = pd.DataFrame(all_detailed)
    
    # Save detailed statistics
    detailed_file = os.path.join(output_dir, 'detailed_statistics.csv')
    detailed_df.to_csv(detailed_file, index=False)
    print(f"Detailed statistics saved to {detailed_file}")
    
    return detailed_df

# Run all functions
if __name__ == "__main__":
    true_cases = extract_true_cases()
    stats = summarize_statistics()
    detailed = summarize_detailed()
    
    if not stats.empty:
        print("\nSummary Statistics:")
        print(stats.to_string(index=False))
    else:
        print("No statistics generated.")
# Out:
# True cases saved to ./presumed_infection/2.Data/Output/ase/true_cases_all_years.csv, total 34686 cases
# Statistics saved to ./presumed_infection/2.Data/Output/ase/statistics_summary.csv
# Detailed statistics saved to ./presumed_infection/2.Data/Output/ase/detailed_statistics.csv
#
# Summary Statistics:
#    Year  Total_Patients  vasopressor_count  vasopressor_pct  ventilation_count  ventilation_pct  creatinine_count  creatinine_pct  bili_count  bili_pct  plt_count  plt_pct  lact_count  lact_pct  CO_count  CO_pct  Patients_with_any  Any_pct
#    2022          197988               9014             4.55               1926             0.97             16351            8.26        7393      3.73       7570     3.82       10030      5.07     19401     9.8              34686    17.52
# OVERALL          197988               9014             4.55               1926             0.97             16351            8.26        7393      3.73       7570     3.82       10030      5.07     19401     9.8              34686    17.52

# %%
# AI generated code to check for missing dates
def list_missing_dates(year):
    """List all HN + Institution pairs with missing blood culture date or first qad date"""
    DATE_PATH = DATA_PATH + f"Window_Period/bloodculture_filter{year}.csv"
    date_df = pd.read_csv(DATE_PATH)
    print(f"Loaded date data: {len(date_df)} rows")
    
    # Check for missing dates
    missing_blood = date_df['blood culture date'].isna()
    missing_qad = date_df['first_qad_date'].isna()
    
    # Cases where either is missing
    missing_either = missing_blood | missing_qad
    
    missing_df = date_df[missing_either][['HN Number', 'Institution (IPAS)', 'blood culture date', 'first_qad_date']].copy()
    
    # Add flags for which is missing
    missing_df['missing_blood'] = missing_df['blood culture date'].isna()
    missing_df['missing_qad'] = missing_df['first_qad_date'].isna()
    
    output_file = os.path.join(DATA_PATH, 'Output', 'ase', f'missing_dates_{year}.csv')
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    missing_df.to_csv(output_file, index=False)
    print(f"Missing dates report saved to {output_file}")
    print(f"Total rows with missing dates: {len(missing_df)}")
    print(f"Unique patients with missing dates: {missing_df[['HN Number', 'Institution (IPAS)']].drop_duplicates().shape[0]}")
    
    return missing_df

# %%
list_missing_dates(2022)
# Out:
# Loaded date data: 139901 rows
# Missing dates report saved to ./presumed_infection/2.Data/Output\ase\missing_dates_2022.csv
# Total rows with missing dates: 0
# Unique patients with missing dates: 0
# Empty DataFrame
# Columns: [HN Number, Institution (IPAS), blood culture date, first_qad_date, missing_blood, missing_qad]
# Index: []
