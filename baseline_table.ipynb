# %%
# import libraries
import os
import pandas as pd
import numpy as np
from scipy import stats
import warnings

# define file paths
DATA_PATH = f"./presumed_infection/2.Data/"
SIC_PATH = os.path.join(DATA_PATH, "Demographics/all_sic_demographics.csv")
ASE_NON_SIC_PATH = os.path.join(DATA_PATH, "Demographics/all_ase_non_sic_demographics.csv")
ANALYSIS_PATH = os.path.join(DATA_PATH, "Analysis/")

# %%
def create_ase_non_sic_and_sic_demographics():
    ase_non_sic_all = []
    sic_all = []
    
    # Track readmissions by Reference Key
    ase_non_sic_admissions_per_patient = {}
    sic_admissions_per_patient = {}
    
    # Track total admissions from patient lists (direct from loaded files)
    total_sic_admissions = 0
    total_ase_admissions = 0
    
    for year in range(2003, 2026):
        try:
            # Load SIC patient list for the year (plt_patient_list)
            sic_path = DATA_PATH + f"Output/plt/plt_patient_list_{year}.csv"
            sic_df = pd.read_csv(sic_path)
            sic_count_this_year = len(sic_df)
            total_sic_admissions += sic_count_this_year
            print(f"Year {year}: Loaded {sic_count_this_year} SIC patients from plt_patient_list")
            
            # Load ASE patient list for the year (ase_patient_list)
            ase_path = DATA_PATH + f"Output/ase/ase_patient_list_{year}.csv"
            ase_df = pd.read_csv(ase_path)
            ase_count_this_year = len(ase_df)
            total_ase_admissions += ase_count_this_year
            print(f"Year {year}: Loaded {ase_count_this_year} ASE patients from ase_patient_list")
            
            # Load demographic data for the year
            demo_path = DATA_PATH + f"Demographics/{year}/filtered_demographic_{year}.csv"
            demo_df = pd.read_csv(demo_path)
            print(f"Year {year}: Loaded {len(demo_df)} demographic rows")
            
            # Create composite key for matching
            demo_df['composite_key'] = demo_df['HN Number'].astype(str) + '_' + demo_df['Institution (IPAS)'].astype(str)
            sic_df['composite_key'] = sic_df['HN Number'].astype(str) + '_' + sic_df['Institution (IPAS)'].astype(str)
            ase_df['composite_key'] = ase_df['HN Number'].astype(str) + '_' + ase_df['Institution (IPAS)'].astype(str)
            
            # Get keys
            sic_keys = set(sic_df['composite_key'].unique())
            ase_keys = set(ase_df['composite_key'].unique())
            
            # Add Year column
            demo_df['Year'] = year
            
            # Get ASE patients (those in ASE list)
            ase_mask = demo_df['composite_key'].isin(ase_keys)
            ase_demo_df = demo_df[ase_mask].copy()
            
            # Split ASE into: ASE-nonSIC (ASE but not SIC) vs SIC
            ase_non_sic_mask = ~ase_demo_df['composite_key'].isin(sic_keys)
            sic_mask = ase_demo_df['composite_key'].isin(sic_keys)
            
            ase_non_sic_year_df = ase_demo_df[ase_non_sic_mask].copy()
            sic_year_df = ase_demo_df[sic_mask].copy()
            
            # Track admissions by Reference Key (for readmission calculation)
            for _, row in ase_non_sic_year_df.iterrows():
                ref_key = row.get('Reference Key')
                if pd.notna(ref_key):
                    ase_non_sic_admissions_per_patient[ref_key] = ase_non_sic_admissions_per_patient.get(ref_key, 0) + 1
            
            for _, row in sic_year_df.iterrows():
                ref_key = row.get('Reference Key')
                if pd.notna(ref_key):
                    sic_admissions_per_patient[ref_key] = sic_admissions_per_patient.get(ref_key, 0) + 1
            
            # Remove composite_key before appending
            ase_non_sic_year_df = ase_non_sic_year_df.drop(columns=['composite_key'])
            sic_year_df = sic_year_df.drop(columns=['composite_key'])
            
            ase_non_sic_all.append(ase_non_sic_year_df)
            sic_all.append(sic_year_df)
            
            print(f"  Year {year}: ASE-nonSIC = {len(ase_non_sic_year_df)}, SIC = {len(sic_year_df)}")
            
        except FileNotFoundError as e:
            print(f"Year {year}: File not found - {e}")
            continue
    
    # Combine all years
    if ase_non_sic_all:
        combined_ase_non_sic = pd.concat(ase_non_sic_all, ignore_index=True)
        combined_sic = pd.concat(sic_all, ignore_index=True)
        
        # Save to CSV (admission-level)
        combined_ase_non_sic.to_csv(ASE_NON_SIC_PATH, index=False)
        combined_sic.to_csv(SIC_PATH, index=False)
        
        # Calculate ASE-nonSIC admissions from totals
        total_ase_non_sic_admissions = total_ase_admissions - total_sic_admissions
        
        print(f"\n--- Summary ---")
        print(f"Total SIC admissions (from plt_patient_list): {total_sic_admissions:,}")
        print(f"Total ASE admissions (from ase_patient_list): {total_ase_admissions:,}")
        print(f"Total ASE-nonSIC admissions (ASE - SIC): {total_ase_non_sic_admissions:,}")
        print(f"Total ASE-nonSIC admissions (from demographic match): {len(combined_ase_non_sic):,}")
        print(f"Total SIC admissions (from demographic match): {len(combined_sic):,}")
        print(f"ASE-nonSIC demographics saved to {ASE_NON_SIC_PATH}")
        print(f"SIC demographics saved to {SIC_PATH}")
        
        return combined_ase_non_sic, combined_sic, ase_non_sic_admissions_per_patient, sic_admissions_per_patient, total_ase_non_sic_admissions, total_sic_admissions
    
    return pd.DataFrame(), pd.DataFrame(), {}, {}, 0, 0

def generate_baseline_table():
    # Load the demographic data (admission-level)
    ase_non_sic_df = pd.read_csv(ASE_NON_SIC_PATH)
    sic_df = pd.read_csv(SIC_PATH)
    
    # Create composite_key if it doesn't exist
    if 'composite_key' not in ase_non_sic_df.columns:
        ase_non_sic_df['composite_key'] = ase_non_sic_df['HN Number'].astype(str) + '_' + ase_non_sic_df['Institution (IPAS)'].astype(str)
    
    if 'composite_key' not in sic_df.columns:
        sic_df['composite_key'] = sic_df['HN Number'].astype(str) + '_' + sic_df['Institution (IPAS)'].astype(str)
    
    # Load CO status from ase_patient_list files
    co_status_dict = {}
    
    for year in range(2003, 2026):
        try:
            ase_path = os.path.join(DATA_PATH, f"Output/ase/ase_patient_list_{year}.csv")
            ase_df = pd.read_csv(ase_path)
            
            # Create composite key
            ase_df['composite_key'] = ase_df['HN Number'].astype(str) + '_' + ase_df['Institution (IPAS)'].astype(str)
            
            # Store CO status (assuming 'CO' column exists in ase_patient_list)
            if 'CO' in ase_df.columns:
                for _, row in ase_df.iterrows():
                    composite_key = row['composite_key']
                    co_status_dict[composite_key] = row['CO']
                    
        except FileNotFoundError:
            continue
        except Exception as e:
            print(f"Error loading year {year}: {e}")
            continue
    
    # Map CO status to dataframes
    ase_non_sic_df['CO'] = ase_non_sic_df['composite_key'].map(co_status_dict)
    sic_df['CO'] = sic_df['composite_key'].map(co_status_dict)
    
    # Fill NaN CO values with False (assuming non-ASE patients or missing)
    ase_non_sic_df['CO'] = ase_non_sic_df['CO'].fillna(False)
    sic_df['CO'] = sic_df['CO'].fillna(False)
    
    # Load the original patient lists to get correct admission counts
    total_sic_admissions = 0
    total_ase_admissions = 0
    
    for year in range(2003, 2026):
        try:
            sic_path = os.path.join(DATA_PATH, f"Output/plt/plt_patient_list_{year}.csv")
            sic_list = pd.read_csv(sic_path)
            total_sic_admissions += len(sic_list)
            
            ase_path = os.path.join(DATA_PATH, f"Output/ase/ase_patient_list_{year}.csv")
            ase_list = pd.read_csv(ase_path)
            total_ase_admissions += len(ase_list)
            
        except FileNotFoundError:
            continue
    
    total_ase_non_sic_admissions = total_ase_admissions - total_sic_admissions
    
    # Calculate unique patients from demographic data (by Reference Key)
    if 'Reference Key' in ase_non_sic_df.columns:
        ase_non_sic_unique_patients = ase_non_sic_df['Reference Key'].nunique()
        sic_unique_patients = sic_df['Reference Key'].nunique()
    else:
        ase_non_sic_unique_patients = len(ase_non_sic_df)
        sic_unique_patients = len(sic_df)
    
    # Calculate CO/HO breakdown for unique patients
    ase_non_sic_unique = ase_non_sic_df.drop_duplicates(subset=['Reference Key']) if 'Reference Key' in ase_non_sic_df.columns else ase_non_sic_df
    sic_unique = sic_df.drop_duplicates(subset=['Reference Key']) if 'Reference Key' in sic_df.columns else sic_df
    
    ase_non_sic_co_count = ase_non_sic_unique['CO'].sum() if 'CO' in ase_non_sic_unique.columns else 0
    ase_non_sic_ho_count = len(ase_non_sic_unique) - ase_non_sic_co_count
    sic_co_count = sic_unique['CO'].sum() if 'CO' in sic_unique.columns else 0
    sic_ho_count = len(sic_unique) - sic_co_count
    
    # Calculate readmission statistics
    ase_non_sic_readmissions = total_ase_non_sic_admissions - ase_non_sic_unique_patients
    sic_readmissions = total_sic_admissions - sic_unique_patients
    
    ase_non_sic_readmission_rate = (ase_non_sic_readmissions / ase_non_sic_unique_patients) * 100 if ase_non_sic_unique_patients > 0 else 0
    sic_readmission_rate = (sic_readmissions / sic_unique_patients) * 100 if sic_unique_patients > 0 else 0
    
    # Calculate p-value for readmission rate
    readmission_contingency = np.array([
        [ase_non_sic_unique_patients, ase_non_sic_readmissions],
        [sic_unique_patients, sic_readmissions]
    ])
    _, p_readmission, _, _ = stats.chi2_contingency(readmission_contingency)
    
    # Average admissions per patient
    ase_non_sic_avg_admissions = total_ase_non_sic_admissions / ase_non_sic_unique_patients if ase_non_sic_unique_patients > 0 else 0
    sic_avg_admissions = total_sic_admissions / sic_unique_patients if sic_unique_patients > 0 else 0
    
    # Prepare baseline table
    baseline_data = []
    
    # Total unique patients (with CO/HO breakdown)
    baseline_data.append({
        'Characteristic': 'Total unique patients',
        'ASE (non-SIC)': f"{ase_non_sic_unique_patients:,}",
        'SIC': f"{sic_unique_patients:,}",
        'P-value': ''
    })
    
    # CO/HO breakdown
    baseline_data.append({
        'Characteristic': '  - Community-Onset (CO)',
        'ASE (non-SIC)': f"{ase_non_sic_co_count:,} ({ase_non_sic_co_count/ase_non_sic_unique_patients*100:.1f}%)" if ase_non_sic_unique_patients > 0 else "0 (0.0%)",
        'SIC': f"{sic_co_count:,} ({sic_co_count/sic_unique_patients*100:.1f}%)" if sic_unique_patients > 0 else "0 (0.0%)",
        'P-value': ''
    })
    
    baseline_data.append({
        'Characteristic': '  - Hospital-Onset (HO)',
        'ASE (non-SIC)': f"{ase_non_sic_ho_count:,} ({ase_non_sic_ho_count/ase_non_sic_unique_patients*100:.1f}%)" if ase_non_sic_unique_patients > 0 else "0 (0.0%)",
        'SIC': f"{sic_ho_count:,} ({sic_ho_count/sic_unique_patients*100:.1f}%)" if sic_unique_patients > 0 else "0 (0.0%)",
        'P-value': ''
    })
    
    # Total admissions
    baseline_data.append({
        'Characteristic': 'Total admissions',
        'ASE (non-SIC)': f"{total_ase_non_sic_admissions:,}",
        'SIC': f"{total_sic_admissions:,}",
        'P-value': ''
    })
    
    # Average admissions per patient
    baseline_data.append({
        'Characteristic': 'Average admissions per patient',
        'ASE (non-SIC)': f"{ase_non_sic_avg_admissions:.2f}",
        'SIC': f"{sic_avg_admissions:.2f}",
        'P-value': ''
    })
    
    # Readmission rate
    baseline_data.append({
        'Characteristic': 'Readmission rate (per patient)',
        'ASE (non-SIC)': f"{ase_non_sic_readmission_rate:.1f}% ({ase_non_sic_readmissions:,} / {ase_non_sic_unique_patients:,})",
        'SIC': f"{sic_readmission_rate:.1f}% ({sic_readmissions:,} / {sic_unique_patients:,})",
        'P-value': f"{p_readmission:.2e}"
    })
    
    # Sex (using unique patients)
    if 'Sex' in ase_non_sic_unique.columns and 'Sex' in sic_unique.columns:
        ase_non_sic_sex = ase_non_sic_unique['Sex'].value_counts()
        sic_sex = sic_unique['Sex'].value_counts()
        
        for sex in ['M', 'F']:
            ase_non_sic_n = ase_non_sic_sex.get(sex, 0)
            sic_n = sic_sex.get(sex, 0)
            ase_non_sic_pct = (ase_non_sic_n / ase_non_sic_unique_patients) * 100
            sic_pct = (sic_n / sic_unique_patients) * 100
            
            baseline_data.append({
                'Characteristic': f'Sex - {sex}',
                'ASE (non-SIC)': f"{ase_non_sic_n:,} ({ase_non_sic_pct:.1f}%)",
                'SIC': f"{sic_n:,} ({sic_pct:.1f}%)",
                'P-value': ''
            })
        
        # Calculate p-value for sex
        categories = list(set(ase_non_sic_sex.index) | set(sic_sex.index))
        ase_non_sic_counts = [ase_non_sic_sex.get(cat, 0) for cat in categories]
        sic_counts = [sic_sex.get(cat, 0) for cat in categories]
        _, p_sex, _, _ = stats.chi2_contingency([ase_non_sic_counts, sic_counts])
        baseline_data.append({
            'Characteristic': 'Sex (overall)',
            'ASE (non-SIC)': '',
            'SIC': '',
            'P-value': f"{p_sex:.2e}"
        })
    
    # Age (using unique patients)
    age_col = 'Admission Age (Year) (episode based)'
    if age_col in ase_non_sic_unique.columns and age_col in sic_unique.columns:
        ase_non_sic_age = pd.to_numeric(ase_non_sic_unique[age_col], errors='coerce').dropna()
        sic_age = pd.to_numeric(sic_unique[age_col], errors='coerce').dropna()
        
        baseline_data.append({
            'Characteristic': 'Age (years) - Mean ± SD',
            'ASE (non-SIC)': f"{ase_non_sic_age.mean():.1f} ± {ase_non_sic_age.std():.1f}",
            'SIC': f"{sic_age.mean():.1f} ± {sic_age.std():.1f}",
            'P-value': ''
        })
        
        baseline_data.append({
            'Characteristic': 'Age (years) - Median (IQR)',
            'ASE (non-SIC)': f"{ase_non_sic_age.median():.1f} ({ase_non_sic_age.quantile(0.25):.1f}-{ase_non_sic_age.quantile(0.75):.1f})",
            'SIC': f"{sic_age.median():.1f} ({sic_age.quantile(0.25):.1f}-{sic_age.quantile(0.75):.1f})",
            'P-value': ''
        })
        
        # Age groups
        def age_group(age):
            if age < 18:
                return '<18'
            elif age < 40:
                return '18-39'
            elif age < 60:
                return '40-59'
            elif age < 75:
                return '60-74'
            else:
                return '≥75'
        
        ase_non_sic_age_group = ase_non_sic_age.apply(age_group).value_counts()
        sic_age_group = sic_age.apply(age_group).value_counts()
        
        for group in ['<18', '18-39', '40-59', '60-74', '≥75']:
            ase_non_sic_n = ase_non_sic_age_group.get(group, 0)
            sic_n = sic_age_group.get(group, 0)
            ase_non_sic_pct = (ase_non_sic_n / len(ase_non_sic_age)) * 100 if len(ase_non_sic_age) > 0 else 0
            sic_pct = (sic_n / len(sic_age)) * 100 if len(sic_age) > 0 else 0
            
            baseline_data.append({
                'Characteristic': f'Age group - {group}',
                'ASE (non-SIC)': f"{ase_non_sic_n:,} ({ase_non_sic_pct:.1f}%)",
                'SIC': f"{sic_n:,} ({sic_pct:.1f}%)",
                'P-value': ''
            })
        
        # P-value for age
        if len(ase_non_sic_age) > 0 and len(sic_age) > 0:
            _, p_age = stats.ttest_ind(ase_non_sic_age, sic_age, equal_var=False)
            baseline_data.append({
                'Characteristic': 'Age (overall)',
                'ASE (non-SIC)': '',
                'SIC': '',
                'P-value': f"{p_age:.2e}"
            })
    
    # Episode Death (Y/N) - using unique patients
    death_col = 'Episode Death (Y/N)'
    if death_col in ase_non_sic_unique.columns and death_col in sic_unique.columns:
        ase_non_sic_death = ase_non_sic_unique[death_col].value_counts()
        sic_death = sic_unique[death_col].value_counts()
        
        for outcome in ['Y', 'N']:
            ase_non_sic_n = ase_non_sic_death.get(outcome, 0)
            sic_n = sic_death.get(outcome, 0)
            ase_non_sic_pct = (ase_non_sic_n / ase_non_sic_unique_patients) * 100
            sic_pct = (sic_n / sic_unique_patients) * 100
            
            baseline_data.append({
                'Characteristic': f'In-hospital mortality - {outcome}',
                'ASE (non-SIC)': f"{ase_non_sic_n:,} ({ase_non_sic_pct:.1f}%)",
                'SIC': f"{sic_n:,} ({sic_pct:.1f}%)",
                'P-value': ''
            })
        
        # Calculate p-value for mortality
        categories = list(set(ase_non_sic_death.index) | set(sic_death.index))
        ase_non_sic_counts = [ase_non_sic_death.get(cat, 0) for cat in categories]
        sic_counts = [sic_death.get(cat, 0) for cat in categories]
        _, p_death, _, _ = stats.chi2_contingency([ase_non_sic_counts, sic_counts])
        baseline_data.append({
            'Characteristic': 'In-hospital mortality (overall)',
            'ASE (non-SIC)': '',
            'SIC': '',
            'P-value': f"{p_death:.2e}"
        })
    
    # 28-day mortality - using unique patients
    mortality_28d_col = '28_day_mortality'
    if mortality_28d_col in ase_non_sic_unique.columns and mortality_28d_col in sic_unique.columns:
        ase_non_sic_mort28 = ase_non_sic_unique[mortality_28d_col].value_counts()
        sic_mort28 = sic_unique[mortality_28d_col].value_counts()
        
        for outcome in [1, 0]:
            ase_non_sic_n = ase_non_sic_mort28.get(outcome, 0)
            sic_n = sic_mort28.get(outcome, 0)
            ase_non_sic_pct = (ase_non_sic_n / ase_non_sic_unique_patients) * 100
            sic_pct = (sic_n / sic_unique_patients) * 100
            
            outcome_label = 'Yes' if outcome == 1 else 'No'
            baseline_data.append({
                'Characteristic': f'28-day mortality - {outcome_label}',
                'ASE (non-SIC)': f"{ase_non_sic_n:,} ({ase_non_sic_pct:.1f}%)",
                'SIC': f"{sic_n:,} ({sic_pct:.1f}%)",
                'P-value': ''
            })
        
        # Calculate p-value for 28-day mortality
        categories = list(set(ase_non_sic_mort28.index) | set(sic_mort28.index))
        ase_non_sic_counts = [ase_non_sic_mort28.get(cat, 0) for cat in categories]
        sic_counts = [sic_mort28.get(cat, 0) for cat in categories]
        _, p_mort28, _, _ = stats.chi2_contingency([ase_non_sic_counts, sic_counts])
        baseline_data.append({
            'Characteristic': '28-day mortality (overall)',
            'ASE (non-SIC)': '',
            'SIC': '',
            'P-value': f"{p_mort28:.2e}"
        })
    
    # Create baseline table DataFrame
    baseline_df = pd.DataFrame(baseline_data)
    
    # Save baseline table
    os.makedirs(ANALYSIS_PATH, exist_ok=True)
    baseline_output = os.path.join(ANALYSIS_PATH, 'baseline_table_ase_nonsic_vs_sic.csv')
    baseline_df.to_csv(baseline_output, index=False)
    print(f"\nBaseline table saved to {baseline_output}")
    
    # Also save as formatted text table
    formatted_output = os.path.join(ANALYSIS_PATH, 'baseline_table_ase_nonsic_vs_sic.txt')
    with open(formatted_output, 'w') as f:
        f.write("Table X. Baseline characteristics of ASE (non-SIC) patients vs SIC patients\n\n")
        f.write(baseline_df.to_string(index=False))
    
    print(f"Formatted table saved to {formatted_output}")
    
    return baseline_df

# Run the functions
ase_non_sic_df, sic_df, ase_non_sic_admissions, sic_admissions, total_ase_non_sic_from_lists, total_sic_from_lists = create_ase_non_sic_and_sic_demographics()
baseline_table = generate_baseline_table()
print("\nBaseline table preview:")
print(baseline_table.to_string(index=False))

# Print admission counts from patient lists
print(f"\n--- Total Admissions from Patient Lists ---")
print(f"Total SIC admissions (from plt_patient_list): {total_sic_from_lists:,}")
print(f"Total ASE-nonSIC admissions (from ase_patient_list - sic_patient_list): {total_ase_non_sic_from_lists:,}")
# Out:
# Year 2003: Loaded 854 SIC patients from plt_patient_list
# Year 2003: Loaded 2411 ASE patients from ase_patient_list
# Year 2003: Loaded 27640 demographic rows
#   Year 2003: ASE-nonSIC = 7204, SIC = 5671
# Year 2004: Loaded 978 SIC patients from plt_patient_list
# Year 2004: Loaded 2784 ASE patients from ase_patient_list
# Year 2004: Loaded 31202 demographic rows
#   Year 2004: ASE-nonSIC = 8837, SIC = 6756
# Year 2005: Loaded 1065 SIC patients from plt_patient_list
# Year 2005: Loaded 2984 ASE patients from ase_patient_list
# Year 2005: Loaded 34036 demographic rows
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_3384\3779955019.py:31: DtypeWarning: Columns (15,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   demo_df = pd.read_csv(demo_path)
#   Year 2005: ASE-nonSIC = 9376, SIC = 7985
# Year 2006: Loaded 983 SIC patients from plt_patient_list
# Year 2006: Loaded 2935 ASE patients from ase_patient_list
# ...

# %%
import scipy.stats as stats

def calculate_co_ho_p_value():
    # Load the demographic data
    ase_non_sic_df = pd.read_csv(ASE_NON_SIC_PATH)
    sic_df = pd.read_csv(SIC_PATH)
    
    # Create composite_key if it doesn't exist
    if 'composite_key' not in ase_non_sic_df.columns:
        ase_non_sic_df['composite_key'] = ase_non_sic_df['HN Number'].astype(str) + '_' + ase_non_sic_df['Institution (IPAS)'].astype(str)
    
    if 'composite_key' not in sic_df.columns:
        sic_df['composite_key'] = sic_df['HN Number'].astype(str) + '_' + sic_df['Institution (IPAS)'].astype(str)
    
    # Load CO status from ase_patient_list files
    co_status_dict = {}
    
    for year in range(2003, 2026):
        try:
            ase_path = os.path.join(DATA_PATH, f"Output/ase/ase_patient_list_{year}.csv")
            ase_df = pd.read_csv(ase_path)
            
            # Create composite key
            ase_df['composite_key'] = ase_df['HN Number'].astype(str) + '_' + ase_df['Institution (IPAS)'].astype(str)
            
            # Store CO status
            if 'CO' in ase_df.columns:
                for _, row in ase_df.iterrows():
                    composite_key = row['composite_key']
                    co_status_dict[composite_key] = row['CO']
                    
        except FileNotFoundError:
            continue
        except Exception as e:
            print(f"Error loading year {year}: {e}")
            continue
    
    # Map CO status to dataframes
    ase_non_sic_df['CO'] = ase_non_sic_df['composite_key'].map(co_status_dict)
    sic_df['CO'] = sic_df['composite_key'].map(co_status_dict)
    
    # Fill NaN CO values with False
    ase_non_sic_df['CO'] = ase_non_sic_df['CO'].fillna(False)
    sic_df['CO'] = sic_df['CO'].fillna(False)
    
    # Get unique patients
    ase_non_sic_unique = ase_non_sic_df.drop_duplicates(subset=['Reference Key']) if 'Reference Key' in ase_non_sic_df.columns else ase_non_sic_df
    sic_unique = sic_df.drop_duplicates(subset=['Reference Key']) if 'Reference Key' in sic_df.columns else sic_df
    
    # Create contingency table
    # Rows: ASE (non-SIC) vs SIC
    # Columns: CO vs HO
    contingency = np.array([
        [ase_non_sic_unique['CO'].sum(), len(ase_non_sic_unique) - ase_non_sic_unique['CO'].sum()],  # ASE (non-SIC): CO, HO
        [sic_unique['CO'].sum(), len(sic_unique) - sic_unique['CO'].sum()]  # SIC: CO, HO
    ])
    
    print("Contingency Table (CO vs HO):")
    print("                    CO      HO")
    print(f"ASE (non-SIC):    {contingency[0][0]:>6}   {contingency[0][1]:>6}")
    print(f"SIC:              {contingency[1][0]:>6}   {contingency[1][1]:>6}")
    
    # Calculate p-value using Chi-square test
    chi2, p_value, dof, expected = stats.chi2_contingency(contingency)
    
    print(f"\nChi-square: {chi2:.4f}")
    print(f"Degrees of freedom: {dof}")
    print(f"P-value: {p_value:.2e}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpretation
    if p_value < 0.001:
        print("\nInterpretation: Statistically significant difference (p < 0.001)")
    elif p_value < 0.01:
        print("\nInterpretation: Statistically significant difference (p < 0.01)")
    elif p_value < 0.05:
        print("\nInterpretation: Statistically significant difference (p < 0.05)")
    else:
        print("\nInterpretation: No statistically significant difference")
    
    return p_value, contingency

# Run the function
p_value, contingency = calculate_co_ho_p_value()
# Out:
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_3384\1274552954.py:5: DtypeWarning: Columns (15,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   ase_non_sic_df = pd.read_csv(ASE_NON_SIC_PATH)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_3384\1274552954.py:6: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sic_df = pd.read_csv(SIC_PATH)
# C:\Users\Vincent Yeung\AppData\Local\Temp\ipykernel_3384\1274552954.py:21: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   ase_df = pd.read_csv(ase_path)
# Contingency Table (CO vs HO):
#                     CO      HO
# ASE (non-SIC):    193972    37062
# SIC:               72758    16333
#
# Chi-square: 242.6987
# Degrees of freedom: 1
# P-value: 1.01e-54
# P-value: 0.0000
#
# Interpretation: Statistically significant difference (p < 0.001)
