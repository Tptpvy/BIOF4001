# %%
import pandas as pd
import os
import glob
import numpy as np
from datetime import datetime, timedelta
import re
import warnings

# %% [markdown]
# ## Blood culture filter & calculate windows period

# %%
# 设置文件夹路径
for year in range(2017, 2018):
    folder_path = f"./presumed_infection/2.Data/Blood_culture/{year}/"

    # 获取所有CSV文件
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

    if not csv_files:
        print("未找到CSV文件")
    else:
        print(f"找到 {len(csv_files)} 个CSV文件")
        
        successful_files = []
        failed_files = []
        no_match_files = []

        all_data = []

        for csv_file in csv_files:
            file_name = os.path.basename(csv_file)
            try:
                # 读取文件
                df = pd.read_csv(csv_file, low_memory=False)

                # 查找筛选列
                filter_col = None
                for col in df.columns:
                    if "Bacterial Culture and ST Within Hospital Stay - Culture Test" in str(col):
                        filter_col = col
                        break

                if filter_col:
                    # 筛选包含Blood的行
                    blood_mask = df[filter_col].astype(str).str.contains("Blood", case=False, na=False)
                    filtered = df.loc[blood_mask]

                    if len(filtered) > 0:
                        # 只保留需要的列
                        columns_to_keep = [
                            "Reference Key",
                            "Institution (IPAS)",
                            "HN Number",
                            "Bacterial Culture and ST Within Hospital Stay - Ref. Date (yyyy-mm-dd HH:MM)"
                        ]

                        # 提取存在的列
                        existing_cols = [col for col in columns_to_keep if col in filtered.columns]

                        if existing_cols:
                            extracted_data = filtered[existing_cols].copy()
                            all_data.append(extracted_data)
                            successful_files.append(file_name)
                            print(f"✓ {file_name}: 成功处理 ({len(filtered)} 行)")
                        else:
                            failed_files.append(file_name)
                            print(f"✗ {file_name}: 缺少必需列")
                    else:
                        no_match_files.append(file_name)
                        print(f"  {file_name}: 无匹配行 (无Blood培养)")
                else:
                    no_match_files.append(file_name)
                    print(f"  {file_name}: 无筛选列")

            except Exception as e:
                failed_files.append(file_name)
                print(f"✗ {file_name} 错误: {e}")

        if all_data:
            # 合并数据
            combined = pd.concat(all_data, ignore_index=True)
            # 去除重复项
            before = len(combined)
            combined = combined.drop_duplicates()
            after = len(combined)

            # 处理日期和计算窗口期
            date_col = "Bacterial Culture and ST Within Hospital Stay - Ref. Date (yyyy-mm-dd HH:MM)"

            if date_col in combined.columns:
                # 将日期列转换为datetime类型
                combined[date_col] = pd.to_datetime(combined[date_col], errors='coerce')

                # 只保留年月日（去掉时间部分）
                combined[date_col] = combined[date_col].dt.date

                # 计算窗口期（前后两天）
                combined['window_period_start'] = combined[date_col] - timedelta(days=2)
                combined['window_period_end'] = combined[date_col] + timedelta(days=2)

                # 将所有日期列转换为字符串格式（只保留年月日）
                combined = combined.rename(columns={date_col: 'blood culture date'})
                combined['blood culture date'] = combined['blood culture date'].astype(str)
                combined['window_period_start'] = combined['window_period_start'].astype(str)
                combined['window_period_end'] = combined['window_period_end'].astype(str)

            # 保存结果
            output_path = f"./presumed_infection/2.Data/Window_Period/"
            os.makedirs(output_path, exist_ok=True)
            output_file = os.path.join(output_path, f"bloodculture_filter{year}(test).csv")
            combined.to_csv(output_file, index=False, encoding='utf-8-sig')
            
            # 输出统计摘要
            print("\n" + "="*50)
            print(f"处理完成 - {year}年")
            print("="*50)
            print(f"成功处理文件: {len(successful_files)} 个")
            for f in successful_files:
                print(f"  ✓ {f}")
            print(f"\n无匹配文件: {len(no_match_files)} 个")
            for f in no_match_files:
                print(f"    {f}")
            print(f"\n失败文件: {len(failed_files)} 个")
            for f in failed_files:
                print(f"  ✗ {f}")
            print("\n" + "="*50)
            print(f"总行数 (去重前): {before}")
            print(f"总行数 (去重后): {after}")
            print(f"输出文件: {output_file}")
            print("="*50)
# Out:
# 找到 56 个CSV文件
# ✓ 7496614_Sepsis_Blood_Culture_2017HKEC_M_Q1.csv: 成功处理 (3497 行)
# ✓ 7496643_Sepsis_Blood_Culture_2017HKWC_M_Q1.csv: 成功处理 (3215 行)
# ✓ 7496653_Sepsis_Blood_Culture_2017KCC_M_Q1.csv: 成功处理 (4756 行)
# ✓ 7496654_Sepsis_Blood_Culture_2017KEC_M_Q1.csv: 成功处理 (4420 行)
# ✓ 7496659_Sepsis_Blood_Culture_2017KWC_M_Q1.csv: 成功处理 (6014 行)
# ✓ 7496663_Sepsis_Blood_Culture_2017NTEC_M_Q1.csv: 成功处理 (5868 行)
# ✓ 7496667_Sepsis_Blood_Culture_2017NTWC_M_Q1.csv: 成功处理 (4935 行)
# ✓ 7496674_Sepsis_Blood_Culture_2017HKEC_F_Q1.csv: 成功处理 (3497 行)
# ✓ 7496676_Sepsis_Blood_Culture_2017HKWC_F_Q1.csv: 成功处理 (3215 行)
# ✓ 7496678_Sepsis_Blood_Culture_2017KCC_F_Q1.csv: 成功处理 (4756 行)
# ✓ 7496681_Sepsis_Blood_Culture_2017KEC_F_Q1.csv: 成功处理 (4420 行)
# ✓ 7496691_Sepsis_Blood_Culture_2017KWC_F_Q1.csv: 成功处理 (6014 行)
# ✓ 7496694_Sepsis_Blood_Culture_2017NTEC_F_Q1.csv: 成功处理 (5868 行)
# ✓ 7496697_Sepsis_Blood_Culture_2017NTWC_F_Q1.csv: 成功处理 (4935 行)
# ✓ 7496705_Sepsis_Blood_Culture_2017HKEC_M_Q2.csv: 成功处理 (3986 行)
# ✓ 7496707_Sepsis_Blood_Culture_2017HKWC_M_Q2.csv: 成功处理 (3472 行)
# ✓ 7496717_Sepsis_Blood_Culture_2017KCC_M_Q2.csv: 成功处理 (5160 行)
# ✓ 7496720_Sepsis_Blood_Culture_2017KEC_M_Q2.csv: 成功处理 (4715 行)
# ✓ 7496721_Sepsis_Blood_Culture_2017KWC_M_Q2.csv: 成功处理 (6322 行)
# ✓ 7496724_Sepsis_Blood_Culture_2017NTEC_M_Q2.csv: 成功处理 (6369 行)
# ✓ 7496728_Sepsis_Blood_Culture_2017NTWC_M_Q2.csv: 成功处理 (5584 行)
# ✓ 7496731_Sepsis_Blood_Culture_2017HKEC_F_Q2.csv: 成功处理 (3986 行)
# ✓ 7496733_Sepsis_Blood_Culture_2017HKWC_F_Q2.csv: 成功处理 (3472 行)
# ✓ 7496734_Sepsis_Blood_Culture_2017KCC_F_Q2.csv: 成功处理 (5160 行)
# ✓ 7496737_Sepsis_Blood_Culture_2017KEC_F_Q2.csv: 成功处理 (4715 行)
# ✓ 7496739_Sepsis_Blood_Culture_2017KWC_F_Q2.csv: 成功处理 (6322 行)
# ✓ 7496742_Sepsis_Blood_Culture_2017NTEC_F_Q2.csv: 成功处理 (6369 行)
# ✓ 7496744_Sepsis_Blood_Culture_2017NTWC_F_Q2.csv: 成功处理 (5584 行)
# ✓ 7496750_Sepsis_Blood_Culture_2017HKEC_M_Q3.csv: 成功处理 (4283 行)
# ✓ 7496752_Sepsis_Blood_Culture_2017HKWC_M_Q3.csv: 成功处理 (3847 行)
# ✓ 7496755_Sepsis_Blood_Culture_2017KCC_M_Q3.csv: 成功处理 (5470 行)
# ✓ 7496758_Sepsis_Blood_Culture_2017KEC_M_Q3.csv: 成功处理 (5032 行)
# ✓ 7496760_Sepsis_Blood_Culture_2017KWC_M_Q3.csv: 成功处理 (6377 行)
# ✓ 7496764_Sepsis_Blood_Culture_2017NTEC_M_Q3.csv: 成功处理 (6128 行)
# ✓ 7496767_Sepsis_Blood_Culture_2017NTWC_M_Q3.csv: 成功处理 (5622 行)
# ✓ 7496775_Sepsis_Blood_Culture_2017HKEC_F_Q3.csv: 成功处理 (4283 行)
# ✓ 7496777_Sepsis_Blood_Culture_2017HKWC_F_Q3.csv: 成功处理 (3847 行)
# ✓ 7496780_Sepsis_Blood_Culture_2017KCC_F_Q3.csv: 成功处理 (5470 行)
# ✓ 7496793_Sepsis_Blood_Culture_2017KEC_F_Q3.csv: 成功处理 (5032 行)
# ✓ 7496797_Sepsis_Blood_Culture_2017KWC_F_Q3.csv: 成功处理 (6377 行)
# ✓ 7496802_Sepsis_Blood_Culture_2017NTEC_F_Q3.csv: 成功处理 (6128 行)
# ✓ 7496806_Sepsis_Blood_Culture_2017NTWC_F_Q3.csv: 成功处理 (5622 行)
# ✓ 7496836_Sepsis_Blood_Culture_2017HKEC_M_Q4.csv: 成功处理 (3694 行)
# ✓ 7496860_Sepsis_Blood_Culture_2017HKWC_M_Q4.csv: 成功处理 (3900 行)
# ✓ 7496863_Sepsis_Blood_Culture_2017KCC_M_Q4.csv: 成功处理 (5210 行)
# ✓ 7496864_Sepsis_Blood_Culture_2017KEC_M_Q4.csv: 成功处理 (4558 行)
# ✓ 7496865_Sepsis_Blood_Culture_2017KWC_M_Q4.csv: 成功处理 (6046 行)
# ✓ 7496866_Sepsis_Blood_Culture_2017NTEC_M_Q4.csv: 成功处理 (5621 行)
# ✓ 7496869_Sepsis_Blood_Culture_2017NTWC_M_Q4.csv: 成功处理 (5207 行)
# ✓ 7496871_Sepsis_Blood_Culture_2017HKEC_F_Q4.csv: 成功处理 (3694 行)
# ✓ 7496874_Sepsis_Blood_Culture_2017HKWC_F_Q4.csv: 成功处理 (3900 行)
# ✓ 7496876_Sepsis_Blood_Culture_2017KCC_F_Q4.csv: 成功处理 (5210 行)
# ✓ 7496877_Sepsis_Blood_Culture_2017KEC_F_Q4.csv: 成功处理 (4558 行)
# ✓ 7496878_Sepsis_Blood_Culture_2017KWC_F_Q4.csv: 成功处理 (6046 行)
# ✓ 7496881_Sepsis_Blood_Culture_2017NTEC_F_Q4.csv: 成功处理 (5621 行)
# ✓ 7496882_Sepsis_Blood_Culture_2017NTWC_F_Q4.csv: 成功处理 (5207 行)
#
# ==================================================
# 处理完成 - 2017年
# ==================================================
# 成功处理文件: 56 个
#   ✓ 7496614_Sepsis_Blood_Culture_2017HKEC_M_Q1.csv
#   ✓ 7496643_Sepsis_Blood_Culture_2017HKWC_M_Q1.csv
#   ✓ 7496653_Sepsis_Blood_Culture_2017KCC_M_Q1.csv
#   ✓ 7496654_Sepsis_Blood_Culture_2017KEC_M_Q1.csv
#   ✓ 7496659_Sepsis_Blood_Culture_2017KWC_M_Q1.csv
#   ✓ 7496663_Sepsis_Blood_Culture_2017NTEC_M_Q1.csv
#   ✓ 7496667_Sepsis_Blood_Culture_2017NTWC_M_Q1.csv
#   ✓ 7496674_Sepsis_Blood_Culture_2017HKEC_F_Q1.csv
#   ✓ 7496676_Sepsis_Blood_Culture_2017HKWC_F_Q1.csv
#   ✓ 7496678_Sepsis_Blood_Culture_2017KCC_F_Q1.csv
#   ✓ 7496681_Sepsis_Blood_Culture_2017KEC_F_Q1.csv
#   ✓ 7496691_Sepsis_Blood_Culture_2017KWC_F_Q1.csv
#   ✓ 7496694_Sepsis_Blood_Culture_2017NTEC_F_Q1.csv
#   ✓ 7496697_Sepsis_Blood_Culture_2017NTWC_F_Q1.csv
#   ✓ 7496705_Sepsis_Blood_Culture_2017HKEC_M_Q2.csv
#   ✓ 7496707_Sepsis_Blood_Culture_2017HKWC_M_Q2.csv
#   ✓ 7496717_Sepsis_Blood_Culture_2017KCC_M_Q2.csv
#   ✓ 7496720_Sepsis_Blood_Culture_2017KEC_M_Q2.csv
#   ✓ 7496721_Sepsis_Blood_Culture_2017KWC_M_Q2.csv
#   ✓ 7496724_Sepsis_Blood_Culture_2017NTEC_M_Q2.csv
#   ✓ 7496728_Sepsis_Blood_Culture_2017NTWC_M_Q2.csv
#   ✓ 7496731_Sepsis_Blood_Culture_2017HKEC_F_Q2.csv
#   ✓ 7496733_Sepsis_Blood_Culture_2017HKWC_F_Q2.csv
#   ✓ 7496734_Sepsis_Blood_Culture_2017KCC_F_Q2.csv
#   ✓ 7496737_Sepsis_Blood_Culture_2017KEC_F_Q2.csv
#   ✓ 7496739_Sepsis_Blood_Culture_2017KWC_F_Q2.csv
#   ✓ 7496742_Sepsis_Blood_Culture_2017NTEC_F_Q2.csv
#   ✓ 7496744_Sepsis_Blood_Culture_2017NTWC_F_Q2.csv
#   ✓ 7496750_Sepsis_Blood_Culture_2017HKEC_M_Q3.csv
#   ✓ 7496752_Sepsis_Blood_Culture_2017HKWC_M_Q3.csv
#   ✓ 7496755_Sepsis_Blood_Culture_2017KCC_M_Q3.csv
#   ✓ 7496758_Sepsis_Blood_Culture_2017KEC_M_Q3.csv
#   ✓ 7496760_Sepsis_Blood_Culture_2017KWC_M_Q3.csv
#   ✓ 7496764_Sepsis_Blood_Culture_2017NTEC_M_Q3.csv
#   ✓ 7496767_Sepsis_Blood_Culture_2017NTWC_M_Q3.csv
#   ✓ 7496775_Sepsis_Blood_Culture_2017HKEC_F_Q3.csv
#   ✓ 7496777_Sepsis_Blood_Culture_2017HKWC_F_Q3.csv
#   ✓ 7496780_Sepsis_Blood_Culture_2017KCC_F_Q3.csv
#   ✓ 7496793_Sepsis_Blood_Culture_2017KEC_F_Q3.csv
#   ✓ 7496797_Sepsis_Blood_Culture_2017KWC_F_Q3.csv
#   ✓ 7496802_Sepsis_Blood_Culture_2017NTEC_F_Q3.csv
#   ✓ 7496806_Sepsis_Blood_Culture_2017NTWC_F_Q3.csv
#   ✓ 7496836_Sepsis_Blood_Culture_2017HKEC_M_Q4.csv
#   ✓ 7496860_Sepsis_Blood_Culture_2017HKWC_M_Q4.csv
#   ✓ 7496863_Sepsis_Blood_Culture_2017KCC_M_Q4.csv
#   ✓ 7496864_Sepsis_Blood_Culture_2017KEC_M_Q4.csv
#   ✓ 7496865_Sepsis_Blood_Culture_2017KWC_M_Q4.csv
#   ✓ 7496866_Sepsis_Blood_Culture_2017NTEC_M_Q4.csv
#   ✓ 7496869_Sepsis_Blood_Culture_2017NTWC_M_Q4.csv
#   ✓ 7496871_Sepsis_Blood_Culture_2017HKEC_F_Q4.csv
#   ✓ 7496874_Sepsis_Blood_Culture_2017HKWC_F_Q4.csv
#   ✓ 7496876_Sepsis_Blood_Culture_2017KCC_F_Q4.csv
#   ✓ 7496877_Sepsis_Blood_Culture_2017KEC_F_Q4.csv
#   ✓ 7496878_Sepsis_Blood_Culture_2017KWC_F_Q4.csv
#   ✓ 7496881_Sepsis_Blood_Culture_2017NTEC_F_Q4.csv
#   ✓ 7496882_Sepsis_Blood_Culture_2017NTWC_F_Q4.csv
#
# 无匹配文件: 0 个
#
# 失败文件: 0 个
#
# ==================================================
# 总行数 (去重前): 278616
# 总行数 (去重后): 131300
# 输出文件: ./presumed_infection/2.Data/Window_Period/bloodculture_filter2017(test).csv
# ==================================================

# %% [markdown]
# ## 4QAD

# %%
warnings.filterwarnings('ignore')

def extract_antibiotic_code(drug_item_code):
    if pd.isna(drug_item_code):
        return None

    code_str = str(drug_item_code).strip()
    match = re.match(r'([A-Za-z]+)', code_str)
    if match:
        return match.group(1).upper()
    else:
        return code_str.upper()

def is_vancomycin(antibiotic_code):
    if pd.isna(antibiotic_code):
        return False
    return antibiotic_code.startswith('VANC')

def parse_frequency(freq_str, start_date, end_date):
    if pd.isna(freq_str) or pd.isna(start_date) or pd.isna(end_date):
        return []

    freq = str(freq_str).upper().strip()

    if "EVERY" in freq and "HOURS" in freq:
        numbers = re.findall(r'\d+', freq)
        if numbers:
            interval_hours = int(numbers[0])

            dates = []
            current_time = datetime.combine(start_date, datetime.min.time())
            end_time = datetime.combine(end_date, datetime.min.time()) + timedelta(days=1)

            while current_time <= end_time:
                dates.append(current_time.date())
                current_time += timedelta(hours=interval_hours)

            unique_dates = sorted(set(dates))
            return [d for d in unique_dates if start_date <= d <= end_date]

    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)

    return dates

def load_antibiotics_data(antibiotic_path):
    print("加载抗生素数据...")

    antibiotic_files = glob.glob(os.path.join(antibiotic_path, "*.csv"))
    if not antibiotic_files:
        print(f"错误: 在路径 {antibiotic_path} 下未找到CSV文件")
        return None

    print(f"找到 {len(antibiotic_files)} 个抗生素数据文件")
    all_dfs = []

    for i, file in enumerate(antibiotic_files):
        try:
            df = pd.read_csv(file, low_memory=False)
            required_cols = ['HN Number', 'Prescription Start Date', 'Prescription End Date',
                           'Drug Item Code', 'Route', 'Drug Frequency']
            
            optional_cols = []
            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                optional_cols.append('Dispensing Date (yyyy-mm-dd)')
            if 'Dispensing Duration' in df.columns:
                optional_cols.append('Dispensing Duration')
            
            all_cols = required_cols + optional_cols
            df = df[all_cols].copy()

            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                df['Dispensing Date (yyyy-mm-dd)'] = pd.to_datetime(df['Dispensing Date (yyyy-mm-dd)'], errors='coerce').dt.date

            df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
            df['Prescription End Date'] = pd.to_datetime(df['Prescription End Date'], errors='coerce').dt.date

            missing_start_mask = df['Prescription Start Date'].isna()
            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                df.loc[missing_start_mask, 'Prescription Start Date'] = df.loc[missing_start_mask, 'Dispensing Date (yyyy-mm-dd)']

            if 'Dispensing Duration' in df.columns and 'Prescription Start Date' in df.columns:
                try:
                    df['Dispensing Duration'] = pd.to_numeric(df['Dispensing Duration'], errors='coerce')
                    for idx, row in df.iterrows():
                        if pd.isna(row['Prescription End Date']) and not pd.isna(row['Prescription Start Date']) and not pd.isna(row['Dispensing Duration']):
                            duration_days = int(row['Dispensing Duration'])
                            if duration_days > 0:
                                end_date = row['Prescription Start Date'] + timedelta(days=duration_days)
                                df.at[idx, 'Prescription End Date'] = end_date
                except Exception as e:
                    print(f"  转换Dispensing Duration时出错: {str(e)}")

            df['Antibiotic_Code'] = df['Drug Item Code'].apply(extract_antibiotic_code)
            df['Is_Vancomycin'] = df['Antibiotic_Code'].apply(is_vancomycin)
            all_dfs.append(df)

        except Exception as e:
            print(f"处理文件 {os.path.basename(file)} 时出错: {str(e)}")
            continue

    if not all_dfs:
        print("错误: 没有成功加载任何抗生素数据")
        return None

    antibiotics_df = pd.concat(all_dfs, ignore_index=True)

    print("数据清洗...")
    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Prescription Start Date', 'Prescription End Date'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行日期为空的记录")

    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Antibiotic_Code'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行抗生素代码为空的记录")

    valid_routes = ['PARENTERAL', 'ORAL', 'INTRAVENOUS']
    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df[antibiotics_df['Route'].isin(valid_routes)]
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行给药途径不在{valid_routes}范围内的记录")

    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Route'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行Route为空的记录")

    invalid_dates_mask = antibiotics_df['Prescription End Date'] < antibiotics_df['Prescription Start Date']
    if invalid_dates_mask.any():
        invalid_count = invalid_dates_mask.sum()
        antibiotics_df.loc[invalid_dates_mask, ['Prescription Start Date', 'Prescription End Date']] = antibiotics_df.loc[invalid_dates_mask, ['Prescription End Date', 'Prescription Start Date']].values

    print(f"抗生素数据处理完成，共 {len(antibiotics_df)} 行记录")
    return antibiotics_df

def load_window_data(window_path, year):
    print("加载窗口期数据...")

    window_files = glob.glob(os.path.join(window_path, f"*{year}*.csv"))
    if not window_files:
        print(f"错误: 在路径 {window_path} 下未找到CSV文件")
        return None

    print(f"找到 {len(window_files)} 个窗口期数据文件")
    all_dfs = []

    for i, file in enumerate(window_files):
        try:
            df = pd.read_csv(file, low_memory=False)
            all_dfs.append(df)
        except Exception as e:
            print(f"处理文件 {os.path.basename(file)} 时出错: {str(e)}")
            continue

    if not all_dfs:
        print("错误: 没有成功加载任何窗口期数据")
        return None

    window_df = pd.concat(all_dfs, ignore_index=True)
    print(f"窗口期数据加载完成，共 {len(window_df)} 行记录")

    date_cols = ['blood culture date', 'window_period_start', 'window_period_end']
    for col in date_cols:
        if col in window_df.columns:
            window_df[col] = pd.to_datetime(window_df[col], errors='coerce').dt.date
        else:
            print(f"警告: 列 {col} 不存在")

    original_count = len(window_df)
    window_df = window_df.dropna(subset=['blood culture date', 'window_period_start', 'window_period_end', 'HN Number'])
    removed_count = original_count - len(window_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行关键信息为空的记录")

    print(f"窗口期数据处理完成，共 {len(window_df)} 行记录")
    return window_df

def create_patient_medication_calendar(antibiotics_df):
    print("创建病人给药日历...")
    patient_calendars = {}
    groups = list(antibiotics_df.groupby('HN Number'))
    total_patients = len(groups)
    print(f"总共 {total_patients} 条住院记录需要处理")

    for i, (hn, group) in enumerate(groups):
        if (i+1) % 500 == 0 or i == 0:
            print(f"处理住院记录 {i+1}/{total_patients}")

        calendar = {}
        for _, row in group.iterrows():
            start_date = row['Prescription Start Date']
            end_date = row['Prescription End Date']
            antibiotic_code = row['Antibiotic_Code']
            route = row['Route']
            frequency = row['Drug Frequency']
            is_vancomycin = row['Is_Vancomycin']

            if end_date < start_date:
                start_date, end_date = end_date, start_date

            try:
                dose_dates = parse_frequency(frequency, start_date, end_date)
                for dose_date in dose_dates:
                    if dose_date not in calendar:
                        calendar[dose_date] = {
                            'drugs': set(),
                            'routes': set(),
                            'drug_info': {}
                        }

                    calendar[dose_date]['drugs'].add(antibiotic_code)
                    calendar[dose_date]['routes'].add(route)

                    if antibiotic_code not in calendar[dose_date]['drug_info']:
                        calendar[dose_date]['drug_info'][antibiotic_code] = {
                            'route': route,
                            'is_vancomycin': is_vancomycin,
                            'first_use_date': dose_date
                        }
            except Exception as e:
                continue

        patient_calendars[hn] = calendar

    print(f"给药日历创建完成，共 {len(patient_calendars)} 条住院记录")
    return patient_calendars

def is_new_antibiotic(antibiotic_code, route, dose_date, patient_calendar, is_vancomycin):
    two_days_ago = dose_date - timedelta(days=2)

    for check_date, med_info in patient_calendar.items():
        if two_days_ago <= check_date < dose_date:
            if antibiotic_code in med_info['drugs']:
                if is_vancomycin:
                    if antibiotic_code in med_info['drug_info']:
                        prev_route = med_info['drug_info'][antibiotic_code]['route']
                        if route == prev_route:
                            return False
                        else:
                            continue
                    else:
                        return False
                else:
                    return False
    return True

def check_4qad_for_window(hn, window_row, patient_calendar):
    window_start = window_row['window_period_start']
    window_end = window_row['window_period_end']

    window_meds = {}
    for date, med_info in patient_calendar.items():
        if window_start <= date <= window_end:
            window_meds[date] = med_info

    if not window_meds:
        return False

    sorted_dates = sorted(window_meds.keys())
    first_new_antibiotic_date = None

    for date in sorted_dates:
        med_info = window_meds[date]
        for antibiotic_code in med_info['drugs']:
            if antibiotic_code in med_info['drug_info']:
                drug_info = med_info['drug_info'][antibiotic_code]
                route = drug_info['route']
                is_vancomycin = drug_info['is_vancomycin']

                if is_new_antibiotic(antibiotic_code, route, date, patient_calendar, is_vancomycin):
                    first_new_antibiotic_date = date
                    break
        if first_new_antibiotic_date:
            break

    if not first_new_antibiotic_date:
        return False

    qad_dates = []
    current_date = first_new_antibiotic_date
    max_gap = 1
    gaps_used = 0
    max_days_to_check = 366

    for _ in range(max_days_to_check):
        if len(qad_dates) >= 4:
            break

        if current_date in patient_calendar:
            qad_dates.append(current_date)
            gaps_used = 0
        else:
            if gaps_used < max_gap:
                gaps_used += 1
            else:
                break
        current_date += timedelta(days=1)

    if len(qad_dates) < 4:
        return False

    has_parenteral = False
    for qad_date in qad_dates[:4]:
        if qad_date in patient_calendar:
            routes = patient_calendar[qad_date]['routes']
            if 'PARENTERAL' in routes or 'INTRAVENOUS' in routes:
                has_parenteral = True
                break

    if not has_parenteral:
        return False

    return True

def add_clusters_column(df):
    cluster_mapping = {}

    hkec_hospitals = ['CHC', 'PYN', 'RH', 'SJH', 'TWE', 'WCH']
    for hospital in hkec_hospitals:
        cluster_mapping[hospital] = 'HKEC'

    hkwc_hospitals = ['DKC', 'FYK', 'GH', 'ML', 'NLH', 'QMH', 'TWH', 'TYH']
    for hospital in hkwc_hospitals:
        cluster_mapping[hospital] = 'HKWC'

    kcc_hospitals = ['BH', 'HCH', 'HKE', 'KH', 'KWH', 'OLM', 'QEH', 'RC', 'WTS']
    for hospital in kcc_hospitals:
        cluster_mapping[hospital] = 'KCC'

    kec_hospitals = ['HHH', 'MT', 'TKO', 'UCH']
    for hospital in kec_hospitals:
        cluster_mapping[hospital] = 'KEC'

    kwc_hospitals = ['CMC', 'KCH', 'LCK', 'NLT', 'PMH', 'YCH']
    for hospital in kwc_hospitals:
        cluster_mapping[hospital] = 'KWC'

    ntec_hospitals = ['AHN', 'BBH', 'CHS', 'NDH', 'PWH', 'SH', 'TPH']
    for hospital in ntec_hospitals:
        cluster_mapping[hospital] = 'NTEC'

    ntwc_hospitals = ['CPH', 'POH', 'SLH', 'TMH', 'TSH']
    for hospital in ntwc_hospitals:
        cluster_mapping[hospital] = 'NTWC'

    df['Clusters'] = df['Institution (IPAS)'].map(cluster_mapping)

    if df['Clusters'].isna().any():
        df['Clusters'] = df['Clusters'].fillna('UNKNOWN')

    return df

def main():
    print("=== 4 QAD Filter 程序开始 ===")

    # Fixed: Added year parameter to loop through years
    for year in range(2017, 2018):
        print(f"\n处理年份: {year}")
        
        antibiotic_path = f"./presumed_infection/2.Data/Microbial/{year}/"
        window_path = f"./presumed_infection/2.Data/Window_Period/"
        output_path_csv = f"./presumed_infection/2.Data/Output/Presumedinfection_csv/"
        output_path_txt = f"./presumed_infection/2.Data/Output/Presumedinfection_txt/"

        # Create output directories if they don't exist
        for path in [output_path_csv, output_path_txt]:
            if not os.path.exists(path):
                os.makedirs(path, exist_ok=True)

        # Load data
        antibiotics_df = load_antibiotics_data(antibiotic_path)
        if antibiotics_df is None or len(antibiotics_df) == 0:
            print(f"年份 {year}: 无法加载抗生素数据或数据为空，跳过")
            continue

        window_df = load_window_data(window_path, year)
        if window_df is None or len(window_df) == 0:
            print(f"年份 {year}: 无法加载窗口期数据或数据为空，跳过")
            continue

        # Create medication calendar
        patient_calendars = create_patient_medication_calendar(antibiotics_df)

        # Check 4QAD conditions
        met_4qad_indices = []
        total_windows = len(window_df)
        print("检查4QAD条件...")
        
        for idx, window_row in window_df.iterrows():
            hn = window_row['HN Number']
            if hn not in patient_calendars:
                continue

            if check_4qad_for_window(hn, window_row, patient_calendars[hn]):
                met_4qad_indices.append(idx)

            if (idx + 1) % 1000 == 0:
                print(f"已处理 {idx + 1}/{total_windows} 个血培养窗口")

        # Extract results
        if met_4qad_indices:
            results_df = window_df.iloc[met_4qad_indices].copy()
            print(f"找到 {len(results_df)} 个满足4QAD条件的记录")
        else:
            print("没有找到满足4QAD条件的记录")
            continue

        # Add Clusters column
        results_df = add_clusters_column(results_df)

        # Select and deduplicate
        selected_columns = ['Reference Key', 'Institution (IPAS)', 'HN Number', 'Clusters']
        if all(col in results_df.columns for col in selected_columns):
            final_df = results_df[selected_columns].copy()
            
            original_count = len(final_df)
            final_df = final_df.drop_duplicates(subset=['HN Number'], keep='first')
            print(f"去重后保留 {len(final_df)} 条记录 (去除了 {original_count - len(final_df)} 条重复记录)")

            # Save results
            csv_file = os.path.join(output_path_csv, f"Presumed_Infection_List_{year}.csv")
            final_df.to_csv(csv_file, index=False)
            print(f"CSV文件已保存: {csv_file}")

            txt_file = os.path.join(output_path_txt, f"Presumed_Infection_List_{year}.txt")
            txt_columns = ['Reference Key', 'Institution (IPAS)', 'HN Number']
            if all(col in final_df.columns for col in txt_columns):
                txt_df = final_df[txt_columns].copy()
                txt_df.to_csv(txt_file, sep='\t', index=False)
                print(f"TXT文件已保存: {txt_file}")

            # Statistics
            print(f"\n=== 统计信息 ===")
            print(f"总血培养窗口数: {total_windows}")
            print(f"满足4QAD条件: {len(results_df)} ({len(results_df)/total_windows*100:.1f}%)")
            print(f"去重后唯一病人数: {len(final_df)}")

            if 'Clusters' in final_df.columns and len(final_df) > 0:
                print("\nCluster分布:")
                cluster_counts = final_df['Clusters'].value_counts()
                total_patients = len(final_df)
                for cluster, count in cluster_counts.items():
                    print(f"  {cluster}: {count} 个病人 ({count/total_patients*100:.1f}%)")
        else:
            print("错误: 数据中缺少必要的列")

    print("\n=== 程序执行完成 ===")
    return None

if __name__ == "__main__":
    try:
        results_df = main()
    except Exception as e:
        print(f"程序执行出错: {str(e)}")
        import traceback
        traceback.print_exc()
# Out:
# === 4 QAD Filter 程序开始 ===
#
# 处理年份: 2017
# 加载抗生素数据...
# 找到 56 个抗生素数据文件
# 数据清洗...
# 移除了 399042 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 2095651 行记录
# 加载窗口期数据...
# 找到 2 个窗口期数据文件
# 窗口期数据加载完成，共 263981 行记录
# 窗口期数据处理完成，共 263981 行记录
# 创建病人给药日历...
# 总共 197664 条住院记录需要处理
# 处理住院记录 1/197664
# 处理住院记录 500/197664
# 处理住院记录 1000/197664
# 处理住院记录 1500/197664
# 处理住院记录 2000/197664
# 处理住院记录 2500/197664
# 处理住院记录 3000/197664
# 处理住院记录 3500/197664
# 处理住院记录 4000/197664
# 处理住院记录 4500/197664
# 处理住院记录 5000/197664
# 处理住院记录 5500/197664
# 处理住院记录 6000/197664
# 处理住院记录 6500/197664
# 处理住院记录 7000/197664
# 处理住院记录 7500/197664
# 处理住院记录 8000/197664
# 处理住院记录 8500/197664
# 处理住院记录 9000/197664
# 处理住院记录 9500/197664
# 处理住院记录 10000/197664
# 处理住院记录 10500/197664
# 处理住院记录 11000/197664
# 处理住院记录 11500/197664
# 处理住院记录 12000/197664
# 处理住院记录 12500/197664
# 处理住院记录 13000/197664
# 处理住院记录 13500/197664
# 处理住院记录 14000/197664
# 处理住院记录 14500/197664
# 处理住院记录 15000/197664
# 处理住院记录 15500/197664
# 处理住院记录 16000/197664
# 处理住院记录 16500/197664
# 处理住院记录 17000/197664
# 处理住院记录 17500/197664
# 处理住院记录 18000/197664
# 处理住院记录 18500/197664
# 处理住院记录 19000/197664
# 处理住院记录 19500/197664
# 处理住院记录 20000/197664
# 处理住院记录 20500/197664
# 处理住院记录 21000/197664
# 处理住院记录 21500/197664
# 处理住院记录 22000/197664
# 处理住院记录 22500/197664
# 处理住院记录 23000/197664
# 处理住院记录 23500/197664
# 处理住院记录 24000/197664
# 处理住院记录 24500/197664
# 处理住院记录 25000/197664
# 处理住院记录 25500/197664
# 处理住院记录 26000/197664
# 处理住院记录 26500/197664
# 处理住院记录 27000/197664
# 处理住院记录 27500/197664
# 处理住院记录 28000/197664
# 处理住院记录 28500/197664
# 处理住院记录 29000/197664
# 处理住院记录 29500/197664
# 处理住院记录 30000/197664
# 处理住院记录 30500/197664
# 处理住院记录 31000/197664
# 处理住院记录 31500/197664
# 处理住院记录 32000/197664
# 处理住院记录 32500/197664
# 处理住院记录 33000/197664
# 处理住院记录 33500/197664
# 处理住院记录 34000/197664
# 处理住院记录 34500/197664
# 处理住院记录 35000/197664
# 处理住院记录 35500/197664
# 处理住院记录 36000/197664
# 处理住院记录 36500/197664
# 处理住院记录 37000/197664
# 处理住院记录 37500/197664
# 处理住院记录 38000/197664
# 处理住院记录 38500/197664
# 处理住院记录 39000/197664
# 处理住院记录 39500/197664
# 处理住院记录 40000/197664
# 处理住院记录 40500/197664
# 处理住院记录 41000/197664
# 处理住院记录 41500/197664
# 处理住院记录 42000/197664
# 处理住院记录 42500/197664
# 处理住院记录 43000/197664
# 处理住院记录 43500/197664
# 处理住院记录 44000/197664
# 处理住院记录 44500/197664
# 处理住院记录 45000/197664
# 处理住院记录 45500/197664
# 处理住院记录 46000/197664
# 处理住院记录 46500/197664
# 处理住院记录 47000/197664
# 处理住院记录 47500/197664
# 处理住院记录 48000/197664
# 处理住院记录 48500/197664
# 处理住院记录 49000/197664
# 处理住院记录 49500/197664
# 处理住院记录 50000/197664
# 处理住院记录 50500/197664
# 处理住院记录 51000/197664
# 处理住院记录 51500/197664
# 处理住院记录 52000/197664
# 处理住院记录 52500/197664
# 处理住院记录 53000/197664
# 处理住院记录 53500/197664
# 处理住院记录 54000/197664
# 处理住院记录 54500/197664
# 处理住院记录 55000/197664
# 处理住院记录 55500/197664
# 处理住院记录 56000/197664
# 处理住院记录 56500/197664
# 处理住院记录 57000/197664
# 处理住院记录 57500/197664
# 处理住院记录 58000/197664
# 处理住院记录 58500/197664
# 处理住院记录 59000/197664
# 处理住院记录 59500/197664
# 处理住院记录 60000/197664
# 处理住院记录 60500/197664
# 处理住院记录 61000/197664
# 处理住院记录 61500/197664
# 处理住院记录 62000/197664
# 处理住院记录 62500/197664
# 处理住院记录 63000/197664
# 处理住院记录 63500/197664
# 处理住院记录 64000/197664
# 处理住院记录 64500/197664
# 处理住院记录 65000/197664
# 处理住院记录 65500/197664
# 处理住院记录 66000/197664
# 处理住院记录 66500/197664
# 处理住院记录 67000/197664
# 处理住院记录 67500/197664
# 处理住院记录 68000/197664
# 处理住院记录 68500/197664
# 处理住院记录 69000/197664
# 处理住院记录 69500/197664
# 处理住院记录 70000/197664
# 处理住院记录 70500/197664
# 处理住院记录 71000/197664
# 处理住院记录 71500/197664
# 处理住院记录 72000/197664
# 处理住院记录 72500/197664
# 处理住院记录 73000/197664
# 处理住院记录 73500/197664
# 处理住院记录 74000/197664
# 处理住院记录 74500/197664
# 处理住院记录 75000/197664
# 处理住院记录 75500/197664
# 处理住院记录 76000/197664
# 处理住院记录 76500/197664
# 处理住院记录 77000/197664
# 处理住院记录 77500/197664
# 处理住院记录 78000/197664
# 处理住院记录 78500/197664
# 处理住院记录 79000/197664
# 处理住院记录 79500/197664
# 处理住院记录 80000/197664
# 处理住院记录 80500/197664
# 处理住院记录 81000/197664
# 处理住院记录 81500/197664
# 处理住院记录 82000/197664
# 处理住院记录 82500/197664
# 处理住院记录 83000/197664
# 处理住院记录 83500/197664
# 处理住院记录 84000/197664
# 处理住院记录 84500/197664
# 处理住院记录 85000/197664
# 处理住院记录 85500/197664
# 处理住院记录 86000/197664
# 处理住院记录 86500/197664
# 处理住院记录 87000/197664
# 处理住院记录 87500/197664
# 处理住院记录 88000/197664
# 处理住院记录 88500/197664
# 处理住院记录 89000/197664
# 处理住院记录 89500/197664
# 处理住院记录 90000/197664
# 处理住院记录 90500/197664
# 处理住院记录 91000/197664
# 处理住院记录 91500/197664
# 处理住院记录 92000/197664
# 处理住院记录 92500/197664
# 处理住院记录 93000/197664
# 处理住院记录 93500/197664
# 处理住院记录 94000/197664
# 处理住院记录 94500/197664
# 处理住院记录 95000/197664
# 处理住院记录 95500/197664
# 处理住院记录 96000/197664
# 处理住院记录 96500/197664
# 处理住院记录 97000/197664
# 处理住院记录 97500/197664
# 处理住院记录 98000/197664
# 处理住院记录 98500/197664
# 处理住院记录 99000/197664
# 处理住院记录 99500/197664
# 处理住院记录 100000/197664
# 处理住院记录 100500/197664
# 处理住院记录 101000/197664
# 处理住院记录 101500/197664
# 处理住院记录 102000/197664
# 处理住院记录 102500/197664
# 处理住院记录 103000/197664
# 处理住院记录 103500/197664
# 处理住院记录 104000/197664
# 处理住院记录 104500/197664
# 处理住院记录 105000/197664
# 处理住院记录 105500/197664
# 处理住院记录 106000/197664
# 处理住院记录 106500/197664
# 处理住院记录 107000/197664
# 处理住院记录 107500/197664
# 处理住院记录 108000/197664
# 处理住院记录 108500/197664
# 处理住院记录 109000/197664
# 处理住院记录 109500/197664
# 处理住院记录 110000/197664
# 处理住院记录 110500/197664
# 处理住院记录 111000/197664
# 处理住院记录 111500/197664
# 处理住院记录 112000/197664
# 处理住院记录 112500/197664
# 处理住院记录 113000/197664
# 处理住院记录 113500/197664
# 处理住院记录 114000/197664
# 处理住院记录 114500/197664
# 处理住院记录 115000/197664
# 处理住院记录 115500/197664
# 处理住院记录 116000/197664
# 处理住院记录 116500/197664
# 处理住院记录 117000/197664
# 处理住院记录 117500/197664
# 处理住院记录 118000/197664
# 处理住院记录 118500/197664
# 处理住院记录 119000/197664
# 处理住院记录 119500/197664
# 处理住院记录 120000/197664
# 处理住院记录 120500/197664
# 处理住院记录 121000/197664
# 处理住院记录 121500/197664
# 处理住院记录 122000/197664
# 处理住院记录 122500/197664
# 处理住院记录 123000/197664
# 处理住院记录 123500/197664
# 处理住院记录 124000/197664
# 处理住院记录 124500/197664
# 处理住院记录 125000/197664
# 处理住院记录 125500/197664
# 处理住院记录 126000/197664
# 处理住院记录 126500/197664
# 处理住院记录 127000/197664
# 处理住院记录 127500/197664
# 处理住院记录 128000/197664
# 处理住院记录 128500/197664
# 处理住院记录 129000/197664
# 处理住院记录 129500/197664
# 处理住院记录 130000/197664
# 处理住院记录 130500/197664
# 处理住院记录 131000/197664
# 处理住院记录 131500/197664
# 处理住院记录 132000/197664
# 处理住院记录 132500/197664
# 处理住院记录 133000/197664
# 处理住院记录 133500/197664
# 处理住院记录 134000/197664
# 处理住院记录 134500/197664
# 处理住院记录 135000/197664
# 处理住院记录 135500/197664
# 处理住院记录 136000/197664
# 处理住院记录 136500/197664
# 处理住院记录 137000/197664
# 处理住院记录 137500/197664
# 处理住院记录 138000/197664
# 处理住院记录 138500/197664
# 处理住院记录 139000/197664
# 处理住院记录 139500/197664
# 处理住院记录 140000/197664
# 处理住院记录 140500/197664
# 处理住院记录 141000/197664
# 处理住院记录 141500/197664
# 处理住院记录 142000/197664
# 处理住院记录 142500/197664
# 处理住院记录 143000/197664
# 处理住院记录 143500/197664
# 处理住院记录 144000/197664
# 处理住院记录 144500/197664
# 处理住院记录 145000/197664
# 处理住院记录 145500/197664
# 处理住院记录 146000/197664
# 处理住院记录 146500/197664
# 处理住院记录 147000/197664
# 处理住院记录 147500/197664
# 处理住院记录 148000/197664
# 处理住院记录 148500/197664
# 处理住院记录 149000/197664
# 处理住院记录 149500/197664
# 处理住院记录 150000/197664
# 处理住院记录 150500/197664
# 处理住院记录 151000/197664
# 处理住院记录 151500/197664
# 处理住院记录 152000/197664
# 处理住院记录 152500/197664
# 处理住院记录 153000/197664
# 处理住院记录 153500/197664
# 处理住院记录 154000/197664
# 处理住院记录 154500/197664
# 处理住院记录 155000/197664
# 处理住院记录 155500/197664
# 处理住院记录 156000/197664
# 处理住院记录 156500/197664
# 处理住院记录 157000/197664
# 处理住院记录 157500/197664
# 处理住院记录 158000/197664
# 处理住院记录 158500/197664
# 处理住院记录 159000/197664
# 处理住院记录 159500/197664
# 处理住院记录 160000/197664
# 处理住院记录 160500/197664
# 处理住院记录 161000/197664
# 处理住院记录 161500/197664
# 处理住院记录 162000/197664
# 处理住院记录 162500/197664
# 处理住院记录 163000/197664
# 处理住院记录 163500/197664
# 处理住院记录 164000/197664
# 处理住院记录 164500/197664
# 处理住院记录 165000/197664
# 处理住院记录 165500/197664
# 处理住院记录 166000/197664
# 处理住院记录 166500/197664
# 处理住院记录 167000/197664
# 处理住院记录 167500/197664
# 处理住院记录 168000/197664
# 处理住院记录 168500/197664
# 处理住院记录 169000/197664
# 处理住院记录 169500/197664
# 处理住院记录 170000/197664
# 处理住院记录 170500/197664
# 处理住院记录 171000/197664
# 处理住院记录 171500/197664
# 处理住院记录 172000/197664
# 处理住院记录 172500/197664
# 处理住院记录 173000/197664
# 处理住院记录 173500/197664
# 处理住院记录 174000/197664
# 处理住院记录 174500/197664
# 处理住院记录 175000/197664
# 处理住院记录 175500/197664
# 处理住院记录 176000/197664
# 处理住院记录 176500/197664
# 处理住院记录 177000/197664
# 处理住院记录 177500/197664
# 处理住院记录 178000/197664
# 处理住院记录 178500/197664
# 处理住院记录 179000/197664
# 处理住院记录 179500/197664
# 处理住院记录 180000/197664
# 处理住院记录 180500/197664
# 处理住院记录 181000/197664
# 处理住院记录 181500/197664
# 处理住院记录 182000/197664
# 处理住院记录 182500/197664
# 处理住院记录 183000/197664
# 处理住院记录 183500/197664
# 处理住院记录 184000/197664
# 处理住院记录 184500/197664
# 处理住院记录 185000/197664
# 处理住院记录 185500/197664
# 处理住院记录 186000/197664
# 处理住院记录 186500/197664
# 处理住院记录 187000/197664
# 处理住院记录 187500/197664
# 处理住院记录 188000/197664
# 处理住院记录 188500/197664
# 处理住院记录 189000/197664
# 处理住院记录 189500/197664
# 处理住院记录 190000/197664
# 处理住院记录 190500/197664
# 处理住院记录 191000/197664
# 处理住院记录 191500/197664
# 处理住院记录 192000/197664
# 处理住院记录 192500/197664
# 处理住院记录 193000/197664
# 处理住院记录 193500/197664
# 处理住院记录 194000/197664
# 处理住院记录 194500/197664
# 处理住院记录 195000/197664
# 处理住院记录 195500/197664
# 处理住院记录 196000/197664
# 处理住院记录 196500/197664
# 处理住院记录 197000/197664
# 处理住院记录 197500/197664
# 给药日历创建完成，共 197664 条住院记录
# 检查4QAD条件...
# 已处理 1000/263981 个血培养窗口
# 已处理 2000/263981 个血培养窗口
# 已处理 3000/263981 个血培养窗口
# 已处理 4000/263981 个血培养窗口
# 已处理 11000/263981 个血培养窗口
# 已处理 12000/263981 个血培养窗口
# 已处理 13000/263981 个血培养窗口
# 已处理 14000/263981 个血培养窗口
# 已处理 15000/263981 个血培养窗口
# 已处理 16000/263981 个血培养窗口
# 已处理 17000/263981 个血培养窗口
# 已处理 18000/263981 个血培养窗口
# 已处理 19000/263981 个血培养窗口
# 已处理 20000/263981 个血培养窗口
# 已处理 21000/263981 个血培养窗口
# 已处理 22000/263981 个血培养窗口
# 已处理 23000/263981 个血培养窗口
# 已处理 24000/263981 个血培养窗口
# 已处理 25000/263981 个血培养窗口
# 已处理 26000/263981 个血培养窗口
# 已处理 27000/263981 个血培养窗口
# 已处理 28000/263981 个血培养窗口
# 已处理 29000/263981 个血培养窗口
# 已处理 30000/263981 个血培养窗口
# 已处理 31000/263981 个血培养窗口
# 已处理 32000/263981 个血培养窗口
# 已处理 33000/263981 个血培养窗口
# 已处理 35000/263981 个血培养窗口
# 已处理 36000/263981 个血培养窗口
# 已处理 37000/263981 个血培养窗口
# 已处理 38000/263981 个血培养窗口
# 已处理 39000/263981 个血培养窗口
# 已处理 40000/263981 个血培养窗口
# 已处理 41000/263981 个血培养窗口
# 已处理 42000/263981 个血培养窗口
# 已处理 43000/263981 个血培养窗口
# 已处理 45000/263981 个血培养窗口
# 已处理 46000/263981 个血培养窗口
# 已处理 48000/263981 个血培养窗口
# 已处理 49000/263981 个血培养窗口
# 已处理 50000/263981 个血培养窗口
# 已处理 51000/263981 个血培养窗口
# 已处理 52000/263981 个血培养窗口
# 已处理 53000/263981 个血培养窗口
# 已处理 54000/263981 个血培养窗口
# 已处理 55000/263981 个血培养窗口
# 已处理 56000/263981 个血培养窗口
# 已处理 57000/263981 个血培养窗口
# 已处理 58000/263981 个血培养窗口
# 已处理 59000/263981 个血培养窗口
# 已处理 60000/263981 个血培养窗口
# 已处理 61000/263981 个血培养窗口
# 已处理 62000/263981 个血培养窗口
# 已处理 63000/263981 个血培养窗口
# 已处理 64000/263981 个血培养窗口
# 已处理 65000/263981 个血培养窗口
# 已处理 66000/263981 个血培养窗口
# 已处理 67000/263981 个血培养窗口
# 已处理 68000/263981 个血培养窗口
# 已处理 69000/263981 个血培养窗口
# 已处理 70000/263981 个血培养窗口
# 已处理 71000/263981 个血培养窗口
# 已处理 72000/263981 个血培养窗口
# 已处理 73000/263981 个血培养窗口
# 已处理 74000/263981 个血培养窗口
# 已处理 75000/263981 个血培养窗口
# 已处理 76000/263981 个血培养窗口
# 已处理 77000/263981 个血培养窗口
# 已处理 78000/263981 个血培养窗口
# 已处理 79000/263981 个血培养窗口
# 已处理 80000/263981 个血培养窗口
# 已处理 81000/263981 个血培养窗口
# 已处理 82000/263981 个血培养窗口
# 已处理 83000/263981 个血培养窗口
# 已处理 84000/263981 个血培养窗口
# 已处理 85000/263981 个血培养窗口
# 已处理 86000/263981 个血培养窗口
# 已处理 87000/263981 个血培养窗口
# 已处理 88000/263981 个血培养窗口
# 已处理 89000/263981 个血培养窗口
# 已处理 90000/263981 个血培养窗口
# 已处理 91000/263981 个血培养窗口
# 已处理 92000/263981 个血培养窗口
# 已处理 93000/263981 个血培养窗口
# 已处理 94000/263981 个血培养窗口
# 已处理 95000/263981 个血培养窗口
# 已处理 96000/263981 个血培养窗口
# 已处理 97000/263981 个血培养窗口
# 已处理 98000/263981 个血培养窗口
# 已处理 99000/263981 个血培养窗口
# 已处理 100000/263981 个血培养窗口
# 已处理 101000/263981 个血培养窗口
# 已处理 102000/263981 个血培养窗口
# 已处理 103000/263981 个血培养窗口
# 已处理 104000/263981 个血培养窗口
# 已处理 105000/263981 个血培养窗口
# 已处理 106000/263981 个血培养窗口
# 已处理 107000/263981 个血培养窗口
# 已处理 108000/263981 个血培养窗口
# 已处理 109000/263981 个血培养窗口
# 已处理 111000/263981 个血培养窗口
# 已处理 112000/263981 个血培养窗口
# 已处理 114000/263981 个血培养窗口
# 已处理 115000/263981 个血培养窗口
# 已处理 116000/263981 个血培养窗口
# 已处理 117000/263981 个血培养窗口
# 已处理 118000/263981 个血培养窗口
# 已处理 119000/263981 个血培养窗口
# 已处理 120000/263981 个血培养窗口
# 已处理 121000/263981 个血培养窗口
# 已处理 122000/263981 个血培养窗口
# 已处理 123000/263981 个血培养窗口
# 已处理 124000/263981 个血培养窗口
# 已处理 125000/263981 个血培养窗口
# 已处理 126000/263981 个血培养窗口
# 已处理 127000/263981 个血培养窗口
# 已处理 128000/263981 个血培养窗口
# 已处理 129000/263981 个血培养窗口
# 已处理 130000/263981 个血培养窗口
# 已处理 131000/263981 个血培养窗口
# 已处理 132000/263981 个血培养窗口
# 已处理 133000/263981 个血培养窗口
# 已处理 134000/263981 个血培养窗口
# 已处理 135000/263981 个血培养窗口
# 已处理 136000/263981 个血培养窗口
# 已处理 137000/263981 个血培养窗口
# 已处理 138000/263981 个血培养窗口
# 已处理 139000/263981 个血培养窗口
# 已处理 140000/263981 个血培养窗口
# 已处理 141000/263981 个血培养窗口
# 已处理 143000/263981 个血培养窗口
# 已处理 145000/263981 个血培养窗口
# 已处理 146000/263981 个血培养窗口
# 已处理 147000/263981 个血培养窗口
# 已处理 148000/263981 个血培养窗口
# 已处理 149000/263981 个血培养窗口
# 已处理 150000/263981 个血培养窗口
# 已处理 151000/263981 个血培养窗口
# 已处理 152000/263981 个血培养窗口
# 已处理 153000/263981 个血培养窗口
# 已处理 154000/263981 个血培养窗口
# 已处理 155000/263981 个血培养窗口
# 已处理 156000/263981 个血培养窗口
# 已处理 157000/263981 个血培养窗口
# 已处理 158000/263981 个血培养窗口
# 已处理 159000/263981 个血培养窗口
# 已处理 160000/263981 个血培养窗口
# 已处理 161000/263981 个血培养窗口
# 已处理 162000/263981 个血培养窗口
# 已处理 164000/263981 个血培养窗口
# 已处理 165000/263981 个血培养窗口
# 已处理 166000/263981 个血培养窗口
# 已处理 167000/263981 个血培养窗口
# 已处理 168000/263981 个血培养窗口
# 已处理 169000/263981 个血培养窗口
# 已处理 170000/263981 个血培养窗口
# 已处理 171000/263981 个血培养窗口
# 已处理 172000/263981 个血培养窗口
# 已处理 173000/263981 个血培养窗口
# 已处理 174000/263981 个血培养窗口
# 已处理 176000/263981 个血培养窗口
# 已处理 177000/263981 个血培养窗口
# 已处理 178000/263981 个血培养窗口
# 已处理 180000/263981 个血培养窗口
# 已处理 181000/263981 个血培养窗口
# 已处理 182000/263981 个血培养窗口
# 已处理 183000/263981 个血培养窗口
# 已处理 184000/263981 个血培养窗口
# 已处理 185000/263981 个血培养窗口
# 已处理 186000/263981 个血培养窗口
# 已处理 187000/263981 个血培养窗口
# 已处理 188000/263981 个血培养窗口
# 已处理 189000/263981 个血培养窗口
# 已处理 190000/263981 个血培养窗口
# 已处理 191000/263981 个血培养窗口
# 已处理 192000/263981 个血培养窗口
# 已处理 193000/263981 个血培养窗口
# 已处理 194000/263981 个血培养窗口
# 已处理 195000/263981 个血培养窗口
# 已处理 196000/263981 个血培养窗口
# 已处理 197000/263981 个血培养窗口
# 已处理 198000/263981 个血培养窗口
# 已处理 199000/263981 个血培养窗口
# 已处理 200000/263981 个血培养窗口
# 已处理 201000/263981 个血培养窗口
# 已处理 202000/263981 个血培养窗口
# 已处理 203000/263981 个血培养窗口
# 已处理 204000/263981 个血培养窗口
# 已处理 205000/263981 个血培养窗口
# 已处理 206000/263981 个血培养窗口
# 已处理 207000/263981 个血培养窗口
# 已处理 208000/263981 个血培养窗口
# 已处理 209000/263981 个血培养窗口
# 已处理 210000/263981 个血培养窗口
# 已处理 211000/263981 个血培养窗口
# 已处理 212000/263981 个血培养窗口
# 已处理 213000/263981 个血培养窗口
# 已处理 214000/263981 个血培养窗口
# 已处理 215000/263981 个血培养窗口
# 已处理 216000/263981 个血培养窗口
# 已处理 217000/263981 个血培养窗口
# 已处理 218000/263981 个血培养窗口
# 已处理 219000/263981 个血培养窗口
# 已处理 220000/263981 个血培养窗口
# 已处理 221000/263981 个血培养窗口
# 已处理 222000/263981 个血培养窗口
# 已处理 223000/263981 个血培养窗口
# 已处理 224000/263981 个血培养窗口
# 已处理 225000/263981 个血培养窗口
# 已处理 226000/263981 个血培养窗口
# 已处理 227000/263981 个血培养窗口
# 已处理 228000/263981 个血培养窗口
# 已处理 229000/263981 个血培养窗口
# 已处理 230000/263981 个血培养窗口
# 已处理 231000/263981 个血培养窗口
# 已处理 232000/263981 个血培养窗口
# 已处理 233000/263981 个血培养窗口
# 已处理 234000/263981 个血培养窗口
# 已处理 235000/263981 个血培养窗口
# 已处理 236000/263981 个血培养窗口
# 已处理 237000/263981 个血培养窗口
# 已处理 238000/263981 个血培养窗口
# 已处理 240000/263981 个血培养窗口
# 已处理 241000/263981 个血培养窗口
# 已处理 242000/263981 个血培养窗口
# 已处理 243000/263981 个血培养窗口
# 已处理 245000/263981 个血培养窗口
# 已处理 246000/263981 个血培养窗口
# 已处理 247000/263981 个血培养窗口
# 已处理 248000/263981 个血培养窗口
# 已处理 249000/263981 个血培养窗口
# 已处理 250000/263981 个血培养窗口
# 已处理 251000/263981 个血培养窗口
# 已处理 252000/263981 个血培养窗口
# 已处理 253000/263981 个血培养窗口
# 已处理 254000/263981 个血培养窗口
# 已处理 255000/263981 个血培养窗口
# 已处理 256000/263981 个血培养窗口
# 已处理 257000/263981 个血培养窗口
# 已处理 258000/263981 个血培养窗口
# 已处理 259000/263981 个血培养窗口
# 已处理 260000/263981 个血培养窗口
# 已处理 261000/263981 个血培养窗口
# 已处理 262000/263981 个血培养窗口
# 已处理 263000/263981 个血培养窗口
# 找到 158367 个满足4QAD条件的记录
# 去重后保留 59791 条记录 (去除了 98576 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/Presumed_Infection_List_2017.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/Presumed_Infection_List_2017.txt
#
# === 统计信息 ===
# 总血培养窗口数: 263981
# 满足4QAD条件: 158367 (60.0%)
# 去重后唯一病人数: 59791
#
# Cluster分布:
#   KWC: 14486 个病人 (24.2%)
#   NTEC: 12402 个病人 (20.7%)
#   KEC: 10560 个病人 (17.7%)
#   HKEC: 7469 个病人 (12.5%)
#   NTWC: 6415 个病人 (10.7%)
#   KCC: 5995 个病人 (10.0%)
#   HKWC: 2464 个病人 (4.1%)
#
# === 程序执行完成 ===
