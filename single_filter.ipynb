# %%
import pandas as pd
import os
import glob
import numpy as np
from datetime import datetime, timedelta
import re
import warnings

# %% [markdown]
# ## Blood culture filter & calculate windows period

# %%
# 设置文件夹路径
for year in range(2000, 2026):
    folder_path = f"./presumed_infection/2.Data/Blood_culture/{year}/"

    # 获取所有CSV文件
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

    if not csv_files:
        print("未找到CSV文件")
    else:
        print(f"找到 {len(csv_files)} 个CSV文件")

        all_data = []

        for csv_file in csv_files:
            try:
                # 读取文件
                df = pd.read_csv(csv_file, low_memory=False)
                file_name = os.path.basename(csv_file)

                # 查找筛选列
                filter_col = None
                for col in df.columns:
                    if "Bacterial Culture and ST Within Hospital Stay - Culture Test" in str(col):
                        filter_col = col
                        break

                if filter_col:
                    # 筛选包含Blood的行
                    blood_mask = df[filter_col].astype(str).str.contains("Blood", case=False, na=False)
                    filtered = df.loc[blood_mask]

                    if len(filtered) > 0:
                        # 只保留需要的列
                        columns_to_keep = [
                            "Reference Key",
                            "Institution (IPAS)",
                            "HN Number",
                            "Bacterial Culture and ST Within Hospital Stay - Ref. Date (yyyy-mm-dd HH:MM)"
                        ]

                        # 提取存在的列
                        existing_cols = [col for col in columns_to_keep if col in filtered.columns]

                        if existing_cols:
                            extracted_data = filtered[existing_cols].copy()
                            all_data.append(extracted_data)
                        else:
                            print(f"✗ {file_name}: 缺少必需列")
                    else:
                        print(f"  {file_name}: 无匹配行")
                else:
                    print(f"  {file_name}: 无筛选列")

            except Exception as e:
                print(f"✗ {os.path.basename(csv_file)} 错误: {e}")

        if all_data:
            # 合并数据
            combined = pd.concat(all_data, ignore_index=True)
            # 去除重复项
            before = len(combined)
            combined = combined.drop_duplicates()
            after = len(combined)

            # 处理日期和计算窗口期
            date_col = "Bacterial Culture and ST Within Hospital Stay - Ref. Date (yyyy-mm-dd HH:MM)"

            if date_col in combined.columns:
                # 将日期列转换为datetime类型
                combined[date_col] = pd.to_datetime(combined[date_col], errors='coerce')

                # 只保留年月日（去掉时间部分）
                combined[date_col] = combined[date_col].dt.date

                # 计算窗口期（前后两天）
                combined['window_period_start'] = combined[date_col] - timedelta(days=2)
                combined['window_period_end'] = combined[date_col] + timedelta(days=2)

                # 将所有日期列转换为字符串格式（只保留年月日）
                combined = combined.rename(columns={date_col: 'blood culture date'})
                combined['blood culture date'] = combined['blood culture date'].astype(str)
                combined['window_period_start'] = combined['window_period_start'].astype(str)
                combined['window_period_end'] = combined['window_period_end'].astype(str)

            # 保存结果
            output_path = f"./presumed_infection/2.Data/Window_Period/"
            os.makedirs(output_path, exist_ok=True)
            output_path = os.path.join(output_path, f"bloodculture_filter{year}.csv")
            combined.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# 找到 14 个CSV文件
# 找到 15 个CSV文件
# 找到 14 个CSV文件
# 找到 14 个CSV文件
# 找到 16 个CSV文件
# 找到 14 个CSV文件
# 找到 11 个CSV文件
# 找到 12 个CSV文件
# 找到 13 个CSV文件
# 找到 7 个CSV文件
# 未找到CSV文件
# 未找到CSV文件
# 找到 10 个CSV文件
# 找到 13 个CSV文件
# 找到 15 个CSV文件
# 找到 14 个CSV文件
# 找到 15 个CSV文件
# 找到 34 个CSV文件
# 找到 52 个CSV文件
# 未找到CSV文件
# 找到 6 个CSV文件
# 找到 28 个CSV文件
# 找到 39 个CSV文件
# 找到 26 个CSV文件
# 找到 30 个CSV文件
# 找到 48 个CSV文件

# %% [markdown]
# ## 4QAD

# %%
warnings.filterwarnings('ignore')

def extract_antibiotic_code(drug_item_code):
    if pd.isna(drug_item_code):
        return None

    code_str = str(drug_item_code).strip()
    match = re.match(r'([A-Za-z]+)', code_str)
    if match:
        return match.group(1).upper()
    else:
        return code_str.upper()

def is_vancomycin(antibiotic_code):
    if pd.isna(antibiotic_code):
        return False
    return antibiotic_code.startswith('VANC')

def parse_frequency(freq_str, start_date, end_date):
    if pd.isna(freq_str) or pd.isna(start_date) or pd.isna(end_date):
        return []

    freq = str(freq_str).upper().strip()

    if "EVERY" in freq and "HOURS" in freq:
        numbers = re.findall(r'\d+', freq)
        if numbers:
            interval_hours = int(numbers[0])

            dates = []
            current_time = datetime.combine(start_date, datetime.min.time())
            end_time = datetime.combine(end_date, datetime.min.time()) + timedelta(days=1)

            while current_time <= end_time:
                dates.append(current_time.date())
                current_time += timedelta(hours=interval_hours)

            unique_dates = sorted(set(dates))
            return [d for d in unique_dates if start_date <= d <= end_date]

    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)

    return dates

def load_antibiotics_data(antibiotic_path):
    print("加载抗生素数据...")

    antibiotic_files = glob.glob(os.path.join(antibiotic_path, "*.csv"))
    if not antibiotic_files:
        print(f"错误: 在路径 {antibiotic_path} 下未找到CSV文件")
        return None

    print(f"找到 {len(antibiotic_files)} 个抗生素数据文件")
    all_dfs = []

    for i, file in enumerate(antibiotic_files):
        try:
            df = pd.read_csv(file, low_memory=False)
            required_cols = ['HN Number', 'Prescription Start Date', 'Prescription End Date',
                           'Drug Item Code', 'Route', 'Drug Frequency']
            
            optional_cols = []
            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                optional_cols.append('Dispensing Date (yyyy-mm-dd)')
            if 'Dispensing Duration' in df.columns:
                optional_cols.append('Dispensing Duration')
            
            all_cols = required_cols + optional_cols
            df = df[all_cols].copy()

            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                df['Dispensing Date (yyyy-mm-dd)'] = pd.to_datetime(df['Dispensing Date (yyyy-mm-dd)'], errors='coerce').dt.date

            df['Prescription Start Date'] = pd.to_datetime(df['Prescription Start Date'], errors='coerce').dt.date
            df['Prescription End Date'] = pd.to_datetime(df['Prescription End Date'], errors='coerce').dt.date

            missing_start_mask = df['Prescription Start Date'].isna()
            if 'Dispensing Date (yyyy-mm-dd)' in df.columns:
                df.loc[missing_start_mask, 'Prescription Start Date'] = df.loc[missing_start_mask, 'Dispensing Date (yyyy-mm-dd)']

            if 'Dispensing Duration' in df.columns and 'Prescription Start Date' in df.columns:
                try:
                    df['Dispensing Duration'] = pd.to_numeric(df['Dispensing Duration'], errors='coerce')
                    for idx, row in df.iterrows():
                        if pd.isna(row['Prescription End Date']) and not pd.isna(row['Prescription Start Date']) and not pd.isna(row['Dispensing Duration']):
                            duration_days = int(row['Dispensing Duration'])
                            if duration_days > 0:
                                end_date = row['Prescription Start Date'] + timedelta(days=duration_days)
                                df.at[idx, 'Prescription End Date'] = end_date
                except Exception as e:
                    print(f"  转换Dispensing Duration时出错: {str(e)}")

            df['Antibiotic_Code'] = df['Drug Item Code'].apply(extract_antibiotic_code)
            df['Is_Vancomycin'] = df['Antibiotic_Code'].apply(is_vancomycin)
            all_dfs.append(df)

        except Exception as e:
            print(f"处理文件 {os.path.basename(file)} 时出错: {str(e)}")
            continue

    if not all_dfs:
        print("错误: 没有成功加载任何抗生素数据")
        return None

    antibiotics_df = pd.concat(all_dfs, ignore_index=True)

    print("数据清洗...")
    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Prescription Start Date', 'Prescription End Date'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行日期为空的记录")

    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Antibiotic_Code'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行抗生素代码为空的记录")

    valid_routes = ['PARENTERAL', 'ORAL', 'INTRAVENOUS']
    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df[antibiotics_df['Route'].isin(valid_routes)]
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行给药途径不在{valid_routes}范围内的记录")

    original_count = len(antibiotics_df)
    antibiotics_df = antibiotics_df.dropna(subset=['Route'])
    removed_count = original_count - len(antibiotics_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行Route为空的记录")

    invalid_dates_mask = antibiotics_df['Prescription End Date'] < antibiotics_df['Prescription Start Date']
    if invalid_dates_mask.any():
        invalid_count = invalid_dates_mask.sum()
        antibiotics_df.loc[invalid_dates_mask, ['Prescription Start Date', 'Prescription End Date']] = antibiotics_df.loc[invalid_dates_mask, ['Prescription End Date', 'Prescription Start Date']].values

    print(f"抗生素数据处理完成，共 {len(antibiotics_df)} 行记录")
    return antibiotics_df

def load_window_data(window_path, year):
    print("加载窗口期数据...")

    window_files = glob.glob(os.path.join(window_path, f"*{year}*.csv"))
    if not window_files:
        print(f"错误: 在路径 {window_path} 下未找到CSV文件")
        return None

    print(f"找到 {len(window_files)} 个窗口期数据文件")
    all_dfs = []

    for i, file in enumerate(window_files):
        try:
            df = pd.read_csv(file, low_memory=False)
            all_dfs.append(df)
        except Exception as e:
            print(f"处理文件 {os.path.basename(file)} 时出错: {str(e)}")
            continue

    if not all_dfs:
        print("错误: 没有成功加载任何窗口期数据")
        return None

    window_df = pd.concat(all_dfs, ignore_index=True)
    print(f"窗口期数据加载完成，共 {len(window_df)} 行记录")

    date_cols = ['blood culture date', 'window_period_start', 'window_period_end']
    for col in date_cols:
        if col in window_df.columns:
            window_df[col] = pd.to_datetime(window_df[col], errors='coerce').dt.date
        else:
            print(f"警告: 列 {col} 不存在")

    original_count = len(window_df)
    window_df = window_df.dropna(subset=['blood culture date', 'window_period_start', 'window_period_end', 'HN Number'])
    removed_count = original_count - len(window_df)
    if removed_count > 0:
        print(f"移除了 {removed_count} 行关键信息为空的记录")

    print(f"窗口期数据处理完成，共 {len(window_df)} 行记录")
    return window_df

def create_patient_medication_calendar(antibiotics_df):
    print("创建病人给药日历...")
    patient_calendars = {}
    groups = list(antibiotics_df.groupby('HN Number'))
    total_patients = len(groups)
    print(f"总共 {total_patients} 条住院记录需要处理")

    for i, (hn, group) in enumerate(groups):
        if (i+1) % 500 == 0 or i == 0:
            print(f"处理住院记录 {i+1}/{total_patients}")

        calendar = {}
        for _, row in group.iterrows():
            start_date = row['Prescription Start Date']
            end_date = row['Prescription End Date']
            antibiotic_code = row['Antibiotic_Code']
            route = row['Route']
            frequency = row['Drug Frequency']
            is_vancomycin = row['Is_Vancomycin']

            if end_date < start_date:
                start_date, end_date = end_date, start_date

            try:
                dose_dates = parse_frequency(frequency, start_date, end_date)
                for dose_date in dose_dates:
                    if dose_date not in calendar:
                        calendar[dose_date] = {
                            'drugs': set(),
                            'routes': set(),
                            'drug_info': {}
                        }

                    calendar[dose_date]['drugs'].add(antibiotic_code)
                    calendar[dose_date]['routes'].add(route)

                    if antibiotic_code not in calendar[dose_date]['drug_info']:
                        calendar[dose_date]['drug_info'][antibiotic_code] = {
                            'route': route,
                            'is_vancomycin': is_vancomycin,
                            'first_use_date': dose_date
                        }
            except Exception as e:
                continue

        patient_calendars[hn] = calendar

    print(f"给药日历创建完成，共 {len(patient_calendars)} 条住院记录")
    return patient_calendars

def is_new_antibiotic(antibiotic_code, route, dose_date, patient_calendar, is_vancomycin):
    two_days_ago = dose_date - timedelta(days=2)

    for check_date, med_info in patient_calendar.items():
        if two_days_ago <= check_date < dose_date:
            if antibiotic_code in med_info['drugs']:
                if is_vancomycin:
                    if antibiotic_code in med_info['drug_info']:
                        prev_route = med_info['drug_info'][antibiotic_code]['route']
                        if route == prev_route:
                            return False
                        else:
                            continue
                    else:
                        return False
                else:
                    return False
    return True

def check_4qad_for_window(hn, window_row, patient_calendar):
    window_start = window_row['window_period_start']
    window_end = window_row['window_period_end']

    window_meds = {}
    for date, med_info in patient_calendar.items():
        if window_start <= date <= window_end:
            window_meds[date] = med_info

    if not window_meds:
        return False

    sorted_dates = sorted(window_meds.keys())
    first_new_antibiotic_date = None

    for date in sorted_dates:
        med_info = window_meds[date]
        for antibiotic_code in med_info['drugs']:
            if antibiotic_code in med_info['drug_info']:
                drug_info = med_info['drug_info'][antibiotic_code]
                route = drug_info['route']
                is_vancomycin = drug_info['is_vancomycin']

                if is_new_antibiotic(antibiotic_code, route, date, patient_calendar, is_vancomycin):
                    first_new_antibiotic_date = date
                    break
        if first_new_antibiotic_date:
            break

    if not first_new_antibiotic_date:
        return False

    qad_dates = []
    current_date = first_new_antibiotic_date
    max_gap = 1
    gaps_used = 0
    max_days_to_check = 366

    for _ in range(max_days_to_check):
        if len(qad_dates) >= 4:
            break

        if current_date in patient_calendar:
            qad_dates.append(current_date)
            gaps_used = 0
        else:
            if gaps_used < max_gap:
                gaps_used += 1
            else:
                break
        current_date += timedelta(days=1)

    if len(qad_dates) < 4:
        return False

    has_parenteral = False
    for qad_date in qad_dates[:4]:
        if qad_date in patient_calendar:
            routes = patient_calendar[qad_date]['routes']
            if 'PARENTERAL' in routes or 'INTRAVENOUS' in routes:
                has_parenteral = True
                break

    if not has_parenteral:
        return False

    return True

def add_clusters_column(df):
    cluster_mapping = {}

    hkec_hospitals = ['CHC', 'PYN', 'RH', 'SJH', 'TWE', 'WCH']
    for hospital in hkec_hospitals:
        cluster_mapping[hospital] = 'HKEC'

    hkwc_hospitals = ['DKC', 'FYK', 'GH', 'ML', 'NLH', 'QMH', 'TWH', 'TYH']
    for hospital in hkwc_hospitals:
        cluster_mapping[hospital] = 'HKWC'

    kcc_hospitals = ['BH', 'HCH', 'HKE', 'KH', 'KWH', 'OLM', 'QEH', 'RC', 'WTS']
    for hospital in kcc_hospitals:
        cluster_mapping[hospital] = 'KCC'

    kec_hospitals = ['HHH', 'MT', 'TKO', 'UCH']
    for hospital in kec_hospitals:
        cluster_mapping[hospital] = 'KEC'

    kwc_hospitals = ['CMC', 'KCH', 'LCK', 'NLT', 'PMH', 'YCH']
    for hospital in kwc_hospitals:
        cluster_mapping[hospital] = 'KWC'

    ntec_hospitals = ['AHN', 'BBH', 'CHS', 'NDH', 'PWH', 'SH', 'TPH']
    for hospital in ntec_hospitals:
        cluster_mapping[hospital] = 'NTEC'

    ntwc_hospitals = ['CPH', 'POH', 'SLH', 'TMH', 'TSH']
    for hospital in ntwc_hospitals:
        cluster_mapping[hospital] = 'NTWC'

    df['Clusters'] = df['Institution (IPAS)'].map(cluster_mapping)

    if df['Clusters'].isna().any():
        df['Clusters'] = df['Clusters'].fillna('UNKNOWN')

    return df

def main():
    print("=== 4 QAD Filter 程序开始 ===")

    # Fixed: Added year parameter to loop through years
    for year in range(2001, 2024):
        print(f"\n处理年份: {year}")
        
        antibiotic_path = f"./presumed_infection/2.Data/Microbial/{year}/"
        window_path = f"./presumed_infection/2.Data/Window_Period/"
        output_path_csv = f"./presumed_infection/2.Data/Output/Presumedinfection_csv/"
        output_path_txt = f"./presumed_infection/2.Data/Output/Presumedinfection_txt/"

        # Create output directories if they don't exist
        for path in [output_path_csv, output_path_txt]:
            if not os.path.exists(path):
                os.makedirs(path, exist_ok=True)

        # Load data
        antibiotics_df = load_antibiotics_data(antibiotic_path)
        if antibiotics_df is None or len(antibiotics_df) == 0:
            print(f"年份 {year}: 无法加载抗生素数据或数据为空，跳过")
            continue

        window_df = load_window_data(window_path, year)
        if window_df is None or len(window_df) == 0:
            print(f"年份 {year}: 无法加载窗口期数据或数据为空，跳过")
            continue

        # Create medication calendar
        patient_calendars = create_patient_medication_calendar(antibiotics_df)

        # Check 4QAD conditions
        met_4qad_indices = []
        total_windows = len(window_df)
        print("检查4QAD条件...")
        
        for idx, window_row in window_df.iterrows():
            hn = window_row['HN Number']
            if hn not in patient_calendars:
                continue

            if check_4qad_for_window(hn, window_row, patient_calendars[hn]):
                met_4qad_indices.append(idx)

            if (idx + 1) % 1000 == 0:
                print(f"已处理 {idx + 1}/{total_windows} 个血培养窗口")

        # Extract results
        if met_4qad_indices:
            results_df = window_df.iloc[met_4qad_indices].copy()
            print(f"找到 {len(results_df)} 个满足4QAD条件的记录")
        else:
            print("没有找到满足4QAD条件的记录")
            continue

        # Add Clusters column
        results_df = add_clusters_column(results_df)

        # Select and deduplicate
        selected_columns = ['Reference Key', 'Institution (IPAS)', 'HN Number', 'Clusters']
        if all(col in results_df.columns for col in selected_columns):
            final_df = results_df[selected_columns].copy()
            
            original_count = len(final_df)
            final_df = final_df.drop_duplicates(subset=['HN Number'], keep='first')
            print(f"去重后保留 {len(final_df)} 条记录 (去除了 {original_count - len(final_df)} 条重复记录)")

            # Save results
            csv_file = os.path.join(output_path_csv, f"Presumed_Infection_List_{year}.csv")
            final_df.to_csv(csv_file, index=False)
            print(f"CSV文件已保存: {csv_file}")

            txt_file = os.path.join(output_path_txt, f"Presumed_Infection_List_{year}.txt")
            txt_columns = ['Reference Key', 'Institution (IPAS)', 'HN Number']
            if all(col in final_df.columns for col in txt_columns):
                txt_df = final_df[txt_columns].copy()
                txt_df.to_csv(txt_file, sep='\t', index=False)
                print(f"TXT文件已保存: {txt_file}")

            # Statistics
            print(f"\n=== 统计信息 ===")
            print(f"总血培养窗口数: {total_windows}")
            print(f"满足4QAD条件: {len(results_df)} ({len(results_df)/total_windows*100:.1f}%)")
            print(f"去重后唯一病人数: {len(final_df)}")

            if 'Clusters' in final_df.columns and len(final_df) > 0:
                print("\nCluster分布:")
                cluster_counts = final_df['Clusters'].value_counts()
                total_patients = len(final_df)
                for cluster, count in cluster_counts.items():
                    print(f"  {cluster}: {count} 个病人 ({count/total_patients*100:.1f}%)")
        else:
            print("错误: 数据中缺少必要的列")

    print("\n=== 程序执行完成 ===")
    return None

if __name__ == "__main__":
    try:
        results_df = main()
    except Exception as e:
        print(f"程序执行出错: {str(e)}")
        import traceback
        traceback.print_exc()
# Out:
# === 4 QAD Filter 程序开始 ===
#
# 处理年份: 2001
# 加载抗生素数据...
# 找到 22 个抗生素数据文件
# 数据清洗...
# 移除了 379236 行日期为空的记录
# 移除了 242127 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 171630 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 88976 行记录
# 窗口期数据处理完成，共 88976 行记录
# 创建病人给药日历...
# 总共 33410 条住院记录需要处理
# 处理住院记录 1/33410
# 处理住院记录 500/33410
# 处理住院记录 1000/33410
# 处理住院记录 1500/33410
# 处理住院记录 2000/33410
# 处理住院记录 2500/33410
# 处理住院记录 3000/33410
# 处理住院记录 3500/33410
# 处理住院记录 4000/33410
# 处理住院记录 4500/33410
# 处理住院记录 5000/33410
# 处理住院记录 5500/33410
# 处理住院记录 6000/33410
# 处理住院记录 6500/33410
# 处理住院记录 7000/33410
# 处理住院记录 7500/33410
# 处理住院记录 8000/33410
# 处理住院记录 8500/33410
# 处理住院记录 9000/33410
# 处理住院记录 9500/33410
# 处理住院记录 10000/33410
# 处理住院记录 10500/33410
# 处理住院记录 11000/33410
# 处理住院记录 11500/33410
# 处理住院记录 12000/33410
# 处理住院记录 12500/33410
# 处理住院记录 13000/33410
# 处理住院记录 13500/33410
# 处理住院记录 14000/33410
# 处理住院记录 14500/33410
# 处理住院记录 15000/33410
# 处理住院记录 15500/33410
# 处理住院记录 16000/33410
# 处理住院记录 16500/33410
# 处理住院记录 17000/33410
# 处理住院记录 17500/33410
# 处理住院记录 18000/33410
# 处理住院记录 18500/33410
# 处理住院记录 19000/33410
# 处理住院记录 19500/33410
# 处理住院记录 20000/33410
# 处理住院记录 20500/33410
# 处理住院记录 21000/33410
# 处理住院记录 21500/33410
# 处理住院记录 22000/33410
# 处理住院记录 22500/33410
# 处理住院记录 23000/33410
# 处理住院记录 23500/33410
# 处理住院记录 24000/33410
# 处理住院记录 24500/33410
# 处理住院记录 25000/33410
# 处理住院记录 25500/33410
# 处理住院记录 26000/33410
# 处理住院记录 26500/33410
# 处理住院记录 27000/33410
# 处理住院记录 27500/33410
# 处理住院记录 28000/33410
# 处理住院记录 28500/33410
# 处理住院记录 29000/33410
# 处理住院记录 29500/33410
# 处理住院记录 30000/33410
# 处理住院记录 30500/33410
# 处理住院记录 31000/33410
# 处理住院记录 31500/33410
# 处理住院记录 32000/33410
# 处理住院记录 32500/33410
# 处理住院记录 33000/33410
# 给药日历创建完成，共 33410 条住院记录
# 检查4QAD条件...
# 已处理 1000/88976 个血培养窗口
# 已处理 2000/88976 个血培养窗口
# 已处理 3000/88976 个血培养窗口
# 已处理 9000/88976 个血培养窗口
# 已处理 15000/88976 个血培养窗口
# 已处理 19000/88976 个血培养窗口
# 已处理 23000/88976 个血培养窗口
# 已处理 24000/88976 个血培养窗口
# 已处理 25000/88976 个血培养窗口
# 已处理 29000/88976 个血培养窗口
# 已处理 33000/88976 个血培养窗口
# 已处理 35000/88976 个血培养窗口
# 已处理 39000/88976 个血培养窗口
# 已处理 41000/88976 个血培养窗口
# 已处理 44000/88976 个血培养窗口
# 已处理 51000/88976 个血培养窗口
# 已处理 53000/88976 个血培养窗口
# 已处理 56000/88976 个血培养窗口
# 已处理 62000/88976 个血培养窗口
# 已处理 63000/88976 个血培养窗口
# 已处理 64000/88976 个血培养窗口
# 已处理 65000/88976 个血培养窗口
# 已处理 70000/88976 个血培养窗口
# 已处理 73000/88976 个血培养窗口
# 已处理 76000/88976 个血培养窗口
# 已处理 78000/88976 个血培养窗口
# 已处理 79000/88976 个血培养窗口
# 已处理 81000/88976 个血培养窗口
# 已处理 84000/88976 个血培养窗口
# 已处理 85000/88976 个血培养窗口
# 找到 190 个满足4QAD条件的记录
# 去重后保留 125 条记录 (去除了 65 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2001/Presumed_Infection_List_2001.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2001/Presumed_Infection_List_2001.txt
#
# === 统计信息 ===
# 总血培养窗口数: 88976
# 满足4QAD条件: 190 (0.2%)
# 去重后唯一病人数: 125
#
# Cluster分布:
#   KCC: 59 个病人 (47.2%)
#   HKEC: 26 个病人 (20.8%)
#   NTEC: 21 个病人 (16.8%)
#   NTWC: 9 个病人 (7.2%)
#   KWC: 5 个病人 (4.0%)
#   KEC: 5 个病人 (4.0%)
#
# 处理年份: 2002
# 加载抗生素数据...
# 找到 16 个抗生素数据文件
# 数据清洗...
# 移除了 51085 行日期为空的记录
# 移除了 369164 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 269814 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 105822 行记录
# 窗口期数据处理完成，共 105822 行记录
# 创建病人给药日历...
# 总共 50558 条住院记录需要处理
# 处理住院记录 1/50558
# 处理住院记录 500/50558
# 处理住院记录 1000/50558
# 处理住院记录 1500/50558
# 处理住院记录 2000/50558
# 处理住院记录 2500/50558
# 处理住院记录 3000/50558
# 处理住院记录 3500/50558
# 处理住院记录 4000/50558
# 处理住院记录 4500/50558
# 处理住院记录 5000/50558
# 处理住院记录 5500/50558
# 处理住院记录 6000/50558
# 处理住院记录 6500/50558
# 处理住院记录 7000/50558
# 处理住院记录 7500/50558
# 处理住院记录 8000/50558
# 处理住院记录 8500/50558
# 处理住院记录 9000/50558
# 处理住院记录 9500/50558
# 处理住院记录 10000/50558
# 处理住院记录 10500/50558
# 处理住院记录 11000/50558
# 处理住院记录 11500/50558
# 处理住院记录 12000/50558
# 处理住院记录 12500/50558
# 处理住院记录 13000/50558
# 处理住院记录 13500/50558
# 处理住院记录 14000/50558
# 处理住院记录 14500/50558
# 处理住院记录 15000/50558
# 处理住院记录 15500/50558
# 处理住院记录 16000/50558
# 处理住院记录 16500/50558
# 处理住院记录 17000/50558
# 处理住院记录 17500/50558
# 处理住院记录 18000/50558
# 处理住院记录 18500/50558
# 处理住院记录 19000/50558
# 处理住院记录 19500/50558
# 处理住院记录 20000/50558
# 处理住院记录 20500/50558
# 处理住院记录 21000/50558
# 处理住院记录 21500/50558
# 处理住院记录 22000/50558
# 处理住院记录 22500/50558
# 处理住院记录 23000/50558
# 处理住院记录 23500/50558
# 处理住院记录 24000/50558
# 处理住院记录 24500/50558
# 处理住院记录 25000/50558
# 处理住院记录 25500/50558
# 处理住院记录 26000/50558
# 处理住院记录 26500/50558
# 处理住院记录 27000/50558
# 处理住院记录 27500/50558
# 处理住院记录 28000/50558
# 处理住院记录 28500/50558
# 处理住院记录 29000/50558
# 处理住院记录 29500/50558
# 处理住院记录 30000/50558
# 处理住院记录 30500/50558
# 处理住院记录 31000/50558
# 处理住院记录 31500/50558
# 处理住院记录 32000/50558
# 处理住院记录 32500/50558
# 处理住院记录 33000/50558
# 处理住院记录 33500/50558
# 处理住院记录 34000/50558
# 处理住院记录 34500/50558
# 处理住院记录 35000/50558
# 处理住院记录 35500/50558
# 处理住院记录 36000/50558
# 处理住院记录 36500/50558
# 处理住院记录 37000/50558
# 处理住院记录 37500/50558
# 处理住院记录 38000/50558
# 处理住院记录 38500/50558
# 处理住院记录 39000/50558
# 处理住院记录 39500/50558
# 处理住院记录 40000/50558
# 处理住院记录 40500/50558
# 处理住院记录 41000/50558
# 处理住院记录 41500/50558
# 处理住院记录 42000/50558
# 处理住院记录 42500/50558
# 处理住院记录 43000/50558
# 处理住院记录 43500/50558
# 处理住院记录 44000/50558
# 处理住院记录 44500/50558
# 处理住院记录 45000/50558
# 处理住院记录 45500/50558
# 处理住院记录 46000/50558
# 处理住院记录 46500/50558
# 处理住院记录 47000/50558
# 处理住院记录 47500/50558
# 处理住院记录 48000/50558
# 处理住院记录 48500/50558
# 处理住院记录 49000/50558
# 处理住院记录 49500/50558
# 处理住院记录 50000/50558
# 处理住院记录 50500/50558
# 给药日历创建完成，共 50558 条住院记录
# 检查4QAD条件...
# 已处理 1000/105822 个血培养窗口
# 已处理 2000/105822 个血培养窗口
# 已处理 4000/105822 个血培养窗口
# 已处理 6000/105822 个血培养窗口
# 已处理 8000/105822 个血培养窗口
# 已处理 9000/105822 个血培养窗口
# 已处理 10000/105822 个血培养窗口
# 已处理 11000/105822 个血培养窗口
# 已处理 13000/105822 个血培养窗口
# 已处理 15000/105822 个血培养窗口
# 已处理 16000/105822 个血培养窗口
# 已处理 19000/105822 个血培养窗口
# 已处理 20000/105822 个血培养窗口
# 已处理 21000/105822 个血培养窗口
# 已处理 38000/105822 个血培养窗口
# 已处理 41000/105822 个血培养窗口
# 已处理 42000/105822 个血培养窗口
# 已处理 43000/105822 个血培养窗口
# 已处理 44000/105822 个血培养窗口
# 已处理 45000/105822 个血培养窗口
# 已处理 56000/105822 个血培养窗口
# 已处理 57000/105822 个血培养窗口
# 已处理 58000/105822 个血培养窗口
# 已处理 59000/105822 个血培养窗口
# 已处理 70000/105822 个血培养窗口
# 已处理 71000/105822 个血培养窗口
# 已处理 73000/105822 个血培养窗口
# 已处理 74000/105822 个血培养窗口
# 已处理 77000/105822 个血培养窗口
# 已处理 78000/105822 个血培养窗口
# 已处理 79000/105822 个血培养窗口
# 已处理 82000/105822 个血培养窗口
# 已处理 100000/105822 个血培养窗口
# 已处理 102000/105822 个血培养窗口
# 已处理 103000/105822 个血培养窗口
# 已处理 105000/105822 个血培养窗口
# 找到 440 个满足4QAD条件的记录
# 去重后保留 303 条记录 (去除了 137 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2002/Presumed_Infection_List_2002.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2002/Presumed_Infection_List_2002.txt
#
# === 统计信息 ===
# 总血培养窗口数: 105822
# 满足4QAD条件: 440 (0.4%)
# 去重后唯一病人数: 303
#
# Cluster分布:
#   KCC: 66 个病人 (21.8%)
#   NTEC: 60 个病人 (19.8%)
#   HKEC: 55 个病人 (18.2%)
#   KWC: 54 个病人 (17.8%)
#   NTWC: 34 个病人 (11.2%)
#   KEC: 34 个病人 (11.2%)
#
# 处理年份: 2003
# 加载抗生素数据...
# 找到 20 个抗生素数据文件
# 数据清洗...
# 移除了 2 行日期为空的记录
# 移除了 491700 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 477080 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 122894 行记录
# 窗口期数据处理完成，共 122894 行记录
# 创建病人给药日历...
# 总共 78446 条住院记录需要处理
# 处理住院记录 1/78446
# 处理住院记录 500/78446
# 处理住院记录 1000/78446
# 处理住院记录 1500/78446
# 处理住院记录 2000/78446
# 处理住院记录 2500/78446
# 处理住院记录 3000/78446
# 处理住院记录 3500/78446
# 处理住院记录 4000/78446
# 处理住院记录 4500/78446
# 处理住院记录 5000/78446
# 处理住院记录 5500/78446
# 处理住院记录 6000/78446
# 处理住院记录 6500/78446
# 处理住院记录 7000/78446
# 处理住院记录 7500/78446
# 处理住院记录 8000/78446
# 处理住院记录 8500/78446
# 处理住院记录 9000/78446
# 处理住院记录 9500/78446
# 处理住院记录 10000/78446
# 处理住院记录 10500/78446
# 处理住院记录 11000/78446
# 处理住院记录 11500/78446
# 处理住院记录 12000/78446
# 处理住院记录 12500/78446
# 处理住院记录 13000/78446
# 处理住院记录 13500/78446
# 处理住院记录 14000/78446
# 处理住院记录 14500/78446
# 处理住院记录 15000/78446
# 处理住院记录 15500/78446
# 处理住院记录 16000/78446
# 处理住院记录 16500/78446
# 处理住院记录 17000/78446
# 处理住院记录 17500/78446
# 处理住院记录 18000/78446
# 处理住院记录 18500/78446
# 处理住院记录 19000/78446
# 处理住院记录 19500/78446
# 处理住院记录 20000/78446
# 处理住院记录 20500/78446
# 处理住院记录 21000/78446
# 处理住院记录 21500/78446
# 处理住院记录 22000/78446
# 处理住院记录 22500/78446
# 处理住院记录 23000/78446
# 处理住院记录 23500/78446
# 处理住院记录 24000/78446
# 处理住院记录 24500/78446
# 处理住院记录 25000/78446
# 处理住院记录 25500/78446
# 处理住院记录 26000/78446
# 处理住院记录 26500/78446
# 处理住院记录 27000/78446
# 处理住院记录 27500/78446
# 处理住院记录 28000/78446
# 处理住院记录 28500/78446
# 处理住院记录 29000/78446
# 处理住院记录 29500/78446
# 处理住院记录 30000/78446
# 处理住院记录 30500/78446
# 处理住院记录 31000/78446
# 处理住院记录 31500/78446
# 处理住院记录 32000/78446
# 处理住院记录 32500/78446
# 处理住院记录 33000/78446
# 处理住院记录 33500/78446
# 处理住院记录 34000/78446
# 处理住院记录 34500/78446
# 处理住院记录 35000/78446
# 处理住院记录 35500/78446
# 处理住院记录 36000/78446
# 处理住院记录 36500/78446
# 处理住院记录 37000/78446
# 处理住院记录 37500/78446
# 处理住院记录 38000/78446
# 处理住院记录 38500/78446
# 处理住院记录 39000/78446
# 处理住院记录 39500/78446
# 处理住院记录 40000/78446
# 处理住院记录 40500/78446
# 处理住院记录 41000/78446
# 处理住院记录 41500/78446
# 处理住院记录 42000/78446
# 处理住院记录 42500/78446
# 处理住院记录 43000/78446
# 处理住院记录 43500/78446
# 处理住院记录 44000/78446
# 处理住院记录 44500/78446
# 处理住院记录 45000/78446
# 处理住院记录 45500/78446
# 处理住院记录 46000/78446
# 处理住院记录 46500/78446
# 处理住院记录 47000/78446
# 处理住院记录 47500/78446
# 处理住院记录 48000/78446
# 处理住院记录 48500/78446
# 处理住院记录 49000/78446
# 处理住院记录 49500/78446
# 处理住院记录 50000/78446
# 处理住院记录 50500/78446
# 处理住院记录 51000/78446
# 处理住院记录 51500/78446
# 处理住院记录 52000/78446
# 处理住院记录 52500/78446
# 处理住院记录 53000/78446
# 处理住院记录 53500/78446
# 处理住院记录 54000/78446
# 处理住院记录 54500/78446
# 处理住院记录 55000/78446
# 处理住院记录 55500/78446
# 处理住院记录 56000/78446
# 处理住院记录 56500/78446
# 处理住院记录 57000/78446
# 处理住院记录 57500/78446
# 处理住院记录 58000/78446
# 处理住院记录 58500/78446
# 处理住院记录 59000/78446
# 处理住院记录 59500/78446
# 处理住院记录 60000/78446
# 处理住院记录 60500/78446
# 处理住院记录 61000/78446
# 处理住院记录 61500/78446
# 处理住院记录 62000/78446
# 处理住院记录 62500/78446
# 处理住院记录 63000/78446
# 处理住院记录 63500/78446
# 处理住院记录 64000/78446
# 处理住院记录 64500/78446
# 处理住院记录 65000/78446
# 处理住院记录 65500/78446
# 处理住院记录 66000/78446
# 处理住院记录 66500/78446
# 处理住院记录 67000/78446
# 处理住院记录 67500/78446
# 处理住院记录 68000/78446
# 处理住院记录 68500/78446
# 处理住院记录 69000/78446
# 处理住院记录 69500/78446
# 处理住院记录 70000/78446
# 处理住院记录 70500/78446
# 已处理 77000/122894 个血培养窗口
# 已处理 78000/122894 个血培养窗口
# 已处理 79000/122894 个血培养窗口
# 已处理 81000/122894 个血培养窗口
# 已处理 82000/122894 个血培养窗口
# 已处理 83000/122894 个血培养窗口
# 已处理 84000/122894 个血培养窗口
# 已处理 98000/122894 个血培养窗口
# 已处理 99000/122894 个血培养窗口
# 已处理 102000/122894 个血培养窗口
# 已处理 105000/122894 个血培养窗口
# 已处理 106000/122894 个血培养窗口
# 已处理 107000/122894 个血培养窗口
# 已处理 108000/122894 个血培养窗口
# 已处理 109000/122894 个血培养窗口
# 找到 7278 个满足4QAD条件的记录
# 去重后保留 5479 条记录 (去除了 1799 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2003/Presumed_Infection_List_2003.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2003/Presumed_Infection_List_2003.txt
#
# === 统计信息 ===
# 总血培养窗口数: 122894
# 满足4QAD条件: 7278 (5.9%)
# 去重后唯一病人数: 5479
#
# Cluster分布:
#   KCC: 2062 个病人 (37.6%)
#   KWC: 982 个病人 (17.9%)
#   NTEC: 951 个病人 (17.4%)
#   HKEC: 720 个病人 (13.1%)
#   KEC: 713 个病人 (13.0%)
#   HKWC: 51 个病人 (0.9%)
#
# 处理年份: 2004
# 加载抗生素数据...
# 找到 21 个抗生素数据文件
# 数据清洗...
# 移除了 576913 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 570270 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 149685 行记录
# 窗口期数据处理完成，共 149685 行记录
# 创建病人给药日历...
# 总共 110540 条住院记录需要处理
# 处理住院记录 1/110540
# 处理住院记录 500/110540
# 处理住院记录 1000/110540
# 处理住院记录 1500/110540
# 处理住院记录 2000/110540
# 处理住院记录 2500/110540
# 处理住院记录 3000/110540
# 处理住院记录 3500/110540
# 处理住院记录 4000/110540
# 处理住院记录 4500/110540
# 处理住院记录 5000/110540
# 处理住院记录 5500/110540
# 处理住院记录 6000/110540
# 处理住院记录 6500/110540
# 处理住院记录 7000/110540
# 处理住院记录 7500/110540
# 处理住院记录 8000/110540
# 处理住院记录 8500/110540
# 处理住院记录 9000/110540
# 处理住院记录 9500/110540
# 处理住院记录 10000/110540
# 处理住院记录 10500/110540
# 处理住院记录 11000/110540
# 处理住院记录 11500/110540
# 处理住院记录 12000/110540
# 处理住院记录 12500/110540
# 处理住院记录 13000/110540
# 处理住院记录 13500/110540
# 处理住院记录 14000/110540
# 处理住院记录 14500/110540
# 处理住院记录 15000/110540
# 处理住院记录 15500/110540
# 处理住院记录 16000/110540
# 处理住院记录 16500/110540
# 处理住院记录 17000/110540
# 处理住院记录 17500/110540
# 处理住院记录 18000/110540
# 处理住院记录 18500/110540
# 处理住院记录 19000/110540
# 处理住院记录 19500/110540
# 处理住院记录 20000/110540
# 处理住院记录 20500/110540
# 处理住院记录 21000/110540
# 处理住院记录 21500/110540
# 处理住院记录 22000/110540
# 处理住院记录 22500/110540
# 处理住院记录 23000/110540
# 处理住院记录 23500/110540
# 处理住院记录 24000/110540
# 处理住院记录 24500/110540
# 处理住院记录 25000/110540
# 处理住院记录 25500/110540
# 处理住院记录 26000/110540
# 处理住院记录 26500/110540
# 处理住院记录 27000/110540
# 处理住院记录 27500/110540
条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2004/Presumed_Infection_List_2004.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2004/Presumed_Infection_List_2004.txt
#
# === 统计信息 ===
# 总血培养窗口数: 149685
# 满足4QAD条件: 10374 (6.9%)
# 去重后唯一病人数: 7775
#
# Cluster分布:
#   NTEC: 2063 个病人 (26.5%)
#   KCC: 1717 个病人 (22.1%)
#   KWC: 1148 个病人 (14.8%)
#   NTWC: 1039 个病人 (13.4%)
#   KEC: 847 个病人 (10.9%)
#   HKEC: 802 个病人 (10.3%)
#   HKWC: 159 个病人 (2.0%)
#
# 处理年份: 2005
# 加载抗生素数据...
# 找到 21 个抗生素数据文件
# 数据清洗...
# 移除了 590377 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 605680 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 152747 行记录
# 窗口期数据处理完成，共 152747 行记录
# 创建病人给药日历...
# 总共 121420 条住院记录需要处理
# 处理住院记录 1/121420
# 处理住院记录 500/121420
# 处理住院记录 1000/121420
# 处理住院记录 1500/121420
# 处理住院记录 2000/121420
# 处理住院记录 2500/121420
# 处理住院记录 3000/121420
# 处理住院记录 3500/121420
# 处理住院记录 4000/121420
# 处理住院记录 4500/121420
# 处理住院记录 5000/121420
# 处理住院记录 5500/121420
# 处理住院记录 6000/121420
# 处理住院记录 6500/121420
# 处理住院记录 7000/121420
# 处理住院记录 7500/121420
# 处理住院记录 8000/121420
# 处理住院记录 8500/121420
# 处理住院记录 9000/121420
# 处理住院记录 9500/121420
# 处理住院记录 10000/121420
# 处理住院记录 10500/121420
# 处理住院记录 11000/121420
# 处理住院记录 11500/121420
# 处理住院记录 12000/121420
# 处理住院记录 12500/121420
# 处理住院记录 13000/121420
# 处理住院记录 13500/121420
# 处理住院记录 14000/121420
# 处理住院记录 14500/121420
# 处理住院记录 15000/121420
# 处理住院记录 15500/121420
# 处理住院记录 16000/121420
# 处理住院记录 16500/121420
# 处理住院记录 17000/121420
# 处理住院记录 17500/121420
# 处理住院记录 18000/121420
# 处理住院记录 18500/121420
# 处理住院记录 19000/121420
# 处理住院记录 19500/121420
# 处理住院记录 20000/121420
# 处理住院记录 20500/121420
# 处理住院记录 21000/121420
# 处理住院记录 21500/121420
# 处理住院记录 22000/121420
# 处理住院记录 22500/121420
# 处理住院记录 23000/121420
# 处理住院记录 23500/121420
# 处理住院记录 24000/121420
# 处理住院记录 24500/121420
# 处理住院记录 25000/121420
# 处理住院记录 25500/121420
# 处理住院记录 26000/121420
# 处理住院记录 26500/121420
# 处理住院记录 27000/121420
# 处理住院记录 27500/121420
# 处理住院记录 28000/121420
# 处理住院记录 28500/121420
# 处理住院记录 29000/121420
# 处理住院记录 29500/121420
# 处理住院记录 30000/121420
# 处理住院记录 30500/121420
# 处理住院记录 31000/121420
# 处理住院记录 31500/121420
# 处理住院记录 32000/121420
# 处理住院记录 32500/121420
# 处理住院记录 33000/121420
# 处理住院记录 33500/121420
# 处理住院记录 34000/121420
# 已处理 134000/152747 个血培养窗口
# 已处理 135000/152747 个血培养窗口
# 已处理 136000/152747 个血培养窗口
# 已处理 137000/152747 个血培养窗口
# 已处理 138000/152747 个血培养窗口
# 已处理 140000/152747 个血培养窗口
# 已处理 141000/152747 个血培养窗口
# 已处理 142000/152747 个血培养窗口
# 已处理 143000/152747 个血培养窗口
# 已处理 144000/152747 个血培养窗口
# 已处理 145000/152747 个血培养窗口
# 已处理 147000/152747 个血培养窗口
# 已处理 148000/152747 个血培养窗口
# 已处理 149000/152747 个血培养窗口
# 已处理 150000/152747 个血培养窗口
# 已处理 151000/152747 个血培养窗口
# 已处理 152000/152747 个血培养窗口
# 找到 11153 个满足4QAD条件的记录
# 去重后保留 8328 条记录 (去除了 2825 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2005/Presumed_Infection_List_2005.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2005/Presumed_Infection_List_2005.txt
#
# === 统计信息 ===
# 总血培养窗口数: 152747
# 满足4QAD条件: 11153 (7.3%)
# 去重后唯一病人数: 8328
#
# Cluster分布:
#   NTEC: 1842 个病人 (22.1%)
#   KCC: 1645 个病人 (19.8%)
#   KWC: 1306 个病人 (15.7%)
#   NTWC: 1254 个病人 (15.1%)
#   HKEC: 1085 个病人 (13.0%)
#   KEC: 1030 个病人 (12.4%)
#   HKWC: 166 个病人 (2.0%)
#
# 处理年份: 2006
# 加载抗生素数据...
# 找到 21 个抗生素数据文件
# 数据清洗...
# 移除了 580091 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 581028 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 105321 行记录
# 窗口期数据处理完成，共 105321 行记录
# 创建病人给药日历...
# 总共 114966 条住院记录需要处理
# 处理住院记录 1/114966
# 处理住院记录 500/114966
# 处理住院记录 1000/114966
# 处理住院记录 1500/114966
# 处理住院记录 2000/114966
# 处理住院记录 2500/114966
# 处理住院记录 3000/114966
# 处理住院记录 3500/114966
# 处理住院记录 4000/114966
# 处理住院记录 4500/114966
# 处理住院记录 5000/114966
# 处理住院记录 5500/114966
# 处理住院记录 6000/114966
# 处理住院记录 6500/114966
# 处理住院记录 7000/114966
# 处理住院记录 7500/114966
# 处理住院记录 8000/114966
# 处理住院记录 8500/114966
# 处理住院记录 9000/114966
# 处理住院记录 9500/114966
# 处理住院记录 10000/114966
# 处理住院记录 10500/114966
# 处理住院记录 11000/114966
# 处理住院记录 11500/114966
# 处理住院记录 12000/114966
# 处理住院记录 12500/114966
# 处理住院记录 13000/114966
# 处理住院记录 13500/114966
# 处理住院记录 14000/114966
# 处理住院记录 14500/114966
# 处理住院记录 15000/114966
# 处理住院记录 15500/114966
# 处理住院记录 16000/114966
# 处理住院记录 16500/114966
# 处理住院记录 17000/114966
# 处理住院记录 17500/114966
# 处理住院记录 18000/114966
# 处理住院记录 18500/114966
# 处理住院记录 19000/114966
# 处理住院记录 19500/114966
# 处理住院记录 20000/114966
# 处理住院记录 20500/114966
# 处理住院记录 21000/114966
# 处理住院记录 21500/114966
# 处理住院记录 22000/114966
# 处理住院记录 22500/114966
# 处理住院记录 23000/114966
# 处理住院记录 23500/114966
# 处理住院记录 24000/114966
# 处理住院记录 24500/114966
# 处理住院记录 25000/114966
# 处理住院记录 25500/114966
# 处理住院记录 26000/114966
# 处理住院记录 26500/114966
# 处理住院记录 27000/114966
# 处理住院记录 27500/114966
# 处理住院记录 28000/114966
# 处理住院记录 28500/114966
# 处理住院记录 29000/114966
# 处理住院记录 29500/114966
# 处理住院记录 30000/114966
# 处理住院记录 30500/114966
# 处理住院记录 31000/114966
# 处理住院记录 31500/114966
# 处理住院记录 32000/114966
# 处理住院记录 32500/114966
# 处理住院记录 33000/114966
# 处理住院记录 33500/114966
# 处理住院记录 34000/114966
# 处理住院记录 34500/114966
# 处理住院记录 35000/114966
# 处理住院记录 35500/114966
# 处理住院记录 36000/114966
# 处理住院记录 36500/114966
# 处理住院记录 37000/114966
# 处理住院记录 37500/114966
# 处理住院记录 38000/114966
# 处理住院记录 38500/114966
# 处理住院记录 39000/114966
# 处理住院记录 39500/114966
# 处理住院记录 40000/114966
# 处理住院记录 40500/114966
# 处理住院记录 41000/114966
# 处理住院记录 41500/114966
# 处理住院记录 42000/114966
# 处理住院记录 42500/114966
# 处理住院记录 43000/114966
# 处理住院记录 43500/114966
# 处理住院记录 44000/114966
# 处理住院记录 44500/114966
# 处理住院记录 45000/114966
# 处理住院记录 45500/114966
# 处理住院记录 46000/114966
# 处理住院记录 46500/114966
# 处理住院记录 47000/114966
# 处理住院记录 47500/114966
# 处理住院记录 48000/114966
# 处理住院记录 48500/114966
# 处理住院记录 49000/114966
# 处理住院记录 49500/114966
# 处理住院记录 50000/114966
# 处理住院记录 50500/114966
# 处理住院记录 51000/114966
# 处理住院记录 51500/114966
# 处理住院记录 52000/114966
# 处理住院记录 52500/114966
# 处理住院记录 53000/114966
# 处理住院记录 53500/114966
# 处理住院记录 54000/114966
# 处理住院记录 54500/114966
# 处理住院记录 55000/114966
# 处理住院记录 55500/114966
# 处理住院记录 56000/114966
# 处理住院记录 56500/114966
# 处理住院记录 57000/114966
# 处理住院记录 57500/114966
# 处理住院记录 58000/114966
# 处理住院记录 58500/114966
# 处理住院记录 59000/114966
# 处理住院记录 59500/114966
# 处理住院记录 60000/114966
# 处理住院记录 60500/114966
# 处理住院记录 61000/114966
# 处理住院记录 61500/114966
# 处理住院记录 62000/114966
# 处理住院记录 62500/114966
# 处理住院记录 63000/114966
# 处理住院记录 63500/114966
# 处理住院记录 64000/114966
# 处理住院记录 64500/114966
# 处理住院记录 65000/114966
# 处理住院记录 65500/114966
# 处理住院记录 66000/114966
# 处理住院记录 66500/114966
# 处理住院记录 67000/114966
# 处理住院记录 67500/114966
# 处理住院记录 68000/114966
# 处理住院记录 68500/114966
# 处理住院记录 69000/114966
# 处理住院记录 69500/114966
# 处理住院记录 70000/114966
# 处理住院记录 70500/114966
# 处理住院记录 71000/114966
# 处理住院记录 71500/114966
# 处理住院记录 72000/114966
# 处理住院记录 72500/114966
# 处理住院记录 73000/114966
# 处理住院记录 73500/114966
# 处理住院记录 74000/114966
# 处理住院记录 74500/114966
# 处理住院记录 75000/114966
# 处理住院记录 75500/114966
# 处理住院记录 76000/114966
# 处理住院记录 76500/114966
# 处理住院记录 77000/114966
# 处理住院记录 77500/114966
# 处理住院记录 78000/114966
# 处理住院记录 78500/114966
# 处理住院记录 79000/114966
# 处理住院记录 79500/114966
# 处理住院记录 80000/114966
# 处理住院记录 80500/114966
# 处理住院记录 81000/114966
# 处理住院记录 81500/114966
# 处理住院记录 82000/114966
# 处理住院记录 82500/114966
# 处理住院记录 83000/114966
# 处理住院记录 83500/114966
# 处理住院记录 84000/114966
# 处理住院记录 84500/114966
# 处理住院记录 85000/114966
# 处理住院记录 85500/114966
# 处理住院记录 86000/114966
# 处理住院记录 86500/114966
# 处理住院记录 87000/114966
# 处理住院记录 87500/114966
# 处理住院记录 88000/114966
# 处理住院记录 88500/114966
# 处理住院记录 89000/114966
# 处理住院记录 89500/114966
# 处理住院记录 90000/114966
# 处理住院记录 90500/114966
# 处理住院记录 91000/114966
# 处理住院记录 91500/114966
# 处理住院记录 92000/114966
# 处理住院记录 92500/114966
# 处理住院记录 93000/114966
# 处理住院记录 93500/114966
# 处理住院记录 94000/114966
# 处理住院记录 94500/114966
# 处理住院记录 95000/114966
# 处理住院记录 95500/114966
# 处理住院记录 96000/114966
# 处理住院记录 96500/114966
# 处理住院记录 97000/114966
# 处理住院记录 97500/114966
# 处理住院记录 98000/114966
# 处理住院记录 98500/114966
# 处理住院记录 99000/114966
# 处理住院记录 99500/114966
# 处理住院记录 100000/114966
# 处理住院记录 100500/114966
# 处理住院记录 101000/114966
# 处理住院记录 101500/114966
# 处理住院记录 102000/114966
# 处理住院记录 102500/114966
# 处理住院记录 103000/114966
# 处理住院记录 103500/114966
# 处理住院记录 104000/114966
# 处理住院记录 104500/114966
# 处理住院记录 105000/114966
# 处理住院记录 105500/114966
# 处理住院记录 106000/114966
# 处理住院记录 106500/114966
# 处理住院记录 107000/114966
# 处理住院记录 107500/114966
# 处理住院记录 108000/114966
# 处理住院记录 108500/114966
# 处理住院记录 109000/114966
# 处理住院记录 109500/114966
# 处理住院记录 110000/114966
# 处理住院记录 110500/114966
# 处理住院记录 111000/114966
# 处理住院记录 111500/114966
# 处理住院记录 112000/114966
# 处理住院记录 112500/114966
# 处理住院记录 113000/114966
# 处理住院记录 113500/114966
# 处理住院记录 114000/114966
# 处理住院记录 114500/114966
# 给药日历创建完成，共 114966 条住院记录
# 检查4QAD条件...
# 已处理 1000/105321 个血培养窗口
# 已处理 2000/105321 个血培养窗口
# 已处理 3000/105321 个血培养窗口
# 已处理 4000/105321 个血培养窗口
# 已处理 5000/105321 个血培养窗口
# 已处理 6000/105321 个血培养窗口
# 已处理 7000/105321 个血培养窗口
# 已处理 9000/105321 个血培养窗口
# 已处理 10000/105321 个血培养窗口
# 已处理 11000/105321 个血培养窗口
# 已处理 12000/105321 个血培养窗口
# 已处理 13000/105321 个血培养窗口
# 已处理 15000/105321 个血培养窗口
# 已处理 17000/105321 个血培养窗口
# 已处理 18000/105321 个血培养窗口
# 已处理 19000/105321 个血培养窗口
# 已处理 20000/105321 个血培养窗口
# 已处理 22000/105321 个血培养窗口
# 已处理 23000/105321 个血培养窗口
# 已处理 25000/105321 个血培养窗口
行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 325997 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 128523 行记录
# 窗口期数据处理完成，共 128523 行记录
# 创建病人给药日历...
# 总共 68326 条住院记录需要处理
# 处理住院记录 1/68326
# 处理住院记录 500/68326
# 处理住院记录 1000/68326
# 处理住院记录 1500/68326
# 处理住院记录 2000/68326
# 处理住院记录 2500/68326
# 处理住院记录 3000/68326
# 处理住院记录 3500/68326
# 处理住院记录 4000/68326
# 处理住院记录 4500/68326
# 处理住院记录 5000/68326
# 处理住院记录 5500/68326
# 处理住院记录 6000/68326
# 处理住院记录 6500/68326
# 处理住院记录 7000/68326
# 处理住院记录 7500/68326
# 处理住院记录 8000/68326
# 处理住院记录 8500/68326
# 处理住院记录 9000/68326
# 处理住院记录 9500/68326
# 处理住院记录 10000/68326
# 处理住院记录 10500/68326
# 处理住院记录 11000/68326
# 处理住院记录 11500/68326
# 处理住院记录 12000/68326
# 处理住院记录 12500/68326
# 处理住院记录 13000/68326
# 处理住院记录 13500/68326
# 处理住院记录 14000/68326
# 处理住院记录 14500/68326
# 处理住院记录 15000/68326
# 处理住院记录 15500/68326
# 处理住院记录 16000/68326
# 处理住院记录 16500/68326
# 处理住院记录 17000/68326
# 处理住院记录 17500/68326
# 处理住院记录 18000/68326
# 处理住院记录 18500/68326
# 处理住院记录 19000/68326
# 处理住院记录 19500/68326
# 处理住院记录 20000/68326
# 处理住院记录 20500/68326
# 处理住院记录 21000/68326
# 处理住院记录 21500/68326
# 处理住院记录 22000/68326
# 处理住院记录 22500/68326
# 处理住院记录 23000/68326
# 处理住院记录 23500/68326
# 处理住院记录 24000/68326
# 处理住院记录 24500/68326
# 处理住院记录 25000/68326
# 处理住院记录 25500/68326
# 处理住院记录 26000/68326
# 处理住院记录 26500/68326
# 处理住院记录 27000/68326
# 处理住院记录 27500/68326
# 处理住院记录 28000/68326
# 处理住院记录 28500/68326
# 处理住院记录 29000/68326
# 处理住院记录 29500/68326
# 处理住院记录 30000/68326
# 处理住院记录 30500/68326
# 处理住院记录 31000/68326
# 处理住院记录 31500/68326
# 处理住院记录 32000/68326
# 处理住院记录 32500/68326
# 处理住院记录 33000/68326
# 处理住院记录 33500/68326
# 处理住院记录 34000/68326
# 处理住院记录 34500/68326
# 处理住院记录 35000/68326
# 处理住院记录 35500/68326
# 处理住院记录 36000/68326
# 处理住院记录 36500/68326
# 处理住院记录 37000/68326
# 处理住院记录 37500/68326
# 处理住院记录 38000/68326
# 处理住院记录 38500/68326
# 处理住院记录 39000/68326
# 处理住院记录 39500/68326
# 处理住院记录 40000/68326
# 处理住院记录 40500/68326
# 处理住院记录 41000/68326
# 处理住院记录 41500/68326
# 处理住院记录 42000/68326
# 处理住院记录 42500/68326
# 处理住院记录 43000/68326
# 处理住院记录 43500/68326
# 处理住院记录 44000/68326
# 处理住院记录 44500/68326
# 处理住院记录 45000/68326
# 处理住院记录 45500/68326
# 处理住院记录 46000/68326
# 处理住院记录 46500/68326
# 处理住院记录 47000/68326
# 处理住院记录 47500/68326
# 处理住院记录 48000/68326
# 处理住院记录 48500/68326
# 处理住院记录 49000/68326
# 处理住院记录 49500/68326
# 处理住院记录 50000/68326
# 处理住院记录 50500/68326
# 处理住院记录 51000/68326
# 处理住院记录 51500/68326
# 处理住院记录 52000/68326
# 处理住院记录 52500/68326
# 处理住院记录 53000/68326
# 处理住院记录 53500/68326
# 处理住院记录 54000/68326
# 处理住院记录 54500/68326
# 处理住院记录 55000/68326
# 处理住院记录 55500/68326
# 处理住院记录 56000/68326
# 处理住院记录 56500/68326
# 处理住院记录 57000/68326
# 处理住院记录 57500/68326
# 处理住院记录 58000/68326
# 处理住院记录 58500/68326
# 处理住院记录 59000/68326
# 处理住院记录 59500/68326
# 处理住院记录 60000/68326
# 处理住院记录 60500/68326
# 处理住院记录 61000/68326
# 处理住院记录 61500/68326
# 处理住院记录 62000/68326
# 处理住院记录 62500/68326
# 处理住院记录 63000/68326
# 处理住院记录 63500/68326
# 处理住院记录 64000/68326
# 处理住院记录 64500/68326
# 处理住院记录 65000/68326
# 处理住院记录 65500/68326
# 处理住院记录 66000/68326
# 处理住院记录 66500/68326
# 处理住院记录 67000/68326
# 处理住院记录 67500/68326
# 处理住院记录 68000/68326
# 给药日历创建完成，共 68326 条住院记录
# 检查4QAD条件...
# 已处理 1000/128523 个血培养窗口
# 已处理 2000/128523 个血培养窗口
# 已处理 3000/128523 个血培养窗口
# 已处理 4000/128523 个血培养窗口
# 已处理 7000/128523 个血培养窗口
# 已处理 8000/128523 个血培养窗口
# 已处理 12000/128523 个血培养窗口
# 已处理 13000/128523 个血培养窗口
# 已处理 14000/128523 个血培养窗口
# 已处理 15000/128523 个血培养窗口
# 已处理 16000/128523 个血培养窗口
# 已处理 17000/128523 个血培养窗口
# 已处理 18000/128523 个血培养窗口
# 已处理 20000/128523 个血培养窗口
# 已处理 21000/128523 个血培养窗口
# 已处理 22000/128523 个血培养窗口
# 已处理 24000/128523 个血培养窗口
# 已处理 25000/128523 个血培养窗口
# 已处理 26000/128523 个血培养窗口
# 已处理 27000/128523 个血培养窗口
# 已处理 28000/128523 个血培养窗口
# 已处理 30000/128523 个血培养窗口
# 已处理 32000/128523 个血培养窗口
# 已处理 33000/128523 个血培养窗口
# 已处理 34000/128523 个血培养窗口
# 已处理 35000/128523 个血培养窗口
# 已处理 36000/128523 个血培养窗口
# 已处理 38000/128523 个血培养窗口
# 已处理 39000/128523 个血培养窗口
# 已处理 40000/128523 个血培养窗口
# 已处理 41000/128523 个血培养窗口
# 已处理 42000/128523 个血培养窗口
# 已处理 43000/128523 个血培养窗口
# 已处理 44000/128523 个血培养窗口
# 已处理 46000/128523 个血培养窗口
# 已处理 47000/128523 个血培养窗口
# 已处理 48000/128523 个血培养窗口
# 已处理 49000/128523 个血培养窗口
# 已处理 61000/128523 个血培养窗口
# 已处理 62000/128523 个血培养窗口
# 已处理 63000/128523 个血培养窗口
# 已处理 65000/128523 个血培养窗口
# 已处理 66000/128523 个血培养窗口
# 已处理 67000/128523 个血培养窗口
# 已处理 68000/128523 个血培养窗口
# 已处理 69000/128523 个血培养窗口
# 已处理 70000/128523 个血培养窗口
# 已处理 83000/128523 个血培养窗口
# 已处理 84000/128523 个血培养窗口
# 已处理 85000/128523 个血培养窗口
# 已处理 86000/128523 个血培养窗口
# 已处理 87000/128523 个血培养窗口
# 已处理 88000/128523 个血培养窗口
# 已处理 89000/128523 个血培养窗口
# 已处理 91000/128523 个血培养窗口
# 已处理 93000/128523 个血培养窗口
# 已处理 94000/128523 个血培养窗口
# 已处理 95000/128523 个血培养窗口
# 已处理 96000/128523 个血培养窗口
# 已处理 113000/128523 个血培养窗口
# 已处理 116000/128523 个血培养窗口
# 已处理 117000/128523 个血培养窗口
# 已处理 118000/128523 个血培养窗口
# 已处理 119000/128523 个血培养窗口
# 找到 4680 个满足4QAD条件的记录
# 去重后保留 3653 条记录 (去除了 1027 条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2007/Presumed_Infection_List_2007.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2007/Presumed_Infection_List_2007.txt
#
# === 统计信息 ===
# 总血培养窗口数: 128523
# 满足4QAD条件: 4680 (3.6%)
# 去重后唯一病人数: 3653
#
# Cluster分布:
#   NTEC: 760 个病人 (20.8%)
#   KCC: 661 个病人 (18.1%)
#   KWC: 637 个病人 (17.4%)
#   HKEC: 582 个病人 (15.9%)
#   NTWC: 483 个病人 (13.2%)
#   KEC: 390 个病人 (10.7%)
#   HKWC: 140 个病人 (3.8%)
#
# 处理年份: 2008
# 加载抗生素数据...
# 找到 15 个抗生素数据文件
# 数据清洗...
# 移除了 413114 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 410808 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 146415 行记录
# 窗口期数据处理完成，共 146415 行记录
# 创建病人给药日历...
# 总共 81663 条住院记录需要处理
# 处理住院记录 1/81663
# 处理住院记录 500/81663
# 处理住院记录 1000/81663
# 处理住院记录 1500/81663
# 处理住院记录 2000/81663
# 处理住院记录 2500/81663
# 处理住院记录 3000/81663
# 处理住院记录 3500/81663
# 处理住院记录 4000/81663
# 处理住院记录 4500/81663
# 处理住院记录 5000/81663
# 处理住院记录 5500/81663
# 处理住院记录 6000/81663
# 处理住院记录 6500/81663
# 处理住院记录 7000/81663
# 处理住院记录 7500/81663
# 处理住院记录 8000/81663
# 处理住院记录 8500/81663
# 处理住院记录 9000/81663
# 处理住院记录 9500/81663
# 处理住院记录 10000/81663
# 处理住院记录 10500/81663
# 处理住院记录 11000/81663
# 处理住院记录 11500/81663
# 处理住院记录 12000/81663
# 处理住院记录 12500/81663
# 处理住院记录 13000/81663
# 处理住院记录 13500/81663
# 处理住院记录 14000/81663
# 处理住院记录 14500/81663
# 处理住院记录 15000/81663
# 处理住院记录 15500/81663
# 处理住院记录 16000/81663
# 处理住院记录 16500/81663
# 处理住院记录 17000/81663
# 处理住院记录 17500/81663
# 处理住院记录 18000/81663
# 处理住院记录 18500/81663
# 处理住院记录 19000/81663
# 处理住院记录 19500/81663
# 处理住院记录 20000/81663
# 处理住院记录 20500/81663
# 处理住院记录 21000/81663
# 处理住院记录 21500/81663
# 处理住院记录 22000/81663
# 处理住院记录 22500/81663
# 处理住院记录 23000/81663
# 处理住院记录 23500/81663
# 处理住院记录 24000/81663
# 处理住院记录 24500/81663
# 处理住院记录 25000/81663
# 处理住院记录 25500/81663
# 处理住院记录 26000/81663
# 处理住院记录 26500/81663
# 处理住院记录 27000/81663
# 处理住院记录 27500/81663
# 处理住院记录 28000/81663
# 处理住院记录 28500/81663
# 处理住院记录 29000/81663
# 处理住院记录 29500/81663
# 处理住院记录 30000/81663
# 处理住院记录 30500/81663
# 处理住院记录 31000/81663
# 处理住院记录 31500/81663
# 处理住院记录 32000/81663
# 处理住院记录 32500/81663
# 处理住院记录 33000/81663
# 处理住院记录 33500/81663
# 处理住院记录 34000/81663
# 处理住院记录 34500/81663
# 处理住院记录 35000/81663
# 处理住院记录 35500/81663
# 处理住院记录 36000/81663
# 处理住院记录 36500/81663
# 处理住院记录 37000/81663
# 处理住院记录 37500/81663
# 处理住院记录 38000/81663
# 处理住院记录 38500/81663
# 处理住院记录 39000/81663
# 处理住院记录 39500/81663
# 处理住院记录 40000/81663
# 处理住院记录 40500/81663
# 处理住院记录 41000/81663
# 处理住院记录 41500/81663
# 处理住院记录 42000/81663
# 处理住院记录 42500/81663
# 处理住院记录 43000/81663
# 处理住院记录 43500/81663
# 处理住院记录 44000/81663
# 处理住院记录 44500/81663
# 处理住院记录 45000/81663
# 处理住院记录 45500/81663
# 处理住院记录 46000/81663
# 处理住院记录 46500/81663
# 处理住院记录 47000/81663
# 处理住院记录 47500/81663
# 处理住院记录 48000/81663
# 处理住院记录 48500/81663
# 处理住院记录 49000/81663
# 处理住院记录 49500/81663
# 处理住院记录 50000/81663
# 处理住院记录 50500/81663
# 处理住院记录 51000/81663
# 处理住院记录 51500/81663
# 处理住院记录 52000/81663
# 处理住院记录 52500/81663
# 处理住院记录 53000/81663
# 处理住院记录 53500/81663
# 处理住院记录 54000/81663
# 处理住院记录 54500/81663
# 处理住院记录 55000/81663
# 处理住院记录 55500/81663
# 处理住院记录 56000/81663
# 处理住院记录 56500/81663
# 处理住院记录 57000/81663
# 处理住院记录 57500/81663
# 处理住院记录 58000/81663
# 处理住院记录 58500/81663
# 处理住院记录 59000/81663
# 处理住院记录 59500/81663
# 处理住院记录 60000/81663
# 处理住院记录 60500/81663
# 处理住院记录 61000/81663
# 处理住院记录 61500/81663
# 处理住院记录 62000/81663
# 处理住院记录 62500/81663
# 处理住院记录 63000/81663
# 处理住院记录 63500/81663
# 处理住院记录 64000/81663
# 处理住院记录 64500/81663
# 处理住院记录 65000/81663
# 处理住院记录 65500/81663
# 处理住院记录 66000/81663
# 处理住院记录 66500/81663
# 处理住院记录 67000/81663
# 处理住院记录 67500/81663
# 处理住院记录 68000/81663
# 处理住院记录 68500/81663
# 处理住院记录 69000/81663
# 处理住院记录 69500/81663
# 处理住院记录 70000/81663
# 处理住院记录 70500/81663
# 处理住院记录 71000/81663
# 处理住院记录 71500/81663
# 处理住院记录 72000/81663
# 处理住院记录 72500/81663
# 处理住院记录 73000/81663
# 处理住院记录 73500/81663
# 处理住院记录 74000/81663
# 处理住院记录 74500/81663
# 处理住院记录 75000/81663
# 处理住院记录 75500/81663
# 处理住院记录 76000/81663
条重复记录)
# CSV文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_csv/2008/Presumed_Infection_List_2008.csv
# TXT文件已保存: ./presumed_infection/2.Data/Output/Presumedinfection_txt/2008/Presumed_Infection_List_2008.txt
#
# === 统计信息 ===
# 总血培养窗口数: 146415
# 满足4QAD条件: 6816 (4.7%)
# 去重后唯一病人数: 5126
#
# Cluster分布:
#   KWC: 1516 个病人 (29.6%)
#   NTEC: 1051 个病人 (20.5%)
#   KCC: 780 个病人 (15.2%)
#   HKEC: 625 个病人 (12.2%)
#   NTWC: 446 个病人 (8.7%)
#   KEC: 426 个病人 (8.3%)
#   HKWC: 282 个病人 (5.5%)
#
# 处理年份: 2009
# 加载抗生素数据...
# 找到 18 个抗生素数据文件
# 数据清洗...
# 移除了 578696 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 591954 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 66324 行记录
# 窗口期数据处理完成，共 66324 行记录
# 创建病人给药日历...
# 总共 112823 条住院记录需要处理
# 处理住院记录 1/112823
# 处理住院记录 500/112823
# 处理住院记录 1000/112823
# 处理住院记录 1500/112823
# 处理住院记录 2000/112823
# 处理住院记录 2500/112823
# 处理住院记录 3000/112823
# 处理住院记录 3500/112823
# 处理住院记录 4000/112823
# 处理住院记录 4500/112823
# 处理住院记录 5000/112823
# 处理住院记录 5500/112823
# 处理住院记录 6000/112823
# 处理住院记录 6500/112823
# 处理住院记录 7000/112823
# 处理住院记录 7500/112823
# 处理住院记录 8000/112823
# 处理住院记录 8500/112823
# 处理住院记录 9000/112823
# 处理住院记录 9500/112823
# 处理住院记录 10000/112823
# 处理住院记录 10500/112823
# 处理住院记录 11000/112823
# 处理住院记录 11500/112823
# 处理住院记录 12000/112823
# 处理住院记录 12500/112823
# 处理住院记录 13000/112823
# 处理住院记录 13500/112823
# 处理住院记录 14000/112823
# 处理住院记录 14500/112823
# 处理住院记录 15000/112823
# 处理住院记录 15500/112823
# 处理住院记录 16000/112823
# 处理住院记录 16500/112823
# 处理住院记录 17000/112823
# 处理住院记录 17500/112823
# 处理住院记录 18000/112823
# 处理住院记录 18500/112823
# 处理住院记录 19000/112823
# 处理住院记录 19500/112823
# 处理住院记录 20000/112823
# 处理住院记录 20500/112823
# 处理住院记录 21000/112823
# 处理住院记录 21500/112823
# 处理住院记录 22000/112823
# 处理住院记录 22500/112823
# 处理住院记录 23000/112823
# 处理住院记录 23500/112823
# 处理住院记录 24000/112823
# 处理住院记录 24500/112823
# 处理住院记录 25000/112823
# 处理住院记录 25500/112823
# 处理住院记录 26000/112823
# 处理住院记录 26500/112823
# 处理住院记录 27000/112823
# 处理住院记录 27500/112823
# 处理住院记录 28000/112823
# 处理住院记录 28500/112823
# 处理住院记录 29000/112823
# 处理住院记录 29500/112823
# 处理住院记录 30000/112823
# 处理住院记录 30500/112823
# 处理住院记录 31000/112823
# 处理住院记录 31500/112823
# 处理住院记录 32000/112823
# 处理住院记录 32500/112823
# 处理住院记录 33000/112823
# 处理住院记录 33500/112823
# 处理住院记录 34000/112823
# 处理住院记录 34500/112823
# 处理住院记录 35000/112823
# 处理住院记录 35500/112823
# 处理住院记录 36000/112823
# 处理住院记录 36500/112823
# 处理住院记录 37000/112823
# 处理住院记录 37500/112823
# 处理住院记录 38000/112823
# 处理住院记录 38500/112823
# 处理住院记录 39000/112823
# 处理住院记录 39500/112823
# 处理住院记录 40000/112823
# 处理住院记录 40500/112823
# ...
#   KEC: 5276 个病人 (4.3%)
#
# 处理年份: 2023
# 加载抗生素数据...
# 找到 48 个抗生素数据文件
# 数据清洗...
# 移除了 4852 行给药途径不在['PARENTERAL', 'ORAL', 'INTRAVENOUS']范围内的记录
# 抗生素数据处理完成，共 3205509 行记录
# 加载窗口期数据...
# 找到 1 个窗口期数据文件
# 窗口期数据加载完成，共 238782 行记录
# 窗口期数据处理完成，共 238782 行记录
# 创建病人给药日历...
# 总共 228686 条住院记录需要处理
# 处理住院记录 1/228686
# 处理住院记录 500/228686
# 处理住院记录 1000/228686
# 处理住院记录 1500/228686
# 处理住院记录 2000/228686
# 处理住院记录 2500/228686
# 处理住院记录 3000/228686
# 处理住院记录 3500/228686
# 处理住院记录 4000/228686
# 处理住院记录 4500/228686
# 处理住院记录 5000/228686
# 处理住院记录 5500/228686
# 处理住院记录 6000/228686
# 处理住院记录 6500/228686
# 处理住院记录 7000/228686
# 处理住院记录 7500/228686
# 处理住院记录 8000/228686
# 处理住院记录 8500/228686
# 处理住院记录 9000/228686
# 处理住院记录 9500/228686
# 处理住院记录 10000/228686
# 处理住院记录 10500/228686
# 处理住院记录 11000/228686
# 处理住院记录 11500/228686
# 处理住院记录 12000/228686
# 处理住院记录 12500/228686
# 处理住院记录 13000/228686
# 处理住院记录 13500/228686
# 处理住院记录 14000/228686
# 处理住院记录 14500/228686
# 处理住院记录 15000/228686
# 处理住院记录 15500/228686
# 处理住院记录 16000/228686
# 处理住院记录 16500/228686
# 处理住院记录 17000/228686
# 处理住院记录 17500/228686
# 处理住院记录 18000/228686
# 处理住院记录 18500/228686
# 处理住院记录 19000/228686
# 处理住院记录 19500/228686
# 处理住院记录 20000/228686
# 处理住院记录 20500/228686
# 处理住院记录 21000/228686
# 处理住院记录 21500/228686
# 处理住院记录 22000/228686
# 处理住院记录 22500/228686
# 处理住院记录 23000/228686
# 处理住院记录 23500/228686
# 处理住院记录 24000/228686
# 处理住院记录 24500/228686
# 处理住院记录 25000/228686
# 处理住院记录 25500/228686
# 处理住院记录 26000/228686
# 处理住院记录 26500/228686
# 处理住院记录 27000/228686
# 处理住院记录 27500/228686
# 处理住院记录 28000/228686
# 处理住院记录 28500/228686
# 处理住院记录 29000/228686
# 处理住院记录 29500/228686
# 处理住院记录 30000/228686
# 处理住院记录 30500/228686
# 处理住院记录 31000/228686
# 处理住院记录 31500/228686
# 处理住院记录 32000/228686
# 处理住院记录 32500/228686
# 处理住院记录 33000/228686
# 处理住院记录 33500/228686
# 处理住院记录 34000/228686
# 处理住院记录 34500/228686
# 处理住院记录 35000/228686
# 处理住院记录 35500/228686
# 处理住院记录 36000/228686
# 处理住院记录 191500/228686
# 处理住院记录 192000/228686
# 处理住院记录 192500/228686
# 处理住院记录 193000/228686
# 处理住院记录 193500/228686
# 处理住院记录 194000/228686
# 处理住院记录 194500/228686
# 处理住院记录 195000/228686
# 处理住院记录 195500/228686
# 处理住院记录 196000/228686
# 处理住院记录 196500/228686
# 处理住院记录 197000/228686
# 处理住院记录 197500/228686
# 处理住院记录 198000/228686
# 处理住院记录 198500/228686
# 处理住院记录 199000/228686
# 处理住院记录 199500/228686
# 处理住院记录 200000/228686
# 处理住院记录 200500/228686
# 处理住院记录 201000/228686
# 处理住院记录 201500/228686
# 处理住院记录 202000/228686
# 处理住院记录 202500/228686
# 处理住院记录 203000/228686
# 处理住院记录 203500/228686
# 处理住院记录 204000/228686
# 处理住院记录 204500/228686
# 处理住院记录 205000/228686
# 处理住院记录 205500/228686
# 处理住院记录 206000/228686
# 处理住院记录 206500/228686
# 处理住院记录 207000/228686
# 处理住院记录 207500/228686
# 处理住院记录 208000/228686
# 处理住院记录 208500/228686
# 处理住院记录 209000/228686
# 处理住院记录 209500/228686
# 处理住院记录 210000/228686
# 处理住院记录 210500/228686
# 处理住院记录 211000/228686
# 处理住院记录 211500/228686
# 处理住院记录 212000/228686
# 处理住院记录 212500/228686
# 处理住院记录 213000/228686
# 处理住院记录 213500/228686
# 处理住院记录 214000/228686
# 处理住院记录 214500/228686
# 处理住院记录 215000/228686
# 处理住院记录 215500/228686
# 处理住院记录 216000/228686
# 处理住院记录 216500/228686
# 处理住院记录 217000/228686
# 处理住院记录 217500/228686
# 处理住院记录 218000/228686
# 处理住院记录 218500/228686
# 处理住院记录 219000/228686
# 处理住院记录 219500/228686
# 处理住院记录 220000/228686
# 处理住院记录 220500/228686
# 处理住院记录 221000/228686
# 处理住院记录 221500/228686
# 处理住院记录 222000/228686
# 处理住院记录 222500/228686
# 处理住院记录 223000/228686
# 处理住院记录 223500/228686
# 处理住院记录 224000/228686
# 处理住院记录 224500/228686
# 处理住院记录 225000/228686
# 处理住院记录 225500/228686
# 处理住院记录 226000/228686
# 处理住院记录 226500/228686
# 处理住院记录 227000/228686
# 处理住院记录 227500/228686
# 处理住院记录 228000/228686
# 处理住院记录 228500/228686
# 给药日历创建完成，共 228686 条住院记录
# 检查4QAD条件...
# 已处理 1000/238782 个血培养窗口
# 已处理 2000/238782 个血培养窗口
# 已处理 3000/238782 个血培养窗口
# 已处理 4000/238782 个血培养窗口
# 已处理 5000/238782 个血培养窗口
# 已处理 6000/238782 个血培养窗口
# 已处理 8000/238782 个血培养窗口
# 已处理 9000/238782 个血培养窗口
# 已处理 10000/238782 个血培养窗口
# 已处理 11000/238782 个血培养窗口
# 已处理 12000/238782 个血培养窗口
# 已处理 13000/238782 个血培养窗口
# 已处理 14000/238782 个血培养窗口
# 已处理 15000/238782 个血培养窗口
# 已处理 16000/238782 个血培养窗口
# 已处理 17000/238782 个血培养窗口
# 已处理 18000/238782 个血培养窗口
# 已处理 19000/238782 个血培养窗口
# 已处理 20000/238782 个血培养窗口
